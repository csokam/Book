# %% [markdown]
# # Google News híreinek kigyűjtése

# %% [markdown]
# ## Szükséges modulok telepítése és importálása

# %%
# %pip install bs4

# %%
import os
import csv
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## Felugró ablak kezelése
#
# Inspect -> Application -> Cookies ->news.google.com -> <b>CONSENT</b> elmentése, majd lekérés indításánál <code>header</code> paraméterként megadva az első indításkor felugró ablakot tudjuk lekezelni.

# %%
headers = {"Cookie": "WP.289daa"}

url = "https://news.google.com/home?hl=hu&gl=HU&ceid=HU:hu"
page = requests.get(url, headers=headers)
soup = bs(page.text, "html.parser")

print(soup)

with open("sample_google_news.html", "w", encoding="utf-8") as file:
    file.write(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="hu"><head><base href="https://news.google.com/"/><link href="//www.gstatic.com" ref="preconnect"/><meta content="origin" name="referrer"/><link href="https://news.google.com/home" rel="canonical"/><meta content="width=device-width,initial-scale=1,minimal-ui" name="viewport"/><meta content="AcBy5YFny2HQgVUCR18tO5YUTf6MpVlcJqGTd-a9-SI" name="google-site-verification"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="Hírek" name="application-name"/><meta content="Hírek" name="apple-mobile-web-app-title"/><meta content="black" name="apple-mobile-web-app-status-bar-style"/><meta content="white" name="theme-color"/><meta content="no" name="msapplication-tap-highlight"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w16" rel="shortcut icon" sizes="16x16"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w24" rel="shortcut icon" sizes="24x24"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w32" rel="shortcut icon" sizes="32x32"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w48" rel="shortcut icon" sizes="48x48"/><link href="//www.gstatic.com" rel="preconnect"/><link href="//fonts.gstatic.com" rel="preconnect"/><link href="//lh3.googleusercontent.com" rel="preconnect"/><link href="//lh4.googleusercontent.com" rel="preconnect"/><link href="//lh5.googleusercontent.com" rel="preconnect"/><link href="//lh6.googleusercontent.com" rel="preconnect"/><link href="//ssl.gstatic.com" rel="preconnect"/><link href="https://www.google-analytics.com/analytics.js" rel="preconnect"/><link href="https://fonts.googleapis.com/css?family=Google+Sans+Text:400,500,700,400i,500i,700i" rel="stylesheet"/><link crossorigin="use-credentials" href="_/DotsSplashUi/manifest.json" rel="manifest"/><link href="/?lfhs=2" rel="home"/><link href="/?lfhs=2" rel="msapplication-starturl"/><link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="icon" sizes="192x192"/><link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="apple-touch-icon-precomposed" sizes="192x192"/><link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="msapplication-square192x192logo" sizes="192x192"/><link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="icon" sizes="512x512"/><link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="apple-touch-icon-precomposed" sizes="512x512"/><link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="msapplication-square512x512logo" sizes="512x512"/><link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="icon" sizes="1024x1024"/><link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="apple-touch-icon-precomposed" sizes="1024x1024"/><link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="msapplication-square1024x1024logo" sizes="1024x1024"/><link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="icon" sizes="120x120"/><link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="msapplication-square120x120logo" sizes="120x120"/><link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="icon" sizes="152x152"/><link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="msapplication-square152x152logo" sizes="152x152"/><link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="icon" sizes="167x167"/><link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="apple-touch-icon-precomposed" sizes="167x167"/><link href="//ssl.gstatic ...
# a.l=function(e){function g(b){var c={};c[b]=k();a.cc_latency.push(c)}function m(b){var c=n("iml");b.setAttribute("data-iml",c);return c}a.cc_aid=e;a.iml_start=a.cc_latency_start_time;a.css_size=0;a.cc_latency=[];a.ccTick=g;a.onJsLoad=function(){g("jsl")};a.onCssLoad=function(){g("cssl")};a._isVisible=function(b,c){if(!c||c.style.display=="none")return!1;var f=b.defaultView;if(f&&f.getComputedStyle&&(f=f.getComputedStyle(c),f.height=="0px"||f.width=="0px"||f.visibility=="hidden"))return!1;if(!c.getBoundingClientRect)return!0;
# var h=c.getBoundingClientRect();c=h.left+a.pageXOffset;f=h.top+a.pageYOffset;if(f+h.height<0||c+h.width<0||h.height<=0||h.width<=0)return!1;b=b.documentElement;return f<=(a.innerHeight||b.clientHeight)&&c<=(a.innerWidth||b.clientWidth)};a._recordImlEl=m;document.documentElement.addEventListener("load",function(b){b=b.target;var c;b.tagName!="IMG"||b.hasAttribute("data-iid")||a._isLazyImage(b)||b.hasAttribute("data-noaft")||(c=m(b));if(a.aft_counter&&(b=a.aft_counter.indexOf(b),b!==-1&&(b=a.aft_counter.splice(b,
# 1).length===1,a.aft_counter.length===0&&b&&c)))a.onaft(c)},!0);a.prt=-1;a.wiz_tick=function(){var b=n("prt");a.prt=b}};}).call(this);
# l('lszMMd')</script><script nonce="BchWCSuOimYDKipP6iIXOg">var _F_cssRowKey = 'boq-dots.DotsSplashUi_desktop_ms.KaIGLacVYjs.L.W.O';var _F_combinedSignature = 'ALs0n2M3IOdMC0XBbmGcNkJP3V2mM80Pyw';function _DumpException(e) {throw e;}</script><style data-href="https://www.gstatic.com/_/mss/boq-dots/_/ss/k=boq-dots.DotsSplashUi_desktop_ms.KaIGLacVYjs.L.W.O/am=CEAgAIPOAgMwAg/d=1/ed=1/rs=ALs0n2OdsOPDzMber237yw4dwdjA_D7iFQ/m=homeview,_b,_tp" nonce="flkcLndc3ghdmwagi608TA">html,body{height:100%;overflow:hidden}body{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;color:rgba(0,0,0,.87);font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif;margin:0;-webkit-text-size-adjust:100%;text-size-adjust:100%}textarea{font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif}a{text-decoration:none;color:#2962ff}img{border:none}*{-webkit-tap-highlight-color:transparent}#apps-debug-tracers{display:none}@media all{body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-webkit-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-moz-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-ms-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::placeholder{color:#bdc1c6}}@media all{body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder{color:#bdc1c6}}@media all{body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::-webkit-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::-moz-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::-ms-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::placeholder{color:rgba(232,234,237,.38)}}@media all{body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder{color:rgba(232,234,237,.38)}}@media screen and (forced-colors:active),(-ms-high-contrast:active){body.dm7YTc .Y5O54e .VfPpkd-StrnGf-rymPhb .VfPpkd-StrnGf-rymPhb-ibnC6b-OWXEXe-OWB6Me .VfPpkd-StrnGf-rymPhb-b9t22c,body.dm7YTc .Y5O54e .VfPpkd-StrnGf-rymPhb .VfPpkd-StrnGf-rymPhb-ibnC6b-OWXEXe-OWB6Me .VfPpkd-StrnGf-rymPhb-fpDzbe-fmcmS,body.dm7YTc .Y5O54e .VfPpkd-StrnGf-rymPhb .VfPpkd-StrnGf-rymPhb-ibnC6b-OWXEXe-OWB6Me .VfPpkd-StrnGf-rymPhb-L8ivfd-fmcmS{color:GrayText}body.dm7YTc .Y5O54e .VfPpkd-StrnGf-rymPhb .VfPpkd-StrnGf-rymPhb-ibnC6b-OWXEXe-OWB6Me .VfPpkd-StrnGf-rymPhb-b9t22c{opacity:1}}@media all{body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-webkit-input-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-moz-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-ms-input-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::placeholder{color:#bdc1c6;color:var(--gm-outlinedtextfield-placeholder-color,#bdc1c6)}}@media all{body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder{color:#bdc1c6;color:var(--gm-outlinedtextfield-placeholder-color,#bdc1c6)}}@media all{body.dm7YTc .NGdKgb .VfPpkd-f ...
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# var k=this||self;/*
#
#  Copyright 2024 Google, Inc
#  SPDX-License-Identifier: MIT
# */
# var l=["focus","blur","error","load","toggle"];function m(a){return a==="mouseenter"?"mouseover":a==="mouseleave"?"mouseout":a==="pointerenter"?"pointerover":a==="pointerleave"?"pointerout":a};function n(a){this.l={};this.m={};this.i=null;this.g=[];this.o=a}n.prototype.handleEvent=function(a,b,c){q(this,{eventType:a,event:b,targetElement:b.target,eic:c,timeStamp:Date.now(),eia:void 0,eirp:void 0,eiack:void 0})};function q(a,b){if(a.i)a.i(b);else{b.eirp=!0;var c;(c=a.g)==null||c.push(b)}}
# function r(a,b,c){if(!(b in a.l)&&a.o){var f=function(e,p,B){a.handleEvent(e,p,B)};a.l[b]=f;c=m(c||b);if(c!==b){var h=a.m[c]||[];h.push(b);a.m[c]=h}a.o.addEventListener(c,function(e){return function(p){f(b,p,e)}});b==="click"&&r(a,"keydown")}}n.prototype.j=function(a){return this.l[a]};n.prototype.ecrd=function(a){this.i=a;var b;if((b=this.g)==null?0:b.length){for(a=0;a<this.g.length;a++)q(this,this.g[a]);this.g=null}};var t=typeof navigator!=="undefined"&&/iPhone|iPad|iPod/.test(navigator.userAgent);function u(a){this.g=a;this.i=[]}u.prototype.addEventListener=function(a,b){t&&(this.g.style.cursor="pointer");var c=this.i,f=c.push,h=this.g;b=b(this.g);var e=!1;l.indexOf(a)>=0&&(e=!0);h.addEventListener(a,b,e);f.call(c,{eventType:a,j:b,capture:e})};var g="click dblclick focus focusin blur error focusout keydown keyup keypress load mouseover mouseout mouseenter mouseleave submit toggle touchstart touchend touchmove touchcancel auxclick change compositionstart compositionupdate compositionend beforeinput input select textinput copy cut paste mousedown mouseup wheel contextmenu dragover dragenter dragleave drop dragstart dragend pointerdown pointermove pointerup pointercancel pointerenter pointerleave pointerover pointerout gotpointercapture lostpointercapture ended loadedmetadata pagehide pageshow visibilitychange beforematch".split(" ");
# if(!(g instanceof Array)){var v;var w=typeof Symbol!="undefined"&&Symbol.iterator&&g[Symbol.iterator];if(w)v=w.call(g);else if(typeof g.length=="number")v={next:d()};else throw Error(String(g)+" is not an iterable or ArrayLike");for(var x,y=[];!(x=v.next()).done;)y.push(x.value)};var z=function(a){return{trigger:function(b){var c=a.j(b.type);c||(r(a,b.type),c=a.j(b.type));var f=b.target||b.srcElement;c&&c(b.type,b,f.ownerDocument.documentElement)},configure:function(b){b(a)}}}(function(){var a=window,b=new u(a.document.documentElement),c=new n(b);g.forEach(function(e){return r(c,e)});var f,h;"onwebkitanimationend"in a&&(f="webkitAnimationEnd");r(c,"animationend",f);"onwebkittransitionend"in a&&(h="webkitTransitionEnd");r(c,"transitionend",h);return{s:c,u:b}}().s),A=["BOQ_wizbind"],
# C=window||k;A[0]in C||typeof C.execScript=="undefined"||C.execScript("var "+A[0]);for(var D;A.length&&(D=A.shift());)A.length||z===void 0?C[D]&&C[D]!==Object.prototype[D]?C=C[D]:C=C[D]={}:C[D]=z;}).call(this);
# </script><script href="https://www.gstatic.com/_/mss/boq-dots/_/js/k=boq-dots.DotsSplashUi_desktop_ms.hu.xuZWU8BTLco.es5.O/am=CEAgAIPOAgMwAg/d=1/excm=_b,_tp,homeview/ed=1/dg=0/wt=2/ujg=1/rs=ALs0n2M6A1tZV3qBslhLI_Ze5vSN8WX7lw/m=_b,_tp" id="base-js" nocollect="" nonce="BchWCSuOimYDKipP6iIXOg">"use strict";this.default_DotsSplashUi_desktop_ms=this.default_DotsSplashUi_desktop_ms||{};(function(_){var window=this;
# try{
# _._F_toggles_initialize=function(a){(typeof globalThis!=="undefined"?globalThis:typeof self!=="undefined"?self:this)._F_toggles=a||[]};(0,_._F_toggles_initialize)([0x204008, 0xc0b3a0c, 0x2300, ]);
# /*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  Copyright 2024 Google, Inc
#  SPDX-License-Identifier: MIT
# */
# var baa,caa,La,gaa,Ua,Wa,haa,iaa,hb,jb,oaa,xb,Db,vaa,Zb,$b,ac,bc,gc,yaa,ic,Baa,Faa,Gaa,xc,Vc,Laa,Maa,Kaa,Oaa,Raa,Qaa,Saa,Taa,Uaa,Xaa,Yaa,$aa,aba,sd,yd,cba,rd,td,hd,iba,Nd,lba,pba,qba,tba,je,ne,yba,Aba,Bba,Cba,Eba,Fba,Jba,Lba,Mba,Pba,Xba,Tba,$ba,ff,bca,cca,eca,uf,kca,lca,Af,Gf,mca,nca,oca,pca,Kf,qca,rca,sca,Rf,Sf,yca,Aca,Bca,Cca,Dca,Eca,Gca,Hca,Lca,aaa,Mca,vg,Nca,xg,Oca,zg,Bg,Pca,Eg,Fg,Gg,Vca,Wca,Og,Pg,Xca,Yca;_.aa=function(a){return function(){return aaa[a].apply(this,arguments)}};
# _.ba=function(a,b){return aaa[a]=b};_.da=function(a){_.ca.setTimeout(function(){throw a;},0)};_.fa=function(a){a&&typeof a.dispose=="function"&&a.dispose()};baa=function(a){for(var b=0,c=arguments.length;b<c;++b){var d=arguments[b];_.ha(d)?baa.apply(null,d):_.fa(d)}};_.ia=function(a,b){if(Error.captureStackTrace)Error.captureStackTrace(this,_.ia);else{var c=Error().stack;c&&(this.stack=c)}a&&(this.message=String(a));b!==void 0&&(this.cause=b);this.o=!0};_.ka=function(a){return a[a.length-1]};
# _.la=function(a,b,c){for(var d=typeof a==="string"?a.split(""):a,e=a.length-1;e>=0;--e)e in d&&b.call(c,d[e],e,a)};_.na=function(a,b,c){b=_.ma(a,b,c);return b<0?null:typeof a==="string"?a.charAt(b):a[b]};_.ma=function(a,b,c){for(var d=a.length,e=typeof a==="string"?a.split(""):a,f=0;f<d;f++)if(f in e&&b.call(c,e[f],f,a))return f;return-1};_.oa=function(a,b){for(var c=typeof a==="string"?a.split(""):a,d=a.length-1;d>=0;d--)if(d in c&&b.call(void 0,c[d],d,a))return d;return-1};
# _.sa=function(a,b){return(0,_.ra)(a,b)>=0};_.ta=function(a,b){_.sa(a,b)||a.push(b)};_.va=function(a,b){b=(0,_.ra)(a,b);var c;(c=b>=0)&&_.ua(a,b);return c};_.ua=function(a,b){return Array.prototype.splice.call(a,b,1).length==1};_.wa=function(a){return Array.prototype.concat.apply([],arguments)};_.ya=function(a){var b=a.length;if(b>0){for(var c=Array(b),d=0;d<b;d++)c[d]=a[d];return c}return[]};
# _.za=function(a,b){for(var c=1;c<arguments.length;c++){var d=arguments[c];if(_.ha(d)){var e=a.length||0,f=d.length||0;a.length=e+f;for(var g=0;g<f;g++)a[e+g]=d[g]}else a.push(d)}};_.Aa=function(a,b,c){return arguments.length<=2?Array.prototype.slice.call(a,b):Array.prototype.slice.call(a,b,c)};_.Da=function(a,b){b=b||a;for(var c=0,d=0,e={};d<a.length;){var f=a[d++],g=_.Ba(f)?"o"+_.Ca(f):(typeof f).charAt(0)+f;Object.prototype.hasOwnProperty.call(e,g)||(e[g]=!0,b[c++]=f)}b.length=c};
# _.Ga=function(a,b){a.sort(b||_.Ea)};_.Ha=function(a,b){if(!_.ha(a)||!_.ha(b)||a.length!=b.length)return!1;for(var c=a.length,d=caa,e=0;e<c;e++)if(!d(a[e],b[e]))return!1;return!0};_.Ea=function(a,b){return a>b?1:a<b?-1:0};caa=function(a,b){return a===b};_.daa=function(a,b){var c={};(0,_.Ia)(a,function(d,e){c[b.call(void 0,d,e,a)]=d});return c};La=function(a){_.Ja?a(_.Ja):Ka.push(a)};_.Oa=function(){!_.Ja&&_.Ma&&_.Na((0,_.Ma)());return _.Ja};
# _.Na=function(a){_.Ja=a;Ka.forEach(function(b){b(_.Ja)});Ka=[]};_.m=function(a){_.Ja&&eaa(a)};_.t=function(){_.Ja&&faa(_.Ja)};gaa=function(){};_.Pa=function(){var a=_.ca.navigator;return a&&(a=a.userAgent)?a:""};Ua=function(a){return Qa?Ra?Ra.brands.some(function(b){return(b=b.brand)&&_.Sa(b,a)}):!1:!1};_.Va=function(a){return _.Sa(_.Pa(),a)};Wa=function(){return Qa?!!Ra&&Ra.brands.length>0:!1};_.Xa=function(){return Wa()?!1:_.Va("Opera")};_.Ya=function(){return Wa()?!1:_.Va("Trident")||_.Va("MSIE")};
# _.Za=function(){return Wa()?!1:_.Va("Edge")};_.$a=function(){return Wa()?Ua("Microsoft Edge"):_.Va("Edg/")};_.ab=function(){return Wa()?Ua("Opera"):_.Va("OPR")};_.bb=function(){return _.Va("Firefox")||_.Va("FxiOS")};_.eb=function(){return _.Va("Safari")&&!(_.cb()||_.db()||_.Xa()||_.Za()||_.$a()||_.ab()||_.bb()||_.Va("Silk")||_.Va("Android"))};_.db=function(){return Wa()?!1:_.Va("Coast")};_.cb=function(){return Wa()?Ua("Chromium"):(_.Va("Chrome")||_.Va("CriOS"))&&!_.Za()||_.Va("Silk")};
# _.fb=function(){return _.Va("Android")&&!(_.cb()||_.bb()||_.Xa()||_.Va("Silk"))};haa=function(a){var b={};a.forEach(function(c){b[c[0]]=c[1]});return function(c){return b[c.find(function(d){return d in b})]||""}};
# iaa=function(a){var b=_.Pa();if(a==="Internet Explorer"){if(_.Ya())if((a=/rv: *([\d\.]*)/.exec(b))&&a[1])b=a[1];else{a="";var c=/MSIE +([\d\.]+)/.exec(b);if(c&&c[1])if(b=/Trident\/(\d.\d)/.exec(b),c[1]=="7.0")if(b&&b[1])switch(b[1]){case "4.0":a="8.0";break;case "5.0":a="9.0";break;case "6.0":a="10.0";break;case "7.0":a="11.0"}else a="7.0";else a=c[1];b=a}else b="";return b}var d=RegExp("([A-Z][\\w ]+)/([^\\s]+)\\s*(?:\\((.*?)\\))?","g");c=[];for(var e;e=d.exec(b);)c.push([e[1],e[2],e[3]||void 0]);
# b=haa(c);switch(a){case "Opera":if(_.Xa())return b(["Version","Opera"]);if(_.ab())return b(["OPR"]);break;case "Microsoft Edge":if(_.Za())return b(["Edge"]);if(_.$a())return b(["Edg"]);break;case "Chromium":if(_.cb())return b(["Chrome","CriOS","HeadlessChrome"])}return a==="Firefox"&&_.bb()||a==="Safari"&&_.eb()||a==="Android Browser"&&_.fb()||a==="Silk"&&_.Va("Silk")?(b=c[2])&&b[1]||"":""};
# _.gb=function(a){if(Wa()&&a!=="Silk"){var b=Ra.brands.find(function(c){return c.brand===a});if(!b||!b.version)return NaN;b=b.version.split(".")}else{b=iaa(a);if(b==="")return NaN;b=b.split(".")}return b.length===0?NaN:Number(b[0])};hb=function(){return Qa?!!Ra&&!!Ra.platform:!1};_.ib=function(){return hb()?Ra.platform==="Android":_.Va("Android")};jb=function(){return _.Va("iPhone")&&!_.Va("iPod")&&!_.Va("iPad")};_.kb=function(){return jb()||_.Va("iPad")||_.Va("iPod")};
# _.mb=function(){return hb()?Ra.platform==="macOS":_.Va("Macintosh")};_.jaa=function(){return hb()?Ra.platform==="Windows":_.Va("Windows")};_.kaa=function(){return hb()?Ra.platform==="Chrome OS":_.Va("CrOS")};_.nb=function(a,b,c){for(var d in a)b.call(c,a[d],d,a)};_.ob=function(a,b){var c={},d;for(d in a)b.call(void 0,a[d],d,a)&&(c[d]=a[d]);return c};_.pb=function(a,b,c){var d={},e;for(e in a)d[e]=b.call(c,a[e],e,a);return d};_.laa=function(a){var b=0,c;for(c in a)b++;return b};_.maa=function(a){for(var b in a)return a[b]};
# _.rb=function(a){var b=[],c=0,d;for(d in a)b[c++]=a[d];return b};_.sb=function(a){var b=[],c=0,d;for(d in a)b[c++]=d;return b};_.ub=function(a){for(var b in a)return!1;return!0};_.vb=function(a){var b={},c;for(c in a)b[c]=a[c];return b};_.wb=function(a,b){for(var c,d,e=1;e<arguments.length;e++){d=arguments[e];for(c in d)a[c]=d[c];for(var f=0;f<naa.length;f++)c=naa[f],Object.prototype.hasOwnProperty.call(d,c)&&(a[c]=d[c])}};
# oaa=function(a){var b=arguments.length;if(b==1&&Array.isArray(arguments[0]))return oaa.apply(null,arguments[0]);for(var c={},d=0;d<b;d++)c[arguments[d]]=!0;return c};xb=function(a){return a.toString().indexOf("`")===-1};_.zb=function(a){if(a instanceof _.yb)return a.j;throw Error("D");};Db=function(a){return new Bb(function(b){return b.substr(0,a.length+1).toLowerCase()===a+":"})};
# _.Eb=function(a,b){b=b===void 0?paa:b;if(a instanceof _.yb)return a;for(var c=0;c<b.length;++c){var d=b[c];if(d instanceof Bb&&d.oe(a))return new _.yb(a)}};_.Gb=function(a){var b=b===void 0?paa:b;return _.Eb(a,b)||_.Fb};_.Hb=function(a){a instanceof _.yb?a=_.zb(a):a=qaa.test(a)?a:void 0;return a};_.Jb=function(a){return new _.Ib(a[0].toLowerCase())};
# _.Nb=function(a){var b=_.Kb.apply(1,arguments);if(b.length===0)return _.Lb(a[0]);for(var c=a[0],d=0;d<b.length;d++)c+=encodeURIComponent(b[d])+a[d+1];return _.Lb(c)};_.Pb=function(a,b){b=_.Hb(b);b!==void 0&&(a.href=b)};_.Sb=function(a,b,c){if(b instanceof _.Qb)a.href=_.Rb(b).toString();else{if(raa.indexOf(c)===-1)throw Error("H`"+c);b=_.Hb(b);if(b===void 0)return;a.href=b}a.rel=c};
# _.Tb=function(a,b){var c,d;return(b=(d=(c=b.document).querySelector)==null?void 0:d.call(c,a+"[nonce]"))?b.nonce||b.getAttribute("nonce")||"":""};_.saa=function(a){var b=_.Tb("script",a.ownerDocument&&a.ownerDocument.defaultView||window);b&&a.setAttribute("nonce",b)};_.Ub=function(a,b){a.src=_.Rb(b);_.saa(a)};_.Vb=function(){var a=Error();taa(a,"incident");_.da(a)};_.Wb=function(a){a=Error(a);taa(a,"warning");return a};
# vaa=function(a){if(!_.uaa)return _.Xb(a);for(var b="",c=0,d=a.length-10240;c<d;)b+=String.fromCharCode.apply(null,a.subarray(c,c+=10240));b+=String.fromCharCode.apply(null,c?a.subarray(c):a);return btoa(b)};_.Yb=function(a){return waa&&a!=null&&a instanceof Uint8Array};Zb=function(){return typeof BigInt==="function"};$b=function(a){return Array.prototype.slice.call(a)};ac=function(a){return typeof Symbol==="function"&&typeof Symbol()==="symbol"?Symbol():a};bc=function(a,b,c){return c?a|b:a&~b};
# _.ec=function(a){return!!((0,_.cc)(a)&2)};gc=function(a){(0,_.fc)(a,34);return a};_.xaa=function(a){(0,_.fc)(a,32);return a};yaa=function(a,b){(0,_.hc)(b,(a|0)&-14591)};ic=function(a,b){(0,_.hc)(b,(a|34)&-14557)};_.jc=function(a){a=a>>14&1023;return a===0?536870912:a};_.kc=function(a){return+!!(a&512)-1};_.lc=function(a){return a.FX===zaa};Baa=function(a){return!(!a||typeof a!=="object"||a.j!==Aaa)};_.mc=function(a){return a!==null&&typeof a==="object"&&!Array.isArray(a)&&a.constructor===Object};
# _.qc=function(a,b,c,d){if(a==null){if(!c)throw Error();}else if(typeof a==="string")a=a?new _.nc(a,_.oc):_.pc();else if(a.constructor!==_.nc)if(_.Yb(a))a=a.length?new _.nc(d?a:new Uint8Array(a),_.oc):_.pc();else{if(!b)throw Error();a=void 0}return a};_.Caa=function(a,b){return!!a&&(Array.isArray(a)?a.includes(b):a.has(b))};_.sc=function(a,b,c){if(!Array.isArray(a)||a.length)return!1;var d=(0,_.cc)(a);if(d&1)return!0;if(!_.Caa(b,c))return!1;(0,_.hc)(a,d|1);return!0};
# _.tc=function(a){if(a&2)throw Error();};_.uc=function(a){if(!Daa)return a.constructor.Ua};_.wc=function(a,b,c){(b=_.vc?b[_.vc]:void 0)?a[_.vc]=$b(b):c&&_.vc&&_.vc in a&&(a[_.vc]=void 0)};_.Ac=function(a){var b=a<0;a=Math.abs(a);var c=a>>>0;a=Math.floor((a-c)/4294967296);b&&(c=_.v(xc(c,a)),b=c.next().value,a=c.next().value,c=b);_.yc=c>>>0;_.zc=a>>>0};_.Eaa=function(a,b){var c=b&2147483648;c&&(a=~a+1>>>0,b=~b>>>0,a==0&&(b=b+1>>>0));a=b*4294967296+(a>>>0);return c?-a:a};
# _.Bc=function(a,b){b>>>=0;a>>>=0;if(b<=2097151)var c=""+(4294967296*b+a);else Zb()?c=""+(BigInt(b)<<BigInt(32)|BigInt(a)):(c=(a>>>24|b<<8)&16777215,b=b>>16&65535,a=(a&16777215)+c*6777216+b*6710656,c+=b*8147497,b*=2,a>=1E7&&(c+=Math.floor(a/1E7),a%=1E7),c>=1E7&&(b+=Math.floor(c/1E7),c%=1E7),c=b+Faa(c)+Faa(a));return c};Faa=function(a){a=String(a);return"0000000".slice(a.length)+a};
# Gaa=function(){var a=_.yc,b=_.zc;b&2147483648?Zb()?a=""+(BigInt(b|0)<<BigInt(32)|BigInt(a>>>0)):(b=_.v(xc(a,b)),a=b.next().value,b=b.next().value,a="-"+_.Bc(a,b)):a=_.Bc(a,b);return a};
# _.Cc=function(a){if(a.length<16)_.Ac(Number(a));else if(Zb())a=BigInt(a),_.yc=Number(a&BigInt(4294967295))>>>0,_.zc=Number(a>>BigInt(32)&BigInt(4294967295));else{var b=+(a[0]==="-");_.zc=_.yc=0;for(var c=a.length,d=b,e=(c-b)%6+b;e<=c;d=e,e+=6)d=Number(a.slice(d,e)),_.zc*=1E6,_.yc=_.yc*1E6+d,_.yc>=4294967296&&(_.zc+=Math.trunc(_.yc/4294967296),_.zc>>>=0,_.yc>>>=0);b&&(b=_.v(xc(_.yc,_.zc)),a=b.next().value,b=b.next().value,_.yc=a,_.zc=b)}};xc=function(a,b){b=~b;a?a=~a+1:b+=1;return[a,b]};
# _.Dc=function(a){if(a!=null&&typeof a!=="number")throw Error("S`"+typeof a+"`"+a);return a};_.Ec=function(a){if(a!=null&&typeof a!=="boolean")throw Error("T`"+Haa(a)+"`"+a);return a};_.Iaa=function(a){if(a==null||typeof a==="boolean")return a;if(typeof a==="number")return!!a};_.Fc=function(a){var b=typeof a;return b==="number"?Number.isFinite(a):b!=="string"?!1:Jaa.test(a)};_.Gc=function(a){if(!Number.isFinite(a))throw _.Wb("enum");return a|0};
# _.Jc=function(a){return a==null?a:Number.isFinite(a)?a|0:void 0};_.Lc=function(a){if(typeof a!=="number")throw _.Wb("int32");if(!Number.isFinite(a))throw _.Wb("int32");return a|0};_.Nc=function(a){return a==null?a:_.Lc(a)};_.Pc=function(a){if(a==null)return a;if(typeof a==="string"){if(!a)return;a=+a}if(typeof a==="number")return Number.isFinite(a)?a|0:void 0};_.Qc=function(a){if(typeof a!=="number")throw _.Wb("uint32");if(!Number.isFinite(a))throw _.Wb("uint32");return a>>>0};
# _.Rc=function(a){if(a==null)return a;if(typeof a==="string"){if(!a)return;a=+a}if(typeof a==="number")return Number.isFinite(a)?a>>>0:void 0};_.Uc=function(a){if(a!=null){var b=!!b;if(!_.Fc(a))throw _.Wb("int64");a=typeof a==="string"?_.Sc(a):b?Kaa(a):_.Tc(a)}return a};Vc=function(a){return a[0]==="-"?!1:a.length<20?!0:a.length===20&&Number(a.substring(0,6))<184467};
# Laa=function(a){return a[0]==="-"?a.length<20?!0:a.length===20&&Number(a.substring(0,7))>-922337:a.length<19?!0:a.length===19&&Number(a.substring(0,6))<922337};Maa=function(a){if(a<0){_.Ac(a);var b=_.Bc(_.yc,_.zc);a=Number(b);return Number.isSafeInteger(a)?a:b}if(Vc(String(a)))return a;_.Ac(a);return _.zc*4294967296+(_.yc>>>0)};_.Tc=function(a){a=Math.trunc(a);Number.isSafeInteger(a)||(_.Ac(a),a=_.Eaa(_.yc,_.zc));return a};_.Wc=function(a){a=Math.trunc(a);return a>=0&&Number.isSafeInteger(a)?a:Maa(a)};
# Kaa=function(a){a=Math.trunc(a);if(Number.isSafeInteger(a))a=String(a);else{var b=String(a);Laa(b)?a=b:(_.Ac(a),a=Gaa())}return a};_.Naa=function(a){a=Math.trunc(a);if(a>=0&&Number.isSafeInteger(a))a=String(a);else{var b=String(a);Vc(b)?a=b:(_.Ac(a),a=_.Bc(_.yc,_.zc))}return a};_.Sc=function(a){var b=Math.trunc(Number(a));if(Number.isSafeInteger(b))return String(b);b=a.indexOf(".");b!==-1&&(a=a.substring(0,b));Laa(a)||(_.Cc(a),a=Gaa());return a};
# _.Xc=function(a){var b=Math.trunc(Number(a));if(Number.isSafeInteger(b)&&b>=0)return String(b);b=a.indexOf(".");b!==-1&&(a=a.substring(0,b));Vc(a)||(_.Cc(a),a=_.Bc(_.yc,_.zc));return a};_.Yc=function(a,b){b=b===void 0?!1:b;if(a==null)return a;if(_.Fc(a))return typeof a==="string"?_.Sc(a):b?Kaa(a):_.Tc(a)};_.Zc=function(a){if(typeof a!=="string")throw Error();return a};_.ad=function(a){if(a!=null&&typeof a!=="string")throw Error();return a};Oaa=function(a){return a==null||typeof a==="string"?a:void 0};
# _.cd=function(a,b,c,d){if(a!=null&&typeof a==="object"&&_.lc(a))return a;if(!Array.isArray(a))return c?d&2?_.bd(b):new b:void 0;var e=c=(0,_.cc)(a);e===0&&(e|=d&32);e|=d&2;e!==c&&(0,_.hc)(a,e);return new b(a)};_.bd=function(a){var b=a[Paa];if(b)return b;b=new a;gc(b.ma);return a[Paa]=b};_.ed=function(a,b){dd=b;a=new a(b);dd=void 0;return a};
# _.w=function(a,b,c){a==null&&(a=dd);dd=void 0;if(a==null){var d=96;c?(a=[c],d|=512):a=[];b&&(d=d&-16760833|(b&1023)<<14)}else{if(!Array.isArray(a))throw Error("U");d=(0,_.cc)(a);if(d&2048)throw Error("V");if(d&64)return a;d|=64;if(c&&(d|=512,c!==a[0]))throw Error("W");a:{c=a;var e=c.length;if(e){var f=e-1;if(_.mc(c[f])){d|=256;b=f-_.kc(d);if(b>=1024)throw Error("X");d=d&-16760833|(b&1023)<<14;break a}}if(b){b=Math.max(b,e-_.kc(d));if(b>1024)throw Error("Y");d=d&-16760833|(b&1023)<<14}}}(0,_.hc)(a,
# d);return a};Raa=function(a,b){return Qaa(b)};Qaa=function(a){switch(typeof a){case "number":return isFinite(a)?a:String(a);case "boolean":return a?1:0;case "object":if(a)if(Array.isArray(a)){if(_.sc(a,void 0,0))return}else{if(_.Yb(a))return vaa(a);if(a instanceof _.nc)return _.fd(a)}}return a};Saa=function(a,b,c){var d=$b(a),e=d.length,f=b&256?d[e-1]:void 0;e+=f?-1:0;for(b=b&512?1:0;b<e;b++)d[b]=c(d[b]);if(f){b=d[b]={};for(var g in f)b[g]=c(f[g])}_.wc(d,a,!1);return d};
# Taa=function(a,b,c,d,e){if(a!=null){if(Array.isArray(a))a=_.sc(a,void 0,0)?void 0:e&&(0,_.cc)(a)&2?a:_.gd(a,b,c,d!==void 0,e);else if(_.mc(a)){var f={},g;for(g in a)f[g]=Taa(a[g],b,c,d,e);a=f}else a=b(a,d);return a}};_.gd=function(a,b,c,d,e){var f=d||c?(0,_.cc)(a):0;d=d?!!(f&32):void 0;for(var g=$b(a),k=0;k<g.length;k++)g[k]=Taa(g[k],b,c,d,e);c&&(_.wc(g,a,!1),c(f,g));return g};
# Uaa=function(a){_.lc(a)?a=hd(a,_.gd(a.ma,Uaa,void 0,void 0,!1),!0):a instanceof _.nc?(a=a.j||"",a=typeof a==="string"?a:new Uint8Array(a)):a=_.Yb(a)?new Uint8Array(a):a;return a};_.Vaa=function(a){return _.lc(a)?a.toJSON():Qaa(a)};
# _.id=function(a,b,c){c=c===void 0?ic:c;if(a!=null){if(waa&&a instanceof Uint8Array)return b?a:new Uint8Array(a);if(Array.isArray(a)){var d=(0,_.cc)(a);d&2||(b&&(b=d===0||!!(d&32)&&!(d&64||!(d&16))),a=b?(0,_.hc)(a,(d|34)&-12293):_.gd(a,_.id,d&4?ic:c,!0,!0));return a}_.lc(a)&&(c=a.ma,d=(0,_.jd)(c),a=d&2?a:_.ed(a.constructor,_.kd(c,d,!0)));return a}};_.kd=function(a,b,c){var d=c||b&2?ic:yaa,e=!!(b&32);a=Saa(a,b,function(f){return _.id(f,e,d)});(0,_.fc)(a,32|(c?2:0));return a};
# _.ld=function(a){var b=a.ma,c=(0,_.jd)(b);return c&2?_.ed(a.constructor,_.kd(b,c,!1)):a};_.md=function(a){var b=a.ma,c=(0,_.jd)(b);return c&2?a:_.ed(a.constructor,_.kd(b,c,!0))};Xaa=function(a,b,c,d){if(!(4&b))return!0;if(c==null)return!1;!d&&c===0&&(4096&b||8192&b)&&(a.constructor[Waa]=(a.constructor[Waa]|0)+1)<5&&_.Vb();return c===0?!1:!(c&b)};Yaa=function(a,b,c,d){b=d+_.kc(b);if(!(b<0||b>=a.length||b>=c))return a[b]};
# _.nd=function(a,b,c,d,e){var f=_.jc(b);if(c>=f||e){var g=b;if(b&256)e=a[a.length-1];else{if(d==null)return g;e=a[f+_.kc(b)]={};g|=256}e[c]=d;c<f&&(a[c+_.kc(b)]=void 0);g!==b&&(0,_.hc)(a,g);return g}a[c+_.kc(b)]=d;b&256&&(a=a[a.length-1],c in a&&delete a[c]);return b};
# _.Zaa=function(a,b,c,d){var e=b&2,f=_.od(a,b,c,d);Array.isArray(f)||(f=_.pd);var g=!!(b&32),k=(0,_.cc)(f);k===0&&g&&!e?(k|=33,(0,_.hc)(f,k)):k&1||(k|=1,(0,_.hc)(f,k));if(e)k&2||gc(f),Object.freeze(f);else if(2&k||2048&k)f=$b(f),e=1,g&&(e|=32),(0,_.hc)(f,e),_.nd(a,b,c,f,d);return f};
# _.ud=function(a,b,c){var d=_.qd(),e=a.ma,f=(0,_.jd)(e);d=2&f?1:d;var g=$aa(e,f,b),k=(0,_.cc)(g);if(Xaa(a,k,void 0,!1)){if(4&k||Object.isFrozen(g))g=$b(g),k=rd(k,f),f=_.nd(e,f,b,g);for(var l=a=0;a<g.length;a++){var n=c(g[a]);n!=null&&(g[l++]=n)}l<a&&(g.length=l);k=aba(k,f);k=bc(k,20,!0);k=bc(k,4096,!1);k=bc(k,8192,!1);(0,_.hc)(g,k);2&k&&Object.freeze(g)}sd(k)||(c=k,k=(a=d===1||d===4&&!!(32&k))?bc(k,2,!0):td(k,f,!1),k!==c&&(0,_.hc)(g,k),a&&Object.freeze(g));d===2&&sd(k)&&(g=$b(g),k=rd(k,f),k=td(k,f,
# !1),(0,_.hc)(g,k),_.nd(e,f,b,g));return g};$aa=function(a,b,c,d){a=_.od(a,b,c,d);return Array.isArray(a)?a:_.pd};aba=function(a,b){a===0&&(a=rd(a,b));return a=bc(a,1,!0)};sd=function(a){return!!(2&a)&&!!(4&a)||!!(2048&a)};
# _.vd=function(a,b,c,d){var e=a.ma,f=(0,_.jd)(e);_.tc(f);if(c==null)return _.nd(e,f,b),a;var g=(0,_.cc)(c),k=g,l=!!(2&g)||Object.isFrozen(c),n=!l&&(void 0===bba||!1);if(Xaa(a,g))for(g=21,l&&(c=$b(c),k=0,g=rd(g,f),g=td(g,f,!0)),l=0;l<c.length;l++)c[l]=d(c[l]);n&&(c=$b(c),k=0,g=rd(g,f),g=td(g,f,!0));g!==k&&(0,_.hc)(c,g);_.nd(e,f,b,c);return a};_.wd=function(a,b,c,d){var e=a.ma,f=(0,_.jd)(e);_.tc(f);_.nd(e,f,b,(d==="0"?Number(c)===0:c===d)?void 0:c);return a};
# yd=function(a,b,c){xd||a in b?b[a]=c:Object.defineProperty(b,a,{value:c,writable:!0})};cba=function(a,b,c){var d=c.ED||(c.ED=ac("o_"+c[0])),e=a[d];if(e!=null)return e&&_.od(a,b,e)==null?(yd(d,a,0),0):e;e=0;for(var f=c.length-1;f>=0;f--){var g=c[f];e===0&&_.od(a,b,g)!=null?e=g:e!==0&&(b=_.nd(a,b,g))}yd(d,a,e);return e};_.zd=function(a,b,c,d){a=a.ma;var e=(0,_.jd)(a),f=_.od(a,e,c,d);b=_.cd(f,b,!1,e);b!==f&&b!=null&&_.nd(a,e,c,b,d);return b};
# _.Ad=function(a,b,c,d,e,f,g,k){var l=!!(2&b);e=l?1:e;g=!!g;k&&(k=!l);l=$aa(a,b,d,f);var n=(0,_.cc)(l),p=!!(4&n);if(!p){n=aba(n,b);var q=l,r=b,u=!!(2&n);u&&(r=bc(r,2,!0));for(var x=!u,y=!0,z=0,G=0;z<q.length;z++){var I=_.cd(q[z],c,!1,r);if(I instanceof c){if(!u){var M=_.ec(I.ma);x&&(x=!M);y&&(y=M)}q[G++]=I}}G<z&&(q.length=G);n=bc(n,4,!0);n=bc(n,16,y);n=bc(n,8,x);(0,_.hc)(q,n);u&&Object.freeze(q)}if(k&&!(8&n||!l.length&&(e===1||e===4&&32&n))){sd(n)&&(l=$b(l),n=rd(n,b),b=_.nd(a,b,d,l,f));c=l;k=n;for(q=
# 0;q<c.length;q++)n=c[q],r=_.ld(n),n!==r&&(c[q]=r);k=bc(k,8,!0);k=bc(k,16,!c.length);(0,_.hc)(c,k);n=k}sd(n)||(c=n,n=(k=e===1||e===4&&!!(32&n))?bc(n,!l.length||16&n&&(!p||32&n)?2:2048,!0):td(n,b,g),n!==c&&(0,_.hc)(l,n),k&&Object.freeze(l));e===2&&sd(n)&&(l=$b(l),n=rd(n,b),n=td(n,b,g),(0,_.hc)(l,n),_.nd(a,b,d,l,f));return l};rd=function(a,b){a=bc(a,2,!!(2&b));a=bc(a,32,!0);return a=bc(a,2048,!1)};td=function(a,b,c){32&b&&c||(a=bc(a,32,!1));return a};
# _.Cd=function(a,b,c,d,e,f,g){a=a.ma;var k=(0,_.jd)(a);_.tc(k);b=_.Ad(a,k,c,b,2,f,!0);c=d!=null?d:new c;if(g&&(typeof e!=="number"||e<0||e>b.length))throw Error();e!=void 0?b.splice(e,g,c):b.push(c);_.ec(c.ma)?(0,_.Bd)(b,8):(0,_.Bd)(b,16)};_.Dd=function(a,b){return a!=null?a:b};_.dba=function(a){if(!Array.isArray(a))throw Error("Z");if(Object.isFrozen(a)||Object.isSealed(a)||!Object.isExtensible(a))throw Error("$");(0,_.fc)(a,128);return a};
# hd=function(a,b,c){var d=_.uc(a),e=(0,_.jd)(c?a.ma:b);a=b.length;if(!a)return b;var f;if(_.mc(c=b[a-1])){a:{var g=c;var k={},l=!1,n;for(n in g){var p=g[n];if(Array.isArray(p)){var q=p;if(_.sc(p,d,+n)||Baa(p)&&p.size===0)p=null;p!=q&&(l=!0)}p!=null?k[n]=p:l=!0}if(l){for(var r in k){g=k;break a}g=null}}g!=c&&(f=!0);a--}for(n=_.kc(e);a>0;a--){r=a-1;c=b[r];r-=n;if(!(c==null||_.sc(c,d,r)||Baa(c)&&c.size===0))break;var u=!0}if(!f&&!u)return b;b=Array.prototype.slice.call(b,0,a);g&&b.push(g);return b};
# _.eba=function(a,b){return b==null?_.bd(a.constructor):_.ed(a.constructor,gc(_.dba(b)))};_.Fd=function(a,b){return new _.Ed(a,b)};_.fba=function(a){a.WWa=!0;return a};_.Id=function(a){return function(b){return _.Gd(a,b)}};_.Jd=function(a,b){b=b===void 0?window:b;b=b===void 0?window:b;return(b=b.WIZ_global_data)&&a in b?b[a]:null};_.Md=function(a){var b=b===void 0?window:b;return new _.Ld(a,_.Jd(a,b))};
# iba=function(a,b,c){c&&(b=Nd(Od,c,function(){return b}));b=Nd(Od,a,function(){return b});gba.set(a,String(b));(a=b.j)&&Nd(hba,a,function(){return b});return b};Nd=function(a,b,c){var d=a.get(b);d||(d=c(b),a.set(b,d));return d};_.Qd=function(a,b,c,d,e){e=e===void 0?!1:e;b=new _.Pd(a,b,c,e===void 0?!1:e);return iba(a,b,d)};_.A=function(a,b){return _.Qd(a,a,b)};_.Td=function(a){if(!_.Rd.has("startup"))throw Error("va`startup");_.jba.has("startup")?a.apply():_.Sd.startup.push(a)};
# _.Ud=function(a,b){b.hasOwnProperty("displayName")||(b.displayName=a.toString());b[kba]=a};lba=function(a){a=a[kba];return a instanceof _.Pd?a:null};_.nba=function(a){if(a instanceof _.Vd)return a.j;if(a instanceof _.Pd)return a;if(typeof a==="function")return _.mba(_.Wd.hb(),a)};_.oba=function(a){return(a=_.nba(a))?_.Xd(_.Yd.hb(),a):void 0};_.$d=function(a){Zd.push(a)};_.be=function(a){_.Ia(Zd,function(b){_.ae(b,a)})};
# pba=function(){if(de)for(var a=de.o,b=0;b<Zd.length;b++){var c=Zd[b];_.sa(a,c)||a.push(c)}};qba=function(){return _.ee(Zd,function(a){return a.j})};_.ge=function(a,b){var c=_.fe[a];c||(c=_.fe[a]=[]);c.push(b)};_.rba=function(){return jb()||_.Va("iPod")?4:_.Va("iPad")?5:_.ib()?he()?3:2:_.ie()?1:0};
# tba=function(a){var b="";var c=_.ca._F_jsUrl;if(typeof document!=="undefined"&&document&&document.getElementById&&(a=document.getElementById(a))){var d=a.tagName.toUpperCase();if(d=="SCRIPT"||d=="LINK")b=a.src?a.src:a.getAttribute("href")}if(c&&b){if(c!=b)throw Error("Ca`"+c+"`"+b);b=c}else b=c||b;if(!sba(b))throw Error("Da");return b};je=function(a){return Nd(uba,a.toString(),function(){return new Set})};
# _.me=function(a,b,c,d,e){a=_.Qd(a,b,d?[d]:void 0,void 0,ke);e&&le(e).add(a);_.Yd.hb().register(a,new vba(a,je(a),c?je(c):new Set,le(a),c?le(c):new Set,d));return a};ne=function(a,b){je(b).add(a)};_.qe=function(a,b){if(!b&&a.hasAttribute("jsshadow"))return null;for(b=0;a=_.pe(a);){if(a&&a===void 0&&b>0){wba||(wba=!0);break}if(a.hasAttribute("jsslot"))b+=1;else if(a.hasAttribute("jsshadow")&&b>0){--b;continue}if(b<=0)return a}return null};
# _.pe=function(a){return a?_.re(a)?_.re(a):a.parentNode&&a.parentNode.nodeType===11?a.parentNode.host:_.se(a):null};_.te=function(a,b,c,d){for(c||(a=_.qe(a,d));a&&a!==void 0;){if(b(a))return a;a=_.qe(a,d)}return null};_.xba=function(a){var b;_.te(a,function(c){return _.re(c)?(b=_.re(c),!0):!1},!0);return b||a};yba=function(a){return _.ue(a)?a.getAttribute("jsname")==="coFSxe":!1};_.zba=function(a){return _.ve(a,yba)};
# Aba=function(a){if(!a)return[];var b=(_.we.has(a)?_.we.get(a):[]).filter(_.zba);_.we.set(a,b);return b};_.xe=function(a){"__jsaction"in a&&delete a.__jsaction};_.Ae=function(a){return _.Ba(a)&&a.Gb!==void 0&&a.Gb instanceof _.ze&&a.ob!==void 0&&(a.mc===void 0||a.mc instanceof _.B)?!0:!1};Bba=function(a){var b=a.JXa;_.Ae(a)&&(b=a.metadata?!a.metadata.fatal:void 0);return b};
# Cba=function(a,b){if(!a)return _.Be();var c=a.Fj;return _.Ae(a)&&(c=a.metadata?a.metadata.Fj:void 0,a.metadata&&a.metadata.FS)?_.Ce(b,{service:{Fl:_.De}}).then(function(d){d=d.service.Fl;for(var e=_.v(a.metadata.FS),f=e.next();!f.done;f=e.next())f=f.value,_.Ee(d.get(f.pWa))&&(c=f.Fj);return c}):_.Be(c)};
# Eba=function(a,b,c){return Cba(a,c).then(function(d){if(d==void 0||d<0)return b;var e=!1;b.then(function(){e=!0},function(){});d=_.Fe(d,_.Be(null));a.metadata&&(a.metadata.zI=!1);d.then(function(){a.metadata&&(a.metadata.zI=!e)});return _.Dba([b,d])})};Fba=function(a,b){return Bba(a)?b.Pe(function(){return _.Be(null)}):b};
# Jba=function(a,b){return _.Ae(a)&&a.metadata&&a.metadata.xK?b.then(function(c){if(!c&&a.metadata&&a.metadata.zI){c=new Gba;var d=new _.Ge;c.j=void 0;var e="type.googleapis.com";e=e===void 0?"type.googleapis.com/":e;e.substr(-1)!=="/"&&(e+="/");_.Ie(d,1,e+"wiz.data.clients.WizDataTimeoutError");_.Je(d,2,c,!1);return _.Hba(_.Iba(new _.Ke,2),[d])}},function(c){if(c instanceof _.Le)return c.status}):b};Lba=function(a,b){var c=_.Ce(a,{service:{a1:_.Kba}});return _.pb(b,function(d){return c.then(function(e){return e.service.a1.o(d)})})};
# _.Me=function(){};Mba=function(a){if(a instanceof Object&&!Object.isFrozen(a)){var b=_.Ne(a.fileName||a.filename||a.sourceURL||_.ca.$googDebugFname||location.href);try{a.fileName=b}catch(c){}}};_.Oe=function(a,b){_.Nba(null,a,b===void 0?"unknown":b)};Pba=function(){var a={};a.location=_.Ne(location);if(Oba())try{a["top.location"]=_.Ne(top.location)}catch(c){a["top.location"]="[external]"}else a["top.location"]="[external]";for(var b in Pe)try{a[b]=Pe[b].call()}catch(c){a[b]="[error] "+c.message}return a};
# Xba=function(a,b){var c=!0;c=c===void 0?!0:c;Qe.init();a&&(a=new Re(a,void 0,!0),a=new Qba(a,{pK:c}),_.Se.j=a,b&&(a.j=b),Rba(a));var d=c?function(f){return _.Oe(f,"severe")}:_.Oe,e=null;b=function(f){_.ca.$googDebugFname&&f&&f.message&&!f.fileName&&(f.message+=" in "+_.ca.$googDebugFname);e?f&&f.message&&(f.message+=" [Possibly caused by: "+e+"]"):e=String(f);d(f)};_.Te("_DumpException",b);_.Te("_B_err",b);_.Ia([_.ca].concat([]),_.Xe(Sba,_.Xe(Tba,!0,d),!0));_.gb("Chromium")>=28||_.gb("Firefox")>=
# 14||_.gb("Internet Explorer")>=11||_.gb("Safari");_.gb("Internet Explorer")<=9||(b=new Ye(d),b.o=!0,b.j=!0,Uba(b),Ze(b,"setTimeout"),Ze(b,"setInterval"),Vba(b),Wba(b),_.Se.o=b)};Tba=function(a,b,c){_.Sa(c.message,"Error in protected function: ")||(c.error&&c.error.stack?b(c.error):a||b(c))};$ba=function(a){var b=_.$e(_.Md("Im6cmf"))+"/jserror";Xba(b,a);a=_.af(_.bf(_.Md("cfb2h"),""));Pe.buildLabel=a;Yba!==null&&_.Se.j&&(Zba&&(_.Se.j.H=!0),_.Se.j.o.push(Yba))};
# _.df=function(a){var b=Od.get(a);return b?b:(b=new _.Pd(a,a,[]),iba(a,b),b)};_.ef=function(a,b){a.__soy_skip_handler=b};ff=function(){};bca=function(a,b,c){a=a.style;if(typeof c==="string")a.cssText=c;else{a.cssText="";for(var d in c)if(aca.call(c,d)){b=a;var e=d,f=c[d];e.indexOf("-")>=0?b.setProperty(e,f):b[e]=f}}};
# cca=function(a,b,c){var d=typeof c;d==="object"||d==="function"?a[b]=c:c==null?a.removeAttribute(b):(d=b.lastIndexOf("xml:",0)===0?"http://www.w3.org/XML/1998/namespace":b.lastIndexOf("xlink:",0)===0?"http://www.w3.org/1999/xlink":null)?a.setAttributeNS(d,b,c):a.setAttribute(b,c)};_.dca=function(){var a=new ff;a.__default=cca;a.style=bca;return a};eca=function(a,b,c,d,e){return b==c&&d==e};_.mf=function(a){for(var b=_.gf,c=_.hf();c!==a;){var d=c.nextSibling;b.removeChild(c);_.jf.o.push(c);c=d}};
# _.hf=function(){return _.nf?_.nf.nextSibling:_.gf.firstChild};
# _.hca=function(a,b){b=b===void 0?{}:b;var c=b.matches===void 0?eca:b.matches;return function(d,e,f){var g=_.jf,k=_.of,l=_.pf,n=_.qf,p=_.nf,q=_.gf,r=_.rf;_.of=d.ownerDocument;_.jf=new fca(d);_.rf=c;_.qf=[];_.nf=null;var u=_.gf=d.parentNode,x,y=gca.call(d);if((x=y.nodeType===11||y.nodeType===9?y.activeElement:null)&&d.contains(x)){for(y=[];x!==u;)y.push(x),x=x.parentNode||(u?x.host:null);u=y}else u=[];_.pf=u;try{return a(d,e,f)}finally{d=_.jf,_.sf&&d.j.length>0&&(0,_.sf)(d.j),_.tf&&d.o.length>0&&(0,_.tf)(d.o),
# _.of=k,_.jf=g,_.rf=r,_.qf=n,_.nf=p,_.gf=q,_.pf=l}}};_.ica=function(a){return _.hca(function(b,c,d){_.gf=_.nf=b;_.nf=null;c(d);_.mf(null);_.nf=_.gf;_.gf=_.gf.parentNode;return b},a)};uf=function(a){a=a.__soy;a.j0();return a};kca=function(a){for(;a&&!a.QF&&!jca(a);)a=a.parentElement;return{element:a,GI:a.QF}};
# lca=function(){_.vf({soy:function(a){var b=a.T?a.T().el():a.vi();var c=b.__soy?uf(b):null;if(c)return _.Be(c);var d=kca(b),e=d.element;e.mz||(e.mz=new Set);var f=e.mz;c=new Set;for(var g=_.v(f),k=g.next();!k.done;k=g.next())k=k.value,_.wf(b,k)&&c.add(k);c.size||(f.add(b),b.__soy_tagged_for_skip=!0);a=d.GI?d.GI.then(function(){f.clear();var l=b.__soy?uf(b):null;if(l)return l;e.__soy.render();return uf(b)}):_.xf([a.Bg(_.yf,d.element),_.Ce(a,{service:{lx:_.zf}})]).then(function(l){var n=l[1].service.lx;
# return l[0].jU().then(function(p){d.element.getAttribute("jsrenderer");f.clear();e.__incrementalDOMData||n.XV(e,p.template,p.args);if((!b.__soy||!uf(b))&&e.__incrementalDOMData){p="Hydration source "+(document.body.contains(e)?"in dom":"not in dom")+";";var q="El source "+(document.body.contains(b)?"in dom":"not in dom");_.da(Error("Ta`"+p+"`"+q+"`"+(b.getAttribute("jscontroller")||b.getAttribute("jsmodel"))));return null}return uf(b)})});b.mz=c;b.QF=a;return a.then(function(l){return l})}})};
# Af=function(a,b){a:{if(typeof window.Event==="function")try{var c=new Event(a,{bubbles:!1,cancelable:!0});break a}catch(d){}c=document.createEvent("Event");c.initEvent(a,!1,!0)}a=c;a.qWa=b;return a};Gf=function(){try{if(typeof window.EventTarget==="function")return new EventTarget}catch(a){}try{return document.createElement("div")}catch(a){}return null};
# mca=function(a){var b,c,d,e;return new Hf((d=(b=a.hf())==null?void 0:b.name)!=null?d:"",(e=(c=a.hf())==null?void 0:c.element)!=null?e:null,a.j.event,a.j.timeStamp,a.Ph(),a.j.targetElement)};nca=function(a,b){for(;a&&a.nodeType===Node.ELEMENT_NODE;a=a.parentNode)b(a)};oca=function(a){var b=this.getAttribute(a);Element.prototype.setAttribute.apply(this,arguments);var c=this.getAttribute(a);_.If(this,Jf,{name:a,nq:c,f_:b},!1)};
# pca=function(a){var b=this.getAttribute(a);Element.prototype.removeAttribute.apply(this,arguments);_.If(this,Jf,{name:a,nq:null,f_:b},!1)};Kf=function(){return!!(window.performance&&window.performance.mark&&window.performance.measure&&window.performance.clearMeasures&&window.performance.clearMarks)};qca=function(a,b){for(var c=0;c<b.length;c++)try{var d=b[c].j(a);if(d!=null&&d.abort)return d}catch(e){_.da(e)}};rca=function(a,b){for(var c=0;c<b.length;c++)try{b[c].o(a)}catch(d){_.da(d)}};
# _.Nf=function(a,b){a=a[_.Lf];if(!a||b.has(a))return _.Mf();b.add(a);return a.init(b)};_.Qf=function(a){var b=new Set;return _.Nf(a,b).addCallback(function(){return new _.Of([].concat(_.Pf(b)).map(function(c){return c.done()}))}).addCallback(function(){return a})};sca=function(a,b){if(b===null)return!1;if("contains"in a&&b.nodeType===1)return a.contains(b);if("compareDocumentPosition"in a)return a===b||!!(a.compareDocumentPosition(b)&16);for(;b&&a!==b;)b=b.parentNode;return b===a};
# Rf=function(a){a.preventDefault?a.preventDefault():a.returnValue=!1};Sf=function(a){a=a.target;!a.getAttribute&&a.parentNode&&(a=a.parentNode);return a};
# yca=function(a){var b=a.event;var c=b.which||b.keyCode;!c&&b.key&&(c=tca[b.key]);uca&&c===3&&(c=13);if(c!==13&&c!==32)c=!1;else{var d=Sf(b);(b=b.type!=="keydown"||!!(!("getAttribute"in d)||(d.getAttribute("type")||d.tagName).toUpperCase()in vca||d.tagName.toUpperCase()==="BUTTON"||d.type&&d.type.toUpperCase()==="FILE"||d.isContentEditable)||b.ctrlKey||b.shiftKey||b.altKey||b.metaKey||(d.getAttribute("type")||d.tagName).toUpperCase()in wca&&c===32)||((b=d.tagName in xca)||(b=d.getAttributeNode("tabindex"),
# b=b!=null&&b.specified),b=!(b&&!d.disabled));if(b)c=!1;else{b=(d.getAttribute("role")||d.type||d.tagName).toUpperCase();var e=!(b in _.$f)&&c===13;d=d.tagName.toUpperCase()!=="INPUT"||!!d.type;c=(_.$f[b]%c===0||e)&&d}}c&&(a.eiack=!0,a.eventType="click")};
# Aca=function(a){var b;if(b=a.eiack){b=a.event;var c=Sf(b);c=(c.type||c.tagName).toUpperCase();if(!(b=(b.which||b.keyCode)===32&&c!=="CHECKBOX")){b=Sf(a.event);c=b.tagName.toUpperCase();var d=(b.getAttribute("role")||"").toUpperCase();b=c==="BUTTON"||d==="BUTTON"?!0:!(b.tagName.toUpperCase()in zca)||c==="A"||c==="SELECT"||(b.getAttribute("type")||b.tagName).toUpperCase()in wca||(b.getAttribute("type")||b.tagName).toUpperCase()in vca?!1:!0}}b&&Rf(a.event)};
# Bca=function(a,b,c){b.eia||b.eventType!=="click"||b.eiack||c.clickonly===void 0||(b.eventType="clickonly",b.eia=[c.clickonly,a])};Cca=function(a,b){a.ecrd(function(c){b.af(c)},0)};Dca=function(a,b){return _.pb(b,function(c,d){var e={};return _.ag(_.Ce(a,{jsdata:(e[d]=c,e)}).addCallback(function(f){return f.jsdata[d]}),function(){return null})})};
# Eca=function(a,b){var c=_.Ce(a,{service:{resolver:_.bg}});return _.pb(b,function(d){if(typeof d=="function")var e=d;else if(d instanceof _.C)e=d.Sn;else if(d instanceof _.B)var f=d;else{d.ctor&&(typeof d.ctor=="function"?e=d.ctor:e=d.ctor.Sn);f=d.RVa;var g=d.NJ}e=f?f.constructor:e;var k=_.cg(e);var l=a.T?a.T().el():a.vi();g&&a.gD(k,g,!!f);return c.then(function(n){return n.service.resolver.resolve(l,e,d.WT,!!f)})})};
# Gca=function(a){var b=window.BOQ_wizbind,c=window.document;dg=null;a=Fca(b,c,a);a.ya=!1;a=a.U;a=(0,_.eg)(a.qh,a);window.wiz_progress=a;_.fg(_.gg(_.hg),_.ig);_.jg({data:kg,afdata:kg});_.jg({afdata_o:kg});_.jg({jsdata:Eca});_.jg({Cc:Dca});a()};_.lg=function(a,b){this.H=a;this.j=b;this.constructor.XF||(this.constructor.XF={});this.constructor.XF[this.toString()]=this};
# Hca=function(a){var b={Nq:_.mg.lk||_.mg.Fm||_.mg.lr&&(0,_.mg.Qw)(3)||_.mg.nu||_.mg.ou?8E3:4043},c=!0;c=c===void 0?!1:c;a=a===void 0?!1:a;b=b===void 0?{}:b;var d=b.cssRowKey||"",e=b.Dj||"";!d&&window&&window._F_cssRowKey&&(d=window._F_cssRowKey,!e&&window._F_combinedSignature&&(e=window._F_combinedSignature));if(d&&typeof window._F_installCss!=="function")throw Error("eb");a=new (b.tXa||_.ng)(_.Lb(tba("base-js")),d,e,c,a);b.n2&&(a.du=b.n2);b.NR&&(a.Ir=b.NR);b.Nq&&(a.Nq=b.Nq);b.Fv&&(a.Fv=b.Fv);b=_.Oa();
# b.va=a;b.PK(!0);return a};_.pg=function(a){a=a.pathname.replace(_.og,"/").match(_.Ica);return(a==null?0:a.length)?a[0]:null};
# _.Kca=function(a){var b=_.pg(a),c="";if(b==="/search")c=_.qg(new _.tg(a.href),"q")||"";else if(b==="/stories")c="Full Coverage";else if(b==="/foryou")c="For You";else if(b==="/topstories")c="Top Stories";else if(b==="/topics")c="Topic";else if(b==="/publications")c="News Edition";else if(b==="/settings")c="Settings";else if(b==="/showcase")c="News Showcase";else if(b==="/articles")c="Article Reading";else if(b==="/home")c="Home";else if(b==="/")c="Root";else if(b==="/my"){a=a.pathname.replace(_.og,
# ...
# var Ui=function(a,b){if(a.C){if(b==2){b=_.y(_.M(a.j,24),"");var c=_.y(_.M(a.j,27),"")}else b==1?(b=_.y(_.M(a.j,23),""),c=_.y(_.M(a.j,26),"")):(b=_.y(_.M(a.j,22),""),c=_.y(_.M(a.j,25),""));b==""&&c==""||ei(a.C,b,c)}},Ti=function(a){a=a.ea[0];return a.classList.contains("gb_Qc")?1:a.classList.contains("gb_Od")?2:0},cj=function(a,b){_.ef(a,["gb_Od","gb_Qc"]);b==1?_.bf(a,"gb_Qc"):b==2&&_.bf(a,"gb_Od")};Z.prototype.ta=function(a){this.o.style.backgroundColor=a};Z.prototype.nb=function(){return this.o.style.backgroundColor};
# Z.prototype.oa=function(){var a=_.Ud("dd");_.Ph(a)&&_.Ph(a).ud(!1);_.gi(a,null)};Z.prototype.Vc=function(a){Ni(this,a-8-10);Xi(this)};var Ni=function(a,b){a.v==null?a.N.log(Error("na")):a.W?a.N.log(Error("oa")):a.Ha=b<0?0:b},Xi=function(a){a.B!=null&&(a.F.i=="gb_Sa"?_.Yg(a.B,"min-width",""):a.Ha!=null&&_.Yg(a.B,"min-width",a.Ha+"px"))};Z.prototype.Wc=function(a){_.Y(_.W("gb_Ic",this.D),"gb_q",!a)};Z.prototype.Hb=function(a){this.Jb&&_.Y(this.H(),"gb_q",!a)};
# Z.prototype.Oc=function(){hi(function(a){a&&a.Oc()})};Z.prototype.Gc=function(a){a&&(_.Xh(_.W("gb_nd"),a),_.pd.i().j.then(function(b){return void b.Qd(a)}))};var Pi=[{id:"gb_Sa",max:599},{id:"gb_xd",max:1023},{id:"gb_2c"}];var dj;_.X.prototype.za=_.fe(function(a,b,c,d,e){return a.call(this,b,_.fe(ci,c),d,e)},_.X.prototype.listen);_.X.prototype.zb=_.X.prototype.ii;var ej=_.W("gb_qa");
# if(ej==null)dj=null;else{var fj=_.J(_.rd,_.Rd,6)||new _.Rd,gj=new Z(ej,fj,_.vd,_.W("gb_vd"));_.E("gbar.P",Z);Z.prototype.pa=Z.prototype.Gb;Z.prototype.pb=Z.prototype.Nj;Z.prototype.pc=Z.prototype.Oa;Z.prototype.pd=Z.prototype.ta;Z.prototype.pe=Z.prototype.Ab;Z.prototype.pf=Z.prototype.Dc;Z.prototype.pg=Z.prototype.Fc;Z.prototype.ph=Z.prototype.mg;Z.prototype.pi=Z.prototype.oa;Z.prototype.pj=Z.prototype.Vc;Z.prototype.pk=Z.prototype.Wc;Z.prototype.pl=Z.prototype.Gc;Z.prototype.pm=Z.prototype.G;Z.prototype.pn=
# Z.prototype.nb;Z.prototype.po=Z.prototype.Lj;Z.prototype.pp=Z.prototype.Ya;Z.prototype.pq=Z.prototype.Oc;Z.prototype.pr=Z.prototype.Hb;_.pd.i().v.resolve(gj);dj=gj}_.hj=dj;
# }catch(e){_._DumpException(e)}
# try{
# _.ij=function(a,b){return _.P(a,36,b)};
# }catch(e){_._DumpException(e)}
# try{
# var jj=document.querySelector(".gb_b .gb_d"),kj=document.querySelector("#gb.gb_Zc");jj&&!kj&&_.Md(_.wd,jj,"click");
# }catch(e){_._DumpException(e)}
# try{
# _.pd.i().v.then(function(a){if(a){var b=_.W("gb_Ic",a.D);b&&(b=new _.Bh(b,_.vd),a.Kj(b))}});
# }catch(e){_._DumpException(e)}
# })(this.gbar_);
# // Google Inc.
# </script><c-wiz c-wiz="" class="zQTmif SSPGKf" data-node-index="0;0" data-ogpc="" data-p='%.@.[["hu","HU",["FINANCE_TOP_INDICES","WEB_TEST_1_0_0"],null,null,1,1,"HU:hu",null,null,null,null,null,null,null,false],"hu","HU",true,[2,4,8],1,true,"642987060",false,false,null,false],true,null,null,null,true]' jsaction="rcuQ6b:npT2md" jsdata="deferred-i5" jslog="148556; 3:W251bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLFtdXQ==;track:vis" jsmodel="hc6Ubd" jsname="a9kxte" jsrenderer="WCtUF" view=""><div class="T4LgNb" jsname="a9kxte"><div class="VjFXz"></div><div class="c4Stqc" jsaction="rcuQ6b:npT2md;zQZjY:gH0i2d;aSYJbc:G3RMRb;" jscontroller="Pk3Jo"><main class="IKXQhd" data-n-tid="26" jsaction="rcuQ6b:npT2md;" jscontroller="aXyUec"><div class="fuAp6" jsname="ReIlqe"></div><div class="afJ4ge" jsaction="rcuQ6b:npT2md;WxNX3b:YQd9Yb;" jscontroller="JXN87"><c-wiz c-wiz="" class="XPbmfb" data-node-index="1;0" data-p='%.@.[["hu","HU",["FINANCE_TOP_INDICES","WEB_TEST_1_0_0"],null,null,1,1,"HU:hu",null,null,null,null,null,null,null,false],"hu","HU",true,[2,4,8],1,true,"642987060",false,false,null,false]]' jsdata="deferred-i6" jsmodel="hc6Ubd" jsrenderer="IAPX8" jsshadow=""><section class="XhbDsd poXG1d" data-n-hl="hu" data-n-tid="24" jslog="127062; 3:W251bGwsbnVsbCxudWxsLG51bGwsImJyaWVmaW5nIl0=; track:vis; index:0" jsname="Vfdmxb"><div class="HlODXd VsXlJe" jsaction="JIbuQc:UEmoBd" jscontroller="pMXDzd"><div aria-disabled="false" class="U26fgb YOnsCc waNn5b ZqhUjb ztUP4e tHCKTc cd29Sd dHeVVb w0hkKb oGH8ff M9Bg4d" data-n-et="1000" jsaction="click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc(preventDefault=true); touchcancel:JMtRjd;;OuuAFc:UauMyf;gSufsc:BS8cLb;RyWlBb:tC9Erd;UTnG9:aDaYxb;nUyoxf:El6wk;" jscontroller="zbPkme" jsname="b7Pkmc" jsshadow="" role="button" tabindex="0"><div class="XI1L0d zSBur" jsname="ksKsZd"></div><span aria-hidden="true" class="DPvwYc ChwdAb Xd067b fAk9Qc" jsname="BC5job">info_outline</span><span class="iDvCIf xfudi">A hírek rangsorolása</span></div><div aria-hidden="true" class="MU4vOe" jsname="bN97Pc"><p class="jBYiqc">A hírekkel kapcsolatos cikkek rangsorolása a minőségük, a tartalmuk eredetisége és frissessége, valamint – amennyiben ez megengedett – az Ön beállításai, a Google Hírekben végzett korábbi tevékenységei és vásárlásai, illetve a más Google-termékekben végzett tevékenységei alapján történik. Előfordulhat, hogy a Google licencszerződést köt néhány ilyen kiadóval, de ez nem befolyásolja a találatok rangsorolását.</p><p class="jBYiqc"><a href="https://support.google.com/googlenews?p=consumer_info&amp;hl=hu" target="_blank">További információ</a></p></div></div><div class="UJdj6" jsaction="rcuQ6b:npT2md"><div class="n6ef1"><h1 class="Da1Shd">Saját
# összefoglaló</h1><div class="Hp1DDd oBu3Fe" role="doc-subtitle"></div></div><c-wiz c-wiz="" class="yPI8Rb" data-node-index="1;0" data-p='%.@.[["hu","HU",["FINANCE_TOP_INDICES","WEB_TEST_1_0_0"],null,null,1,1,"HU:hu",null,null,null,null,null,null,null,false],"hu","HU",true,[2,4,8],1,true,"642987060",false,false,null,false]]' jsdata="deferred-i7" jsmodel="hc6Ubd" jsrenderer="wFEuWd" jsshadow=""><div class="WCkv8e" jsaction="rcuQ6b:npT2md" jscontroller="otyLQd" jslog="133909; index:0"><div class="wnLEqe"><div class="Ocye0e"></div><div><div class="VL00xb"><div class="uXmrie"></div><button aria-label="Időjárási adatok lekérése…" class="rRo62" disabled=""><svg class="JnWIZd NMm5M" focusable="false" height="12" viewbox="0 0 24 24" width="12"><path d="M20.94 11A8.994 8.994 0 0 0 13 3.06V1h-2v2.06A8.994 8.994 0 0 0 3.06 11H1v2h2.06A8.994 8.994 0 0 0 11 20.94V23h2v-2.06A8.994 8.994 0 0 0 20.94 13H23v-2h-2.06zM12 19c-3.87 0-7-3.13-7-7s3.13-7 7-7 7 3.13 7 7-3.13 7-7 7z"></path></svg><svg class="MTJqdc NMm5M" focusable="false" height="12" viewbox="0 0 24 24" width="12"><path d="M12 8c-2.21 0-4 1.79-4 4s1.79 4 4 4 4-1.79 4-4-1.79-4-4-4zm8.94 3A8.994 8.994 0 0 0 13 3.06V1h-2v2.06A8.994 8.994 0 0 0 3.06 11H1v2h2.06A8.994 8.994 0 0 0 11 20.94V23h2v-2.06A8.994 8.994 0 0 0 20.94 13H23v-2h-2.06zM12 19c-3.87 0-7-3.13-7-7s3.13-7 7-7 7 3.13 7 7-3.13 7-7 7z"></path></svg></button></div><div class="wal0Rd"></div><div class="QLNUEb"></div></div></div><div class="CcMACc"><div class="aT4VZb" jsname="sYlLx"><div aria-hidden="true" class="qN9IM" id="i8" jsname="Q4wMtf"><div aria-label="Ma: maximum 25, minimum 13" class="PCFVm"><div class="Hmgqjd">Ma</div><div alt="" class="P8kLrd" role="img"><span jsname="VqOxwd" soy-skip="" ssk="5:Kvhqf"></span></div><div class="mY96Db"><span class="iN1nBb">25 °</span><span class="ODg3ac">13 °</span></div></div><div aria-label="hétfő: maximum 29, minimum 17" class="PCFVm"><div class="Hmgqjd">H</div><div alt="" class="P8kLrd" role="img"><span jsname="VqOxwd" soy-skip="" ssk="5:Kvhqf"></span></div><div class="mY96Db"><span class="iN1nBb">29 °</span><span class="ODg3ac">17 °</span></div></div><div aria-label="kedd: maximum 32, minimum 20" class="PCFVm"><div class="Hmgqjd">K</div><div alt="" class="P8kLrd" role="img"><span jsname="VqOxwd" soy-skip="" ssk="5:Kvhqf"></span></div><div class="mY96Db"><span class="iN1nBb">32 °</span><span class="ODg3ac">20 °</span></div></div><div aria-label="szerda: maximum 33, minimum 18" class="PCFVm"><div class="Hmgqjd">Sze</div><div alt="" class="P8kLrd" role="img"><span jsname="VqOxwd" soy-skip="" ssk="5:Kvhqf"></span></div><div class="mY96Db"><span class="iN1nBb">33 °</span><span class="ODg3ac">18 °</span></div></div></div></div><div class="dSBEqc"><button aria-controls="i8" aria-expanded="false" aria-label="Kibontás az előrejelzés megtekintéséhez" class="HDbYSe" jsaction="click:wmG6Be" jsname="ix0Hvc" title="Kibontás az előrejelzés megtekintéséhez"><svg class="NMm5M hhikbc" focusable="false" height="20" viewbox="0 0 24 24" width="20"><path d="M15.41 7.41L14 6l-6 6 6 6 1.41-1.41L10.83 12l4.58-4.59z"></path></svg></button><div aria-label="Baj, 25 °C" class="yINXKd" id="i9"><div alt="" aria-labelledby="i9" class="uNlVc" role="img"><span jsname="H0Rex" soy-skip="" ssk="5:Kvhqf"></span></div><div class="hJ2BFb"><div class="Dd5J2"><div class="EoTBfe">Baj</div><button aria-label="Pontos helyadatok használata" class="YyrBp" jsaction="click:CadiRe" title="Pontos helyadatok használata"><svg class="zRMMZb NMm5M" focusable="false" height="12" viewbox="0 0 24 24" width="12"><path d="M12 8c-2.21 0-4 1.79-4 4s1.79 4 4 4 4-1.79 4-4-1.79-4-4-4zm8.94 3A8.994 8.994 0 0 0 13 3.06V1h-2v2.06A8.994 8.994 0 0 0 3.06 11H1v2h2.06A8.994 8.994 0 0 0 11 20.94V23h2v-2.06A8.994 8.994 0 0 0 20.94 13H23v-2h-2.06zM12 19c-3.87 0-7-3.13-7-7s3.13-7 7-7 7 3.13 7 7-3.13 7-7 7z"></path></svg></button></div><div class="iNL53" data-n-tid="35">25 °C</div><a class="Fqws6b" href="https://www.weather.com/wx/today/?lat=47.65&amp;lon=18 ...
# c.initAft=function(){f=0;e=Array.prototype.slice.call(document.getElementsByTagName("img")).filter(function(a){return!!a.getAttribute("data-iml")});[].forEach.call(document.getElementsByTagName("img"),function(a){try{_recordIsAboveFold(a)}catch(b){throw b.message=a.hasAttribute("data-iid")?b.message+"\nrecordIsAboveFold error for defer inlined image":b.message+("\nrecordIsAboveFold error for img element with <src: "+a.src+">"),b;}});if(d.length===0)c.onaft(f)};}).call(this);
# initAft()</script><script id="_ij" nonce="BchWCSuOimYDKipP6iIXOg">window.IJ_values = ['\/\/www.google.com\/advanced_search?hl\x3dhu\x26fg\x3d1',[null,null,"",false,null,null,null,false],'0','www.google.com','https:\/\/news.google.com\/', null ,'boq_dotssplashserver_20240611.11_p1','news.google.com','HU:hu', 0.0 , 1.0 , 0.0 , null , null , null ,'','BchWCSuOimYDKipP6iIXOg','flkcLndc3ghdmwagi608TA','DEFAULT','Magyar (Magyarország)','', 2024.0 ,'https:\/\/news.google.com\/home', null ,'ltr', false ,'https:\/\/accounts.google.com\/AccountChooser?continue\x3dhttps:\/\/news.google.com\/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu\x26hl\x3dhu','\/\/accounts.google.com\/ServiceLogin?continue\x3dhttps:\/\/news.google.com\/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu\x26hl\x3dhu','https:\/\/accounts.google.com\/ServiceLogin?hl\x3dhu\x26continue\x3dhttps:\/\/news.google.com\/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu','https:\/\/accounts.google.com\/SignOutOptions?continue\x3dhttps:\/\/news.google.com\/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu','HU','hu', true , false , true , false , false , false , false , true , true , false , false , true ,'hu','hu','magyar','\/\/www.google.com\/preferences?hl\x3dhu\x26prev\x3dhttps:\/\/news.google.com\/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu\x26lang\x3d1#languages','us_2020_elections,us_2020_elections_local_news_with_summary_submix;gemini_briefing_local_v2,gemini_briefing_local_news_with_summary_submix','hu','\/\/support.google.com\/websearch\/answer\/179386?source\x3dg\x26hl\x3dhu','\/\/www.google.com','https:\/\/goto2.corp.google.com\/mdtredirect?data_id_filter\x3dnews.google.com\x26system_name\x3ddots-splash-server',[], null , null , null , null ,'','https:\/\/myaccount.google.com\/privacypolicy?hl\x3dhu','\/\/www.google.com\/history\/optout?hl\x3dhu', false ,'\/\/www.google.com\/setprefs?sig\x3d0_3hjSH5bforp83NAz_3bDDEOUdNA%3D\x26prev\x3dhttps:\/\/news.google.com\/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu\x26safeui\x3dimages','\/\/www.google.com\/setprefs?sig\x3d0_3hjSH5bforp83NAz_3bDDEOUdNA%3D\x26prev\x3dhttps:\/\/news.google.com\/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu\x26safeui\x3don','\/\/www.google.com\/safesearch?hl\x3dhu\x26prev\x3dhttps:\/\/news.google.com\/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu','\/\/www.google.com\/setprefs?sig\x3d0_3hjSH5bforp83NAz_3bDDEOUdNA%3D\x26prev\x3dhttps:\/\/news.google.com\/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu\x26safeui\x3doff', null ,'\/\/support.google.com\/websearch\/?source\x3dg\x26hl\x3dhu','\/\/www.google.com\/history\/optout?hl\x3dhu','HU','\/\/www.google.com\/preferences?hl\x3dhu\x26prev\x3dhttps:\/\/news.google.com\/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu\x26fg\x3d1', 1.0 ,'\/\/www.google.com\/setprefs?cs\x3d2\x26sig\x3d0_3hjSH5bforp83NAz_3bDDEOUdNA%3D\x26prev\x3dhttps:\/\/news.google.com\/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu\x26hl\x3dhu','\/\/www.google.com\/setprefs?cs\x3d1\x26sig\x3d0_3hjSH5bforp83NAz_3bDDEOUdNA%3D\x26prev\x3dhttps:\/\/news.google.com\/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu\x26hl\x3dhu','\/\/support.google.com\/googleshopping?hl\x3dhu','\/\/shopping.google.com\/settings', true , true , null , 0.0 , false , false , false , false , true ,'HU', false ,[[["gl","HU"],["hl","hu"]]],'\x26gl\x3dHU\x26hl\x3dhu','https:\/\/myaccount.google.com\/termsofservice?hl\x3dhu', null , false , null ,'\/\/www.google.com\/history\/privacyadvisor\/search\/unauth?cctld\x3dcom\x26utm_source\x3dgooglemenu\x26hl\x3dhu',]; window.IJ_valuesCb && window.IJ_valuesCb();</script><script nonce="BchWCSuOimYDKipP6iIXOg">AF_initDataCallback({key: 'ds:1', hash: '1', data:["gbres",[[null,"Saját\nösszefoglaló","június 16., vasárnap"],null,null,[[null,"Vezető hírek",null,null,null,null,null,null,null,null,null,null,[null,null,null,null,["#ffffff","#000000"]]],[[[[13,[13,"CBMiV2h0dHBzOi8vdGVsZXguaHUva3VsZm9sZC8yMDI0LzA2LzE2L2l6cmFlbC1pZGYtZ2F6YS10YWt0aWthaS1zenVuZXQtaHVtYW5pdGFyaXVzLXNlZ2VsedIBAA"],"Az izraeli hadsereg egy dél-gázai út mellett leállította a hadműveleteket, „taktikai szünetet” tart",null ...
# try{
# if(_.hj){var lj;if(lj=_.M(_.hj.j,3))for(var mj=_.Fh(lj),nj=0;nj<mj.length;nj++){var oj=mj[nj];if(_.Lh&&oj.dataset)oj.dataset.ogpc="";else{if(/-[a-z]/.test("ogpc"))throw Error("Q");oj.setAttribute("data-"+_.ii("ogpc"),"")}}_.bj(_.hj,!!_.hj.i&&_.hj.i.qb(),!1)};
# }catch(e){_._DumpException(e)}
# try{
# _.pj=function(a){var b,c,d=(c=(b=(a.ownerDocument&&a.ownerDocument.defaultView||window).document).querySelector)==null?void 0:c.call(b,"script[nonce]");(b=d?d.nonce||d.getAttribute("nonce")||"":"")&&a.setAttribute("nonce",b)};_.qj=function(a){if(!a)return null;a=_.M(a,4);var b;a===null||a===void 0?b=null:b=_.ue(a);return b};_.rj=function(a){this.J=_.w(a)};_.C(_.rj,_.T);_.sj=function(a,b){return(b||document).getElementsByTagName(String(a))};
# }catch(e){_._DumpException(e)}
# try{
# var uj=function(a,b,c){a<b?tj(a+1,b):_.vd.log(Error("pa`"+a+"`"+b),{url:c})},tj=function(a,b){if(vj){var c=_.Ne("SCRIPT");c.async=!0;c.type="text/javascript";c.charset="UTF-8";c.src=_.se(vj);_.pj(c);c.onerror=_.fe(uj,a,b,c.src);_.sj("HEAD")[0].appendChild(c)}},wj=function(a){this.J=_.w(a)};_.C(wj,_.T);var xj=_.J(_.rd,wj,17)||new wj,yj,vj=(yj=_.J(xj,_.rj,1))?_.qj(yj):null,zj,Aj=(zj=_.J(xj,_.rj,2))?_.qj(zj):null,Bj=function(){tj(1,2);if(Aj){var a=_.Ne("LINK");a.setAttribute("type","text/css");a.rel="stylesheet";if(_.fa("stylesheet","stylesheet")){a.href=_.se(Aj).toString();var b=_.Ie(a.ownerDocument&&a.ownerDocument.defaultView);b&&a.setAttribute("nonce",b)}else a.href=Aj instanceof _.re?_.se(Aj).toString():_.Je(Aj);(b=_.Ie())&&a.setAttribute("nonce",b);_.sj("HEAD")[0].appendChild(a)}};(function(){var a=_.sd();if(_.L(a,18))Bj();else{var b=_.he(a,19)||0;window.addEventListener("load",function(){window.setTimeout(Bj,b)})}})();
# }catch(e){_._DumpException(e)}
# })(this.gbar_);
# // Google Inc.
# </script><div ng-non-bindable=""><div class="gb_Ce">Keresés</div><div class="gb_Ee">Keresés törlése</div><div class="gb_De">A keresés bezárása</div><div class="gb_m">Google-alkalmazások</div><div class="gb_Rc">Főmenü</div></div>

# %% [markdown]
# ## Munkafolyamat egy előkészített mintán

# %%
g = open("sample_google_news.html", "r", encoding="utf-8")
soup = bs(g, "html.parser")

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="hu">
# <head>
# <base href="https://news.google.com/"/>
# <link href="//www.gstatic.com" ref="preconnect"/>
# <meta content="origin" name="referrer"/>
# <link href="https://news.google.com/home" rel="canonical"/>
# <meta content="width=device-width,initial-scale=1,minimal-ui" name="viewport"/>
# <meta content="AcBy5YFny2HQgVUCR18tO5YUTf6MpVlcJqGTd-a9-SI" name="google-site-verification"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="Hírek" name="application-name"/>
# <meta content="Hírek" name="apple-mobile-web-app-title"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="white" name="theme-color"/>
# <meta content="no" name="msapplication-tap-highlight"/>
# <link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w16" rel="shortcut icon" sizes="16x16"/>
# <link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w24" rel="shortcut icon" sizes="24x24"/>
# <link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w32" rel="shortcut icon" sizes="32x32"/>
# <link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w48" rel="shortcut icon" sizes="48x48"/>
# <link href="//www.gstatic.com" rel="preconnect"/>
# <link href="//fonts.gstatic.com" rel="preconnect"/>
# <link href="//lh3.googleusercontent.com" rel="preconnect"/>
# <link href="//lh4.googleusercontent.com" rel="preconnect"/>
# <link href="//lh5.googleusercontent.com" rel="preconnect"/>
# <link href="//lh6.googleusercontent.com" rel="preconnect"/>
# <link href="//ssl.gstatic.com" rel="preconnect"/>
# <link href="https://www.google-analytics.com/analytics.js" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css?family=Google+Sans+Text:400,500,700,400i,500i,700i" rel="stylesheet"/>
# <link crossorigin="use-credentials" href="_/DotsSplashUi/manifest.json" rel="manifest"/>
# <link href="/?lfhs=2" rel="home"/>
# <link href="/?lfhs=2" rel="msapplication-starturl"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="icon" sizes="192x192"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="apple-touch-icon-precomposed" sizes="192x192"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="msapplication-square192x192logo" sizes="192x192"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="icon" sizes="512x512"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="apple-touch-icon-precomposed" sizes="512x512"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="msapplication-square512x512logo" sizes="512x512"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="icon" sizes="1024x1024"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="apple-touch-icon-precomposed" sizes="1024x1024"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="msapplication-square1024x1024logo" sizes="1024x1024"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="icon" sizes="120x120"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="msapplication-square120x120logo" sizes="120x120"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="icon" sizes="152x152"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="msapplication-square152x152logo" sizes="152x152"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="icon" sizes="167x167"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="apple-touch-icon-precomposed" sizes="167x167"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="msapplication-square167x167logo" sizes="167x167"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_180.png" rel="icon" sizes="180x180"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_180.png" rel="msapplication-square180x180logo" sizes="180x180"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_80.png" rel="icon" sizes="80x80"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_80.png" rel="apple-touch-icon-precomposed" sizes="80x80"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_80.png" rel="msapplication-square80x80logo" sizes="80x80"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_87.png" rel="icon" sizes="87x87"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_87.png" rel="apple-touch-icon-precomposed" sizes="87x87"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_87.png" rel="msapplication-square87x87logo" sizes="87x87"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_58.png" rel="icon" sizes="58x58"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_58.png" rel="apple-touch-icon-precomposed" sizes="58x58"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_58.png" rel="msapplication-square58x58logo" sizes="58x58"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_60.png" rel="icon" sizes="60x60"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_60.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_60.png" rel="msapplication-square60x60logo" sizes="60x60"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_40.png" rel="icon" sizes="40x40"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_40.png" rel="apple-touch-icon-precomposed" sizes="40x40"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_40.png" rel="msapplication-square40x40logo" sizes="40x40"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="apple-touch-startup-image" sizes="192x192"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="apple-touch-startup-image" sizes="512x512"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="apple-touch-startup-image" sizes="1024x1024"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="apple-touch-startup-image" sizes="120x120"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="apple-touch-startup-image" sizes="152x152"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="apple-touch-startup-image" sizes="167x167"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_180.png" rel="apple-touch-startup-image" sizes="180x180"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_80.png" rel="apple-touch-startup-image" sizes="80x80"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_87.png" rel="apple-touch-startup-image" sizes="87x87"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_58.png" rel="apple-touch-startup-image" sizes="58x58"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_60.png" rel="apple-touch-startup-image" sizes="60x60"/>
# <link href="//ssl.gstatic.com/gnews/logo/google_news_40.png" rel="apple-touch-startup-image" sizes="40x40"/>
# <script data-id="_gd" nonce="BchWCSuOimYDKipP6iIXOg">
#    window.WIZ_global_data = {"Dftppe":"%.@.]","DpimGf":false,"EP1ykd":["/_/*","/_/SubscribewithgoogleClientUi","/_/SubscribewithgoogleClientUi/*","/__deprecated","/__deprecated/*","/_nm","/_nm/","/_nm/*","/accounts/*","/eval","/eval/*","/swg","/swg/","/swg/*"],"FdrFJe":"6001772353788292909","Fwhl2e":"%.@.[\"hu\",\"HU\",[\"FINANCE_TOP_INDICES\",\"WEB_TEST_1_0_0\"],null,null,1,1,\"HU:hu\",null,null,null,null,null,null,null,false],\"hu\",\"HU\",true,[2,4,8],1,true,\"642987060\",false,false,null,false]","GASP4":1333,"Guyvcf":"/home","Im6cmf":"/_/DotsSplashUi","JgLEj":0,"LVIXXb":1,"LoQv7e":false,"MT7f9b":[],"MZbqOb":"//www.google.com/setprefs?cs\u003d2\u0026sig\u003d0_3hjSH5bforp83NAz_3bDDEOUdNA%3D\u0026prev\u003dhttps://news.google.com/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu\u0026hl\u003dhu","MuJWjd":true,"QrtxK":"","S06Grb":"","S6lZl":116942117,"TSDtV":"%.@.[[null,[[45447431,null,false,null,null,null,\"qrBgi\"],[45447428,300,null,null,null,null,\"wkakMe\"],[45633044,null,false,null,null,null,\"NvNvpf\"],[45623969,null,false,null,null,null,\"nifQxc\"],[45447429,null,false,null,null,null,\"pfipFd\"],[45447425,null,false,null,null,null,\"dH92cf\"],[45447449,null,false,null,null,null,\"J5nTvb\"],[45447448,null,null,null,\"cnn.com\",null,\"i6NW6e\"],[45627087,null,false,null,null,null,\"RMzsWe\"],[45623159,null,false,null,null,null,\"wy2X5d\"],[45459555,null,false,null,null,null,\"Imeoqb\"],[45638852,null,false,null,null,null,\"Bkw72\"],[45447441,null,false,null,null,null,\"lGu6U\"],[45532880,null,false,null,null,null,\"tCJq5e\"],[45620460,null,false,null,null,null,\"nyycsb\"],[45639079,null,false,null,null,null,\"wguzSc\"],[45447447,null,null,null,\"us_2020_elections,us_2020_elections_local_news_with_summary_submix;gemini_briefing_local_v2,gemini_briefing_local_news_with_summary_submix\",null,\"Ia4eSd\"],[45447430,null,true,null,null,null,\"HcBDid\"],[45447451,null,null,null,\"glbl_20_blog,spain_blog,20_web,pol_twitter,spn_twitter\",null,\"AQrj7e\"],[45447438,null,false,null,null,null,\"ZuxVNe\"],[45639080,null,true,null,null,null,\"NC12Hf\"],[45447446,null,null,null,\"114086,117964,122423,123687,126247\",null,\"arpmnf\"],[45447445,10000,null,null,null,null,\"gksIhe\"],[45447439,null,false,null,null,null,\"zufSJe\"],[45447442,null,null,null,\"114086,117964,122423,123687,126247\",null,\"K01E3b\"],[45447443,null,null,null,\"117964,122423\",null,\"wRa13\"],[45639078,null,true,null,null,null,\"yef8ib\"],[45639074,null,false,null,null,null,\"ZGvemd\"],[45447432,null,false,null,null,null,\"xGtuJf\"],[45620815,null,false,null,null,null,\"oY8Nb\"],[45447452,null,null,null,\"\",null,\"iTkiFf\"],[45447444,null,true,null,null,null,\"j1Sd4d\"],[45447427,10000,null,null,null,null,\"IrjXhf\"],[45447453,null,null,null,\"\",null,\"JNfYbb\"]],\"CAMSEB0Jy/nmKwqA+doGCpHtBAo\\u003d\"]]]","UDh4De":"//www.google.com/setprefs?cs\u003d0\u0026sig\u003d0_3hjSH5bforp83NAz_3bDDEOUdNA%3D\u0026prev\u003dhttps://news.google.com/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu\u0026hl\u003dhu","UTVOtf":false,"Vvafkd":false,"Y12zTb":"//www.google.com/setprefs?cs\u003d1\u0026sig\u003d0_3hjSH5bforp83NAz_3bDDEOUdNA%3D\u0026prev\u003dhttps://news.google.com/home?hl%3Dhu%26gl%3DHU%26ceid%3DHU:hu\u0026hl\u003dhu","Yllh3e":"%.@.1718551018059237,150358616,3556978475]","cfb2h":"boq_dotssplashserver_20240611.11_p1","eNnkwf":"1718551018","eptZe":"/_/DotsSplashUi/","fPDxwd":[93880154,97517168,97579925],"gGcLoe":false,"hbSvMb":[97517168,1714259,93894898,97579925,1706538,93880154,48887078,97442195,93874000,97608128,97517154,97579911,93880140,48887064,97442181,93873986,97605796],"iCzhFc":false,"k76Vlc":["G-SYGF1G18MM"],"mc2ogb":1,"nQyAE":{"wkakMe":"300","pfipFd":"false","xGtuJf":"false","IrjXhf":"10000","NvNvpf":"false","zufSJe":"false","dH92cf":"false","i6NW6e":"cnn.com","wRa13":"117964,122423","j1Sd4d":"true","tCJq5e":"false","K01E3b":"114086,117964,122423,123687,126247","JNfYbb":"","RMzsWe":"false","AQrj7e":"glbl_20_blog,spain_blog,20_web,pol_twitter,spn_twitter","gksIhe":"10000","oY8Nb":"f ...
#   </script>
# <script nonce="BchWCSuOimYDKipP6iIXOg">
#    (function(){'use strict';var a=window,d=a.performance,l=k();a.cc_latency_start_time=d&&d.now?0:d&&d.timing&&d.timing.navigationStart?d.timing.navigationStart:l;function k(){return d&&d.now?d.now():(new Date).getTime()}function n(e){if(d&&d.now&&d.mark){var g=d.mark(e);if(g)return g.startTime;if(d.getEntriesByName&&(e=d.getEntriesByName(e).pop()))return e.startTime}return k()}a.onaft=function(){n("aft")};a._isLazyImage=function(e){return e.hasAttribute("data-src")||e.hasAttribute("data-ils")||e.getAttribute("loading")==="lazy"};
# a.l=function(e){function g(b){var c={};c[b]=k();a.cc_latency.push(c)}function m(b){var c=n("iml");b.setAttribute("data-iml",c);return c}a.cc_aid=e;a.iml_start=a.cc_latency_start_time;a.css_size=0;a.cc_latency=[];a.ccTick=g;a.onJsLoad=function(){g("jsl")};a.onCssLoad=function(){g("cssl")};a._isVisible=function(b,c){if(!c||c.style.display=="none")return!1;var f=b.defaultView;if(f&&f.getComputedStyle&&(f=f.getComputedStyle(c),f.height=="0px"||f.width=="0px"||f.visibility=="hidden"))return!1;if(!c.getBoundingClientRect)return!0;
# var h=c.getBoundingClientRect();c=h.left+a.pageXOffset;f=h.top+a.pageYOffset;if(f+h.height<0||c+h.width<0||h.height<=0||h.width<=0)return!1;b=b.documentElement;return f<=(a.innerHeight||b.clientHeight)&&c<=(a.innerWidth||b.clientWidth)};a._recordImlEl=m;document.documentElement.addEventListener("load",function(b){b=b.target;var c;b.tagName!="IMG"||b.hasAttribute("data-iid")||a._isLazyImage(b)||b.hasAttribute("data-noaft")||(c=m(b));if(a.aft_counter&&(b=a.aft_counter.indexOf(b),b!==-1&&(b=a.aft_counter.splice(b,
# 1).length===1,a.aft_counter.length===0&&b&&c)))a.onaft(c)},!0);a.prt=-1;a.wiz_tick=function(){var b=n("prt");a.prt=b}};}).call(this);
# l('lszMMd')
#   </script>
# <script nonce="BchWCSuOimYDKipP6iIXOg">
#    var _F_cssRowKey = 'boq-dots.DotsSplashUi_desktop_ms.KaIGLacVYjs.L.W.O';var _F_combinedSignature = 'ALs0n2M3IOdMC0XBbmGcNkJP3V2mM80Pyw';function _DumpException(e) {throw e;}
#   </script>
# <style data-href="https://www.gstatic.com/_/mss/boq-dots/_/ss/k=boq-dots.DotsSplashUi_desktop_ms.KaIGLacVYjs.L.W.O/am=CEAgAIPOAgMwAg/d=1/ed=1/rs=ALs0n2OdsOPDzMber237yw4dwdjA_D7iFQ/m=homeview,_b,_tp" nonce="flkcLndc3ghdmwagi608TA">
#    html,body{height:100%;overflow:hidden}body{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;color:rgba(0,0,0,.87);font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif;margin:0;-webkit-text-size-adjust:100%;text-size-adjust:100%}textarea{font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif}a{text-decoration:none;color:#2962ff}img{border:none}*{-webkit-tap-highlight-color:transparent}#apps-debug-tracers{display:none}@media all{body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-webkit-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-moz-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-ms-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::placeholder{color:#bdc1c6}}@media all{body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder{color:#bdc1c6}}@media all{body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::-webkit-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::-moz-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::-ms-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::placeholder{color:rgba(232,234,237,.38)}}@media all{body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder{color:rgba(232,234,237,.38)}}@media screen and (forced-colors:active),(-ms-high-contrast:active){body.dm7YTc .Y5O54e .VfPpkd-StrnGf-rymPhb .VfPpkd-StrnGf-rymPhb-ibnC6b-OWXEXe-OWB6Me .VfPpkd-StrnGf-rymPhb-b9t22c,body.dm7YTc .Y5O54e .VfPpkd-StrnGf-rymPhb .VfPpkd-StrnGf-rymPhb-ibnC6b-OWXEXe-OWB6Me .VfPpkd-StrnGf-rymPhb-fpDzbe-fmcmS,body.dm7YTc .Y5O54e .VfPpkd-StrnGf-rymPhb .VfPpkd-StrnGf-rymPhb-ibnC6b-OWXEXe-OWB6Me .VfPpkd-StrnGf-rymPhb-L8ivfd-fmcmS{color:GrayText}body.dm7YTc .Y5O54e .VfPpkd-StrnGf-rymPhb .VfPpkd-StrnGf-rymPhb-ibnC6b-OWXEXe-OWB6Me .VfPpkd-StrnGf-rymPhb-b9t22c{opacity:1}}@media all{body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-webkit-input-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-moz-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-ms-input-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::placeholder{color:#bdc1c6;color:var(--gm-outlinedtextfield-placeholder-color,#bdc1c6)}}@media all{body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder{color:#bdc1c6;color:var(--gm-outlinedtextfield-placeholder-color,#bdc1c6)}}@media all{body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::-webkit-input-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::-moz-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::-ms-input-placeholder,body.dm7YTc .NGdKgb .Vf ...
#   </style>
# <script nonce="BchWCSuOimYDKipP6iIXOg">
#    onCssLoad();
#   </script>
# <style nonce="flkcLndc3ghdmwagi608TA">
#    @font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu7GxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fChc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfChc9.ttf)format('truetype');}@font-face{font-family:'Material Icons Extended';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/materialiconsextended/v151/kJEjBvgX7BgnkSrUwT8UnLVc38YydejYY-oE_LvM.ttf)format('truetype');}.material-icons-extended{font-family:'Material Icons Extended';font-weight:normal;font-style:normal;font-size:24px;line-height:1;letter-spacing:normal;text-transform:none;display:inline-block;white-space:nowrap;word-wrap:normal;direction:ltr;}@font-face{font-family:'Google Material Icons';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/googlematerialicons/v141/Gw6kwdfw6UnXLJCcmafZyFRXb3BL9rvi0QZG3g.otf)format('opentype');}.google-material-icons{font-family:'Google Material Icons';font-weight:normal;font-style:normal;font-size:24px;line-height:1;letter-spacing:normal;text-transform:none;display:inline-block;white-space:nowrap;word-wrap:normal;direction:ltr;}@font-face{font-family:'Product Sans';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/productsans/v9/pxiDypQkot1TnFhsFMOfGShVGdeL.ttf)format('truetype');}@font-face{font-family:'Google Sans';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/googlesans/v58/4Ua_rENHsxJlGDuGo1OIlJfC6l_24rlCK1Yo_Iqcsih3SAyH6cAwhWdRFD48TE63OOYKtrwEIJlrpyw.ttf)format('truetype');}@font-face{font-family:'Google Sans';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/googlesans/v58/4Ua_rENHsxJlGDuGo1OIlJfC6l_24rlCK1Yo_Iqcsih3SAyH6cAwhX9RFD48TE63OOYKtrwEIJlrpyw.ttf)format('truetype');}@font-face{font-family:'Google Sans';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/googlesans/v58/4Ua_rENHsxJlGDuGo1OIlJfC6l_24rlCK1Yo_Iqcsih3SAyH6cAwhWdRFD48TE63OOYKtrw2IJlrpyw.ttf)format('truetype');}@font-face{font-family:'Google Sans';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/googlesans/v58/4Ua_rENHsxJlGDuGo1OIlJfC6l_24rlCK1Yo_Iqcsih3SAyH6cAwhX9RFD48TE63OOYKtrw2IJlrpyw.ttf)format('truetype');}@font-face{font-family:'Google Sans';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/googlesans/v58/4Ua_rENHsxJlGDuGo1OIlJfC6l_24rlCK1Yo_Iqcsih3SAyH6cAwhX9RFD48TE63OOYKtrzjJ5lrpyw.ttf)format('truetype');}@font-face{font-family:'Google Sans Display';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/googlesansdisplay/v13/ea8FacM9Wef3EJPWRrHjgE4B6CnlZxHVDvD9pA.ttf)format('truetype');}
#   </style>
# <script nonce="BchWCSuOimYDKipP6iIXOg">
#    (function(){'use strict';function d(){var a=g,b=0;return function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}}};/*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# var k=this||self;/*
#
#  Copyright 2024 Google, Inc
#  SPDX-License-Identifier: MIT
# */
# var l=["focus","blur","error","load","toggle"];function m(a){return a==="mouseenter"?"mouseover":a==="mouseleave"?"mouseout":a==="pointerenter"?"pointerover":a==="pointerleave"?"pointerout":a};function n(a){this.l={};this.m={};this.i=null;this.g=[];this.o=a}n.prototype.handleEvent=function(a,b,c){q(this,{eventType:a,event:b,targetElement:b.target,eic:c,timeStamp:Date.now(),eia:void 0,eirp:void 0,eiack:void 0})};function q(a,b){if(a.i)a.i(b);else{b.eirp=!0;var c;(c=a.g)==null||c.push(b)}}
# function r(a,b,c){if(!(b in a.l)&&a.o){var f=function(e,p,B){a.handleEvent(e,p,B)};a.l[b]=f;c=m(c||b);if(c!==b){var h=a.m[c]||[];h.push(b);a.m[c]=h}a.o.addEventListener(c,function(e){return function(p){f(b,p,e)}});b==="click"&&r(a,"keydown")}}n.prototype.j=function(a){return this.l[a]};n.prototype.ecrd=function(a){this.i=a;var b;if((b=this.g)==null?0:b.length){for(a=0;a<this.g.length;a++)q(this,this.g[a]);this.g=null}};var t=typeof navigator!=="undefined"&&/iPhone|iPad|iPod/.test(navigator.userAgent);function u(a){this.g=a;this.i=[]}u.prototype.addEventListener=function(a,b){t&&(this.g.style.cursor="pointer");var c=this.i,f=c.push,h=this.g;b=b(this.g);var e=!1;l.indexOf(a)>=0&&(e=!0);h.addEventListener(a,b,e);f.call(c,{eventType:a,j:b,capture:e})};var g="click dblclick focus focusin blur error focusout keydown keyup keypress load mouseover mouseout mouseenter mouseleave submit toggle touchstart touchend touchmove touchcancel auxclick change compositionstart compositionupdate compositionend beforeinput input select textinput copy cut paste mousedown mouseup wheel contextmenu dragover dragenter dragleave drop dragstart dragend pointerdown pointermove pointerup pointercancel pointerenter pointerleave pointerover pointerout gotpointercapture lostpointercapture ended loadedmetadata pagehide pageshow visibilitychange beforematch".split(" ");
# if(!(g instanceof Array)){var v;var w=typeof Symbol!="undefined"&&Symbol.iterator&&g[Symbol.iterator];if(w)v=w.call(g);else if(typeof g.length=="number")v={next:d()};else throw Error(String(g)+" is not an iterable or ArrayLike");for(var x,y=[];!(x=v.next()).done;)y.push(x.value)};var z=function(a){return{trigger:function(b){var c=a.j(b.type);c||(r(a,b.type),c=a.j(b.type));var f=b.target||b.srcElement;c&&c(b.type,b,f.ownerDocument.documentElement)},configure:function(b){b(a)}}}(function(){var a=window,b=new u(a.document.documentElement),c=new n(b);g.forEach(function(e){return r(c,e)});var f,h;"onwebkitanimationend"in a&&(f="webkitAnimationEnd");r(c,"animationend",f);"onwebkittransitionend"in a&&(h="webkitTransitionEnd");r(c,"transitionend",h);return{s:c,u:b}}().s),A=["BOQ_wizbind"],
# C=window||k;A[0]in C||typeof C.execScript=="undefined"||C.execScript("var "+A[0]);for(var D;A.length&&(D=A.shift());)A.length||z===void 0?C[D]&&C[D]!==Object.prototype[D]?C=C[D]:C=C[D]={}:C[D]=z;}).call(this);
#   </script>
# <script href="https://www.gstatic.com/_/mss/boq-dots/_/js/k=boq-dots.DotsSplashUi_desktop_ms.hu.xuZWU8BTLco.es5.O/am=CEAgAIPOAgMwAg/d=1/excm=_b,_tp,homeview/ed=1/dg=0/wt=2/ujg=1/rs=ALs0n2M6A1tZV3qBslhLI_Ze5vSN8WX7lw/m=_b,_tp" id="base-js" nocollect="" nonce="BchWCSuOimYDKipP6iIXOg">
#    "use strict";this.default_DotsSplashUi_desktop_ms=this.default_DotsSplashUi_desktop_ms||{};(function(_){var window=this;
# try{
# _._F_toggles_initialize=function(a){(typeof globalThis!=="undefined"?globalThis:typeof self!=="undefined"?self:this)._F_toggles=a||[]};(0,_._F_toggles_initialize)([0x204008, 0xc0b3a0c, 0x2300, ]);
# /*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  Copyright 2024 Google, Inc
#  SPDX-License-Identifier: MIT
# */
# var baa,caa,La,gaa,Ua,Wa,haa,iaa,hb,jb,oaa,xb,Db,vaa,Zb,$b,ac,bc,gc,yaa,ic,Baa,Faa,Gaa,xc,Vc,Laa,Maa,Kaa,Oaa,Raa,Qaa,Saa,Taa,Uaa,Xaa,Yaa,$aa,aba,sd,yd,cba,rd,td,hd,iba,Nd,lba,pba,qba,tba,je,ne,yba,Aba,Bba,Cba,Eba,Fba,Jba,Lba,Mba,Pba,Xba,Tba,$ba,ff,bca,cca,eca,uf,kca,lca,Af,Gf,mca,nca,oca,pca,Kf,qca,rca,sca,Rf,Sf,yca,Aca,Bca,Cca,Dca,Eca,Gca,Hca,Lca,aaa,Mca,vg,Nca,xg,Oca,zg,Bg,Pca,Eg,Fg,Gg,Vca,Wca,Og,Pg,Xca,Yca;_.aa=function(a){return function(){return aaa[a].apply(this,arguments)}};
# _.ba=function(a,b){return aaa[a]=b};_.da=function(a){_.ca.setTimeout(function(){throw a;},0)};_.fa=function(a){a&&typeof a.dispose=="function"&&a.dispose()};baa=function(a){for(var b=0,c=arguments.length;b<c;++b){var d=arguments[b];_.ha(d)?baa.apply(null,d):_.fa(d)}};_.ia=function(a,b){if(Error.captureStackTrace)Error.captureStackTrace(this,_.ia);else{var c=Error().stack;c&&(this.stack=c)}a&&(this.message=String(a));b!==void 0&&(this.cause=b);this.o=!0};_.ka=function(a){return a[a.length-1]};
# _.la=function(a,b,c){for(var d=typeof a==="string"?a.split(""):a,e=a.length-1;e>=0;--e)e in d&&b.call(c,d[e],e,a)};_.na=function(a,b,c){b=_.ma(a,b,c);return b<0?null:typeof a==="string"?a.charAt(b):a[b]};_.ma=function(a,b,c){for(var d=a.length,e=typeof a==="string"?a.split(""):a,f=0;f<d;f++)if(f in e&&b.call(c,e[f],f,a))return f;return-1};_.oa=function(a,b){for(var c=typeof a==="string"?a.split(""):a,d=a.length-1;d>=0;d--)if(d in c&&b.call(void 0,c[d],d,a))return d;return-1};
# _.sa=function(a,b){return(0,_.ra)(a,b)>=0};_.ta=function(a,b){_.sa(a,b)||a.push(b)};_.va=function(a,b){b=(0,_.ra)(a,b);var c;(c=b>=0)&&_.ua(a,b);return c};_.ua=function(a,b){return Array.prototype.splice.call(a,b,1).length==1};_.wa=function(a){return Array.prototype.concat.apply([],arguments)};_.ya=function(a){var b=a.length;if(b>0){for(var c=Array(b),d=0;d<b;d++)c[d]=a[d];return c}return[]};
# _.za=function(a,b){for(var c=1;c<arguments.length;c++){var d=arguments[c];if(_.ha(d)){var e=a.length||0,f=d.length||0;a.length=e+f;for(var g=0;g<f;g++)a[e+g]=d[g]}else a.push(d)}};_.Aa=function(a,b,c){return arguments.length<=2?Array.prototype.slice.call(a,b):Array.prototype.slice.call(a,b,c)};_.Da=function(a,b){b=b||a;for(var c=0,d=0,e={};d<a.length;){var f=a[d++],g=_.Ba(f)?"o"+_.Ca(f):(typeof f).charAt(0)+f;Object.prototype.hasOwnProperty.call(e,g)||(e[g]=!0,b[c++]=f)}b.length=c};
# _.Ga=function(a,b){a.sort(b||_.Ea)};_.Ha=function(a,b){if(!_.ha(a)||!_.ha(b)||a.length!=b.length)return!1;for(var c=a.length,d=caa,e=0;e<c;e++)if(!d(a[e],b[e]))return!1;return!0};_.Ea=function(a,b){return a>b?1:a<b?-1:0};caa=function(a,b){return a===b};_.daa=function(a,b){var c={};(0,_.Ia)(a,function(d,e){c[b.call(void 0,d,e,a)]=d});return c};La=function(a){_.Ja?a(_.Ja):Ka.push(a)};_.Oa=function(){!_.Ja&&_.Ma&&_.Na((0,_.Ma)());return _.Ja};
# _.Na=function(a){_.Ja=a;Ka.forEach(function(b){b(_.Ja)});Ka=[]};_.m=function(a){_.Ja&&eaa(a)};_.t=function(){_.Ja&&faa(_.Ja)};gaa=function(){};_.Pa=function(){var a=_.ca.navigator;return a&&(a=a.userAgent)?a:""};Ua=function(a){return Qa?Ra?Ra.brands.some(function(b){return(b=b.brand)&&_.Sa(b,a)}):!1:!1};_.Va=function(a){return _.Sa(_.Pa(),a)};Wa=function(){return Qa?!!Ra&&Ra.brands.length>0:!1};_.Xa=function(){return Wa()?!1:_.Va("Opera")};_.Ya=function(){return Wa()?!1:_.Va("Trident")||_.Va("MSIE")};
# _.Za=function(){return Wa()?!1:_.Va("Edge")};_.$a=function(){return Wa()?Ua("Microsoft Edge"):_.Va("Edg/")};_.ab=function(){return Wa()?Ua("Opera"):_.Va("OPR")};_.bb=function(){return _.Va("Firefox")||_.Va("FxiOS")};_.eb=function(){return _.Va("Safari")&&!(_.cb()||_.db()||_.Xa()||_.Za()||_.$a()||_.ab()||_.bb()||_.Va("Silk")||_.Va("Android"))};_.db=function(){return Wa()?!1:_.Va("Coast")};_.cb=function(){return Wa()?Ua("Chromium"):(_.Va("Chrome")||_.Va("CriOS"))&&!_.Za()||_.Va("Silk")};
# _.fb=function(){return _.Va("Android")&&!(_.cb()||_.bb()||_.Xa()||_.Va("Silk"))};haa=function(a){var b={};a.forEach(function(c){b[c[0]]=c[1]});return function(c){return b[c.find(function(d){return d in b})]||""}};
# iaa=function(a){var b=_.Pa();if(a==="Internet Explorer"){if(_.Ya())if((a=/rv: *([\d\.]*)/.exec(b))&&a[1])b=a[1];else{a="";var c=/MSIE +([\d\.]+)/.exec(b);if(c&&c[1])if(b=/Trident\/(\d.\d)/.exec(b),c[1]=="7.0")if(b&&b[1])switch(b[1]){case "4.0":a="8.0";break;case "5.0":a="9.0";break;case "6.0":a="10.0";break;case "7.0":a="11.0"}else a="7.0";else a=c[1];b=a}else b="";return b}var d=RegExp("([A-Z][\\w ]+)/([^\\s]+)\\s*(?:\\((.*?)\\))?","g");c=[];for(var e;e=d.exec(b);)c.push([e[1],e[2],e[3]||void 0]);
# b=haa(c);switch(a){case "Opera":if(_.Xa())return b(["Version","Opera"]);if(_.ab())return b(["OPR"]);break;case "Microsoft Edge":if(_.Za())return b(["Edge"]);if(_.$a())return b(["Edg"]);break;case "Chromium":if(_.cb())return b(["Chrome","CriOS","HeadlessChrome"])}return a==="Firefox"&&_.bb()||a==="Safari"&&_.eb()||a==="Android Browser"&&_.fb()||a==="Silk"&&_.Va("Silk")?(b=c[2])&&b[1]||"":""};
# _.gb=function(a){if(Wa()&&a!=="Silk"){var b=Ra.brands.find(function(c){return c.brand===a});if(!b||!b.version)return NaN;b=b.version.split(".")}else{b=iaa(a);if(b==="")return NaN;b=b.split(".")}return b.length===0?NaN:Number(b[0])};hb=function(){return Qa?!!Ra&&!!Ra.platform:!1};_.ib=function(){return hb()?Ra.platform==="Android":_.Va("Android")};jb=function(){return _.Va("iPhone")&&!_.Va("iPod")&&!_.Va("iPad")};_.kb=function(){return jb()||_.Va("iPad")||_.Va("iPod")};
# _.mb=function(){return hb()?Ra.platform==="macOS":_.Va("Macintosh")};_.jaa=function(){return hb()?Ra.platform==="Windows":_.Va("Windows")};_.kaa=function(){return hb()?Ra.platform==="Chrome OS":_.Va("CrOS")};_.nb=function(a,b,c){for(var d in a)b.call(c,a[d],d,a)};_.ob=function(a,b){var c={},d;for(d in a)b.call(void 0,a[d],d,a)&&(c[d]=a[d]);return c};_.pb=function(a,b,c){var d={},e;for(e in a)d[e]=b.call(c,a[e],e,a);return d};_.laa=function(a){var b=0,c;for(c in a)b++;return b};_.maa=function(a){for(var b in a)return a[b]};
# _.rb=function(a){var b=[],c=0,d;for(d in a)b[c++]=a[d];return b};_.sb=function(a){var b=[],c=0,d;for(d in a)b[c++]=d;return b};_.ub=function(a){for(var b in a)return!1;return!0};_.vb=function(a){var b={},c;for(c in a)b[c]=a[c];return b};_.wb=function(a,b){for(var c,d,e=1;e<arguments.length;e++){d=arguments[e];for(c in d)a[c]=d[c];for(var f=0;f<naa.length;f++)c=naa[f],Object.prototype.hasOwnProperty.call(d,c)&&(a[c]=d[c])}};
# oaa=function(a){var b=arguments.length;if(b==1&&Array.isArray(arguments[0]))return oaa.apply(null,arguments[0]);for(var c={},d=0;d<b;d++)c[arguments[d]]=!0;return c};xb=function(a){return a.toString().indexOf("`")===-1};_.zb=function(a){if(a instanceof _.yb)return a.j;throw Error("D");};Db=function(a){return new Bb(function(b){return b.substr(0,a.length+1).toLowerCase()===a+":"})};
# _.Eb=function(a,b){b=b===void 0?paa:b;if(a instanceof _.yb)return a;for(var c=0;c<b.length;++c){var d=b[c];if(d instanceof Bb&&d.oe(a))return new _.yb(a)}};_.Gb=function(a){var b=b===void 0?paa:b;return _.Eb(a,b)||_.Fb};_.Hb=function(a){a instanceof _.yb?a=_.zb(a):a=qaa.test(a)?a:void 0;return a};_.Jb=function(a){return new _.Ib(a[0].toLowerCase())};
# _.Nb=function(a){var b=_.Kb.apply(1,arguments);if(b.length===0)return _.Lb(a[0]);for(var c=a[0],d=0;d<b.length;d++)c+=encodeURIComponent(b[d])+a[d+1];return _.Lb(c)};_.Pb=function(a,b){b=_.Hb(b);b!==void 0&&(a.href=b)};_.Sb=function(a,b,c){if(b instanceof _.Qb)a.href=_.Rb(b).toString();else{if(raa.indexOf(c)===-1)throw Error("H`"+c);b=_.Hb(b);if(b===void 0)return;a.href=b}a.rel=c};
# _.Tb=function(a,b){var c,d;return(b=(d=(c=b.document).querySelector)==null?void 0:d.call(c,a+"[nonce]"))?b.nonce||b.getAttribute("nonce")||"":""};_.saa=function(a){var b=_.Tb("script",a.ownerDocument&&a.ownerDocument.defaultView||window);b&&a.setAttribute("nonce",b)};_.Ub=function(a,b){a.src=_.Rb(b);_.saa(a)};_.Vb=function(){var a=Error();taa(a,"incident");_.da(a)};_.Wb=function(a){a=Error(a);taa(a,"warning");return a};
# vaa=function(a){if(!_.uaa)return _.Xb(a);for(var b="",c=0,d=a.length-10240;c<d;)b+=String.fromCharCode.apply(null,a.subarray(c,c+=10240));b+=String.fromCharCode.apply(null,c?a.subarray(c):a);return btoa(b)};_.Yb=function(a){return waa&&a!=null&&a instanceof Uint8Array};Zb=function(){return typeof BigInt==="function"};$b=function(a){return Array.prototype.slice.call(a)};ac=function(a){return typeof Symbol==="function"&&typeof Symbol()==="symbol"?Symbol():a};bc=function(a,b,c){return c?a|b:a&~b};
# _.ec=function(a){return!!((0,_.cc)(a)&2)};gc=function(a){(0,_.fc)(a,34);return a};_.xaa=function(a){(0,_.fc)(a,32);return a};yaa=function(a,b){(0,_.hc)(b,(a|0)&-14591)};ic=function(a,b){(0,_.hc)(b,(a|34)&-14557)};_.jc=function(a){a=a>>14&1023;return a===0?536870912:a};_.kc=function(a){return+!!(a&512)-1};_.lc=function(a){return a.FX===zaa};Baa=function(a){return!(!a||typeof a!=="object"||a.j!==Aaa)};_.mc=function(a){return a!==null&&typeof a==="object"&&!Array.isArray(a)&&a.constructor===Object};
# _.qc=function(a,b,c,d){if(a==null){if(!c)throw Error();}else if(typeof a==="string")a=a?new _.nc(a,_.oc):_.pc();else if(a.constructor!==_.nc)if(_.Yb(a))a=a.length?new _.nc(d?a:new Uint8Array(a),_.oc):_.pc();else{if(!b)throw Error();a=void 0}return a};_.Caa=function(a,b){return!!a&&(Array.isArray(a)?a.includes(b):a.has(b))};_.sc=function(a,b,c){if(!Array.isArray(a)||a.length)return!1;var d=(0,_.cc)(a);if(d&1)return!0;if(!_.Caa(b,c))return!1;(0,_.hc)(a,d|1);return!0};
# _.tc=function(a){if(a&2)throw Error();};_.uc=function(a){if(!Daa)return a.constructor.Ua};_.wc=function(a,b,c){(b=_.vc?b[_.vc]:void 0)?a[_.vc]=$b(b):c&&_.vc&&_.vc in a&&(a[_.vc]=void 0)};_.Ac=function(a){var b=a<0;a=Math.abs(a);var c=a>>>0;a=Math.floor((a-c)/4294967296);b&&(c=_.v(xc(c,a)),b=c.next().value,a=c.next().value,c=b);_.yc=c>>>0;_.zc=a>>>0};_.Eaa=function(a,b){var c=b&2147483648;c&&(a=~a+1>>>0,b=~b>>>0,a==0&&(b=b+1>>>0));a=b*4294967296+(a>>>0);return c?-a:a};
# _.Bc=function(a,b){b>>>=0;a>>>=0;if(b<=2097151)var c=""+(4294967296*b+a);else Zb()?c=""+(BigInt(b)<<BigInt(32)|BigInt(a)):(c=(a>>>24|b<<8)&16777215,b=b>>16&65535,a=(a&16777215)+c*6777216+b*6710656,c+=b*8147497,b*=2,a>=1E7&&(c+=Math.floor(a/1E7),a%=1E7),c>=1E7&&(b+=Math.floor(c/1E7),c%=1E7),c=b+Faa(c)+Faa(a));return c};Faa=function(a){a=String(a);return"0000000".slice(a.length)+a};
# Gaa=function(){var a=_.yc,b=_.zc;b&2147483648?Zb()?a=""+(BigInt(b|0)<<BigInt(32)|BigInt(a>>>0)):(b=_.v(xc(a,b)),a=b.next().value,b=b.next().value,a="-"+_.Bc(a,b)):a=_.Bc(a,b);return a};
# _.Cc=function(a){if(a.length<16)_.Ac(Number(a));else if(Zb())a=BigInt(a),_.yc=Number(a&BigInt(4294967295))>>>0,_.zc=Number(a>>BigInt(32)&BigInt(4294967295));else{var b=+(a[0]==="-");_.zc=_.yc=0;for(var c=a.length,d=b,e=(c-b)%6+b;e<=c;d=e,e+=6)d=Number(a.slice(d,e)),_.zc*=1E6,_.yc=_.yc*1E6+d,_.yc>=4294967296&&(_.zc+=Math.trunc(_.yc/4294967296),_.zc>>>=0,_.yc>>>=0);b&&(b=_.v(xc(_.yc,_.zc)),a=b.next().value,b=b.next().value,_.yc=a,_.zc=b)}};xc=function(a,b){b=~b;a?a=~a+1:b+=1;return[a,b]};
# _.Dc=function(a){if(a!=null&&typeof a!=="number")throw Error("S`"+typeof a+"`"+a);return a};_.Ec=function(a){if(a!=null&&typeof a!=="boolean")throw Error("T`"+Haa(a)+"`"+a);return a};_.Iaa=function(a){if(a==null||typeof a==="boolean")return a;if(typeof a==="number")return!!a};_.Fc=function(a){var b=typeof a;return b==="number"?Number.isFinite(a):b!=="string"?!1:Jaa.test(a)};_.Gc=function(a){if(!Number.isFinite(a))throw _.Wb("enum");return a|0};
# _.Jc=function(a){return a==null?a:Number.isFinite(a)?a|0:void 0};_.Lc=function(a){if(typeof a!=="number")throw _.Wb("int32");if(!Number.isFinite(a))throw _.Wb("int32");return a|0};_.Nc=function(a){return a==null?a:_.Lc(a)};_.Pc=function(a){if(a==null)return a;if(typeof a==="string"){if(!a)return;a=+a}if(typeof a==="number")return Number.isFinite(a)?a|0:void 0};_.Qc=function(a){if(typeof a!=="number")throw _.Wb("uint32");if(!Number.isFinite(a))throw _.Wb("uint32");return a>>>0};
# _.Rc=function(a){if(a==null)return a;if(typeof a==="string"){if(!a)return;a=+a}if(typeof a==="number")return Number.isFinite(a)?a>>>0:void 0};_.Uc=function(a){if(a!=null){var b=!!b;if(!_.Fc(a))throw _.Wb("int64");a=typeof a==="string"?_.Sc(a):b?Kaa(a):_.Tc(a)}return a};Vc=function(a){return a[0]==="-"?!1:a.length<20?!0:a.length===20&&Number(a.substring(0,6))<184467};
# Laa=function(a){return a[0]==="-"?a.length<20?!0:a.length===20&&Number(a.substring(0,7))>-922337:a.length<19?!0:a.length===19&&Number(a.substring(0,6))<922337};Maa=function(a){if(a<0){_.Ac(a);var b=_.Bc(_.yc,_.zc);a=Number(b);return Number.isSafeInteger(a)?a:b}if(Vc(String(a)))return a;_.Ac(a);return _.zc*4294967296+(_.yc>>>0)};_.Tc=function(a){a=Math.trunc(a);Number.isSafeInteger(a)||(_.Ac(a),a=_.Eaa(_.yc,_.zc));return a};_.Wc=function(a){a=Math.trunc(a);return a>=0&&Number.isSafeInteger(a)?a:Maa(a)};
# Kaa=function(a){a=Math.trunc(a);if(Number.isSafeInteger(a))a=String(a);else{var b=String(a);Laa(b)?a=b:(_.Ac(a),a=Gaa())}return a};_.Naa=function(a){a=Math.trunc(a);if(a>=0&&Number.isSafeInteger(a))a=String(a);else{var b=String(a);Vc(b)?a=b:(_.Ac(a),a=_.Bc(_.yc,_.zc))}return a};_.Sc=function(a){var b=Math.trunc(Number(a));if(Number.isSafeInteger(b))return String(b);b=a.indexOf(".");b!==-1&&(a=a.substring(0,b));Laa(a)||(_.Cc(a),a=Gaa());return a};
# _.Xc=function(a){var b=Math.trunc(Number(a));if(Number.isSafeInteger(b)&&b>=0)return String(b);b=a.indexOf(".");b!==-1&&(a=a.substring(0,b));Vc(a)||(_.Cc(a),a=_.Bc(_.yc,_.zc));return a};_.Yc=function(a,b){b=b===void 0?!1:b;if(a==null)return a;if(_.Fc(a))return typeof a==="string"?_.Sc(a):b?Kaa(a):_.Tc(a)};_.Zc=function(a){if(typeof a!=="string")throw Error();return a};_.ad=function(a){if(a!=null&&typeof a!=="string")throw Error();return a};Oaa=function(a){return a==null||typeof a==="string"?a:void 0};
# _.cd=function(a,b,c,d){if(a!=null&&typeof a==="object"&&_.lc(a))return a;if(!Array.isArray(a))return c?d&2?_.bd(b):new b:void 0;var e=c=(0,_.cc)(a);e===0&&(e|=d&32);e|=d&2;e!==c&&(0,_.hc)(a,e);return new b(a)};_.bd=function(a){var b=a[Paa];if(b)return b;b=new a;gc(b.ma);return a[Paa]=b};_.ed=function(a,b){dd=b;a=new a(b);dd=void 0;return a};
# _.w=function(a,b,c){a==null&&(a=dd);dd=void 0;if(a==null){var d=96;c?(a=[c],d|=512):a=[];b&&(d=d&-16760833|(b&1023)<<14)}else{if(!Array.isArray(a))throw Error("U");d=(0,_.cc)(a);if(d&2048)throw Error("V");if(d&64)return a;d|=64;if(c&&(d|=512,c!==a[0]))throw Error("W");a:{c=a;var e=c.length;if(e){var f=e-1;if(_.mc(c[f])){d|=256;b=f-_.kc(d);if(b>=1024)throw Error("X");d=d&-16760833|(b&1023)<<14;break a}}if(b){b=Math.max(b,e-_.kc(d));if(b>1024)throw Error("Y");d=d&-16760833|(b&1023)<<14}}}(0,_.hc)(a,
# d);return a};Raa=function(a,b){return Qaa(b)};Qaa=function(a){switch(typeof a){case "number":return isFinite(a)?a:String(a);case "boolean":return a?1:0;case "object":if(a)if(Array.isArray(a)){if(_.sc(a,void 0,0))return}else{if(_.Yb(a))return vaa(a);if(a instanceof _.nc)return _.fd(a)}}return a};Saa=function(a,b,c){var d=$b(a),e=d.length,f=b&256?d[e-1]:void 0;e+=f?-1:0;for(b=b&512?1:0;b<e;b++)d[b]=c(d[b]);if(f){b=d[b]={};for(var g in f)b[g]=c(f[g])}_.wc(d,a,!1);return d};
# Taa=function(a,b,c,d,e){if(a!=null){if(Array.isArray(a))a=_.sc(a,void 0,0)?void 0:e&&(0,_.cc)(a)&2?a:_.gd(a,b,c,d!==void 0,e);else if(_.mc(a)){var f={},g;for(g in a)f[g]=Taa(a[g],b,c,d,e);a=f}else a=b(a,d);return a}};_.gd=function(a,b,c,d,e){var f=d||c?(0,_.cc)(a):0;d=d?!!(f&32):void 0;for(var g=$b(a),k=0;k<g.length;k++)g[k]=Taa(g[k],b,c,d,e);c&&(_.wc(g,a,!1),c(f,g));return g};
# Uaa=function(a){_.lc(a)?a=hd(a,_.gd(a.ma,Uaa,void 0,void 0,!1),!0):a instanceof _.nc?(a=a.j||"",a=typeof a==="string"?a:new Uint8Array(a)):a=_.Yb(a)?new Uint8Array(a):a;return a};_.Vaa=function(a){return _.lc(a)?a.toJSON():Qaa(a)};
# _.id=function(a,b,c){c=c===void 0?ic:c;if(a!=null){if(waa&&a instanceof Uint8Array)return b?a:new Uint8Array(a);if(Array.isArray(a)){var d=(0,_.cc)(a);d&2||(b&&(b=d===0||!!(d&32)&&!(d&64||!(d&16))),a=b?(0,_.hc)(a,(d|34)&-12293):_.gd(a,_.id,d&4?ic:c,!0,!0));return a}_.lc(a)&&(c=a.ma,d=(0,_.jd)(c),a=d&2?a:_.ed(a.constructor,_.kd(c,d,!0)));return a}};_.kd=function(a,b,c){var d=c||b&2?ic:yaa,e=!!(b&32);a=Saa(a,b,function(f){return _.id(f,e,d)});(0,_.fc)(a,32|(c?2:0));return a};
# _.ld=function(a){var b=a.ma,c=(0,_.jd)(b);return c&2?_.ed(a.constructor,_.kd(b,c,!1)):a};_.md=function(a){var b=a.ma,c=(0,_.jd)(b);return c&2?a:_.ed(a.constructor,_.kd(b,c,!0))};Xaa=function(a,b,c,d){if(!(4&b))return!0;if(c==null)return!1;!d&&c===0&&(4096&b||8192&b)&&(a.constructor[Waa]=(a.constructor[Waa]|0)+1)<5&&_.Vb();return c===0?!1:!(c&b)};Yaa=function(a,b,c,d){b=d+_.kc(b);if(!(b<0||b>=a.length||b>=c))return a[b]};
# _.nd=function(a,b,c,d,e){var f=_.jc(b);if(c>=f||e){var g=b;if(b&256)e=a[a.length-1];else{if(d==null)return g;e=a[f+_.kc(b)]={};g|=256}e[c]=d;c<f&&(a[c+_.kc(b)]=void 0);g!==b&&(0,_.hc)(a,g);return g}a[c+_.kc(b)]=d;b&256&&(a=a[a.length-1],c in a&&delete a[c]);return b};
# _.Zaa=function(a,b,c,d){var e=b&2,f=_.od(a,b,c,d);Array.isArray(f)||(f=_.pd);var g=!!(b&32),k=(0,_.cc)(f);k===0&&g&&!e?(k|=33,(0,_.hc)(f,k)):k&1||(k|=1,(0,_.hc)(f,k));if(e)k&2||gc(f),Object.freeze(f);else if(2&k||2048&k)f=$b(f),e=1,g&&(e|=32),(0,_.hc)(f,e),_.nd(a,b,c,f,d);return f};
# _.ud=function(a,b,c){var d=_.qd(),e=a.ma,f=(0,_.jd)(e);d=2&f?1:d;var g=$aa(e,f,b),k=(0,_.cc)(g);if(Xaa(a,k,void 0,!1)){if(4&k||Object.isFrozen(g))g=$b(g),k=rd(k,f),f=_.nd(e,f,b,g);for(var l=a=0;a<g.length;a++){var n=c(g[a]);n!=null&&(g[l++]=n)}l<a&&(g.length=l);k=aba(k,f);k=bc(k,20,!0);k=bc(k,4096,!1);k=bc(k,8192,!1);(0,_.hc)(g,k);2&k&&Object.freeze(g)}sd(k)||(c=k,k=(a=d===1||d===4&&!!(32&k))?bc(k,2,!0):td(k,f,!1),k!==c&&(0,_.hc)(g,k),a&&Object.freeze(g));d===2&&sd(k)&&(g=$b(g),k=rd(k,f),k=td(k,f,
# !1),(0,_.hc)(g,k),_.nd(e,f,b,g));return g};$aa=function(a,b,c,d){a=_.od(a,b,c,d);return Array.isArray(a)?a:_.pd};aba=function(a,b){a===0&&(a=rd(a,b));return a=bc(a,1,!0)};sd=function(a){return!!(2&a)&&!!(4&a)||!!(2048&a)};
# _.vd=function(a,b,c,d){var e=a.ma,f=(0,_.jd)(e);_.tc(f);if(c==null)return _.nd(e,f,b),a;var g=(0,_.cc)(c),k=g,l=!!(2&g)||Object.isFrozen(c),n=!l&&(void 0===bba||!1);if(Xaa(a,g))for(g=21,l&&(c=$b(c),k=0,g=rd(g,f),g=td(g,f,!0)),l=0;l<c.length;l++)c[l]=d(c[l]);n&&(c=$b(c),k=0,g=rd(g,f),g=td(g,f,!0));g!==k&&(0,_.hc)(c,g);_.nd(e,f,b,c);return a};_.wd=function(a,b,c,d){var e=a.ma,f=(0,_.jd)(e);_.tc(f);_.nd(e,f,b,(d==="0"?Number(c)===0:c===d)?void 0:c);return a};
# yd=function(a,b,c){xd||a in b?b[a]=c:Object.defineProperty(b,a,{value:c,writable:!0})};cba=function(a,b,c){var d=c.ED||(c.ED=ac("o_"+c[0])),e=a[d];if(e!=null)return e&&_.od(a,b,e)==null?(yd(d,a,0),0):e;e=0;for(var f=c.length-1;f>=0;f--){var g=c[f];e===0&&_.od(a,b,g)!=null?e=g:e!==0&&(b=_.nd(a,b,g))}yd(d,a,e);return e};_.zd=function(a,b,c,d){a=a.ma;var e=(0,_.jd)(a),f=_.od(a,e,c,d);b=_.cd(f,b,!1,e);b!==f&&b!=null&&_.nd(a,e,c,b,d);return b};
# _.Ad=function(a,b,c,d,e,f,g,k){var l=!!(2&b);e=l?1:e;g=!!g;k&&(k=!l);l=$aa(a,b,d,f);var n=(0,_.cc)(l),p=!!(4&n);if(!p){n=aba(n,b);var q=l,r=b,u=!!(2&n);u&&(r=bc(r,2,!0));for(var x=!u,y=!0,z=0,G=0;z<q.length;z++){var I=_.cd(q[z],c,!1,r);if(I instanceof c){if(!u){var M=_.ec(I.ma);x&&(x=!M);y&&(y=M)}q[G++]=I}}G<z&&(q.length=G);n=bc(n,4,!0);n=bc(n,16,y);n=bc(n,8,x);(0,_.hc)(q,n);u&&Object.freeze(q)}if(k&&!(8&n||!l.length&&(e===1||e===4&&32&n))){sd(n)&&(l=$b(l),n=rd(n,b),b=_.nd(a,b,d,l,f));c=l;k=n;for(q=
# 0;q<c.length;q++)n=c[q],r=_.ld(n),n!==r&&(c[q]=r);k=bc(k,8,!0);k=bc(k,16,!c.length);(0,_.hc)(c,k);n=k}sd(n)||(c=n,n=(k=e===1||e===4&&!!(32&n))?bc(n,!l.length||16&n&&(!p||32&n)?2:2048,!0):td(n,b,g),n!==c&&(0,_.hc)(l,n),k&&Object.freeze(l));e===2&&sd(n)&&(l=$b(l),n=rd(n,b),n=td(n,b,g),(0,_.hc)(l,n),_.nd(a,b,d,l,f));return l};rd=function(a,b){a=bc(a,2,!!(2&b));a=bc(a,32,!0);return a=bc(a,2048,!1)};td=function(a,b,c){32&b&&c||(a=bc(a,32,!1));return a};
# _.Cd=function(a,b,c,d,e,f,g){a=a.ma;var k=(0,_.jd)(a);_.tc(k);b=_.Ad(a,k,c,b,2,f,!0);c=d!=null?d:new c;if(g&&(typeof e!=="number"||e<0||e>b.length))throw Error();e!=void 0?b.splice(e,g,c):b.push(c);_.ec(c.ma)?(0,_.Bd)(b,8):(0,_.Bd)(b,16)};_.Dd=function(a,b){return a!=null?a:b};_.dba=function(a){if(!Array.isArray(a))throw Error("Z");if(Object.isFrozen(a)||Object.isSealed(a)||!Object.isExtensible(a))throw Error("$");(0,_.fc)(a,128);return a};
# hd=function(a,b,c){var d=_.uc(a),e=(0,_.jd)(c?a.ma:b);a=b.length;if(!a)return b;var f;if(_.mc(c=b[a-1])){a:{var g=c;var k={},l=!1,n;for(n in g){var p=g[n];if(Array.isArray(p)){var q=p;if(_.sc(p,d,+n)||Baa(p)&&p.size===0)p=null;p!=q&&(l=!0)}p!=null?k[n]=p:l=!0}if(l){for(var r in k){g=k;break a}g=null}}g!=c&&(f=!0);a--}for(n=_.kc(e);a>0;a--){r=a-1;c=b[r];r-=n;if(!(c==null||_.sc(c,d,r)||Baa(c)&&c.size===0))break;var u=!0}if(!f&&!u)return b;b=Array.prototype.slice.call(b,0,a);g&&b.push(g);return b};
# _.eba=function(a,b){return b==null?_.bd(a.constructor):_.ed(a.constructor,gc(_.dba(b)))};_.Fd=function(a,b){return new _.Ed(a,b)};_.fba=function(a){a.WWa=!0;return a};_.Id=function(a){return function(b){return _.Gd(a,b)}};_.Jd=function(a,b){b=b===void 0?window:b;b=b===void 0?window:b;return(b=b.WIZ_global_data)&&a in b?b[a]:null};_.Md=function(a){var b=b===void 0?window:b;return new _.Ld(a,_.Jd(a,b))};
# iba=function(a,b,c){c&&(b=Nd(Od,c,function(){return b}));b=Nd(Od,a,function(){return b});gba.set(a,String(b));(a=b.j)&&Nd(hba,a,function(){return b});return b};Nd=function(a,b,c){var d=a.get(b);d||(d=c(b),a.set(b,d));return d};_.Qd=function(a,b,c,d,e){e=e===void 0?!1:e;b=new _.Pd(a,b,c,e===void 0?!1:e);return iba(a,b,d)};_.A=function(a,b){return _.Qd(a,a,b)};_.Td=function(a){if(!_.Rd.has("startup"))throw Error("va`startup");_.jba.has("startup")?a.apply():_.Sd.startup.push(a)};
# _.Ud=function(a,b){b.hasOwnProperty("displayName")||(b.displayName=a.toString());b[kba]=a};lba=function(a){a=a[kba];return a instanceof _.Pd?a:null};_.nba=function(a){if(a instanceof _.Vd)return a.j;if(a instanceof _.Pd)return a;if(typeof a==="function")return _.mba(_.Wd.hb(),a)};_.oba=function(a){return(a=_.nba(a))?_.Xd(_.Yd.hb(),a):void 0};_.$d=function(a){Zd.push(a)};_.be=function(a){_.Ia(Zd,function(b){_.ae(b,a)})};
# pba=function(){if(de)for(var a=de.o,b=0;b<Zd.length;b++){var c=Zd[b];_.sa(a,c)||a.push(c)}};qba=function(){return _.ee(Zd,function(a){return a.j})};_.ge=function(a,b){var c=_.fe[a];c||(c=_.fe[a]=[]);c.push(b)};_.rba=function(){return jb()||_.Va("iPod")?4:_.Va("iPad")?5:_.ib()?he()?3:2:_.ie()?1:0};
# tba=function(a){var b="";var c=_.ca._F_jsUrl;if(typeof document!=="undefined"&&document&&document.getElementById&&(a=document.getElementById(a))){var d=a.tagName.toUpperCase();if(d=="SCRIPT"||d=="LINK")b=a.src?a.src:a.getAttribute("href")}if(c&&b){if(c!=b)throw Error("Ca`"+c+"`"+b);b=c}else b=c||b;if(!sba(b))throw Error("Da");return b};je=function(a){return Nd(uba,a.toString(),function(){return new Set})};
# _.me=function(a,b,c,d,e){a=_.Qd(a,b,d?[d]:void 0,void 0,ke);e&&le(e).add(a);_.Yd.hb().register(a,new vba(a,je(a),c?je(c):new Set,le(a),c?le(c):new Set,d));return a};ne=function(a,b){je(b).add(a)};_.qe=function(a,b){if(!b&&a.hasAttribute("jsshadow"))return null;for(b=0;a=_.pe(a);){if(a&&a===void 0&&b>0){wba||(wba=!0);break}if(a.hasAttribute("jsslot"))b+=1;else if(a.hasAttribute("jsshadow")&&b>0){--b;continue}if(b<=0)return a}return null};
# ...
#   </script>
# <script nonce="BchWCSuOimYDKipP6iIXOg">
#    AF_initDataCallback({key: 'ds:1', hash: '1', data:["gbres",[[null,"Saját\nösszefoglaló","június 16., vasárnap"],null,null,[[null,"Vezető hírek",null,null,null,null,null,null,null,null,null,null,[null,null,null,null,["#ffffff","#000000"]]],[[[[13,[13,"CBMiV2h0dHBzOi8vdGVsZXguaHUva3VsZm9sZC8yMDI0LzA2LzE2L2l6cmFlbC1pZGYtZ2F6YS10YWt0aWthaS1zenVuZXQtaHVtYW5pdGFyaXVzLXNlZ2VsedIBAA"],"Az izraeli hadsereg egy dél-gázai út mellett leállította a hadműveleteket, „taktikai szünetet” tart",null,[1718536135],null,"https://telex.hu/kulfold/2024/06/16/izrael-idf-gaza-taktikai-szunet-humanitarius-segely",null,[["/attachments/CC8iK0NnNWhWM0ZXYkdKcFNtdGpkbFYyVFJDM0FSaVRBaWdCTWdZWlFJaEtvUWc",null,140,140,null,"CC8iK0NnNWhWM0ZXYkdKcFNtdGpkbFYyVFJDM0FSaVRBaWdCTWdZWlFJaEtvUWc",null,null,null,null,null,null,null,"https://assets.telex.hu/images/20240616/1718535860-temp-OJflCO_hero-normal:xl.jpg"]],null,[12,[12,"PublisherOfCBMiV2h0dHBzOi8vdGVsZXguaHUva3VsZm9sZC8yMDI0LzA2LzE2L2l6cmFlbC1pZGYtZ2F6YS10YWt0aWthaS1zenVuZXQtaHVtYW5pdGFyaXVzLXNlZ2VsedIBAA"],"Telex",["https://encrypted-tbn0.gstatic.com/faviconV2?url\u003dhttps://telex.hu\u0026client\u003dNEWS_360\u0026size\u003d96\u0026type\u003dFAVICON\u0026fallback_opts\u003dTYPE,SIZE,URL",null,180,180,null,"https://encrypted-tbn0.gstatic.com/faviconV2?url\u003dhttps://telex.hu\u0026client\u003dNEWS_360\u0026size\u003d96\u0026type\u003dFAVICON\u0026fallback_opts\u003dTYPE,SIZE,URL","https://encrypted-tbn0.gstatic.com/faviconV2?url\u003dhttps://telex.hu\u0026client\u003dNEWS_360\u0026size\u003d96\u0026type\u003dFAVICON\u0026fallback_opts\u003dTYPE,SIZE,URL"],null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,["https://lh3.googleusercontent.com/asBFYQMPjdamXrUjFvgcqPXJExOvxAbx1pm9nDWQi2fpE1OtWsGh-HMagm_cMprYeIhcXAJipg",null,1228,400,null,"CAUqBwgKMOXmngswkoHNtC9qCWltYWdlL3BuZw"],["https://lh3.googleusercontent.com/Mfag3hz9IVYWE-DIdrmu79kIL0jXrn070OSwvSYhli-LcCHxeDpJmzG-k8Sb3opjuWkL3uskk5g",null,800,255,null,"CAUqBwgKMOXmngswx5Ts01xqCWltYWdlL3BuZw"]],null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,[null,[["Tovább – Telex","publications/CAAqBwgKMOXmngswgfG2Aw",[null,null,null,null,null,"link"],0]],null,null,[null,null,["Panoptic Response ID: 190219f35f9"]]],null,"https://telex.hu/kulfold/2024/06/16/izrael-idf-gaza-taktikai-szunet-humanitarius-segely",null,null,"..._..._wFKbWh0dHBzOi8vbGgzLmdvb2dsZXVzZXJjb250ZW50LmNvbS9NZmFnM2h6OUlWWVdFLURJZHJtdTc5a0lMMGpYcm4wNzBPU3d2U1lobGktTGNDSHhlRHBKbXpHLWs4U2Izb3BqdVdrTDN1c2trNWeaAiQKCkNBb3c1ZWFlQ3cSFkNBQXFCd2dLTU9YbW5nc3dnZkcyQXc",[[null,null,null,null,"channel_story_360:CAAqNggKIjBDQklTSGpvSmMzUnZjbmt0TXpZd1NoRUtEd2pKeU03bUN4SE50MFhwVnVrRVBDZ0FQAQ",0,141,null,null,null,62,null,[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"4324838101672638413","14668656887199001193","https://assets.telex.hu/images/20240616/1718535860-temp-OJflCO_hero-normal:xl.jpg",[881]],[],null,1,null,null,null,null,null,[null,3],[[1718536135],[1718551000,581905000]],[[[10,83]]],[[1718551000458498,23267296,1594704133],null,0],null,"EAMogN++rqrghgM\u003d","EAM\u003d"]],null,1,null,null,[null,null,null,null,null,null,null,null,null,null,null,"Minden kapcsolódó tudósítás",1],null,1,0],[[[13,[13,"CBMiT2h0dHBzOi8vd3d3LnBvcnRmb2xpby5odS9nbG9iYWwvMjAyNDA2MTYvdGFrdGlrYWktdHVzenVuZXRiZS1rZXpkLWl6cmFlbC02OTI2NDnSAVNodHRwczovL3d3dy5wb3J0Zm9saW8uaHUvZ2xvYmFsLzIwMjQwNjE2L3Rha3Rpa2FpLXR1c3p1bmV0YmUta2V6ZC1penJhZWwtNjkyNjQ5P2FtcA"],"Taktikai tűszünetbe kezd Izrael",null,[1718527560],null,"https://www.portfolio.hu/global/20240616/taktikai-tuszunetbe-kezd-izrael-692649","https://www.portfolio.hu/global/20240616/taktikai-tuszunetbe-kezd-izrael-692649",[["/attachments/CC8iK0NnNUpkMXBFTFhwT1FUaHRaV2N5VFJDYkF4amFCU2dLTWdZTnBwUUl1Z1k",null,null,null,null,"CC8iK0NnNUpkMXBFTFhwT1FUaHRaV2N5VFJDYkF4amFCU2dLTWdZTnBwU ...
#   </script>
# <script nonce="BchWCSuOimYDKipP6iIXOg">
#    AF_initDataCallback({key: 'ds:0', hash: '2', data:["waares",[2,null,[24,[24,"ui|11bf0087-93a0-41f5-8656-750fe91edaee"],null,[[2,null,[24,[24,"ui|bf7279cc-058b-4030-aa61-be57c085e722"],null,[[6,null,null,null,null,null,["Magyarország","topics/CAAqIQgKIhtDQkFTRGdvSUwyMHZNRE5uYWpJU0FtaDFLQUFQAQ",[null,null,null,null,null,"flag"],0,null,null,null,null,null,null,[[null,null,null,null,"topic_nav:1bec9c38-32bc-4fc0-b480-15c93f1741b2",7,141,null,null,null,null,null,[null,"CAAqIQgKIhtDQkFTRGdvSUwyMHZNRE5uYWpJU0FtaDFLQUFQAQ"]]]],null,"aa|ui|55ed31ca-42f2-4cf1-8dfd-24fab35ad721"],[6,null,null,null,null,null,["Világ","topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx1YlY4U0FtaDFHZ0pJVlNnQVAB",[null,null,null,null,null,"public"],0,null,null,null,null,null,null,[[null,null,null,null,"topic_nav:1bec9c38-32bc-4fc0-b480-15c93f1741b2",7,141,null,null,null,null,null,[null,"CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx1YlY4U0FtaDFHZ0pJVlNnQVAB"]]]],null,"aa|ui|8ce5fe54-75e0-4a16-85e2-68656ad1eda4"],[6,null,null,null,null,null,["Helyi hírek","topics/CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE",[null,null,null,null,null,"room"],0,null,null,null,null,null,null,[[null,null,null,null,"topic_nav:1bec9c38-32bc-4fc0-b480-15c93f1741b2",7,141,null,null,null,null,null,[null,"CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE"]]]],null,"aa|ui|e47b7fb2-f944-40cc-98de-7a904443684a"],[6,null,null,null,null,null,["Vállalkozás","topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx6TVdZU0FtaDFHZ0pJVlNnQVAB",[null,null,null,null,null,"business"],0,null,null,null,null,null,null,[[null,null,null,null,"topic_nav:1bec9c38-32bc-4fc0-b480-15c93f1741b2",7,141,null,null,null,null,null,[null,"CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx6TVdZU0FtaDFHZ0pJVlNnQVAB"]]]],null,"aa|ui|3ad35dfc-3c66-4963-82a0-1567d5d88264"],[6,null,null,null,null,null,["Tudomány és technika","topics/CAAqKAgKIiJDQkFTRXdvSkwyMHZNR1ptZHpWbUVnSm9kUm9DU0ZVb0FBUAE",[null,null,null,null,null,"experiment"],0,null,null,null,null,null,null,[[null,null,null,null,"topic_nav:1bec9c38-32bc-4fc0-b480-15c93f1741b2",7,141,null,null,null,null,null,[null,"CAAqKAgKIiJDQkFTRXdvSkwyMHZNR1ptZHpWbUVnSm9kUm9DU0ZVb0FBUAE"]]]],null,"aa|ui|ce21706f-24a6-4568-818d-205d0aab75b3"],[6,null,null,null,null,null,["Szórakozás","topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNREpxYW5RU0FtaDFHZ0pJVlNnQVAB",[null,null,null,null,null,"theaters"],0,null,null,null,null,null,null,[[null,null,null,null,"topic_nav:1bec9c38-32bc-4fc0-b480-15c93f1741b2",7,141,null,null,null,null,null,[null,"CAAqJggKIiBDQkFTRWdvSUwyMHZNREpxYW5RU0FtaDFHZ0pJVlNnQVAB"]]]],null,"aa|ui|466d19d9-2749-42a3-bb66-f5ef9b5a6c99"],[6,null,null,null,null,null,["Sport","topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRFp1ZEdvU0FtaDFHZ0pJVlNnQVAB",[null,null,null,null,null,"directions_bike"],0,null,null,null,null,null,null,[[null,null,null,null,"topic_nav:1bec9c38-32bc-4fc0-b480-15c93f1741b2",7,141,null,null,null,null,null,[null,"CAAqJggKIiBDQkFTRWdvSUwyMHZNRFp1ZEdvU0FtaDFHZ0pJVlNnQVAB"]]]],null,"aa|ui|dbebbab6-6768-4310-aa1c-184f95329bda"]],null,null,null,null,null,null,null,null,null,null,null,3,null,null,null,null,false,null,null,null,null,null,null,null,null,"ui|ded8652e-a271-4618-8b44-5da7218daa90",[[[null,null,null,null,"topic_nav:1bec9c38-32bc-4fc0-b480-15c93f1741b2",7,141]],47]],null,null,null,null,null,"aa|ui|bf7279cc-058b-4030-aa61-be57c085e722"]],null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"ui|e4368e8c-bf04-446c-9d5e-cd45f12b5304",[[[null,null,null,null,null,null,141,null,null,null,null,null,[]]]]],null,null,null,null,null,"aa|ui|11bf0087-93a0-41f5-8656-750fe91edaee"],null,3], sideChannel: {}});
#   </script>
# <script nonce="BchWCSuOimYDKipP6iIXOg">
#    AF_initDataCallback({key: 'ds:2', hash: '3', data:["gfres",[35,null,[[null,null,null,null,null,1,25,25,13,null,[1718521200],null,["{\"v\":\"5.1.8\",\"fr\":60,\"ip\":0,\"op\":100,\"w\":1500,\"h\":1500,\"nm\":\"_Partly_Cloudy\",\"ddd\":0,\"assets\":[],\"layers\":[{\"ddd\":0,\"ind\":1,\"ty\":4,\"nm\":\"cloudHalfCirc\",\"sr\":1,\"ks\":{\"o\":{\"a\":1,\"k\":[{\"i\":{\"x\":[0.833],\"y\":[0.833]},\"o\":{\"x\":[0.167],\"y\":[0.167]},\"n\":[\"0p833_0p833_0p167_0p167\"],\"t\":42,\"s\":[0],\"e\":[70]},{\"t\":54}],\"ix\":11},\"r\":{\"a\":0,\"k\":0,\"ix\":10},\"p\":{\"a\":1,\"k\":[{\"i\":{\"x\":0.36,\"y\":1},\"o\":{\"x\":0.22,\"y\":1},\"n\":\"0p36_1_0p22_1\",\"t\":0,\"s\":[259.5,763.4,0],\"e\":[585.5,763.4,0],\"to\":[54.3333320617676,0,0],\"ti\":[-54.3333320617676,0,0]},{\"t\":75}],\"ix\":2},\"a\":{\"a\":0,\"k\":[0,0,0],\"ix\":1},\"s\":{\"a\":0,\"k\":[65,65,100],\"ix\":6}},\"ao\":0,\"shapes\":[{\"ty\":\"gr\",\"it\":[{\"ind\":0,\"ty\":\"sh\",\"ix\":1,\"ks\":{\"a\":0,\"k\":{\"i\":[[5.52,0],[0,-5.52],[0.01,-0.02]],\"o\":[[-5.52,0],[0.01,-0.02],[0,-5.52]],\"v\":[[9.594,0.135],[-0.406,10.148],[19.594,10.135]],\"c\":true},\"ix\":2},\"nm\":\"Path 1\",\"mn\":\"ADBE Vector Shape - Group\",\"hd\":false},{\"ty\":\"fl\",\"c\":{\"a\":0,\"k\":[0.945097982883,0.952941000462,0.956862986088,1],\"ix\":4},\"o\":{\"a\":0,\"k\":100,\"ix\":5},\"r\":1,\"nm\":\"Fill 1\",\"mn\":\"ADBE Vector Graphic - Fill\",\"hd\":false},{\"ty\":\"tr\",\"p\":{\"a\":0,\"k\":[-235,432],\"ix\":2},\"a\":{\"a\":0,\"k\":[0,0],\"ix\":1},\"s\":{\"a\":0,\"k\":[3125,3125],\"ix\":3},\"r\":{\"a\":0,\"k\":0,\"ix\":6},\"o\":{\"a\":0,\"k\":100,\"ix\":7},\"sk\":{\"a\":0,\"k\":0,\"ix\":4},\"sa\":{\"a\":0,\"k\":0,\"ix\":5},\"nm\":\"Transform\"}],\"nm\":\"Group 1\",\"np\":2,\"cix\":2,\"ix\":1,\"mn\":\"ADBE Vector Group\",\"hd\":false}],\"ip\":-35,\"op\":865,\"st\":17,\"bm\":0},{\"ddd\":0,\"ind\":2,\"ty\":3,\"nm\":\"CloudCtrl 2\",\"sr\":1,\"ks\":{\"o\":{\"a\":0,\"k\":0,\"ix\":11},\"r\":{\"a\":0,\"k\":0,\"ix\":10},\"p\":{\"a\":1,\"k\":[{\"i\":{\"x\":0.36,\"y\":1},\"o\":{\"x\":0.22,\"y\":1},\"n\":\"0p36_1_0p22_1\",\"t\":1,\"s\":[171,497,0],\"e\":[499,497,0],\"to\":[54.6666679382324,0,0],\"ti\":[-54.6666679382324,0,0]},{\"t\":75}],\"ix\":2},\"a\":{\"a\":0,\"k\":[0,0,0],\"ix\":1},\"s\":{\"a\":0,\"k\":[66,66,100],\"ix\":6}},\"ao\":0,\"ip\":-33,\"op\":849,\"st\":-2,\"bm\":0},{\"ddd\":0,\"ind\":4,\"ty\":4,\"nm\":\"topOval 3\",\"parent\":9,\"td\":1,\"sr\":1,\"ks\":{\"o\":{\"a\":0,\"k\":100,\"ix\":11},\"r\":{\"a\":0,\"k\":0,\"ix\":10},\"p\":{\"a\":0,\"k\":[-250,20.615,0],\"ix\":2},\"a\":{\"a\":0,\"k\":[0,0,0],\"ix\":1},\"s\":{\"a\":0,\"k\":[100,100,100],\"ix\":6}},\"ao\":0,\"shapes\":[{\"ty\":\"gr\",\"it\":[{\"d\":1,\"ty\":\"el\",\"s\":{\"a\":0,\"k\":[24,24],\"ix\":2},\"p\":{\"a\":0,\"k\":[12,12],\"ix\":3},\"nm\":\"Ellipse Path 1\",\"mn\":\"ADBE Vector Shape - Ellipse\",\"hd\":false},{\"ty\":\"fl\",\"c\":{\"a\":0,\"k\":[0,0,0,1],\"ix\":4},\"o\":{\"a\":0,\"k\":100,\"ix\":5},\"r\":1,\"nm\":\"Fill 1\",\"mn\":\"ADBE Vector Graphic - Fill\",\"hd\":false},{\"ty\":\"tr\",\"p\":{\"a\":0,\"k\":[0,0],\"ix\":2},\"a\":{\"a\":0,\"k\":[0,0],\"ix\":1},\"s\":{\"a\":0,\"k\":[3125,3125],\"ix\":3},\"r\":{\"a\":0,\"k\":0,\"ix\":6},\"o\":{\"a\":0,\"k\":100,\"ix\":7},\"sk\":{\"a\":0,\"k\":0,\"ix\":4},\"sa\":{\"a\":0,\"k\":0,\"ix\":5},\"nm\":\"Transform\"}],\"nm\":\"Oval\",\"np\":2,\"cix\":2,\"ix\":1,\"mn\":\"ADBE Vector Group\",\"hd\":false}],\"ip\":-63,\"op\":837,\"st\":-11,\"bm\":0},{\"ddd\":0,\"ind\":5,\"ty\":4,\"nm\":\"sun 3\",\"parent\":12,\"tt\":1,\"sr\":1,\"ks\":{\"o\":{\"a\":1,\"k\":[{\"i\":{\"x\":[0.36],\"y\":[1]},\"o\":{\"x\":[0.22],\"y\":[0.878]},\"n\":[\"0p36_1_0p22_0p878\"],\"t\":10,\"s\":[1],\"e\":[100]},{\"t\":75}],\"ix\":11},\"r\":{\"a\":0,\"k\":0,\"ix\":10},\"p\":{\"a\":1,\"k\":[{\"i\":{\"x\":0.36,\"y\":1},\"o\":{\"x\":0.22,\"y\":1},\"n\":\"0p36_1_0p22_1\",\"t\":1,\"s\":[-169,12,0],\"e\":[-494,12,0],\"to\":[-54.1666679382324,0,0],\"ti\":[54.1666679382324,0,0]},{\"t\":75}],\"ix\":2},\"a\":{\"a\":0,\"k\":[-496,- ...
#   </script>
# <script id="wiz_jd" nonce="BchWCSuOimYDKipP6iIXOg">
#    if (window['_wjdc']) {const wjd = {}; window['_wjdc'](wjd); delete window['_wjdc'];}
#   </script>
# <script aria-hidden="true" id="WIZ-footer" nonce="BchWCSuOimYDKipP6iIXOg">
#    window.wiz_progress&&window.wiz_progress(); window.stopScanForCss&&window.stopScanForCss(); ccTick('bl');
#   </script>
# </body>
# </html>
# <script nonce="BchWCSuOimYDKipP6iIXOg">
#  this.gbar_=this.gbar_||{};(function(_){var window=this;
# try{
# if(_.hj){var lj;if(lj=_.M(_.hj.j,3))for(var mj=_.Fh(lj),nj=0;nj<mj.length;nj++){var oj=mj[nj];if(_.Lh&&oj.dataset)oj.dataset.ogpc="";else{if(/-[a-z]/.test("ogpc"))throw Error("Q");oj.setAttribute("data-"+_.ii("ogpc"),"")}}_.bj(_.hj,!!_.hj.i&&_.hj.i.qb(),!1)};
# }catch(e){_._DumpException(e)}
# try{
# _.pj=function(a){var b,c,d=(c=(b=(a.ownerDocument&&a.ownerDocument.defaultView||window).document).querySelector)==null?void 0:c.call(b,"script[nonce]");(b=d?d.nonce||d.getAttribute("nonce")||"":"")&&a.setAttribute("nonce",b)};_.qj=function(a){if(!a)return null;a=_.M(a,4);var b;a===null||a===void 0?b=null:b=_.ue(a);return b};_.rj=function(a){this.J=_.w(a)};_.C(_.rj,_.T);_.sj=function(a,b){return(b||document).getElementsByTagName(String(a))};
# }catch(e){_._DumpException(e)}
# try{
# var uj=function(a,b,c){a<b?tj(a+1,b):_.vd.log(Error("pa`"+a+"`"+b),{url:c})},tj=function(a,b){if(vj){var c=_.Ne("SCRIPT");c.async=!0;c.type="text/javascript";c.charset="UTF-8";c.src=_.se(vj);_.pj(c);c.onerror=_.fe(uj,a,b,c.src);_.sj("HEAD")[0].appendChild(c)}},wj=function(a){this.J=_.w(a)};_.C(wj,_.T);var xj=_.J(_.rd,wj,17)||new wj,yj,vj=(yj=_.J(xj,_.rj,1))?_.qj(yj):null,zj,Aj=(zj=_.J(xj,_.rj,2))?_.qj(zj):null,Bj=function(){tj(1,2);if(Aj){var a=_.Ne("LINK");a.setAttribute("type","text/css");a.rel="stylesheet";if(_.fa("stylesheet","stylesheet")){a.href=_.se(Aj).toString();var b=_.Ie(a.ownerDocument&&a.ownerDocument.defaultView);b&&a.setAttribute("nonce",b)}else a.href=Aj instanceof _.re?_.se(Aj).toString():_.Je(Aj);(b=_.Ie())&&a.setAttribute("nonce",b);_.sj("HEAD")[0].appendChild(a)}};(function(){var a=_.sd();if(_.L(a,18))Bj();else{var b=_.he(a,19)||0;window.addEventListener("load",function(){window.setTimeout(Bj,b)})}})();
# }catch(e){_._DumpException(e)}
# })(this.gbar_);
# // Google Inc.
# </script>
# <div ng-non-bindable="">
# <div class="gb_Ce">
#   Keresés
#  </div>
# <div class="gb_Ee">
#   Keresés törlése
#  </div>
# <div class="gb_De">
#   A keresés bezárása
#  </div>
# <div class="gb_m">
#   Google-alkalmazások
#  </div>
# <div class="gb_Rc">
#   Főmenü
#  </div>
# </div>

# %% [markdown]
# ## Cikke adatainak letöltése azonosító alapján

# %%
articles = soup.find_all("article")

article_list = []
content = []

for article in articles:
    article_list.append(article)

for article in article_list:
    atags = article.find_all("a")
    title = atags[1].text.strip()
    source = article.find("div", class_="vr1PYe")
    published = article.find("time").get("datetime")

    content.append((title, source.text.strip(), published))

for item in content:
    print(item)
# Out:
# ('Az izraeli hadsereg egy dél-gázai út mellett leállította a hadműveleteket, „taktikai szünetet” tart', 'Telex', '2024-06-16T11:08:55Z')
# ('Taktikai tűszünetbe kezd Izrael', 'Portfolio', '2024-06-16T08:46:00Z')
# ('Az ENSZ szerint megtagadták egy segélykonvoj bejutását Gáza északi részére', '444.hu', '2024-06-14T19:21:14Z')
# ('Az izraeli hadsereg szünetelteti a nappali katonai tevékenységet a Gázai övezet déli részén', '24.hu', '2024-06-16T09:49:00Z')
# ('Megkezdődtek a tárgyalások az ukrán háború lezárásáról, három hónap ostrom után elesett Heorhijivka - Háborús híreink szombaton', 'Portfolio', '2024-06-15T19:26:00Z')
# ('Vadonatúj békejavaslat érkezett, kiverheti a biztosítékot Putyinnál egy új tervezet – Háborús híreink vasárnap', 'Portfolio', '2024-06-16T14:01:00Z')
# ('Putyin bedühödött az ukrajnai békecsúcsra', 'Privátbankár.hu', '2024-06-16T07:32:00Z')
# ('Kiderült: ezért nem kötött békét Ukrajna és Oroszország a háború elején', 'Mandiner', '2024-06-16T02:44:00Z')
# ('Megkongatta a vészharangot a magyar rendőrség, őrületes, ami a határon történik', 'Naphíre', '2024-06-16T07:18:59Z')
# ('Belföld - A DK szerint Vitézy Dávid képtelen elfogadni a vereséget, ezért fideszes', 'Index.hu', '2024-06-15T18:26:00Z')

# %% [markdown]
# ## Fájlkezelés

# %%
if os.path.exists("output_google_news.csv"):
    os.remove("output_google_news.csv")

with open("output_google_news.csv", "a", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["title", "source", "published"])
    writer.writerows(content)
    print("Fájl írása kész!")
# Out:
# Fájl írása kész!
