# %% [markdown]
# # Vizualizáció térképen

# %% [markdown]
# ## Szükséges könyvtárak telepítése és importálása

# %%
# %pip install folium
# %pip install geopandas
# %pip install geopy

# %%
import folium
from geopy.distance import geodesic
from folium.plugins import MarkerCluster

# %% [markdown]
# ## Szükséges változók és adatok

# %%
marker_cluster = MarkerCluster()

m = folium.Map(
    location=[47.75558, 18.12893], zoom_start=9, scrollWheelZoom=False
)  # Komárom

cities = [
    {
        "city": "Komárom",
        "location": [47.75558, 18.12893],
        "major": "Alkalmazott informatika",
        "institute": "Selye János Egyetem",
        "distance": 0,
        "midpoint": 0,
    },
    {
        "city": "Pozsony",
        "location": [48.1361, 17.1030],
        "major": "",
        "institute": "Slovenská technická univerzita v Bratislave",
        "distance": 0,
        "midpoint": 0,
    },
    {
        "city": "Nagyszombat",
        "location": [48.3791, 17.5867],
        "major": "",
        "institute": "Trnavská univerzita v Trnave",
        "distance": 0,
        "midpoint": 0,
    },
    {
        "city": "Budapest",
        "location": [47.4816, 19.1300],
        "major": "",
        "institute": "Óbudai Egyetem",
        "distance": 0,
        "midpoint": 0,
    },
    {
        "city": "Győr",
        "location": [47.69366, 17.62800],
        "major": "",
        "institute": "Széchenyi István Egyetem",
        "distance": 0,
        "midpoint": 0,
    },
    {
        "city": "Nyitra",
        "location": [48.3134, 18.0855],
        "major": "",
        "institute": "Univerzita Konštantína Filozofa v Nitre",
        "distance": 0,
        "midpoint": 0,
    },
]

# %% [markdown]
# ### Egyedi jelölő létrehozása

# %%
def create_custom_icon(color, size):
    icon_html = f"""
    <div style="background-color:{color}; width:{'10px' if size=='large' else '5px'}; height:{'10px' if size=='large' else '5px'}; 
                border-radius: {'50%'}; border-color:{"black"}"></div>
    """
    return folium.DivIcon(html=icon_html)

# %% [markdown]
# ## Jelölők elhelyezése a térképen

# %%
for city in cities:
    folium.Marker(
        color="red",
        location=city["location"],
        tooltip=city["major"],
        popup=city["city"],
        icon=create_custom_icon("red", "large"),
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f914b5aff60b7c00dd16934148a495cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f914b5aff60b7c00dd16934148a495cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f914b5aff60b7c00dd16934148a495cd = L.map(
#                 &quot;map_f914b5aff60b7c00dd16934148a495cd&quot;,
#                 {
#                     center: [47.75558, 18.12893],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c516d9e8568f1589c39e9b9cedb74d96 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c516d9e8568f1589c39e9b9cedb74d96.addTo(map_f914b5aff60b7c00dd16934148a495cd);
#
#
#             var marker_df16d829d33c0127618086f97af93fc3 = L.marker(
#                 [47.75558, 18.12893],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_f914b5aff60b7c00dd16934148a495cd);
#
#
#             var div_icon_403ac0fa38bc6f23bbd74ed2440c3f62 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_df16d829d33c0127618086f97af93fc3.setIcon(div_icon_403ac0fa38bc6f23bbd74ed2440c3f62);
#
#
#         var popup_b2bc29acb63535d2c5455095dc645d24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75e455baa409dcaf5c67e2a0c16ee001 = $(`&lt;div id=&quot;html_75e455baa409dcaf5c67e2a0c16ee001&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Komárom&lt;/div&gt;`)[0];
#                 popup_b2bc29acb63535d2c5455095dc645d24.setContent(html_75e455baa409dcaf5c67e2a0c16ee001);
#
#
#
#         marker_df16d829d33c0127618086f97af93fc3.bindPopup(popup_b2bc29acb63535d2c5455095dc645d24)
#         ;
#
#
#
#
#             marker_df16d829d33c0127618086f97af93fc3.bindTooltip(
#                 `&lt;div&gt;
#                      Alkalmazott informatika
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_94b3e40ca481018543c3829fe4c556d2 = L.marker(
#                 [48.1361, 17.103],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_f914b5aff60b7c00dd16934148a495cd);
#
#
#             var div_icon_28ac67851fd05c52ec942af705962ef1 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_94b3e40ca481018543c3829fe4c556d2.setIcon(div_icon_28ac67851fd05c52ec942af705962ef1);
#
#
#         var popup_a86e9139b82ab093a4777a3be182c841 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_22a55ea82f6dd89c3f6be2a06575bedd = $(`&lt;div id=&quot;html_22a55ea82f6dd89c3f6be2a06575bedd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pozsony&lt;/div&gt;`)[0];
#                 popup_a86e9139b82ab093a4777a3be182c841.setContent(html_22a55ea82f6dd89c3f6be2a06575bedd);
#
#
#
#         marker_94b3e40ca481018543c3829fe4c556d2.bindPopup(popup_a86e9139b82ab093a4777a3be182c841)
#         ;
#
#
#
#
#             marker_94b3e40ca481018543c3829fe4c556d2.bindTooltip(
#                 `&lt;div&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a880de5a2177f89a5b13ee2d96d4f079 = L.marker(
#                 [48.3791, 17.5867],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_f914b5aff60b7c00dd16934148a495cd);
#
#
#             var div_icon_f232ba4687710f1d8d476bb64114b6da = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_a880de5a2177f89a5b13ee2d96d4f079.setIcon(div_icon_f232ba4687710f1d8d476bb64114b6da);
#
#
#         var popup_1e988b030d206ba19fc47473c2a26d68 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aaa6943e337d3384d63bd80b76682faa = $(`&lt;div id=&quot;html_aaa6943e337d3384d63bd80b76682faa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nagyszombat&lt;/div&gt;`)[0];
#                 popup_1e988b030d206ba19fc47473c2a26d68.setContent(html_aaa6943e337d3384d63bd80b76682faa);
#
#
#
#         marker_a880de5a2177

# %% [markdown]
# ## Városok közti távolság meghatározása és városok összekötése

# %%
for city in cities:
    city["distance"] = geodesic(cities[0]["location"], city["location"]).kilometers
    city["midpoint"] = (
        (cities[0]["location"][0] + city["location"][0]) / 2,
        (cities[0]["location"][1] + city["location"][1]) / 2,
    )
    folium.PolyLine(
        locations=[cities[0]["location"], city["location"]],
        color="blue",
        dash_array="10",
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f914b5aff60b7c00dd16934148a495cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f914b5aff60b7c00dd16934148a495cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f914b5aff60b7c00dd16934148a495cd = L.map(
#                 &quot;map_f914b5aff60b7c00dd16934148a495cd&quot;,
#                 {
#                     center: [47.75558, 18.12893],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c516d9e8568f1589c39e9b9cedb74d96 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c516d9e8568f1589c39e9b9cedb74d96.addTo(map_f914b5aff60b7c00dd16934148a495cd);
#
#
#             var marker_df16d829d33c0127618086f97af93fc3 = L.marker(
#                 [47.75558, 18.12893],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_f914b5aff60b7c00dd16934148a495cd);
#
#
#             var div_icon_403ac0fa38bc6f23bbd74ed2440c3f62 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_df16d829d33c0127618086f97af93fc3.setIcon(div_icon_403ac0fa38bc6f23bbd74ed2440c3f62);
#
#
#         var popup_b2bc29acb63535d2c5455095dc645d24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75e455baa409dcaf5c67e2a0c16ee001 = $(`&lt;div id=&quot;html_75e455baa409dcaf5c67e2a0c16ee001&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Komárom&lt;/div&gt;`)[0];
#                 popup_b2bc29acb63535d2c5455095dc645d24.setContent(html_75e455baa409dcaf5c67e2a0c16ee001);
#
#
#
#         marker_df16d829d33c0127618086f97af93fc3.bindPopup(popup_b2bc29acb63535d2c5455095dc645d24)
#         ;
#
#
#
#
#             marker_df16d829d33c0127618086f97af93fc3.bindTooltip(
#                 `&lt;div&gt;
#                      Alkalmazott informatika
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_94b3e40ca481018543c3829fe4c556d2 = L.marker(
#                 [48.1361, 17.103],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_f914b5aff60b7c00dd16934148a495cd);
#
#
#             var div_icon_28ac67851fd05c52ec942af705962ef1 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_94b3e40ca481018543c3829fe4c556d2.setIcon(div_icon_28ac67851fd05c52ec942af705962ef1);
#
#
#         var popup_a86e9139b82ab093a4777a3be182c841 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_22a55ea82f6dd89c3f6be2a06575bedd = $(`&lt;div id=&quot;html_22a55ea82f6dd89c3f6be2a06575bedd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pozsony&lt;/div&gt;`)[0];
#                 popup_a86e9139b82ab093a4777a3be182c841.setContent(html_22a55ea82f6dd89c3f6be2a06575bedd);
#
#
#
#         marker_94b3e40ca481018543c3829fe4c556d2.bindPopup(popup_a86e9139b82ab093a4777a3be182c841)
#         ;
#
#
#
#
#             marker_94b3e40ca481018543c3829fe4c556d2.bindTooltip(
#                 `&lt;div&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a880de5a2177f89a5b13ee2d96d4f079 = L.marker(
#                 [48.3791, 17.5867],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_f914b5aff60b7c00dd16934148a495cd);
#
#
#             var div_icon_f232ba4687710f1d8d476bb64114b6da = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_a880de5a2177f89a5b13ee2d96d4f079.setIcon(div_icon_f232ba4687710f1d8d476bb64114b6da);
#
#
#         var popup_1e988b030d206ba19fc47473c2a26d68 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aaa6943e337d3384d63bd80b76682faa = $(`&lt;div id=&quot;html_aaa6943e337d3384d63bd80b76682faa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nagyszombat&lt;/div&gt;`)[0];
#                 popup_1e988b030d206ba19fc47473c2a26d68.setContent(html_aaa6943e337d3384d63bd80b76682faa);
#
#
#
#         marker_a880de5a2177

# %%
for i in range(1, len(cities)):
    folium.Marker(
        location=cities[i]["midpoint"],
        icon=folium.DivIcon(
            html=f'<div style="font-size: 12pt; color: black; background-color: rgba(255, 255, 255, 0.75); padding: 2px; border-radius:10px;display: inline-block;">{cities[i]["distance"]:.2f}km</div>'
        ),
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f914b5aff60b7c00dd16934148a495cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f914b5aff60b7c00dd16934148a495cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f914b5aff60b7c00dd16934148a495cd = L.map(
#                 &quot;map_f914b5aff60b7c00dd16934148a495cd&quot;,
#                 {
#                     center: [47.75558, 18.12893],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c516d9e8568f1589c39e9b9cedb74d96 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c516d9e8568f1589c39e9b9cedb74d96.addTo(map_f914b5aff60b7c00dd16934148a495cd);
#
#
#             var marker_df16d829d33c0127618086f97af93fc3 = L.marker(
#                 [47.75558, 18.12893],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_f914b5aff60b7c00dd16934148a495cd);
#
#
#             var div_icon_403ac0fa38bc6f23bbd74ed2440c3f62 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_df16d829d33c0127618086f97af93fc3.setIcon(div_icon_403ac0fa38bc6f23bbd74ed2440c3f62);
#
#
#         var popup_b2bc29acb63535d2c5455095dc645d24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75e455baa409dcaf5c67e2a0c16ee001 = $(`&lt;div id=&quot;html_75e455baa409dcaf5c67e2a0c16ee001&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Komárom&lt;/div&gt;`)[0];
#                 popup_b2bc29acb63535d2c5455095dc645d24.setContent(html_75e455baa409dcaf5c67e2a0c16ee001);
#
#
#
#         marker_df16d829d33c0127618086f97af93fc3.bindPopup(popup_b2bc29acb63535d2c5455095dc645d24)
#         ;
#
#
#
#
#             marker_df16d829d33c0127618086f97af93fc3.bindTooltip(
#                 `&lt;div&gt;
#                      Alkalmazott informatika
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_94b3e40ca481018543c3829fe4c556d2 = L.marker(
#                 [48.1361, 17.103],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_f914b5aff60b7c00dd16934148a495cd);
#
#
#             var div_icon_28ac67851fd05c52ec942af705962ef1 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_94b3e40ca481018543c3829fe4c556d2.setIcon(div_icon_28ac67851fd05c52ec942af705962ef1);
#
#
#         var popup_a86e9139b82ab093a4777a3be182c841 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_22a55ea82f6dd89c3f6be2a06575bedd = $(`&lt;div id=&quot;html_22a55ea82f6dd89c3f6be2a06575bedd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pozsony&lt;/div&gt;`)[0];
#                 popup_a86e9139b82ab093a4777a3be182c841.setContent(html_22a55ea82f6dd89c3f6be2a06575bedd);
#
#
#
#         marker_94b3e40ca481018543c3829fe4c556d2.bindPopup(popup_a86e9139b82ab093a4777a3be182c841)
#         ;
#
#
#
#
#             marker_94b3e40ca481018543c3829fe4c556d2.bindTooltip(
#                 `&lt;div&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a880de5a2177f89a5b13ee2d96d4f079 = L.marker(
#                 [48.3791, 17.5867],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_f914b5aff60b7c00dd16934148a495cd);
#
#
#             var div_icon_f232ba4687710f1d8d476bb64114b6da = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_a880de5a2177f89a5b13ee2d96d4f079.setIcon(div_icon_f232ba4687710f1d8d476bb64114b6da);
#
#
#         var popup_1e988b030d206ba19fc47473c2a26d68 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aaa6943e337d3384d63bd80b76682faa = $(`&lt;div id=&quot;html_aaa6943e337d3384d63bd80b76682faa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nagyszombat&lt;/div&gt;`)[0];
#                 popup_1e988b030d206ba19fc47473c2a26d68.setContent(html_aaa6943e337d3384d63bd80b76682faa);
#
#
#
#         marker_a880de5a2177
