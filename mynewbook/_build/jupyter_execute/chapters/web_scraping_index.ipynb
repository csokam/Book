# %% [markdown]
# # Index híreinek kigyűjtése
#
# A <a href="https://index.hu/24ora/">index.hu/24ora</a> struktúrája szintén kellemes, gyakorlásra alkalmas.

# %% [markdown]
# ## Szükséges könyvtárak letöltése, importálása

# %%
# %pip install bs4

# %%
import os
import csv
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## Weboldal HTML struktúrájának letöltése

# %%
url = "https://index.hu/24ora/"
page = requests.get(url)
soup = bs(page.text, "html.parser")

print(soup)

with open("sample_index.html", "w", encoding="utf-8") as file:
    file.write(soup.prettify())
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="hu" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <head>
# <title>Hírek - 24 óra - Index.hu</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=EmulateIE11" http-equiv="X-UA-Compatible"/>
# <!-- [if IE]>
#         <meta http-equiv="imagetoolbar" content="no" />
#         <meta name="MSSmartTagsPreventParsing" content="true" />
#         <meta http-equiv="X-UA-Compatible" content="IE=Edge">
#         <![endif]-->
# <meta content="1717420549" name="manis:deploy">
# <meta name="manis:breakpoint"/>
# <meta name="manis:breakpoints"/>
# <meta content="https://index.hu/copyright/" name="copyright">
# <meta content="unsafe-url" name="referrer"/>
# <meta content="app-id=480103271" name="apple-itunes-app"/>
# <meta content="app-id=com.aff.index.main" name="google-play-app"/>
# <meta content="noindex" name="robots"/> <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <meta content="330827937019153" property="fb:app_id"><meta content="667823645" property="fb:admins"><meta content="560525343980775,348326671885918" property="fb:pages"><meta content="Friss hírek és információk az Indexen" name="description"> <meta content="https://index.hu/assets/images/facebook_logo.png?v5" property="og:image"/><meta content="https://www.facebook.com/Indexhu" property="article:publisher"/><meta content="summary_large_image" name="twitter:card"/><meta content="@indexhu" name="twitter:site"/><meta content="https://index.hu/assets/images/facebook_logo.png" name="twitter:image:src"/> <link href="/assets/static/opensearch.xml" rel="search" title="Index" type="application/opensearchdescription+xml"/>
# <link href="/copyright/" rel="copyright" title="Szerzői jogok"/>
# <link href="/impresszum/" rel="author" title="Impresszum"/>
# <link href="/" id="homelink" rel="home" title=""/>
# <link href="/assets/images/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/assets/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/assets/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/assets/images/favicons/manifest.json" rel="manifest"/>
# <link href="/assets/images/favicons/favicon.ico" rel="shortcut icon"/>
# <link color="#ff9900" href="/assets/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="Index" name="apple-mobile-web-app-title"/>
# <meta content="Index" name="application-name"/>
# <meta content="#ffffff" name="theme-color"/>
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <link href="https://index.hu/assets/static/indexnew_css/public/global.css?v=1717420560" rel="stylesheet" type="text/css"><link href="https://index.hu/assets/static/indexnew_css/public/index-global.css?v=1717420560" rel="stylesheet" type="text/css"> <link href="https://index.hu/assets/static/indexnew_css/public/rovat.css?v=1717420560" rel="stylesheet" type="text/css">
# <link href="https://index.hu/assets/static/indexnew_css/public/fixed_header.css?v=1717420560" rel="stylesheet" type="text/css">
# <link href="https://index.hu/assets/static/indexnew_css/public/24ora.css?v=1717420560" rel="stylesheet" type="text/css">
# <link href="/24ora/rss/" rel="alternate" title="24óra cikkek" type="application/rss+xml">
# <meta content="1" name="logcustomtarget">
# <!-- i8 -->
# <script src="https://index.hu/ident/getall/?c=aTg=" type="text/javascript"></script>
# <script src="https://index.hu/assets/static/js/public/index_vendor.ugly.js?v=1717420561" type="text/javascript"></script>
# <script src="https://index.hu/assets/static/js/public/index_base.ugly.js?v=1717420561" type="text/javascript"></script>
# <script src="https://index.hu/assets/static/js/public/index_election.ugly.js?v=1717420561" type="text/javascript"></script>
# <script src="https://index.hu/assets/static/js/public/cemp_fejlec.ugly.js?v=1717420561" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/index.rovat.min.js?v=1710407521" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/autocomplete.min.js?v=1717420549" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/calendar.min.js?v=1717420549" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/chosen2.min.js?v=1717420549" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/jquery-ui.min.js?v=1717420549" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/index.24ora.min.js?v=1717420549" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/scrolling_shadow.js?v=1717420549" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/pip_video.min.js?v=1717420549" type="text/javascript"></script>
# <script type="text/javascript">
#         var _gaq = { push: function() {} };
#         ( function( i, s, o, g, r, a, m ) {
#             i[ 'GoogleAnalyticsObject' ] = r;
#             i[ r ] = i[ r ] || function() {
#                 ( i[ r ].q = i[ r ].q || [] ).push( arguments )
#             }, i[ r ].l = 1 * new Date();
#             a = s.createElement( o ), m = s.getElementsByTagName( o )[ 0 ];
#             a.async = 1;
#             a.src=g;
#             m.parentNode.insertBefore( a, m )
#         } )( window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga' );
#         var oldaltipus = '24ora_cimlap';
#         ( function( $ ) {
#             window.scrollTrackerEnabled = 1;
#             window.Analytics = {
#                 add: function( command, params, target ) {
#                     if( typeof command === 'undefined' || typeof params === 'undefined' || !command || !params ) {
#                         return this;
#                     }
#                     params.location = ( params.location || document.location.href ).replace( '//m.', '//' );
#                     if( this.loaded ) {
#                         if( typeof target !== 'undefined' ) {
#                             command = target + '.' + command;
#                         }
#                         ga( command, params );
#                     }
#                     else {
#                         this.stack.push( [ command, $.extend( {}, params ), target ] );
#                     }
#                     return this;
#                 },
#                 process: function() {
#                     if( this.loaded ) {
#                         return;
#                     }
#                     var arg;
#                     while( this.stack.length ) {
#                         arg = this.stack.shift();
#                         if( typeof arg[ 2 ] !== 'undefined' && Common[ 'ga_' + arg[ 2 ] ] === true ) {
#                             arg[ 0 ] = arg[ 2 ] + '.' + arg[ 0 ];
#                         }
#                         ga( arg[ 0 ], arg[ 1 ] );
#                     }
#                     this.loaded = true;
#                 },
#                 stack: []
#             };
#             $( document ).on( 'ready', function() {
#                 if( typeof window.Common === 'undefined' ) {
#                     window.Common = {
#                         ga_secondary: false
#                     };
#                 }
#                 if( typeof __passportHeader_config === 'undefined' ) {
#                     __passportHeader_config = {};
#                 }
#                 Common.ga_secondary = false;
#                 var ga_base_config = {
#                     sampleRate: 100,
#                     trackingId: 'UA-181415-27'
#                 };
#                 var ga_set_config = {
#                     dimension1: '24ora_cimlap',
#                     dimension2: ( __passportHeader_config.loggedIn ? '' : 'Not' ) + 'LoggedIn',
#                                             dimension3: Page.getLayout(),
#                                                                                 language: document.domain === 'totalcarmagazine.com' ? 'en-us' : 'hu-hu',
#                     location: document.location.href.replace( '//m.', '//' )
#                 };
#                 if( typeof __passportHeaderUserId !== 'undefined' ) {
#                     ga_base_config.userId = __passportHeaderUserId;
#                 }
#                 ga( 'create', ga_base_config );
#                 ga( 'require', 'displayfeatures' );
#                 ga( 'set', ga_set_config );
#                                     Common.ga_secondary = true;
#                     var ga_secondary_config = $.extend( {}, ga_base_config );
#                     ga_secondary_config.name = 'secondary';
#                     ga_secondary_config.trackingId = 'UA-181415-11';
#                     ga_secondary_config.sampleRate = 10;
#                     ga( 'create', ga_secondary_config );
#                     ga( 'secondary.require', 'displayfeatures' );
#                     ga( 'secondary.set', ga_set_config );
#                                 ga('set', 'anonymizeIp', true);
#                 // cross_site ajanlo kivetelkezelese
#                 if(
#                     (
#                         $( '#passportHeader, #_iph_fixed-header' ).length ||
#                         $( '#inforadio_audioplayer1' ).length ||
#                         $( '.header_send').length ||
#                         document.location.host.indexOf( 'm.' ) === 0 ||
#                         document.location.host.substring( document.location.host.length - 4 ) === '.com'
#                     ) &&
#                     ((Common.topfolder !== 'i2' && Common.topfolder !== 'index2') || !Common.parsed_url.hash || Common.parsed_url.hash.indexOf( '#bloghu' ) !== 0 )
#                 ) {
#                     ga( 'send', 'pageview' );
#                     if( Common.ga_secondary ) {
#                         ga( 'secondary.send', 'pageview' );
#                     }
#                 }
#                 Analytics.process();
#             } );
#         } )( jQuery );
#     </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-7GR3T85C96"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         var ga4params = {"content_group":"24ora\/","rovat":"24\u00f3ra","oldaltipus":"24ora_cimlap","cikktipus":"Keres\u0151"};
#         ga4params.layout = Page.getLayout();
#         ga4params.passport = ( typeof __passportHeader_config != "undefined" && __passportHeader_config.loggedIn ? '' : 'Not' ) + 'LoggedIn';
#         gtag('js', new Date());
#         gtag('config', 'G-7GR3T85C96', ga4params);
#     </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-PPDGL3DR');</script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript">
#         Common.folder_id = 267;
#         Common.folder_parent_ids = [ 261 ];
#         Common.is_new_design = 1;
#     </script>
# <script>
#     window.fbAsyncInit = function() {
#         FB.init({
#             appId      : '330827937019153',
#             xfbml      : true,
#             status     : false,
#             version    : 'v5.0'
#         });
#         window.fb_initialized = true;
#     };
#
#     (function(d, s, id) {
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) return;
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/hu_HU/sdk.js";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
# </script>
# <script type="text/javascript">
#         $(function () {
#             window.LinkPreview && window.LinkPreview.init();
#         });
#     </script>
# <script type="text/javascript"><!--//--><![CDATA[//><!--
#     var IndexStatConfig = {
#         pixels: [ { id: 267, type: 2 }, { id: 261, type: 3 }, { id: 1, type: 5 }, { id: 2, type: 4 }],
#         device: 'desktop'
#     }
#     //--><!]]>
# </script>
# <script async="" src="//indexstat.index.hu/stat.min.js?dd=20240603" type="text/javascript"></script>
# <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script async="true" type="text/javascript">
#     var nuCmp = true; try { Promise.resolve(1).finally() } catch(e) { nuCmp = false; }
#     if (nuCmp) {
#         (function() {
#             var host = 'index.hu';
#             var element = document.createElement('script');
#             var firstScript = document.getElementsByTagName('script')[0];
#             var url = 'https://cmp.quantcast.com'
#                 .concat('/choice/', '4z9XXyvnuPTjK', '/', host, '/choice.js?tag_version=V2');
#             var uspTries = 0;
#             var uspTriesLimit = 3;
#             element.async = true;
#             element.type = 'text/javascript';
#             element.src = url;
#
#             firstScript.parentNode.insertBefore(element, firstScript);
#
#             function makeStub() {
#                 var TCF_LOCATOR_NAME = '__tcfapiLocator';
#                 var queue = [];
#                 var win = window;
#                 var cmpFrame;
#
#                 function addFrame() {
#                     var doc = win.document;
#                     var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#                     if (!otherCMP) {
#                         if (doc.body) {
#                             var iframe = doc.createElement('iframe');
#
#                             iframe.style.cssText = 'display:none';
#                             iframe.name = TCF_LOCATOR_NAME;
#                             doc.body.appendChild(iframe);
#                         } else {
#                             setTimeout(addFrame, 5);
#                         }
#                     }
#                     return !otherCMP;
#                 }
#
#                 function tcfAPIHandler() {
#                     var gdprApplies;
#                     var args = arguments;
#
#                     if (!args.length) {
#                         return queue;
#                     } else if (args[0] === 'setGdprApplies') {
#                         if (
#                             args.length > 3 &&
#                             args[2] === 2 &&
#                             typeof args[3] === 'boolean'
#                         ) {
#                             gdprApplies = args[3];
#                             if (typeof args[2] === 'function') {
#                                 args[2]('set', true);
#                             }
#                         }
#                     } else if (args[0] === 'ping') {
#                         var retr = {
#                             gdprApplies: gdprApplies,
#                             cmpLoaded: false,
#                             cmpStatus: 'stub'
#                         };
#
#                         if (typeof args[2] === 'function') {
#                             args[2](retr);
#                         }
#                     } else {
#                         if(args[0] === 'init' && typeof args[3] === 'object') {
#                             args[3] = { ...args[3], tag_version: 'V2' };
#                         }
#                         queue.push(args);
#                     }
#                 }
#
#                 function postMessageEventHandler(event) {
#                     var msgIsString = typeof event.data === 'string';
#                     var json = {};
#
#                     try {
#                         if (msgIsString) {
#                             json = JSON.parse(event.data);
#                         } else {
#                             json = event.data;
#                         }
#                     } catch (ignore) {}
#
#                     var payload = json.__tcfapiCall;
#
#                     if (payload) {
#                         window.__tcfapi(
#                             payload.command,
#                             payload.version,
#                             function(retValue, success) {
#                                 var returnMsg = {
#                                     __tcfapiReturn: {
#                                         returnValue: retValue,
#                                         success: success,
#                                         callId: payload.callId
#                                     }
#                                 };
#                                 if (msgIsString) {
#                                     returnMsg = JSON.stringify(returnMsg);
#                                 }
#                                 if (event && event.source && event.source.postMessage) {
#                                     event.source.postMessage(returnMsg, '*');
#                                 }
#                             },
#                             payload.parameter
#                         );
#                     }
#                 }
#
#                 while (win) {
#                     try {
#                         if (win.frames[TCF_LOCATOR_NAME]) {
#                             cmpFrame = win;
#                             break;
#                         }
#                     } catch (ignore) {}
#
#                     if (win === window.top) {
#                         break;
#                     }
#                     win = win.parent;
#                 }
#                 if (!cmpFrame) {
#                     addFrame();
#                     win.__tcfapi = tcfAPIHandler;
#                     win.addEventListener('message', postMessageEventHandler, false);
#                 }
#             };
#
#             makeStub();
#
#             var uspStubFunction = function() {
#                 var arg = arguments;
#                 if (typeof window.__uspapi !== uspStubFunction) {
#                     setTimeout(function() {
#                         if (typeof window.__uspapi !== 'undefined') {
#                             window.__uspapi.apply(window.__uspapi, arg);
#                         }
#                     }, 500);
#                 }
#             };
#
#             var checkIfUspIsReady = function() {
#                 uspTries++;
#                 if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#                     console.warn('USP is not accessible');
#                 } else {
#                     clearInterval(uspInterval);
#                 }
#             };
#
#             if (typeof window.__uspapi === 'undefined') {
#                 window.__uspapi = uspStubFunction;
#                 var uspInterval = setInterval(checkIfUspIsReady, 6000);
#             }
#         })();
#     }
# </script>
# <!-- End Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script src="//indexhu.adocean.pl/files/js/ado.js" type="text/javascript"></script>
# <script>
#     window.adocf = {};
#     window.adocf.useDOMContentLoaded = true;
#     window.iap_base = 'https://index.hu/';
#     var tagStr = document.querySelector('meta[name="keywords"]') ? document.querySelector('meta[name="keywords"]').getAttribute("content").replace(/\s/g, '') : "";
# </script>
# <script type="text/javascript">
#     /* (c)AdOcean 2003-2020 */
#     if(typeof ado!=="object"){ado={};ado.config=ado.preview=ado.placement=ado.master=ado.slave=function(){};}
#     ado.config({mode: "new", xml: false, consent: true, characterEncoding: true, attachReferrer: true, fpc: "auto" , defaultServer:"indexhu.adocean.pl" ,cookieDomain:"SLD"});
#     ado.preview({enabled: true});
#     /* (c)AdOcean 2003-2020, MASTER: c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87 */
#     ado.master({id: 'c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87', server: 'indexhu.adocean.pl', vars: typeof customTargetAdocean !== "undefined" ? customTargetAdocean : '', keys: tagStr });
# </script>
# <script type="module">
#     document.addEventListener('DOMContentLoaded', async () => {
#         const { Loader } = await (await import('https://iap.cdn.indexvas.hu/Scripts.js')).default;
#         window.GoaLoader = new Loader({"debug":false,"engine":"AdOcean","master":"c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87","stat":true})
#     })
# </script>
# <script type="text/javascript">
#     Common.maxFeedAjanloLoadCount = 1;
#     Common.feedAjanloLoadCount = 3;
#     Common.feedAjanloMoreButton = 1;
#     Common.feedAjanloTovabbUrl = "https://index.hu/24ora/";
# </script>
# <link href="/manifest.json" rel="manifest"/>
# <script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js"></script>
# <script>
#     var OneSignal = window.OneSignal || [];
#     OneSignal.push(function() {
#         OneSignal.sendTags({
#             is_web: true
#         });
#         OneSignal.init({
#             appId: "bd30d7a1-7b22-4adb-bacf-e4bf80d25bf7",
#             autoRegister: false,
#             notifyButton: {
#                 enable: true
#             }
#         });
#     });
# </script>
# <script>
#     window.googletag = window.googletag || {cmd: []};
#     googletag.cmd.push(function() {
#                 googletag.pubads().enableSingleRequest();
#                 googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#             if(!event.isEmpty) {
#                 $(document.getElementById(event.slot.getSlotElementId())).closest(".mobile-sticky").show().find("button.mobile-sticky-closing").on("click", function(){
#                     $(this).closest(".mobile-sticky").hide();
#                 });
#             }
#         });
#         googletag.enableServices();
#     });
# </script>
# </meta></link></link></link></link></link></link></meta></meta></meta></meta></meta></meta></meta></head>
# <body class="device_desktop indexhu rovat h24ora rovat_24ora iframe_disallowed">
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PPDGL3DR" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div id="fb-root"></div>
# <script>(function() {
#   var _fbq = window._fbq || (window._fbq = []);
#   if (!_fbq.loaded) {
#     var fbds = document.createElement('script');
#     fbds.async = true;
#     fbds.src = '//connect.facebook.net/en_US/fbds.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(fbds, s);
#     _fbq.loaded = true;
#   }
#   _fbq.push(['addPixelId', '551982981568628']);
# })();
# window._fbq = window._fbq || [];
# window._fbq.push(['track', 'PixelInitialized', {}]);
# </script>
# <noscript><img alt="" height="1" src="https://www.facebook.com/tr?id=551982981568628&amp;ev=PixelInitialized" style="display:none" width="1"/></noscript>
# <div class="layer xl_layer">
# <div class="iap iap--ado ad-label--hidden no-padding no-margin" data-id="adoceanindexhulmgghmhsud" id="adoceanindexhulmgghmhsud">
# <script class="iap-script">
#                                                             window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhulmgghmhsud","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_Layer","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#                                                         </script>
# </div>
# <div class="iap iap--ado ad-label--hidden no-padding no-margin" data-id="ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7" id="ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7">
# <script class="iap-script">
#                                                             window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7","empty":true,"lazy":false,"quality":false,"masterless":true,"area":"Index_Aloldalak_Layer_gde_test","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#                                                         </script>
# </div>
# </div>
# <div class="sticky">
# </div>
# <div class="container" id="ad_null_position">
# </div>
# <div aria-hidden="true" class="m-cf-search modal" data-backdrop="false" data-js-modal-window="search" role="dialog" style="display: none" tabindex="-1">
# <div class="m-cf-search_wrapper">
# <div class="m-cf-search_wrapper_container" data-js-cemp-search="container">
# <form action="https://index.hu/24ora/" class="m-cf-search_wrapper_container_form" method="get">
# <input name="word" type="hidden" value="1"/>
# <input name="pepe" type="hidden" value="1"/>
# <input name="tol" type="hidden" value="1999-01-01"/>
# <input name="ig" type="hidden" value="2024-06-03"/>
# <input class="m-cf-search_wrapper_container_form_input" data-js-cemp-search="input" name="s" placeholder="Keresés" tabindex="0" type="search"/>
# <button class="m-cf-search_wrapper_container_form_button" type="submit">
# <span class="m-cf-search_wrapper_container_form_button_wrapper">
# <svg class="m-cf-search_wrapper_container_form_button_wrapper_icon" style="height:21px;width:21px;" viewbox="0 0 21 21"><path d="M20.8 18.867c.267.267.267.7 0 .967l-.966.967c-.267.267-.7.267-.966 0L13.5 15.434c-.073-.074-.122-.16-.155-.253-1.39 1.014-3.094 1.62-4.944 1.62-4.64 0-8.4-3.76-8.4-8.4C0 3.76 3.76 0 8.4 0c4.64 0 8.4 3.76 8.4 8.4 0 1.85-.606 3.556-1.62 4.945.092.032.18.08.253.155l5.368 5.367zM8.4 2.8c-3.093 0-5.6 2.507-5.6 5.6 0 3.093 2.507 5.6 5.6 5.6 3.093 0 5.6-2.507 5.6-5.6 0-3.093-2.507-5.6-5.6-5.6z"></path></svg>
# <span class="m-cf-search_wrapper_container_form_button_wrapper_label h-visibility-off_small-down">Keresés</span>
# </span>
# </button>
# </form>
# </div>
# </div>
# </div>
# <div class="m-cf-indalista" data-js-dropdown="inda">
# <div class="m-cf-indalista_container">
# <ul class="m-cf-indalista_container_list">
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="blog.hu" href="https://blog.hu/" target="_blank">Blog.hu</a>
# </li>
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="forum" href="http://forum.index.hu/Topic/showTopicList" target="_blank">Fórum</a>
# </li>
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="indavideo" href="http://indavideo.hu/" target="_blank">Indavideó</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-cf-kiadvanylista">
# <div class="m-cf-kiadvanylista_container">
# <ul class="m-cf-kiadvanylista_container_list">
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Economx" data-target="economx" href="https://www.economx.hu" target="_blank">Economx</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Dívány" data-target="divany" href="https://divany.hu/" target="_blank">Dívány</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Totalcar" data-target="totalcar" href="https://totalcar.hu/" target="_blank">Totalcar</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Femina" data-target="femina" href="https://femina.hu/" target="_blank">Femina</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Port" data-target="port" href="https://port.hu/" target="_blank">Port</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="We ❤︎ Budapest" data-target="we_x2764_xfe0e_budapest" href="https://welovebudapest.com/" target="_blank">We ❤︎ Budapest</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Velvet" data-target="velvet" href="https://velvet.hu/" target="_blank">Velvet</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <button class="m-cf-kiadvanylista_container_list_item_inda" data-target="[data-js-dropdown=inda]" data-toggle="dropdown" type="button">
# <span class="m-cf-kiadvanylista_container_list_item_inda_container">
# <span class="m-cf-kiadvanylista_container_list_item_inda_container_label">Inda</span>
# <svg class="m-cf-kiadvanylista_container_list_item_inda_container_icon" viewbox="0 0 11 7">
# <path d="M5.5 5.125L1.032.657C.846.47.534.467.344.657c-.185.184-.19.497 0 .687l4.812 4.812c.092.092.217.14.342.14.125 0 .25-.045.346-.14l4.812-4.812c.185-.185.19-.498 0-.688-.184-.184-.498-.19-.688 0L5.5 5.127z"></path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-cf-fejlec">
# <div class="m-cf-fejlec_container">
# <div class="m-cf-fejlec_container_wrapper">
# <ul class="m-cf-fejlec_container_links">
# <li class="m-cf-fejlec_container_links_item itemCover">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Címlap" href="https://dex.hu/x.php?id=fxdfejlecpnc&amp;url=https%3A%2F%2Findex.hu%2F">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_logo" viewbox="-54 12 8 20"><path class="m-cf-fejlec_container_links_item_link_container_logo_stem" d="M-54 18h8v14h-8V18z"></path><path class="m-cf-fejlec_container_links_item_link_container_logo_dot" d="M-54 12h8v4h-8v-4z"></path></svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">Címlap</span>
# </span>
# </a>
# </li>
# <li class="m-cf-fejlec_container_links_item itemHeadings">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Rovatok" href="https://dex.hu/x.php?id=fxdfejlec&amp;url=https%3A%2F%2Findex.hu%2Frovatok">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_icon iconHamburger" viewbox="0 0 22 17">
# <path d="M0 1.5C0 .672.67 0 1.495 0h19.01C21.33 0 22 .666 22 1.5c0 .828-.67 1.5-1.495 1.5H1.495C.67 3 0 2.334 0 1.5zm0 7C0 7.672.67 7 1.495 7h19.01C21.33 7 22 7.666 22 8.5c0 .828-.67 1.5-1.495 1.5H1.495C.67 10 0 9.334 0 8.5zm0 7c0-.828.67-1.5 1.495-1.5h19.01c.826 0 1.495.666 1.495 1.5 0 .828-.67 1.5-1.495 1.5H1.495C.67 17 0 16.334 0 15.5z"></path>
# </svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">Rovatok</span>
# </span>
# </a>
# </li>
# <li class="m-cf-fejlec_container_links_item itemLatest">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Legfrissebbek" href="https://dex.hu/x.php?id=fxdfejlec&amp;url=https%3A%2F%2Findex.hu%2F24ora">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_icon iconClock" viewbox="0 0 22 22"><path d="M11 19.25c-4.557 0-8.25-3.693-8.25-8.25S6.443 2.75 11 2.75s8.25 3.693 8.25 8.25-3.693 8.25-8.25 8.25M11 0C4.925 0 0 4.925 0 11s4.925 11 11 11 11-4.925 11-11S17.075 0 11 0"></path><path d="M12.833 10.89V6.874c0-.76-.616-1.375-1.375-1.375-.76 0-1.375.616-1.375 1.375v5.04h.11l-.11.113 2.27 2.27c.536.535 1.406.535 1.943 0 .538-.538.538-1.41 0-1.946l-1.463-1.463z"></path></svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">Friss hírek</span>
# </span>
# </a>
# </li> </ul>
# </div>
# <div class="m-cf-fejlec_container_inda">
# <ul class="m-cf-fejlec_container_inda_kiadvanyok">
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Economx" data-target="economx" href="https://www.economx.hu" target="_blank">Economx</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Dívány" data-target="divany" href="https://divany.hu/" target="_blank">Dívány</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Totalcar" data-target="totalcar" href="https://totalcar.hu/" target="_blank">Totalcar</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Femina" data-target="femina" href="https://femina.hu/" target="_blank">Femina</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Port" data-target="port" href="https://port.hu/" target="_blank">Port</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="We ❤︎ Budapest" data-target="we_x2764_xfe0e_budapest" href="https://welovebudapest.com/" target="_blank">We ❤︎ Budapest</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Velvet" data-target="velvet" href="https://velvet.hu/" target="_blank">Velvet</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <button class="m-cf-fejlec_container_inda_kiadvanyok_item_inda" data-target="[data-js-dropdown=inda]" data-toggle="dropdown" type="button">
# <span class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container">
# <span class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container_label">Inda</span>
# <svg class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container_icon" viewbox="0 0 11 7">
# <path d="M5.5 5.125L1.032.657C.846.47.534.467.344.657c-.185.184-.19.497 0 .687l4.812 4.812c.092.092.217.14.342.14.125 0 .25-.045.346-.14l4.812-4.812c.185-.185.19-.498 0-.688-.184-.184-.498-.19-.688 0L5.5 5.127z"></path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# <ul class="m-cf-fejlec_container_inda_actions">
# <li class="m-cf-fejlec_container_inda_actions_item itemSearch">
# <button class="m-cf-fejlec_container_inda_actions_item_button" data-ga-category="Keresés" data-js-cemp-search="button" data-target="[data-js-modal-window=search]" data-toggle="modal" type="button">
# <span class="m-cf-fejlec_container_inda_actions_item_button_wrapper">
# <svg class="m-cf-fejlec_container_inda_actions_item_button_wrapper_icon" viewbox="0 0 21 21">
# <path d="M20.8 18.867c.267.267.267.7 0 .967l-.966.967c-.267.267-.7.267-.966 0L13.5 15.434c-.073-.074-.122-.16-.155-.253-1.39 1.014-3.094 1.62-4.944 1.62-4.64 0-8.4-3.76-8.4-8.4C0 3.76 3.76 0 8.4 0c4.64 0 8.4 3.76 8.4 8.4 0 1.85-.606 3.556-1.62 4.945.092.032.18.08.253.155l5.368 5.367zM8.4 2.8c-3.093 0-5.6 2.507-5.6 5.6 0 3.093 2.507 5.6 5.6 5.6 3.093 0 5.6-2.507 5.6-5.6 0-3.093-2.507-5.6-5.6-5.6z"></path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# <div class="fixed-header">
# <script type="text/javascript">
#
#     (function() {
#         var sc = document.createElement('script'); sc.type = 'text/javascript'; sc.async = true;
#         sc.src = __passportHeader_config.HEADER_URL + 'passportHeader.js';
#        var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sc, s);
#     })();    </script>
# <div id="passportHeader" style="height: 36px; visibility: hidden;"></div></div>
# </div>
# </div>
# </div>
# <section class="blokk hajtas-felett container index-header cimlap-blokk-index">
# <div class="index-header-wrapper">
# <a class="logo" data-ga-category="Index logó" href="/"></a>
# <ul class="trending-topics">
# <li stamp-index="0">
# <a class="cimke cimke-rovat cimke-203267" href="https://dex.hu/x.php?id=inxcl_stamp&amp;url=https%3A%2F%2Findex.hu%2Fsport%2Ffutball%2F2024%2Feb%2F">EB 2024</a>
# </li> </ul>
# <div class="header-parts">
# <div class="calendar">
# <time datetime="2024-06-03" title="23. hét">2024. 06. 03. hétfő</time>
# <div id="name-day">Klotild</div>
# </div>
# <section class="exchange njs-carousel">
# <a class="exchange-ticker" data-g-category="Árfolyam" href="https://dex.hu/x.php?id=inxfejlec&amp;url=http%3A%2F%2Fportfoliofinancial.hu%2F" target="_blank" title="Forrás: portfoliofinancial.hu">
# <span class="currency-item goood">
# <span class="ticker">EUR</span>
# <span class="price">
#                     390,29                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="currency-item baaad">
# <span class="ticker">USD</span>
# <span class="price">
#                     358,19                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="currency-item goood">
# <span class="ticker">GBP</span>
# <span class="price">
#                     458,33                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="exchange-item goood">
# <span class="ticker">BUX</span>
# <span class="price">
#                     69 459                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="exchange-item goood">
# <span class="ticker">OTP</span>
# <span class="price">
#                     17 560                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="exchange-item goood">
# <span class="ticker">MOL</span>
# <span class="price">
#                     2 820                    <span class="forint">Ft</span>
# </span>
# </span>
# </a>
# </section>
# <a class="weather" data-ga-category="Időjárás" data-temprature="20.2" href="https://dex.hu/x.php?id=inxcl_idojaras&amp;url=https://index.hu/idojaras" title="most: 20,2 °C">
# <div class="temperature">
# <div class="night">15 °C</div>
# <div class="day">24 °C</div>
# </div>
# <div class="weather-icon">
# <ul>
# <li class="icon-cloud"></li>
# </ul>
# </div>
# </a>
# </div>
# <nav id="index-rovatok">
# <a class="rovat-link navi_belfold" data-ga-category="Belföld" data-rovat-dropdown="" href="#" id="belfold">
#                 Belföld            </a>
# <a class="rovat-link navi_kulfold" data-ga-category="Külföld" data-rovat-dropdown="" href="#" id="kulfold">
#                 Külföld            </a>
# <a class="rovat-link navi_gazdasag" data-ga-category="Gazdaság" data-rovat-dropdown="" href="#" id="gazdasag">
#                 Gazdaság            </a>
# <a class="rovat-link navi_kultur" data-ga-category="Kult" data-rovat-dropdown="" href="#" id="kultur">
#                 Kult            </a>
# <a class="rovat-link navi_velemeny" data-ga-category="Vélemény" data-rovat-dropdown="" href="#" id="velemeny">
#                 Vélemény            </a>
# <a class="rovat-link navi_techtud" data-ga-category="Tech-Tud" data-rovat-dropdown="" href="#" id="techtud">
#                 Tech-Tud            </a>
# <a class="rovat-link navi_sport" data-ga-category="Sport" data-rovat-dropdown="" href="#" id="sport">
#                 Sport            </a>
# <a class="rovat-link navi_fomo" data-ga-category="Fomo" data-rovat-dropdown="" href="#" id="fomo">
#                 Fomo            </a>
# <a class="rovat-link navi_24ora selected" data-ga-category="24 Óra" data-rovat-dropdown="" href="#" id="24ora">
#                 24 Óra            </a>
# <a class="rovat-link navi_blog notification" data-ga-category="Blog" data-rovat-dropdown="" href="#" id="blog">
#                 Blog            </a>
# <a class="rovat-link navi_video notification" data-ga-category="Videó" data-rovat-dropdown="" href="#" id="video">
#                 Videó            </a>
# <a class="rovat-link navi_podcast notification" data-ga-category="Podcast" data-rovat-dropdown="" href="#" id="podcast">
#                 Podcast            </a>
# <a class="rovat-icon navi_twitter" data-ga-category="Twitter" href="https://twitter.com/indexhu" id="twitter" target="_blank"></a>
# <a class="rovat-icon navi_socials" data-ga-category="Socials" data-rovat-dropdown="" href="#" id="socials"></a>
# </nav>
# <div class="dropdown-container" hidden="" id="dropdown-menu-wrapper">
# <div class="loader animating">
# <span class="loader-item"></span>
# <span class="loader-item"></span>
# <span class="loader-item"></span>
# </div>
# </div>
# <script>
#     document.addEventListener('DOMContentLoaded', () => {
#         window.rovatDropdown = new RovatDropdown({
#             base_url: 'https://index.hu/',
#             callbacks: {
#                 video: function(element) {
#                     window.video_slider = new DropdownSlider(element.querySelector('.slider'), { threshold: 0 });
#                 }
#             }
#         });
#     });
# </script>
# </div>
# </section>
# <div class="container top_szponzor adverticum-kapubanner">
# <div class="ad-container">
# <div class="iap iap--ado" data-id="adoceanindexhuqclsmvirum" id="adoceanindexhuqclsmvirum">
# <script class="iap-script">
#                                                             window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhuqclsmvirum","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_LB","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#                                                         </script>
# </div>
# </div>
# </div>
# <div class="container border rovat-container">
# <div id="js_content_template_normal">
# <!--
#         <article class="rovatajanlo unordered not-important normal">
#             <header class="rovat-cikk-head">
#                 <h3>
#                     <span class="separator-box"></span>
#                         <span class="cikk-date-label" data-datestamp="{{Puzzler.ccd.ts}}" data-date="{{Puzzler.timestampToDate( Puzzler.ccd.ts )}}">{{Puzzler.ccd.datum}}</span>
#                     <span class="separator"></span>
#                     {{Puzzler.isMindekozben( Puzzler.ccd.url ) ? '<ul class="cikk-cimkek"><li><a href="http://index.hu/mindekozben" class="cimke cimke-mufaj">Mindeközben</a></li></ul>' : ''}}
#                     {{ Puzzler.ccd.kiadvany_csoki ? Puzzler.ccd.kiadvany_csoki : ''; }}
#                 </h3>
#                 <div class="clearfix"></div>
#             </header>
#
#             <h2>
#                 {{Puzzler.ccd.kep ? '<a href="' + Puzzler.ccd.url + '"  title="' + Puzzler.ccd.cim + '"><img class="need_to_load" src="' + Puzzler.ccd.kep + '" alt="' + Puzzler.ccd.cim + '" /></a>' : '' }}
#                 <a href="{{Puzzler.ccd.url}}" class="cim" title="{{Puzzler.ccd.cim}}">{{Puzzler.ccd.cim}}</a>
#             </h2>
#             {{Puzzler.ccd.ajanlo ? '<div class="ajanlo">' + Puzzler.ccd.ajanlo + '</div>' : '' }}
#         </article>
# -->
# </div>
# <div id="js_content_template_lead">
# <!--
#         <article class="rovatajanlo vezeto keppel not-important">
#             <div class="article-container">
#                 <a href="{{Puzzler.ccd.url}}"  title="{{Puzzler.ccd.cim}}">
#                     <img src="{{Puzzler.ccd.kep}}" alt="{{Puzzler.ccd.cim}}">
#                 </a>
#                 <h2>
#                     <a href="{{Puzzler.ccd.url}}" class="cim"  title="{{Puzzler.ccd.cim}}">{{Puzzler.ccd.cim}}</a>
#                 </h2>
#             </div>
#             <div class="author-share-date-container">
#             <div class="author-share-date">
#                 <div class="bal-hasab">
#                     <div class="szerzok_container">
#                             {{Puzzler.ccd.alnevek.replace(/\\(.)/mg, "$1")}}
#                     </div>
#                     <div class="datum">
#                         {{Puzzler.ccd.datum}}
#                     </div>
#                 </div>
#                 <div class="jobb-hasab">
#                     <div class="megoszt ">
#                         <div class="fb-share" data-action="recommend" data-href="{{Puzzler.ccd.url}}"> {{Puzzler.ccd.actual_fb_like}} </div>
#                 <div class="index-social-box cikk-top-box">
#                     <a href="#" class="megosztas-gomb"></a>
#                     <ul class="megosztas-doboz">
#                         <li class="mail">
#                             <a class="email" href="mailto:ugyelet@NEMSPA_M.mail.index.hu?subject={{Puzzler.ccd.cim}}&amp;body=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                             <li class="facebook">
#                                 <a href="https://www.facebook.com/sharer/sharer.php?u=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                             </li>
#                         <li class="twitter">
#                             <a href="http://twitter.com/share?lang=hu&amp;text={{Puzzler.ccd.cim}}&amp;url=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                         <li class="tumblr">
#                             <a href="http://www.tumblr.com/share/link?url=http:{{Puzzler.ccd.url}}&amp;name={{Puzzler.ccd.cim}}&amp;description=%28via+%3Ca+href%3D%22http%3A%2F%2Findex.hu%2F%22%3EIndex%3C%2Fa%3E%29" target="_blank"></a>
#                         </li>
#                         <li class="google-plus">
#                             <a href="https://plus.google.com/share?url=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                     </ul>
#                 </div>
#                             <div class="hozzaszolasok"></div>
#                    </div>
#
#                                 </div>
#                             </div>
#             </div>
#             <div class="ajanlo">{{Puzzler.ccd.ajanlo}}</div>
#         </article>
# -->
# </div>
# <div id="js_content_template_datumcsik">
# <!--
#         <div class="datumcsik clearfix">{{Puzzler.ccd.month ? Puzzler.ccd.month : Puzzler.timestampToDate( Puzzler.ccd.ts, true )}}</div>
# -->
# </div>
# <div class="kereses-urlap">
# <h3>Keresés</h3>
# <form action="" id="kereses-urlap">
# <div class="mezocsoport alap-kereso">
# <div class="kereses-wrapper">
# <input id="kereses-mezo" name="s" placeholder="Keresés" type="text" value=""/>
# </div>
# <div class="kereses-gomb-wrapper">
# <input class="gomb-elsodleges kereses-ikon" type="submit" value=""/>
# </div>
# </div>
# <div class="reszletes-kereses-gomb-container">
# <button class="gomb-masodlagos reszletes-kereses-gomb" href="#">Részletes keresés</button>
# </div>
# <div class="reszletes-kereses-container">
# <div class="datum-container">
# <div class="mezocsoport">
# <div class="datum-wrapper">
# <input autocomplete="off" class="date-selector" id="datum-tol" name="tol" type="text" value="1999-01-01"/>
# </div>
# <div class="datum-label-wrapper">
# <label for="datum-tol">-tól</label>
# </div>
# </div>
# <div class="mezocsoport">
# <div class="datum-wrapper">
# <input autocomplete="off" class="date-selector" id="datum-ig" name="ig" type="text" value="2024-06-03"/>
# </div>
# <div class="datum-label-wrapper">
# <label for="datum-ig">-ig</label>
# </div>
# </div>
# </div>
# <div class="onthisday-container">
# <input class="onthisday-kapcsolo" id="onthisday" name="onthisday" type="checkbox" value="1"/>
# <label class="onthisday-label" for="onthisday">Ezen a napon<span></span></label>
# </div>
# <div class="tarskiadvany-container">
# <input class="tarskiadvany-kapcsolo" id="tarskiadvanyokbanis" name="tarskiadvanyokbanis" type="checkbox" value="1"/>
# <label class="tarskiadvany-label" for="tarskiadvanyokbanis">Az Index környékéről is<span>Totalcar, Totalbike, Velvet, Dívány, Comment:Com, Könyvesblog, Tékozló Homár</span></label>
# <div class="tarskiadvany-opciok">
# <div class="szerzo-rovat-container">
# <div class="mezocsoport">
# <div class="input-wrapper">
# <select class="chosen-select" data-placeholder="Szerzők" name="profil">
# <option value=""></option>
# <option value="">Összes</option>
# <option value="acs_daniel">Ács Dániel</option>
# <option value="acs_tibor">Ács Tibor</option>
# <option value="adamek_alma">Adamek Alma</option>
# <option value="aghassi_attila">Ághassi Attila</option>
# <option value="ago_bela">Ágó Béla</option>
# <option value="agoston_zoltan">Ágoston Zoltán</option>
# <option value="ajpek_orsi">Ajpek Orsi</option>
# <option value="ambrus_adam">Ambrus Ádám</option>
# <option value="ambrus_balazs">Ambrus Balázs</option>
# <option value="andacs_botond">Andacs Botond</option>
# <option value="androczi_balazs">Andróczi Balázs</option>
# <option value="antalics_adam">Antalics Ádám</option>
# <option value="aradi_laszlo">Aradi László</option>
# <option value="aranyi_vanda">Arányi Vanda</option>
# <option value="arato_laszlo">Arató László</option>
# <option value="arnotszky_janka_judi">Arnótszky Judit Janka</option>
# <option value="arvai_peter">Árvai Péter</option>
# <option value="bacsanyi_peter">Bacsányi Péter</option>
# <option value="bakcsy_arpad">Bakcsy Árpád</option>
# <option value="bakro-nagy_ferenc">Bakró-Nagy Ferenc</option>
# <option value="baksa_roland">Baksa Roland</option>
# <option value="balazs_barbara">Balázs Barbara</option>
# <option value="balazsi_levente">Balázsi Levente</option>
# <option value="balint_agnes">Bálint Ágnes</option>
# <option value="balint_lilla">Bálint Lilla</option>
# ...
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/03/onkormanyzati-valasztas-2024-fopolgarmester-jelolt-kampany/" title="Elstartolt az utolsó kampányhét, bedobták magukat a főpolgármester-jelöltek">
#                 Elstartolt az utolsó kampányhét, bedobták magukat a főpolgármester-jelöltek            </a>
# </h2>
# <div class="ajanlo">
#             Csak úgy záporoznak a választóknak szóló üzenetek.        </div>
# </article>
# <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/kulfold/usa/feher_haz/2024/06/03/valasztas-wisconsin-egyesult-allamok-donald-trump-joe-biden/" title="Ők azok, akik eldönthetik, ki legyen a világ legnagyobb hatalommal rendelkező embere">
# <img alt="Ők azok, akik eldönthetik, ki legyen a világ legnagyobb hatalommal rendelkező embere" loading="lazy" src="https://kep.index.hu/1/0/5661/56615/566155/56615567_4186185_c238c343fe4e2453ed3c7a173e7a0cca_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/kulfold/usa/feher_haz/2024/06/03/valasztas-wisconsin-egyesult-allamok-donald-trump-joe-biden/" title="Ők azok, akik eldönthetik, ki legyen a világ legnagyobb hatalommal rendelkező embere">
#                         Ők azok, akik eldönthetik, ki legyen a világ legnagyobb hatalommal rendelkező embere                    </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/kovacs_ferenc">
# <img alt="Kovács Ferenc" class="szerzo-kep" src="https://kep.index.hu/1/0/3491/34914/349140/34914065_2672211_e0721dac08463d57ec82f5c7ea99423a_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/kovacs_ferenc" rel="author">Kovács Ferenc</a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1115"></span>
# </div>
# </div>
# </div>
# <div class="datum">
#                         2024.06.03. 15:05                        <span class="modositas-datuma-gomb" title="Módosítás dátuma">Módosítva: 2024-06-03 16:12:27</span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#             Melyik amerikai államokban számítanak a vidéki fehér szavazók voksai?        </div>
# </article>
# <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717419420">6 órája</span>
# <span class="separator"></span>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/orszagos-vizugyi-foigazgatosag-ovf-duna-arhullam/" title="Jön az árhullám a Dunán, hétvégén már Budapestet is elérheti">
# <img alt="Jön az árhullám a Dunán, hétvégén már Budapestet is elérheti" loading="lazy" src="https://kep.index.hu/1/0/5414/54143/541439/54143923_3998689_d795526e21f5f6c2df45db161000c27a_wm.jpg">
# </img></a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/orszagos-vizugyi-foigazgatosag-ovf-duna-arhullam/" title="Jön az árhullám a Dunán, hétvégén már Budapestet is elérheti">
#                 Jön az árhullám a Dunán, hétvégén már Budapestet is elérheti            </a>
# </h2>
# <div class="ajanlo">
#             A vízügy szakemberei a nap 24 órájában követik az adatokat, figyelik a folyót.        </div>
# </article>
# <article class="rovatajanlo normal right">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717418880">6 órája</span>
# <span class="separator"></span>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/nebih-tesco-bab-visszahivas/" title="Vörös vesebabot hívott vissza a Nébih, növényvédőszert tartalmazhat">
#                 Vörös vesebabot hívott vissza a Nébih, növényvédőszert tartalmazhat            </a>
# </h2>
# <div class="ajanlo">
#             A termék bármelyik Tesco-üzletbe visszavihető.        </div>
# </article>
# <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717418280">7 órája</span>
# <span class="separator"></span>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a href="https://index.hu/sport/forma1/2024/06/03/formula-1-alpine-esteben-ocon-tavozas-2024-pilotavaltas/" title="Eldőlt Esteban Ocon sokat vitatott jövője az Alpine csapatánál">
# <img alt="Eldőlt Esteban Ocon sokat vitatott jövője az Alpine csapatánál" loading="lazy" src="https://kep.index.hu/1/0/5663/56630/566309/56630913_4187307_ed17589c07ef6097bf55826df5ea3d68_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/forma1/2024/06/03/formula-1-alpine-esteben-ocon-tavozas-2024-pilotavaltas/" title="Eldőlt Esteban Ocon sokat vitatott jövője az Alpine csapatánál">
#                 Eldőlt Esteban Ocon sokat vitatott jövője az Alpine csapatánál            </a>
# </h2>
# <div class="ajanlo">
#             Korábban is kétséges volt, de a Monacói Nagydíj után napi szintű témává vált.        </div>
# </article>
# <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717418160">7 órája</span>
# <span class="separator"></span>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/yettel-online-csalas-atveres/" title="Figyelmeztetett a Yettel: újabb módszerrel próbálkoznak a csalók">
# <img alt="Figyelmeztetett a Yettel: újabb módszerrel próbálkoznak a csalók" loading="lazy" src="https://kep.index.hu/1/0/5663/56630/566307/56630767_4187297_14d10ac0a01947b2cae9eec8cefc9890_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/yettel-online-csalas-atveres/" title="Figyelmeztetett a Yettel: újabb módszerrel próbálkoznak a csalók">
#                 Figyelmeztetett a Yettel: újabb módszerrel próbálkoznak a csalók            </a>
# </h2>
# <div class="ajanlo">
#             Az ügyfelek adatait akarják megszerezni.        </div>
# </article>
# <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717417260">7 órája</span>
# <span class="separator"></span>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a href="https://index.hu/techtud/2024/06/03/haztartas-tisztitoszar-praktika-eset-szodabikarbona-keverek-latvanyos-felesleges/" title="Ez a praktikus házi tisztítószer-keverék valójában nem tisztít">
# <img alt="Ez a praktikus házi tisztítószer-keverék valójában nem tisztít" loading="lazy" src="https://kep.index.hu/1/0/5659/56596/565966/56596687_4184687_567220a557403e33d432e14d5fff0715_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/techtud/2024/06/03/haztartas-tisztitoszar-praktika-eset-szodabikarbona-keverek-latvanyos-felesleges/" title="Ez a praktikus házi tisztítószer-keverék valójában nem tisztít">
#                 Ez a praktikus házi tisztítószer-keverék valójában nem tisztít            </a>
# </h2>
# <div class="ajanlo">
#             Az ecet és szódabikarbóna keverése inkább csak látványosságnak jó.        </div>
# </article>
# <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717417140">7 órája</span>
# <span class="separator"></span>
# <ul class="cikk-cimkek">
# </ul>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/magyar-orszagos-kozjegyzoi-kamara-orokles-vegrendelet-felmeres/" title="Rengeteg mindent rosszul tudunk az öröklési szabályokról, pedig milliók múlhatnak rajta">
# <img alt="Rengeteg mindent rosszul tudunk az öröklési szabályokról, pedig milliók múlhatnak rajta" loading="lazy" src="https://kep.index.hu/1/0/4901/49013/490134/49013414_3736434_2a015e6cc241af0ddaf35c9a3f26fd41_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/magyar-orszagos-kozjegyzoi-kamara-orokles-vegrendelet-felmeres/" title="Rengeteg mindent rosszul tudunk az öröklési szabályokról, pedig milliók múlhatnak rajta">
#                 Rengeteg mindent rosszul tudunk az öröklési szabályokról, pedig milliók múlhatnak rajta            </a>
# </h2>
# <div class="ajanlo">
#             Sokan nincsenek tisztában azzal, milyen öröklési szabályok vonatkoznak a különböző vagyontárgyakra.        </div>
# </article>
# </main>
# <div class="clear"></div>
# </div>
# <footer class="m-page-footer">
# <div class="container m-page-footer_container">
# <ul class="m-page-footer_container_list">
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fimpresszum%2F">Impresszum</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findamediasales.hu%2F">Médiaajánlat</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fcopyright%2F">Szerzői jogok</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fadatvedelem%2F">Adatvédelmi elvek</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fsutiszabalyzat%2F">Süti szabályzat</a>
# </li>
# <li class="m-page-footer_container_list_item hasText">
# <a class="change-consent m-page-footer_container_list_item_link" onclick="window.__tcfapi('displayConsentUi', 2, function() {} );">Süti beállítások</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2F24ora%2Frss%2F">RSS</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Finfo%2Fallas%2F">Állás</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Fajanlat.indamediasales.hu%2Fmarkabiztonsag%2FIndamedia_Sales_Markabiztonsagi_nyilatkozat.pdf">Márkabiztonság</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fdsa" target="_blank">DSA</a>
# </li>
# <li class="m-page-footer_container_list_item hasText">
# <span class="m-page-footer_container_list_item_text">© 1999-2024 <span>Index.hu</span> Zrt.</span>
# </li>
# </ul>
# </div>
# </footer>
# <div class="layout_watcher phone"></div>
# <div class="layout_watcher portrait-tablet"></div>
# <div class="layout_watcher landscape-tablet"></div>
# <div class="layout_watcher desktop"></div>
# <div class="newsletter_modal" id="newsletterModal"></div>
# <script>
#     new NewsletterModal( document.getElementById('newsletterModal'), {'assetUrl': 'https://index.hu/assets/'});
# </script>
# <script>
#         var bodyContent = '';
#         $emailAdress = 'bla';
#                 bodyContent = 'Olvasói levelet, meghívót, sajtóközleményt készül küldeni a(z) <strong><a href="mailto:{emailAddress}" target="_blank" class="email">{emailShow}</a></strong> címen a szerkesztőségnek. Fontos nekünk, ezért az adataira is nagyon vigyázunk, ahogy az <a href="https://index.hu/adatvedelem" target="_blank">adatvédelmi tájékoztatónkban</a> részletezzük is. Ha Önnek is oké, kattintson az OK gombra.';
#         bodyContentMeghivo = 'Nyilatkozatot, bejelentést, vagy felhasználási kérelmet készül küldeni a(z) <strong><a href="mailto:{emailAddress}" target="_blank" class="email">{emailShow}</a></strong> címen a lapigazgatónak.Fontos nekünk, ezért az adataira is nagyon vigyázunk, ahogy az <a href="https://index.hu/adatvedelem" target="_blank">adatvédelmi tájékoztatónkban</a> részletezzük is. Ha Önnek is oké, kattintson az OK gombra.'
#
#         $(document).ready(function() {
#
#             $('a.email').on('click', function(e) {
#                 e.preventDefault();
#
#                 if (
#                     // Csak akkor jelenítjük meg a modal ablakot, ha ezeknek a feltételeknek valamelyike teljesül
#                     $(this).hasClass('irok_neki') ||               // Ha írok neki típusú a link vagy
#                     $(this).attr('href').indexOf('mailto:') !== -1  // van mailto link a href-ben
#                 ) {
#
#
#                     var emailAddress = $(this).attr('href')
#                         .replace('mailto:', '')
#                         .replace('NEMSPA_M.', '');
#
#                     var emailShow = emailAddress.match(/([a-zA-Z0-9._+-]+@[a-zA-Z0-9._-]+\.[a-zA-Z0-9._-]+)/)[0];
#
#                     var content = $(e.target).hasClass('meghivo') ? bodyContentMeghivo.replace(/{emailAddress}/gi, emailAddress).replace(/{emailShow}/g, emailShow) : bodyContent.replace(/{emailAddress}/gi, emailAddress).replace(/{emailShow}/g, emailShow);
#
#                     var mailtoModal = new vModal({
#                         title: 'Adatvédelmi tájékoztatás',
#                         body: content,
#                         buttons: {
#                             more: 'Vissza',
#                             confirm: 'OK'
#                         },
#                         className: 'vanilla_modal--basic',
#                         events: {
#                             confirm: function() {
#                                 //chrome miatt kell új lapon megnyitni, különben nem működik!
#                                 window.open('mailto:' + emailAddress, '_blank');
#                             }
#                         }
#                     });
#
#                     mailtoModal.open();
#
#                 }
#
#             });
#
#         });
#     </script>
# <script type="text/javascript">
#             <!--//--><![CDATA[//><!--
#             var pp_gemius_identifier = pp_gemius_original_identifier = new String('B9OVVi_kSaN4kjyXnmrlRnaITKLZOwR45wv6Si7xT2f.S7'); <!-- 24 óra -->
#             var pp_gemius_use_cmp = true;
#             var pp_gemius_cmp_timeout = Infinity;
#             //--><!]]>
#         </script>
# <script type="text/javascript">
#             <!--//--><![CDATA[//><!--
#             function gemius_pending(i) { window[i] = window[i] || function() {var x = window[i+'_pdata'] = window[i+'_pdata'] || []; x[x.length]=arguments;};};
#             gemius_pending('gemius_hit'); gemius_pending('gemius_event');
#             gemius_pending('pp_gemius_hit'); gemius_pending('pp_gemius_event');
#
#             (function(d,t) {try {
#             var gt=d.createElement(t),s=d.getElementsByTagName(t)[0],l='http'+((location.protocol=='https:')?'s':'');
#             gt.setAttribute('async','async');
#             gt.setAttribute('defer','defer');
#             gt.src=l+'://gahu.hit.gemius.pl/xgemius.js';
#             s.parentNode.insertBefore(gt,s);}
#             catch (e) {}})(document,'script');
#             //--><!]]>
#         </script>
# <script type="text/javascript">
#             var gemABObj = {
#                 docBody: document.getElementsByTagName('body')[0],
#                 incScript: document.createElement('SCRIPT'),
#                 checkIt: function(){document.getElementById("mnxHDozyKPjB")?pp_gemius_hit("nSdFzTtkvTTrx.B7K13yyfU378aFPueKFs36aeS6yET.A7","addon=no-adblock"):pp_gemius_hit("nSzrCTsGCKuF9KNE6iWTitVrzbu1Eg8GQHsHaml5W8n.b7","addon=adblock")}
#             };
#             gemABObj.incScript.src = '//indexhu.adocean.pl/files/x/mof/ghshscq/xajkevmjdv/ads.js';
#             gemABObj.docBody.appendChild(gemABObj.incScript);
#
#             window.addEventListener("load",gemABObj.checkIt);
#         </script>
# </body>
# </html>

# %%
f = open("sample_index.html", "r", encoding="utf-8")
soup = bs(f, "html.parser")

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="hu" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <head>
# <title>
#    Hírek - 24 óra - Index.hu
#   </title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=EmulateIE11" http-equiv="X-UA-Compatible"/>
# <!-- [if IE]>
#         <meta http-equiv="imagetoolbar" content="no" />
#         <meta name="MSSmartTagsPreventParsing" content="true" />
#         <meta http-equiv="X-UA-Compatible" content="IE=Edge">
#         <![endif]-->
# <meta content="1717420549" name="manis:deploy"/>
# <meta name="manis:breakpoint">
# <meta name="manis:breakpoints"/>
# <meta content="https://index.hu/copyright/" name="copyright"/>
# <meta content="unsafe-url" name="referrer">
# <meta content="app-id=480103271" name="apple-itunes-app"/>
# <meta content="app-id=com.aff.index.main" name="google-play-app"/>
# <meta content="noindex" name="robots"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="330827937019153" property="fb:app_id"/>
# <meta content="667823645" property="fb:admins"/>
# <meta content="560525343980775,348326671885918" property="fb:pages"/>
# <meta content="Friss hírek és információk az Indexen" name="description"/>
# <meta content="https://index.hu/assets/images/facebook_logo.png?v5" property="og:image">
# <meta content="https://www.facebook.com/Indexhu" property="article:publisher">
# <meta content="summary_large_image" name="twitter:card">
# <meta content="@indexhu" name="twitter:site">
# <meta content="https://index.hu/assets/images/facebook_logo.png" name="twitter:image:src">
# <link href="/assets/static/opensearch.xml" rel="search" title="Index" type="application/opensearchdescription+xml"/>
# <link href="/copyright/" rel="copyright" title="Szerzői jogok"/>
# <link href="/impresszum/" rel="author" title="Impresszum"/>
# <link href="/" id="homelink" rel="home" title=""/>
# <link href="/assets/images/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/assets/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/assets/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/assets/images/favicons/manifest.json" rel="manifest"/>
# <link href="/assets/images/favicons/favicon.ico" rel="shortcut icon"/>
# <link color="#ff9900" href="/assets/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="Index" name="apple-mobile-web-app-title"/>
# <meta content="Index" name="application-name"/>
# <meta content="#ffffff" name="theme-color"/>
# <script type="text/javascript">
#           var _sf_startpt=(new Date()).getTime()
#          </script>
# <link href="https://index.hu/assets/static/indexnew_css/public/global.css?v=1717420560" rel="stylesheet" type="text/css"/>
# <link href="https://index.hu/assets/static/indexnew_css/public/index-global.css?v=1717420560" rel="stylesheet" type="text/css"/>
# <link href="https://index.hu/assets/static/indexnew_css/public/rovat.css?v=1717420560" rel="stylesheet" type="text/css"/>
# <link href="https://index.hu/assets/static/indexnew_css/public/fixed_header.css?v=1717420560" rel="stylesheet" type="text/css"/>
# <link href="https://index.hu/assets/static/indexnew_css/public/24ora.css?v=1717420560" rel="stylesheet" type="text/css"/>
# <link href="/24ora/rss/" rel="alternate" title="24óra cikkek" type="application/rss+xml"/>
# <meta content="1" name="logcustomtarget"/>
# <!-- i8 -->
# <script src="https://index.hu/ident/getall/?c=aTg=" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/static/js/public/index_vendor.ugly.js?v=1717420561" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/static/js/public/index_base.ugly.js?v=1717420561" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/static/js/public/index_election.ugly.js?v=1717420561" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/static/js/public/cemp_fejlec.ugly.js?v=1717420561" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/index.rovat.min.js?v=1710407521" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/autocomplete.min.js?v=1717420549" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/calendar.min.js?v=1717420549" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/chosen2.min.js?v=1717420549" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/jquery-ui.min.js?v=1717420549" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/index.24ora.min.js?v=1717420549" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/scrolling_shadow.js?v=1717420549" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/pip_video.min.js?v=1717420549" type="text/javascript">
# </script>
# <script type="text/javascript">
#                  var _gaq = { push: function() {} };
#         ( function( i, s, o, g, r, a, m ) {
#             i[ 'GoogleAnalyticsObject' ] = r;
#             i[ r ] = i[ r ] || function() {
#                 ( i[ r ].q = i[ r ].q || [] ).push( arguments )
#             }, i[ r ].l = 1 * new Date();
#             a = s.createElement( o ), m = s.getElementsByTagName( o )[ 0 ];
#             a.async = 1;
#             a.src=g;
#             m.parentNode.insertBefore( a, m )
#         } )( window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga' );
#         var oldaltipus = '24ora_cimlap';
#         ( function( $ ) {
#             window.scrollTrackerEnabled = 1;
#             window.Analytics = {
#                 add: function( command, params, target ) {
#                     if( typeof command === 'undefined' || typeof params === 'undefined' || !command || !params ) {
#                         return this;
#                     }
#                     params.location = ( params.location || document.location.href ).replace( '//m.', '//' );
#                     if( this.loaded ) {
#                         if( typeof target !== 'undefined' ) {
#                             command = target + '.' + command;
#                         }
#                         ga( command, params );
#                     }
#                     else {
#                         this.stack.push( [ command, $.extend( {}, params ), target ] );
#                     }
#                     return this;
#                 },
#                 process: function() {
#                     if( this.loaded ) {
#                         return;
#                     }
#                     var arg;
#                     while( this.stack.length ) {
#                         arg = this.stack.shift();
#                         if( typeof arg[ 2 ] !== 'undefined' && Common[ 'ga_' + arg[ 2 ] ] === true ) {
#                             arg[ 0 ] = arg[ 2 ] + '.' + arg[ 0 ];
#                         }
#                         ga( arg[ 0 ], arg[ 1 ] );
#                     }
#                     this.loaded = true;
#                 },
#                 stack: []
#             };
#             $( document ).on( 'ready', function() {
#                 if( typeof window.Common === 'undefined' ) {
#                     window.Common = {
#                         ga_secondary: false
#                     };
#                 }
#                 if( typeof __passportHeader_config === 'undefined' ) {
#                     __passportHeader_config = {};
#                 }
#                 Common.ga_secondary = false;
#                 var ga_base_config = {
#                     sampleRate: 100,
#                     trackingId: 'UA-181415-27'
#                 };
#                 var ga_set_config = {
#                     dimension1: '24ora_cimlap',
#                     dimension2: ( __passportHeader_config.loggedIn ? '' : 'Not' ) + 'LoggedIn',
#                                             dimension3: Page.getLayout(),
#                                                                                 language: document.domain === 'totalcarmagazine.com' ? 'en-us' : 'hu-hu',
#                     location: document.location.href.replace( '//m.', '//' )
#                 };
#                 if( typeof __passportHeaderUserId !== 'undefined' ) {
#                     ga_base_config.userId = __passportHeaderUserId;
#                 }
#                 ga( 'create', ga_base_config );
#                 ga( 'require', 'displayfeatures' );
#                 ga( 'set', ga_set_config );
#                                     Common.ga_secondary = true;
#                     var ga_secondary_config = $.extend( {}, ga_base_config );
#                     ga_secondary_config.name = 'secondary';
#                     ga_secondary_config.trackingId = 'UA-181415-11';
#                     ga_secondary_config.sampleRate = 10;
#                     ga( 'create', ga_secondary_config );
#                     ga( 'secondary.require', 'displayfeatures' );
#                     ga( 'secondary.set', ga_set_config );
#                                 ga('set', 'anonymizeIp', true);
#                 // cross_site ajanlo kivetelkezelese
#                 if(
#                     (
#                         $( '#passportHeader, #_iph_fixed-header' ).length ||
#                         $( '#inforadio_audioplayer1' ).length ||
#                         $( '.header_send').length ||
#                         document.location.host.indexOf( 'm.' ) === 0 ||
#                         document.location.host.substring( document.location.host.length - 4 ) === '.com'
#                     ) &&
#                     ((Common.topfolder !== 'i2' && Common.topfolder !== 'index2') || !Common.parsed_url.hash || Common.parsed_url.hash.indexOf( '#bloghu' ) !== 0 )
#                 ) {
#                     ga( 'send', 'pageview' );
#                     if( Common.ga_secondary ) {
#                         ga( 'secondary.send', 'pageview' );
#                     }
#                 }
#                 Analytics.process();
#             } );
#         } )( jQuery );
#                 </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-7GR3T85C96">
# </script>
# <script>
#                  window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         var ga4params = {"content_group":"24ora\/","rovat":"24\u00f3ra","oldaltipus":"24ora_cimlap","cikktipus":"Keres\u0151"};
#         ga4params.layout = Page.getLayout();
#         ga4params.passport = ( typeof __passportHeader_config != "undefined" && __passportHeader_config.loggedIn ? '' : 'Not' ) + 'LoggedIn';
#         gtag('js', new Date());
#         gtag('config', 'G-7GR3T85C96', ga4params);
#                 </script>
# <!-- Google Tag Manager -->
# <script>
#                  (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-PPDGL3DR');
#                 </script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript">
#                  Common.folder_id = 267;
#         Common.folder_parent_ids = [ 261 ];
#         Common.is_new_design = 1;
#                 </script>
# <script>
#                  window.fbAsyncInit = function() {
#         FB.init({
#             appId      : '330827937019153',
#             xfbml      : true,
#             status     : false,
#             version    : 'v5.0'
#         });
#         window.fb_initialized = true;
#     };
#
#     (function(d, s, id) {
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) return;
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/hu_HU/sdk.js";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
#                 </script>
# <script type="text/javascript">
#                  $(function () {
#             window.LinkPreview && window.LinkPreview.init();
#         });
#                 </script>
# <script type="text/javascript">
#                  <!--//--><![CDATA[//><!--
#     var IndexStatConfig = {
#         pixels: [ { id: 267, type: 2 }, { id: 261, type: 3 }, { id: 1, type: 5 }, { id: 2, type: 4 }],
#         device: 'desktop'
#     }
#     //--><!]]>
#                 </script>
# <script async="" src="//indexstat.index.hu/stat.min.js?dd=20240603" type="text/javascript">
# </script>
# <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script async="true" type="text/javascript">
#                  var nuCmp = true; try { Promise.resolve(1).finally() } catch(e) { nuCmp = false; }
#     if (nuCmp) {
#         (function() {
#             var host = 'index.hu';
#             var element = document.createElement('script');
#             var firstScript = document.getElementsByTagName('script')[0];
#             var url = 'https://cmp.quantcast.com'
#                 .concat('/choice/', '4z9XXyvnuPTjK', '/', host, '/choice.js?tag_version=V2');
#             var uspTries = 0;
#             var uspTriesLimit = 3;
#             element.async = true;
#             element.type = 'text/javascript';
#             element.src = url;
#
#             firstScript.parentNode.insertBefore(element, firstScript);
#
#             function makeStub() {
#                 var TCF_LOCATOR_NAME = '__tcfapiLocator';
#                 var queue = [];
#                 var win = window;
#                 var cmpFrame;
#
#                 function addFrame() {
#                     var doc = win.document;
#                     var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#                     if (!otherCMP) {
#                         if (doc.body) {
#                             var iframe = doc.createElement('iframe');
#
#                             iframe.style.cssText = 'display:none';
#                             iframe.name = TCF_LOCATOR_NAME;
#                             doc.body.appendChild(iframe);
#                         } else {
#                             setTimeout(addFrame, 5);
#                         }
#                     }
#                     return !otherCMP;
#                 }
#
#                 function tcfAPIHandler() {
#                     var gdprApplies;
#                     var args = arguments;
#
#                     if (!args.length) {
#                         return queue;
#                     } else if (args[0] === 'setGdprApplies') {
#                         if (
#                             args.length > 3 &&
#                             args[2] === 2 &&
#                             typeof args[3] === 'boolean'
#                         ) {
#                             gdprApplies = args[3];
#                             if (typeof args[2] === 'function') {
#                                 args[2]('set', true);
#                             }
#                         }
#                     } else if (args[0] === 'ping') {
#                         var retr = {
#                             gdprApplies: gdprApplies,
#                             cmpLoaded: false,
#                             cmpStatus: 'stub'
#                         };
#
#                         if (typeof args[2] === 'function') {
#                             args[2](retr);
#                         }
#                     } else {
#                         if(args[0] === 'init' && typeof args[3] === 'object') {
#                             args[3] = { ...args[3], tag_version: 'V2' };
#                         }
#                         queue.push(args);
#                     }
#                 }
#
#                 function postMessageEventHandler(event) {
#                     var msgIsString = typeof event.data === 'string';
#                     var json = {};
#
#                     try {
#                         if (msgIsString) {
#                             json = JSON.parse(event.data);
#                         } else {
#                             json = event.data;
#                         }
#                     } catch (ignore) {}
#
#                     var payload = json.__tcfapiCall;
#
#                     if (payload) {
#                         window.__tcfapi(
#                             payload.command,
#                             payload.version,
#                             function(retValue, success) {
#                                 var returnMsg = {
#                                     __tcfapiReturn: {
#                                         returnValue: retValue,
#                                         success: success,
#                                         callId: payload.callId
#                                     }
#                                 };
#                                 if (msgIsString) {
#                                     returnMsg = JSON.stringify(returnMsg);
#                                 }
#                                 if (event && event.source && event.source.postMessage) {
#                                     event.source.postMessage(returnMsg, '*');
#                                 }
#                             },
#                             payload.parameter
#                         );
#                     }
#                 }
#
#                 while (win) {
#                     try {
#                         if (win.frames[TCF_LOCATOR_NAME]) {
#                             cmpFrame = win;
#                             break;
#                         }
#                     } catch (ignore) {}
#
#                     if (win === window.top) {
#                         break;
#                     }
#                     win = win.parent;
#                 }
#                 if (!cmpFrame) {
#                     addFrame();
#                     win.__tcfapi = tcfAPIHandler;
#                     win.addEventListener('message', postMessageEventHandler, false);
#                 }
#             };
#
#             makeStub();
#
#             var uspStubFunction = function() {
#                 var arg = arguments;
#                 if (typeof window.__uspapi !== uspStubFunction) {
#                     setTimeout(function() {
#                         if (typeof window.__uspapi !== 'undefined') {
#                             window.__uspapi.apply(window.__uspapi, arg);
#                         }
#                     }, 500);
#                 }
#             };
#
#             var checkIfUspIsReady = function() {
#                 uspTries++;
#                 if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#                     console.warn('USP is not accessible');
#                 } else {
#                     clearInterval(uspInterval);
#                 }
#             };
#
#             if (typeof window.__uspapi === 'undefined') {
#                 window.__uspapi = uspStubFunction;
#                 var uspInterval = setInterval(checkIfUspIsReady, 6000);
#             }
#         })();
#     }
#                 </script>
# <!-- End Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script src="//indexhu.adocean.pl/files/js/ado.js" type="text/javascript">
# </script>
# <script>
#                  window.adocf = {};
#     window.adocf.useDOMContentLoaded = true;
#     window.iap_base = 'https://index.hu/';
#     var tagStr = document.querySelector('meta[name="keywords"]') ? document.querySelector('meta[name="keywords"]').getAttribute("content").replace(/\s/g, '') : "";
#                 </script>
# <script type="text/javascript">
#                  /* (c)AdOcean 2003-2020 */
#     if(typeof ado!=="object"){ado={};ado.config=ado.preview=ado.placement=ado.master=ado.slave=function(){};}
#     ado.config({mode: "new", xml: false, consent: true, characterEncoding: true, attachReferrer: true, fpc: "auto" , defaultServer:"indexhu.adocean.pl" ,cookieDomain:"SLD"});
#     ado.preview({enabled: true});
#     /* (c)AdOcean 2003-2020, MASTER: c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87 */
#     ado.master({id: 'c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87', server: 'indexhu.adocean.pl', vars: typeof customTargetAdocean !== "undefined" ? customTargetAdocean : '', keys: tagStr });
#                 </script>
# <script type="module">
#                  document.addEventListener('DOMContentLoaded', async () => {
#         const { Loader } = await (await import('https://iap.cdn.indexvas.hu/Scripts.js')).default;
#         window.GoaLoader = new Loader({"debug":false,"engine":"AdOcean","master":"c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87","stat":true})
#     })
#                 </script>
# <script type="text/javascript">
#                  Common.maxFeedAjanloLoadCount = 1;
#     Common.feedAjanloLoadCount = 3;
#     Common.feedAjanloMoreButton = 1;
#     Common.feedAjanloTovabbUrl = "https://index.hu/24ora/";
#                 </script>
# <link href="/manifest.json" rel="manifest">
# <script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js">
# </script>
# <script>
#                  var OneSignal = window.OneSignal || [];
#     OneSignal.push(function() {
#         OneSignal.sendTags({
#             is_web: true
#         });
#         OneSignal.init({
#             appId: "bd30d7a1-7b22-4adb-bacf-e4bf80d25bf7",
#             autoRegister: false,
#             notifyButton: {
#                 enable: true
#             }
#         });
#     });
#                 </script>
# <script>
#                  window.googletag = window.googletag || {cmd: []};
#     googletag.cmd.push(function() {
#                 googletag.pubads().enableSingleRequest();
#                 googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#             if(!event.isEmpty) {
#                 $(document.getElementById(event.slot.getSlotElementId())).closest(".mobile-sticky").show().find("button.mobile-sticky-closing").on("click", function(){
#                     $(this).closest(".mobile-sticky").hide();
#                 });
#             }
#         });
#         googletag.enableServices();
#     });
#                 </script>
# </link>
# </meta>
# </meta>
# </meta>
# </meta>
# </meta>
# </meta>
# </meta>
# </head>
# <body class="device_desktop indexhu rovat h24ora rovat_24ora iframe_disallowed">
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PPDGL3DR" style="display:none;visibility:hidden" width="0">
# </iframe>
# </noscript>
# <div id="fb-root">
# </div>
# <script>
#    (function() {
#   var _fbq = window._fbq || (window._fbq = []);
#   if (!_fbq.loaded) {
#     var fbds = document.createElement('script');
#     fbds.async = true;
#     fbds.src = '//connect.facebook.net/en_US/fbds.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(fbds, s);
#     _fbq.loaded = true;
#   }
#   _fbq.push(['addPixelId', '551982981568628']);
# })();
# window._fbq = window._fbq || [];
# window._fbq.push(['track', 'PixelInitialized', {}]);
#   </script>
# <noscript>
# <img alt="" height="1" src="https://www.facebook.com/tr?id=551982981568628&amp;ev=PixelInitialized" style="display:none" width="1"/>
# </noscript>
# <div class="layer xl_layer">
# <div class="iap iap--ado ad-label--hidden no-padding no-margin" data-id="adoceanindexhulmgghmhsud" id="adoceanindexhulmgghmhsud">
# <script class="iap-script">
#      window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhulmgghmhsud","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_Layer","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#     </script>
# </div>
# <div class="iap iap--ado ad-label--hidden no-padding no-margin" data-id="ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7" id="ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7">
# <script class="iap-script">
#      window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7","empty":true,"lazy":false,"quality":false,"masterless":true,"area":"Index_Aloldalak_Layer_gde_test","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#     </script>
# </div>
# </div>
# <div class="sticky">
# </div>
# <div class="container" id="ad_null_position">
# </div>
# <div aria-hidden="true" class="m-cf-search modal" data-backdrop="false" data-js-modal-window="search" role="dialog" style="display: none" tabindex="-1">
# <div class="m-cf-search_wrapper">
# <div class="m-cf-search_wrapper_container" data-js-cemp-search="container">
# <form action="https://index.hu/24ora/" class="m-cf-search_wrapper_container_form" method="get">
# <input name="word" type="hidden" value="1"/>
# <input name="pepe" type="hidden" value="1"/>
# <input name="tol" type="hidden" value="1999-01-01"/>
# <input name="ig" type="hidden" value="2024-06-03"/>
# <input class="m-cf-search_wrapper_container_form_input" data-js-cemp-search="input" name="s" placeholder="Keresés" tabindex="0" type="search"/>
# <button class="m-cf-search_wrapper_container_form_button" type="submit">
# <span class="m-cf-search_wrapper_container_form_button_wrapper">
# <svg class="m-cf-search_wrapper_container_form_button_wrapper_icon" style="height:21px;width:21px;" viewbox="0 0 21 21">
# <path d="M20.8 18.867c.267.267.267.7 0 .967l-.966.967c-.267.267-.7.267-.966 0L13.5 15.434c-.073-.074-.122-.16-.155-.253-1.39 1.014-3.094 1.62-4.944 1.62-4.64 0-8.4-3.76-8.4-8.4C0 3.76 3.76 0 8.4 0c4.64 0 8.4 3.76 8.4 8.4 0 1.85-.606 3.556-1.62 4.945.092.032.18.08.253.155l5.368 5.367zM8.4 2.8c-3.093 0-5.6 2.507-5.6 5.6 0 3.093 2.507 5.6 5.6 5.6 3.093 0 5.6-2.507 5.6-5.6 0-3.093-2.507-5.6-5.6-5.6z">
# </path>
# </svg>
# <span class="m-cf-search_wrapper_container_form_button_wrapper_label h-visibility-off_small-down">
#          Keresés
#         </span>
# </span>
# </button>
# </form>
# </div>
# </div>
# </div>
# <div class="m-cf-indalista" data-js-dropdown="inda">
# <div class="m-cf-indalista_container">
# <ul class="m-cf-indalista_container_list">
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="blog.hu" href="https://blog.hu/" target="_blank">
#        Blog.hu
#       </a>
# </li>
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="forum" href="http://forum.index.hu/Topic/showTopicList" target="_blank">
#        Fórum
#       </a>
# </li>
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="indavideo" href="http://indavideo.hu/" target="_blank">
#        Indavideó
#       </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-cf-kiadvanylista">
# <div class="m-cf-kiadvanylista_container">
# <ul class="m-cf-kiadvanylista_container_list">
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Economx" data-target="economx" href="https://www.economx.hu" target="_blank">
#        Economx
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Dívány" data-target="divany" href="https://divany.hu/" target="_blank">
#        Dívány
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Totalcar" data-target="totalcar" href="https://totalcar.hu/" target="_blank">
#        Totalcar
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Femina" data-target="femina" href="https://femina.hu/" target="_blank">
#        Femina
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Port" data-target="port" href="https://port.hu/" target="_blank">
#        Port
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="We ❤︎ Budapest" data-target="we_x2764_xfe0e_budapest" href="https://welovebudapest.com/" target="_blank">
#        We ❤︎ Budapest
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Velvet" data-target="velvet" href="https://velvet.hu/" target="_blank">
#        Velvet
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <button class="m-cf-kiadvanylista_container_list_item_inda" data-target="[data-js-dropdown=inda]" data-toggle="dropdown" type="button">
# <span class="m-cf-kiadvanylista_container_list_item_inda_container">
# <span class="m-cf-kiadvanylista_container_list_item_inda_container_label">
#          Inda
#         </span>
# <svg class="m-cf-kiadvanylista_container_list_item_inda_container_icon" viewbox="0 0 11 7">
# <path d="M5.5 5.125L1.032.657C.846.47.534.467.344.657c-.185.184-.19.497 0 .687l4.812 4.812c.092.092.217.14.342.14.125 0 .25-.045.346-.14l4.812-4.812c.185-.185.19-.498 0-.688-.184-.184-.498-.19-.688 0L5.5 5.127z">
# </path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-cf-fejlec">
# <div class="m-cf-fejlec_container">
# <div class="m-cf-fejlec_container_wrapper">
# <ul class="m-cf-fejlec_container_links">
# <li class="m-cf-fejlec_container_links_item itemCover">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Címlap" href="https://dex.hu/x.php?id=fxdfejlecpnc&amp;url=https%3A%2F%2Findex.hu%2F">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_logo" viewbox="-54 12 8 20">
# <path class="m-cf-fejlec_container_links_item_link_container_logo_stem" d="M-54 18h8v14h-8V18z">
# </path>
# <path class="m-cf-fejlec_container_links_item_link_container_logo_dot" d="M-54 12h8v4h-8v-4z">
# </path>
# </svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">
#           Címlap
#          </span>
# </span>
# </a>
# </li>
# <li class="m-cf-fejlec_container_links_item itemHeadings">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Rovatok" href="https://dex.hu/x.php?id=fxdfejlec&amp;url=https%3A%2F%2Findex.hu%2Frovatok">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_icon iconHamburger" viewbox="0 0 22 17">
# <path d="M0 1.5C0 .672.67 0 1.495 0h19.01C21.33 0 22 .666 22 1.5c0 .828-.67 1.5-1.495 1.5H1.495C.67 3 0 2.334 0 1.5zm0 7C0 7.672.67 7 1.495 7h19.01C21.33 7 22 7.666 22 8.5c0 .828-.67 1.5-1.495 1.5H1.495C.67 10 0 9.334 0 8.5zm0 7c0-.828.67-1.5 1.495-1.5h19.01c.826 0 1.495.666 1.495 1.5 0 .828-.67 1.5-1.495 1.5H1.495C.67 17 0 16.334 0 15.5z">
# </path>
# </svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">
#           Rovatok
#          </span>
# </span>
# </a>
# </li>
# <li class="m-cf-fejlec_container_links_item itemLatest">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Legfrissebbek" href="https://dex.hu/x.php?id=fxdfejlec&amp;url=https%3A%2F%2Findex.hu%2F24ora">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_icon iconClock" viewbox="0 0 22 22">
# <path d="M11 19.25c-4.557 0-8.25-3.693-8.25-8.25S6.443 2.75 11 2.75s8.25 3.693 8.25 8.25-3.693 8.25-8.25 8.25M11 0C4.925 0 0 4.925 0 11s4.925 11 11 11 11-4.925 11-11S17.075 0 11 0">
# </path>
# <path d="M12.833 10.89V6.874c0-.76-.616-1.375-1.375-1.375-.76 0-1.375.616-1.375 1.375v5.04h.11l-.11.113 2.27 2.27c.536.535 1.406.535 1.943 0 .538-.538.538-1.41 0-1.946l-1.463-1.463z">
# </path>
# </svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">
#           Friss hírek
#          </span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# <div class="m-cf-fejlec_container_inda">
# <ul class="m-cf-fejlec_container_inda_kiadvanyok">
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Economx" data-target="economx" href="https://www.economx.hu" target="_blank">
#         Economx
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Dívány" data-target="divany" href="https://divany.hu/" target="_blank">
#         Dívány
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Totalcar" data-target="totalcar" href="https://totalcar.hu/" target="_blank">
#         Totalcar
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Femina" data-target="femina" href="https://femina.hu/" target="_blank">
#         Femina
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Port" data-target="port" href="https://port.hu/" target="_blank">
#         Port
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="We ❤︎ Budapest" data-target="we_x2764_xfe0e_budapest" href="https://welovebudapest.com/" target="_blank">
#         We ❤︎ Budapest
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Velvet" data-target="velvet" href="https://velvet.hu/" target="_blank">
#         Velvet
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <button class="m-cf-fejlec_container_inda_kiadvanyok_item_inda" data-target="[data-js-dropdown=inda]" data-toggle="dropdown" type="button">
# <span class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container">
# <span class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container_label">
#           Inda
#          </span>
# <svg class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container_icon" viewbox="0 0 11 7">
# <path d="M5.5 5.125L1.032.657C.846.47.534.467.344.657c-.185.184-.19.497 0 .687l4.812 4.812c.092.092.217.14.342.14.125 0 .25-.045.346-.14l4.812-4.812c.185-.185.19-.498 0-.688-.184-.184-.498-.19-.688 0L5.5 5.127z">
# </path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# <ul class="m-cf-fejlec_container_inda_actions">
# <li class="m-cf-fejlec_container_inda_actions_item itemSearch">
# <button class="m-cf-fejlec_container_inda_actions_item_button" data-ga-category="Keresés" data-js-cemp-search="button" data-target="[data-js-modal-window=search]" data-toggle="modal" type="button">
# <span class="m-cf-fejlec_container_inda_actions_item_button_wrapper">
# <svg class="m-cf-fejlec_container_inda_actions_item_button_wrapper_icon" viewbox="0 0 21 21">
# <path d="M20.8 18.867c.267.267.267.7 0 .967l-.966.967c-.267.267-.7.267-.966 0L13.5 15.434c-.073-.074-.122-.16-.155-.253-1.39 1.014-3.094 1.62-4.944 1.62-4.64 0-8.4-3.76-8.4-8.4C0 3.76 3.76 0 8.4 0c4.64 0 8.4 3.76 8.4 8.4 0 1.85-.606 3.556-1.62 4.945.092.032.18.08.253.155l5.368 5.367zM8.4 2.8c-3.093 0-5.6 2.507-5.6 5.6 0 3.093 2.507 5.6 5.6 5.6 3.093 0 5.6-2.507 5.6-5.6 0-3.093-2.507-5.6-5.6-5.6z">
# </path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# <div class="fixed-header">
# <script type="text/javascript">
#        (function() {
#         var sc = document.createElement('script'); sc.type = 'text/javascript'; sc.async = true;
#         sc.src = __passportHeader_config.HEADER_URL + 'passportHeader.js';
#        var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sc, s);
#     })();
#       </script>
# <div id="passportHeader" style="height: 36px; visibility: hidden;">
# </div>
# </div>
# </div>
# </div>
# </div>
# <section class="blokk hajtas-felett container index-header cimlap-blokk-index">
# <div class="index-header-wrapper">
# <a class="logo" data-ga-category="Index logó" href="/">
# </a>
# <ul class="trending-topics">
# <li stamp-index="0">
# <a class="cimke cimke-rovat cimke-203267" href="https://dex.hu/x.php?id=inxcl_stamp&amp;url=https%3A%2F%2Findex.hu%2Fsport%2Ffutball%2F2024%2Feb%2F">
#        EB 2024
#       </a>
# </li>
# </ul>
# <div class="header-parts">
# <div class="calendar">
# <time datetime="2024-06-03" title="23. hét">
#        2024. 06. 03. hétfő
#       </time>
# <div id="name-day">
#        Klotild
#       </div>
# </div>
# <section class="exchange njs-carousel">
# <a class="exchange-ticker" data-g-category="Árfolyam" href="https://dex.hu/x.php?id=inxfejlec&amp;url=http%3A%2F%2Fportfoliofinancial.hu%2F" target="_blank" title="Forrás: portfoliofinancial.hu">
# <span class="currency-item goood">
# <span class="ticker">
#          EUR
#         </span>
# <span class="price">
#          390,29
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="currency-item baaad">
# <span class="ticker">
#          USD
#         </span>
# <span class="price">
#          358,19
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="currency-item goood">
# <span class="ticker">
#          GBP
#         </span>
# <span class="price">
#          458,33
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="exchange-item goood">
# <span class="ticker">
#          BUX
#         </span>
# <span class="price">
#          69 459
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="exchange-item goood">
# <span class="ticker">
#          OTP
#         </span>
# <span class="price">
#          17 560
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="exchange-item goood">
# <span class="ticker">
#          MOL
#         </span>
# <span class="price">
#          2 820
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# </a>
# </section>
# <a class="weather" data-ga-category="Időjárás" data-temprature="20.2" href="https://dex.hu/x.php?id=inxcl_idojaras&amp;url=https://index.hu/idojaras" title="most: 20,2 °C">
# <div class="temperature">
# <div class="night">
#         15 °C
#        </div>
# <div class="day">
#         24 °C
#        </div>
# </div>
# <div class="weather-icon">
# <ul>
# <li class="icon-cloud">
# </li>
# </ul>
# </div>
# </a>
# </div>
# <nav id="index-rovatok">
# <a class="rovat-link navi_belfold" data-ga-category="Belföld" data-rovat-dropdown="" href="#" id="belfold">
#       Belföld
#      </a>
# <a class="rovat-link navi_kulfold" data-ga-category="Külföld" data-rovat-dropdown="" href="#" id="kulfold">
#       Külföld
#      </a>
# <a class="rovat-link navi_gazdasag" data-ga-category="Gazdaság" data-rovat-dropdown="" href="#" id="gazdasag">
#       Gazdaság
#      </a>
# <a class="rovat-link navi_kultur" data-ga-category="Kult" data-rovat-dropdown="" href="#" id="kultur">
#       Kult
#      </a>
# <a class="rovat-link navi_velemeny" data-ga-category="Vélemény" data-rovat-dropdown="" href="#" id="velemeny">
#       Vélemény
#      </a>
# <a class="rovat-link navi_techtud" data-ga-category="Tech-Tud" data-rovat-dropdown="" href="#" id="techtud">
#       Tech-Tud
#      </a>
# <a class="rovat-link navi_sport" data-ga-category="Sport" data-rovat-dropdown="" href="#" id="sport">
#       Sport
#      </a>
# <a class="rovat-link navi_fomo" data-ga-category="Fomo" data-rovat-dropdown="" href="#" id="fomo">
#       Fomo
#      </a>
# <a class="rovat-link navi_24ora selected" data-ga-category="24 Óra" data-rovat-dropdown="" href="#" id="24ora">
#       24 Óra
#      </a>
# <a class="rovat-link navi_blog notification" data-ga-category="Blog" data-rovat-dropdown="" href="#" id="blog">
#       Blog
#      </a>
# <a class="rovat-link navi_video notification" data-ga-category="Videó" data-rovat-dropdown="" href="#" id="video">
#       Videó
#      </a>
# <a class="rovat-link navi_podcast notification" data-ga-category="Podcast" data-rovat-dropdown="" href="#" id="podcast">
#       Podcast
#      </a>
# <a class="rovat-icon navi_twitter" data-ga-category="Twitter" href="https://twitter.com/indexhu" id="twitter" target="_blank">
# </a>
# <a class="rovat-icon navi_socials" data-ga-category="Socials" data-rovat-dropdown="" href="#" id="socials">
# </a>
# </nav>
# <div class="dropdown-container" hidden="" id="dropdown-menu-wrapper">
# <div class="loader animating">
# <span class="loader-item">
# </span>
# <span class="loader-item">
# </span>
# <span class="loader-item">
# </span>
# </div>
# </div>
# <script>
#      document.addEventListener('DOMContentLoaded', () => {
#         window.rovatDropdown = new RovatDropdown({
#             base_url: 'https://index.hu/',
#             callbacks: {
#                 video: function(element) {
#                     window.video_slider = new DropdownSlider(element.querySelector('.slider'), { threshold: 0 });
#                 }
#             }
#         });
#     });
#     </script>
# </div>
# </section>
# <div class="container top_szponzor adverticum-kapubanner">
# <div class="ad-container">
# <div class="iap iap--ado" data-id="adoceanindexhuqclsmvirum" id="adoceanindexhuqclsmvirum">
# <script class="iap-script">
#       window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhuqclsmvirum","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_LB","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#      </script>
# </div>
# </div>
# </div>
# <div class="container border rovat-container">
# <div id="js_content_template_normal">
# <!--
#         <article class="rovatajanlo unordered not-important normal">
#             <header class="rovat-cikk-head">
#                 <h3>
#                     <span class="separator-box"></span>
#                         <span class="cikk-date-label" data-datestamp="{{Puzzler.ccd.ts}}" data-date="{{Puzzler.timestampToDate( Puzzler.ccd.ts )}}">{{Puzzler.ccd.datum}}</span>
#                     <span class="separator"></span>
#                     {{Puzzler.isMindekozben( Puzzler.ccd.url ) ? '<ul class="cikk-cimkek"><li><a href="http://index.hu/mindekozben" class="cimke cimke-mufaj">Mindeközben</a></li></ul>' : ''}}
#                     {{ Puzzler.ccd.kiadvany_csoki ? Puzzler.ccd.kiadvany_csoki : ''; }}
#                 </h3>
#                 <div class="clearfix"></div>
#             </header>
#
#             <h2>
#                 {{Puzzler.ccd.kep ? '<a href="' + Puzzler.ccd.url + '"  title="' + Puzzler.ccd.cim + '"><img class="need_to_load" src="' + Puzzler.ccd.kep + '" alt="' + Puzzler.ccd.cim + '" /></a>' : '' }}
#                 <a href="{{Puzzler.ccd.url}}" class="cim" title="{{Puzzler.ccd.cim}}">{{Puzzler.ccd.cim}}</a>
#             </h2>
#             {{Puzzler.ccd.ajanlo ? '<div class="ajanlo">' + Puzzler.ccd.ajanlo + '</div>' : '' }}
#         </article>
# -->
# </div>
# <div id="js_content_template_lead">
# <!--
#         <article class="rovatajanlo vezeto keppel not-important">
#             <div class="article-container">
#                 <a href="{{Puzzler.ccd.url}}"  title="{{Puzzler.ccd.cim}}">
#                     <img src="{{Puzzler.ccd.kep}}" alt="{{Puzzler.ccd.cim}}">
#                 </a>
#                 <h2>
#                     <a href="{{Puzzler.ccd.url}}" class="cim"  title="{{Puzzler.ccd.cim}}">{{Puzzler.ccd.cim}}</a>
#                 </h2>
#             </div>
#             <div class="author-share-date-container">
#             <div class="author-share-date">
#                 <div class="bal-hasab">
#                     <div class="szerzok_container">
#                             {{Puzzler.ccd.alnevek.replace(/\\(.)/mg, "$1")}}
#                     </div>
#                     <div class="datum">
#                         {{Puzzler.ccd.datum}}
#                     </div>
#                 </div>
#                 <div class="jobb-hasab">
#                     <div class="megoszt ">
#                         <div class="fb-share" data-action="recommend" data-href="{{Puzzler.ccd.url}}"> {{Puzzler.ccd.actual_fb_like}} </div>
#                 <div class="index-social-box cikk-top-box">
#                     <a href="#" class="megosztas-gomb"></a>
#                     <ul class="megosztas-doboz">
#                         <li class="mail">
#                             <a class="email" href="mailto:ugyelet@NEMSPA_M.mail.index.hu?subject={{Puzzler.ccd.cim}}&amp;body=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                             <li class="facebook">
#                                 <a href="https://www.facebook.com/sharer/sharer.php?u=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                             </li>
#                         <li class="twitter">
#                             <a href="http://twitter.com/share?lang=hu&amp;text={{Puzzler.ccd.cim}}&amp;url=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                         <li class="tumblr">
#                             <a href="http://www.tumblr.com/share/link?url=http:{{Puzzler.ccd.url}}&amp;name={{Puzzler.ccd.cim}}&amp;description=%28via+%3Ca+href%3D%22http%3A%2F%2Findex.hu%2F%22%3EIndex%3C%2Fa%3E%29" target="_blank"></a>
#                         </li>
#                         <li class="google-plus">
#                             <a href="https://plus.google.com/share?url=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                     </ul>
#                 </div>
#                             <div class="hozzaszolasok"></div>
#                    </div>
#
#                                 </div>
#                             </div>
#             </div>
#             <div class="ajanlo">{{Puzzler.ccd.ajanlo}}</div>
#         </article>
# -->
# </div>
# <div id="js_content_template_datumcsik">
# <!--
#         <div class="datumcsik clearfix">{{Puzzler.ccd.month ? Puzzler.ccd.month : Puzzler.timestampToDate( Puzzler.ccd.ts, true )}}</div>
# -->
# </div>
# <div class="kereses-urlap">
# <h3>
#      Keresés
#     </h3>
# <form action="" id="kereses-urlap">
# <div class="mezocsoport alap-kereso">
# <div class="kereses-wrapper">
# <input id="kereses-mezo" name="s" placeholder="Keresés" type="text" value=""/>
# </div>
# <div class="kereses-gomb-wrapper">
# <input class="gomb-elsodleges kereses-ikon" type="submit" value=""/>
# </div>
# </div>
# <div class="reszletes-kereses-gomb-container">
# <button class="gomb-masodlagos reszletes-kereses-gomb" href="#">
#        Részletes keresés
#       </button>
# </div>
# <div class="reszletes-kereses-container">
# <div class="datum-container">
# <div class="mezocsoport">
# <div class="datum-wrapper">
# <input autocomplete="off" class="date-selector" id="datum-tol" name="tol" type="text" value="1999-01-01"/>
# </div>
# <div class="datum-label-wrapper">
# <label for="datum-tol">
#           -tól
#          </label>
# </div>
# </div>
# <div class="mezocsoport">
# <div class="datum-wrapper">
# <input autocomplete="off" class="date-selector" id="datum-ig" name="ig" type="text" value="2024-06-03"/>
# </div>
# <div class="datum-label-wrapper">
# <label for="datum-ig">
#           -ig
#          </label>
# </div>
# </div>
# </div>
# <div class="onthisday-container">
# <input class="onthisday-kapcsolo" id="onthisday" name="onthisday" type="checkbox" value="1"/>
# <label class="onthisday-label" for="onthisday">
#         Ezen a napon
#         <span>
# </span>
# </label>
# </div>
# <div class="tarskiadvany-container">
# <input class="tarskiadvany-kapcsolo" id="tarskiadvanyokbanis" name="tarskiadvanyokbanis" type="checkbox" value="1"/>
# <label class="tarskiadvany-label" for="tarskiadvanyokbanis">
#         Az Index környékéről is
#         <span>
#          Totalcar, Totalbike, Velvet, Dívány, Comment:Com, Könyvesblog, Tékozló Homár
#         </span>
# </label>
# <div class="tarskiadvany-opciok">
# <div class="szerzo-rovat-container">
# <div class="mezocsoport">
# <div class="input-wrapper">
# <select class="chosen-select" data-placeholder="Szerzők" name="profil">
# <option value="">
# </option>
# <option value="">
#              Összes
#             </option>
# <option value="acs_daniel">
#              Ács Dániel
#             </option>
# <option value="acs_tibor">
#              Ács Tibor
#             </option>
# <option value="adamek_alma">
#              Adamek Alma
#             </option>
# <option value="aghassi_attila">
#              Ághassi Attila
#             </option>
# <option value="ago_bela">
#              Ágó Béla
#             </option>
# <option value="agoston_zoltan">
#              Ágoston Zoltán
#             </option>
# <option value="ajpek_orsi">
#              Ajpek Orsi
#             </option>
# <option value="ambrus_adam">
#              Ambrus Ádám
#             </option>
# <option value="ambrus_balazs">
# ...
#        Elstartolt az utolsó kampányhét, bedobták magukat a főpolgármester-jelöltek
#       </a>
# </h2>
# <div class="ajanlo">
#       Csak úgy záporoznak a választóknak szóló üzenetek.
#      </div>
# </article>
# <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/kulfold/usa/feher_haz/2024/06/03/valasztas-wisconsin-egyesult-allamok-donald-trump-joe-biden/" title="Ők azok, akik eldönthetik, ki legyen a világ legnagyobb hatalommal rendelkező embere">
# <img alt="Ők azok, akik eldönthetik, ki legyen a világ legnagyobb hatalommal rendelkező embere" loading="lazy" src="https://kep.index.hu/1/0/5661/56615/566155/56615567_4186185_c238c343fe4e2453ed3c7a173e7a0cca_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/kulfold/usa/feher_haz/2024/06/03/valasztas-wisconsin-egyesult-allamok-donald-trump-joe-biden/" title="Ők azok, akik eldönthetik, ki legyen a világ legnagyobb hatalommal rendelkező embere">
#         Ők azok, akik eldönthetik, ki legyen a világ legnagyobb hatalommal rendelkező embere
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/kovacs_ferenc">
# <img alt="Kovács Ferenc" class="szerzo-kep" src="https://kep.index.hu/1/0/3491/34914/349140/34914065_2672211_e0721dac08463d57ec82f5c7ea99423a_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/kovacs_ferenc" rel="author">
#             Kovács Ferenc
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1115">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.03. 15:05
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-03 16:12:27
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Melyik amerikai államokban számítanak a vidéki fehér szavazók voksai?
#      </div>
# </article>
# <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717419420">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/orszagos-vizugyi-foigazgatosag-ovf-duna-arhullam/" title="Jön az árhullám a Dunán, hétvégén már Budapestet is elérheti">
# <img alt="Jön az árhullám a Dunán, hétvégén már Budapestet is elérheti" loading="lazy" src="https://kep.index.hu/1/0/5414/54143/541439/54143923_3998689_d795526e21f5f6c2df45db161000c27a_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/orszagos-vizugyi-foigazgatosag-ovf-duna-arhullam/" title="Jön az árhullám a Dunán, hétvégén már Budapestet is elérheti">
#        Jön az árhullám a Dunán, hétvégén már Budapestet is elérheti
#       </a>
# </h2>
# <div class="ajanlo">
#       A vízügy szakemberei a nap 24 órájában követik az adatokat, figyelik a folyót.
#      </div>
# </article>
# <article class="rovatajanlo normal right">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717418880">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/nebih-tesco-bab-visszahivas/" title="Vörös vesebabot hívott vissza a Nébih, növényvédőszert tartalmazhat">
#        Vörös vesebabot hívott vissza a Nébih, növényvédőszert tartalmazhat
#       </a>
# </h2>
# <div class="ajanlo">
#       A termék bármelyik Tesco-üzletbe visszavihető.
#      </div>
# </article>
# <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717418280">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/forma1/2024/06/03/formula-1-alpine-esteben-ocon-tavozas-2024-pilotavaltas/" title="Eldőlt Esteban Ocon sokat vitatott jövője az Alpine csapatánál">
# <img alt="Eldőlt Esteban Ocon sokat vitatott jövője az Alpine csapatánál" loading="lazy" src="https://kep.index.hu/1/0/5663/56630/566309/56630913_4187307_ed17589c07ef6097bf55826df5ea3d68_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/forma1/2024/06/03/formula-1-alpine-esteben-ocon-tavozas-2024-pilotavaltas/" title="Eldőlt Esteban Ocon sokat vitatott jövője az Alpine csapatánál">
#        Eldőlt Esteban Ocon sokat vitatott jövője az Alpine csapatánál
#       </a>
# </h2>
# <div class="ajanlo">
#       Korábban is kétséges volt, de a Monacói Nagydíj után napi szintű témává vált.
#      </div>
# </article>
# <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717418160">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/yettel-online-csalas-atveres/" title="Figyelmeztetett a Yettel: újabb módszerrel próbálkoznak a csalók">
# <img alt="Figyelmeztetett a Yettel: újabb módszerrel próbálkoznak a csalók" loading="lazy" src="https://kep.index.hu/1/0/5663/56630/566307/56630767_4187297_14d10ac0a01947b2cae9eec8cefc9890_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/yettel-online-csalas-atveres/" title="Figyelmeztetett a Yettel: újabb módszerrel próbálkoznak a csalók">
#        Figyelmeztetett a Yettel: újabb módszerrel próbálkoznak a csalók
#       </a>
# </h2>
# <div class="ajanlo">
#       Az ügyfelek adatait akarják megszerezni.
#      </div>
# </article>
# <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717417260">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/techtud/2024/06/03/haztartas-tisztitoszar-praktika-eset-szodabikarbona-keverek-latvanyos-felesleges/" title="Ez a praktikus házi tisztítószer-keverék valójában nem tisztít">
# <img alt="Ez a praktikus házi tisztítószer-keverék valójában nem tisztít" loading="lazy" src="https://kep.index.hu/1/0/5659/56596/565966/56596687_4184687_567220a557403e33d432e14d5fff0715_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/techtud/2024/06/03/haztartas-tisztitoszar-praktika-eset-szodabikarbona-keverek-latvanyos-felesleges/" title="Ez a praktikus házi tisztítószer-keverék valójában nem tisztít">
#        Ez a praktikus házi tisztítószer-keverék valójában nem tisztít
#       </a>
# </h2>
# <div class="ajanlo">
#       Az ecet és szódabikarbóna keverése inkább csak látványosságnak jó.
#      </div>
# </article>
# <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717417140">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/magyar-orszagos-kozjegyzoi-kamara-orokles-vegrendelet-felmeres/" title="Rengeteg mindent rosszul tudunk az öröklési szabályokról, pedig milliók múlhatnak rajta">
# <img alt="Rengeteg mindent rosszul tudunk az öröklési szabályokról, pedig milliók múlhatnak rajta" loading="lazy" src="https://kep.index.hu/1/0/4901/49013/490134/49013414_3736434_2a015e6cc241af0ddaf35c9a3f26fd41_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/magyar-orszagos-kozjegyzoi-kamara-orokles-vegrendelet-felmeres/" title="Rengeteg mindent rosszul tudunk az öröklési szabályokról, pedig milliók múlhatnak rajta">
#        Rengeteg mindent rosszul tudunk az öröklési szabályokról, pedig milliók múlhatnak rajta
#       </a>
# </h2>
# <div class="ajanlo">
#       Sokan nincsenek tisztában azzal, milyen öröklési szabályok vonatkoznak a különböző vagyontárgyakra.
#      </div>
# </article>
# </main>
# <div class="clear">
# </div>
# </div>
# <footer class="m-page-footer">
# <div class="container m-page-footer_container">
# <ul class="m-page-footer_container_list">
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fimpresszum%2F">
#        Impresszum
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findamediasales.hu%2F">
#        Médiaajánlat
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fcopyright%2F">
#        Szerzői jogok
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fadatvedelem%2F">
#        Adatvédelmi elvek
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fsutiszabalyzat%2F">
#        Süti szabályzat
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasText">
# <a class="change-consent m-page-footer_container_list_item_link" onclick="window.__tcfapi('displayConsentUi', 2, function() {} );">
#        Süti beállítások
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2F24ora%2Frss%2F">
#        RSS
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Finfo%2Fallas%2F">
#        Állás
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Fajanlat.indamediasales.hu%2Fmarkabiztonsag%2FIndamedia_Sales_Markabiztonsagi_nyilatkozat.pdf">
#        Márkabiztonság
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fdsa" target="_blank">
#        DSA
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasText">
# <span class="m-page-footer_container_list_item_text">
#        © 1999-2024
#        <span>
#         Index.hu
#        </span>
#        Zrt.
#       </span>
# </li>
# </ul>
# </div>
# </footer>
# <div class="layout_watcher phone">
# </div>
# <div class="layout_watcher portrait-tablet">
# </div>
# <div class="layout_watcher landscape-tablet">
# </div>
# <div class="layout_watcher desktop">
# </div>
# <div class="newsletter_modal" id="newsletterModal">
# </div>
# <script>
#    new NewsletterModal( document.getElementById('newsletterModal'), {'assetUrl': 'https://index.hu/assets/'});
#   </script>
# <script>
#    var bodyContent = '';
#         $emailAdress = 'bla';
#                 bodyContent = 'Olvasói levelet, meghívót, sajtóközleményt készül küldeni a(z) <strong><a href="mailto:{emailAddress}" target="_blank" class="email">{emailShow}</a></strong> címen a szerkesztőségnek. Fontos nekünk, ezért az adataira is nagyon vigyázunk, ahogy az <a href="https://index.hu/adatvedelem" target="_blank">adatvédelmi tájékoztatónkban</a> részletezzük is. Ha Önnek is oké, kattintson az OK gombra.';
#         bodyContentMeghivo = 'Nyilatkozatot, bejelentést, vagy felhasználási kérelmet készül küldeni a(z) <strong><a href="mailto:{emailAddress}" target="_blank" class="email">{emailShow}</a></strong> címen a lapigazgatónak.Fontos nekünk, ezért az adataira is nagyon vigyázunk, ahogy az <a href="https://index.hu/adatvedelem" target="_blank">adatvédelmi tájékoztatónkban</a> részletezzük is. Ha Önnek is oké, kattintson az OK gombra.'
#
#         $(document).ready(function() {
#
#             $('a.email').on('click', function(e) {
#                 e.preventDefault();
#
#                 if (
#                     // Csak akkor jelenítjük meg a modal ablakot, ha ezeknek a feltételeknek valamelyike teljesül
#                     $(this).hasClass('irok_neki') ||               // Ha írok neki típusú a link vagy
#                     $(this).attr('href').indexOf('mailto:') !== -1  // van mailto link a href-ben
#                 ) {
#
#
#                     var emailAddress = $(this).attr('href')
#                         .replace('mailto:', '')
#                         .replace('NEMSPA_M.', '');
#
#                     var emailShow = emailAddress.match(/([a-zA-Z0-9._+-]+@[a-zA-Z0-9._-]+\.[a-zA-Z0-9._-]+)/)[0];
#
#                     var content = $(e.target).hasClass('meghivo') ? bodyContentMeghivo.replace(/{emailAddress}/gi, emailAddress).replace(/{emailShow}/g, emailShow) : bodyContent.replace(/{emailAddress}/gi, emailAddress).replace(/{emailShow}/g, emailShow);
#
#                     var mailtoModal = new vModal({
#                         title: 'Adatvédelmi tájékoztatás',
#                         body: content,
#                         buttons: {
#                             more: 'Vissza',
#                             confirm: 'OK'
#                         },
#                         className: 'vanilla_modal--basic',
#                         events: {
#                             confirm: function() {
#                                 //chrome miatt kell új lapon megnyitni, különben nem működik!
#                                 window.open('mailto:' + emailAddress, '_blank');
#                             }
#                         }
#                     });
#
#                     mailtoModal.open();
#
#                 }
#
#             });
#
#         });
#   </script>
# <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
#             var pp_gemius_identifier = pp_gemius_original_identifier = new String('B9OVVi_kSaN4kjyXnmrlRnaITKLZOwR45wv6Si7xT2f.S7'); <!-- 24 óra -->
#             var pp_gemius_use_cmp = true;
#             var pp_gemius_cmp_timeout = Infinity;
#             //--><!]]>
#   </script>
# <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
#             function gemius_pending(i) { window[i] = window[i] || function() {var x = window[i+'_pdata'] = window[i+'_pdata'] || []; x[x.length]=arguments;};};
#             gemius_pending('gemius_hit'); gemius_pending('gemius_event');
#             gemius_pending('pp_gemius_hit'); gemius_pending('pp_gemius_event');
#
#             (function(d,t) {try {
#             var gt=d.createElement(t),s=d.getElementsByTagName(t)[0],l='http'+((location.protocol=='https:')?'s':'');
#             gt.setAttribute('async','async');
#             gt.setAttribute('defer','defer');
#             gt.src=l+'://gahu.hit.gemius.pl/xgemius.js';
#             s.parentNode.insertBefore(gt,s);}
#             catch (e) {}})(document,'script');
#             //--><!]]>
#   </script>
# <script type="text/javascript">
#    var gemABObj = {
#                 docBody: document.getElementsByTagName('body')[0],
#                 incScript: document.createElement('SCRIPT'),
#                 checkIt: function(){document.getElementById("mnxHDozyKPjB")?pp_gemius_hit("nSdFzTtkvTTrx.B7K13yyfU378aFPueKFs36aeS6yET.A7","addon=no-adblock"):pp_gemius_hit("nSzrCTsGCKuF9KNE6iWTitVrzbu1Eg8GQHsHaml5W8n.b7","addon=adblock")}
#             };
#             gemABObj.incScript.src = '//indexhu.adocean.pl/files/x/mof/ghshscq/xajkevmjdv/ads.js';
#             gemABObj.docBody.appendChild(gemABObj.incScript);
#
#             window.addEventListener("load",gemABObj.checkIt);
#   </script>
# </body>
# </html>

# %% [markdown]
# ## Cikkek adatait tároló kódrészlek kigyűjtése

# %%
articles = soup.find_all("article")

print(len(articles))
print(articles)
# Out:
# 60
# [<article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/kulfold/2024/06/03/afrika-szudan-polgarhaboru-nepirtas-egyesult-allamok-ensz-beavatkozas-konfliktus-valsag/" title="Népirtás készülődik Szudánban megint, amikor a világ éppen másfelé figyel">
# <img alt="Népirtás készülődik Szudánban megint, amikor a világ éppen másfelé figyel" loading="lazy" src="https://kep.index.hu/1/0/5658/56584/565848/56584891_4183845_2f9d4833e1dbaf33605fb97af588f7a2_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/03/afrika-szudan-polgarhaboru-nepirtas-egyesult-allamok-ensz-beavatkozas-konfliktus-valsag/" title="Népirtás készülődik Szudánban megint, amikor a világ éppen másfelé figyel">
#         Népirtás készülődik Szudánban megint, amikor a világ éppen másfelé figyel
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo kep-nelkul">
# <div class="kovetes nem-kovetheto">
#            Marton Máté
#           </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.03. 20:49
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-03 21:01:41
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Milliók élete forog kockán.
#      </div>
# <div class="iap iap--ado roadblock" data-id="adoceanindexhundcjqssfzl" id="adoceanindexhundcjqssfzl">
# <script class="iap-script">
#        window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhundcjqssfzl","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_RB_A","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#       </script>
# </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717441260">
#         14 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/degusztator/2024/06/03/salt-budapest-ev-etterme-dining-guide-gala-dijazottak/" title="Ők az idei Dining Guide Év Étterme gála díjazottjai">
# <img alt="Ők az idei Dining Guide Év Étterme gála díjazottjai" loading="lazy" src="https://kep.index.hu/1/0/5663/56635/566352/56635215_4187627_75cdf4a583fca85c8ace8cee2df8bbf9_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/degusztator/2024/06/03/salt-budapest-ev-etterme-dining-guide-gala-dijazottak/" title="Ők az idei Dining Guide Év Étterme gála díjazottjai">
#        Ők az idei Dining Guide Év Étterme gála díjazottjai
#       </a>
# </h2>
# <div class="ajanlo">
#       Idén jelentősen megváltozott a díj odaítélésének feltételrendszere.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717439580">
#         42 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/03/lengyelorszag-kibertamadas-krzysztof-gawkowski/" title="Újabb kibertámadások érték a kulcsfontosságú infrastruktúrát Lengyelországban">
# <img alt="Újabb kibertámadások érték a kulcsfontosságú infrastruktúrát Lengyelországban" loading="lazy" src="https://kep.index.hu/1/0/5663/56633/566338/56633899_4187541_3ecca3a97c9e90b55eaec12147430c80_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/03/lengyelorszag-kibertamadas-krzysztof-gawkowski/" title="Újabb kibertámadások érték a kulcsfontosságú infrastruktúrát Lengyelországban">
#        Újabb kibertámadások érték a kulcsfontosságú infrastruktúrát Lengyelországban
#       </a>
# </h2>
# <div class="ajanlo">
#       A miniszter szerint az incidens célja pánikkeltés, valamint a rendszer összezavarása volt.
#      </div>
# </article>, <article class="rovatajanlo normal right">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717439522">
#         43 perce
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/03/racz-gyuricza-dora-uj-videoja-megprobalja-felulirni-az-insta-vilagot/" title="Rácz-Gyuricza Dóra új videója megpróbálja felülírni az Insta-világot">
#        Rácz-Gyuricza Dóra új videója megpróbálja felülírni az Insta-világot
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717439460">
#         44 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/halalos-baleset-kozlekedes-5-os-fout-kistelek-karambol-utkozes/" title="Halálos baleset történt Kistelek közelében">
# <img alt="Halálos baleset történt Kistelek közelében" loading="lazy" src="https://kep.index.hu/1/0/5481/54810/548102/54810223_4050395_c047b7cb34d85136f6854079d980714b_wm.png"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/halalos-baleset-kozlekedes-5-os-fout-kistelek-karambol-utkozes/" title="Halálos baleset történt Kistelek közelében">
#        Halálos baleset történt Kistelek közelében
#       </a>
# </h2>
# <div class="ajanlo">
#       Egy motorkerékpár és egy személygépkocsi összeütközött.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717439340">
#         46 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/idojaras-vihar-tuzoltosag-katasztrofavedelem/" title="Országszerte sok munkát adott a viharos időjárás a tűzoltóknak">
# <img alt="Országszerte sok munkát adott a viharos időjárás a tűzoltóknak" loading="lazy" src="https://kep.index.hu/1/0/5481/54810/548102/54810223_4050395_c047b7cb34d85136f6854079d980714b_wm.png"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/idojaras-vihar-tuzoltosag-katasztrofavedelem/" title="Országszerte sok munkát adott a viharos időjárás a tűzoltóknak">
#        Országszerte sok munkát adott a viharos időjárás a tűzoltóknak
#       </a>
# </h2>
# <div class="ajanlo">
#       Kaposvárott egy tizenöt méteres fa fordult ki gyökerestől a földből, és hat autóban tett kárt.
#      </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/sport/futball/2024/eb/2024/06/03/eb-2024-c-csoport-beharangozo-anglia-dania-szerbia-szlovenia/" title="Övék a világ legerősebb kerete, mégis biztosra vehető, hogy valahogyan úgyis elbuknak">
# <img alt="Övék a világ legerősebb kerete, mégis biztosra vehető, hogy valahogyan úgyis elbuknak" loading="lazy" src="https://kep.index.hu/1/0/5663/56633/566330/56633091_4187491_48f9ee2aae3a4ca18fbb748387679725_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/sport/futball/2024/eb/2024/06/03/eb-2024-c-csoport-beharangozo-anglia-dania-szerbia-szlovenia/" title="Övék a világ legerősebb kerete, mégis biztosra vehető, hogy valahogyan úgyis elbuknak">
#         Övék a világ legerősebb kerete, mégis biztosra vehető, hogy valahogyan úgyis elbuknak
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/borbely_laszlo">
# <img alt="Borbély László" class="szerzo-kep" src="https://kep.index.hu/1/0/3656/36569/365693/36569341_2793883_8bef07e71c12c027a9e605eb5d3fe81f_wm.png"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/borbely_laszlo" rel="author">
#             Borbély László
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1237">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.03. 20:25
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-03 20:28:11
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Egy meglepetésbajnok és a magyar válogatott selejtezős riválisa is a favorit csoportjában.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717438920">
#         53 perce
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/03/vandalizmus-rongalas-klimaaktivista-food-response-monet-festmeny-pipacsmezo/" title="Letartóztatták a klímaaktivistát, miután megrongált egy Monet-festményt Párizsban">
# <img alt="Letartóztatták a klímaaktivistát, miután megrongált egy Monet-festményt Párizsban" loading="lazy" src="https://kep.index.hu/1/0/5663/56632/566326/56632641_4187457_bcb93df8c05b8222b659b8e048da2778_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/03/vandalizmus-rongalas-klimaaktivista-food-response-monet-festmeny-pipacsmezo/" title="Letartóztatták a klímaaktivistát, miután megrongált egy Monet-festményt Párizsban">
#        Letartóztatták a klímaaktivistát, miután megrongált egy Monet-festményt Párizsban
#       </a>
# </h2>
# <div class="ajanlo">
#       Úgy tudni, nem védte üveg a festményt.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717438560">
#         59 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/gazdasag/2024/06/03/celeb-cegek-nyereseg-kasza-tibor-majka-sebestyen-balazs/" title="Nincs több titok, ilyen évet produkáltak tavaly Kasza Tibor cégei">
# <img alt="Nincs több titok, ilyen évet produkáltak tavaly Kasza Tibor cégei" loading="lazy" src="https://kep.index.hu/1/0/5022/50223/502239/50223911_3828821_31b206e77fa84b670010e3eae4e8ec16_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/gazdasag/2024/06/03/celeb-cegek-nyereseg-kasza-tibor-majka-sebestyen-balazs/" title="Nincs több titok, ilyen évet produkáltak tavaly Kasza Tibor cégei">
#        Nincs több titok, ilyen évet produkáltak tavaly Kasza Tibor cégei
#       </a>
# </h2>
# <div class="ajanlo">
#       De Majka és Sebestyén Balázs cégei is jól működnek.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717437900">
#         1 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/03/robert-oppenheimer-hirosima-atomtamadas-tulelo/" title="J. Robert Oppenheimer unokája Hirosimában találkozott az atomtámadás túlélőjével">
# <img alt="J. Robert Oppenheimer unokája Hirosimában találkozott az atomtámadás túlélőjével" loading="lazy" src="https://kep.index.hu/1/0/5663/56635/566351/56635121_4187621_2746963ea690ae26c22888aacf14bd21_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/03/robert-oppenheimer-hirosima-atomtamadas-tulelo/" title="J. Robert Oppenheimer unokája Hirosimában találkozott az atomtámadás túlélőjével">
#        J. Robert Oppenheimer unokája Hirosimában találkozott az atomtámadás túlélőjével
#       </a>
# </h2>
# <div class="ajanlo">
#       Ogura Keikó nyolcéves kislányként élte túl az atomtámadást.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717437900">
#         1 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/cinematrix/2024/06/03/geek-girl-netflix-teve-sorozat-pilot-evadkezdes-streaming-young-adult-regeny-adaptacio-kritika/" title="Bátran döntögeti a tabukat a Netflix új sorozata">
# <img alt="Bátran döntögeti a tabukat a Netflix új sorozata" loading="lazy" src="https://kep.index.hu/1/0/5662/56622/566227/56622797_4186733_f2e989e490a6e4e40870451d2fa0305c_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/cinematrix/2024/06/03/geek-girl-netflix-teve-sorozat-pilot-evadkezdes-streaming-young-adult-regeny-adaptacio-kritika/" title="Bátran döntögeti a tabukat a Netflix új sorozata">
#        Bátran döntögeti a tabukat a Netflix új sorozata
#       </a>
# </h2>
# <div class="ajanlo">
#       A Geek Girl meglepően komoly néznivaló lett.
#      </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/fomo/2024/06/03/estonia-kompkatasztrofa-rtl-sorozat/" title="Mai napig rejtély övezi Európa egyik legnagyobb katasztrófáját">
# <img alt="Mai napig rejtély övezi Európa egyik legnagyobb katasztrófáját" loading="lazy" src="https://kep.index.hu/1/0/5660/56600/566006/56600637_4184977_0fd2ec247d3b461d5bb04a2bdf8a8821_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/fomo/2024/06/03/estonia-kompkatasztrofa-rtl-sorozat/" title="Mai napig rejtély övezi Európa egyik legnagyobb katasztrófáját">
#         Mai napig rejtély övezi Európa egyik legnagyobb katasztrófáját
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/harnisch_kitti">
# <img alt="Harnisch Kitti" class="szerzo-kep" src="https://kep.index.hu/1/0/4152/41525/415253/41525355_3169809_6bc9f849e6e4839cc9b4639882de03c1_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/harnisch_kitti" rel="author">
#             Harnisch Kitti
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1353">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.03. 20:05
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-03 20:43:19
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Idén lesz 30 éve, hogy Tallin és Stockholm között elsüllyedt az Estonia komphajó.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717437900">
#         1 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/gazdasag/2024/06/03/atletikai-vb-budapest-bevetel-budapest-2023-zrt/" title="Majdnem hárommilliárd forint bevételt hozott az atlétikai világbajnokság">
# <img alt="Majdnem hárommilliárd forint bevételt hozott az atlétikai világbajnokság" loading="lazy" src="https://kep.index.hu/1/0/5663/56634/566342/56634227_4187565_4964abc262878b500d319a4dab952681_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/gazdasag/2024/06/03/atletikai-vb-budapest-bevetel-budapest-2023-zrt/" title="Majdnem hárommilliárd forint bevételt hozott az atlétikai világbajnokság">
#        Majdnem hárommilliárd forint bevételt hozott az atlétikai világbajnokság
#       </a>
# </h2>
# <div class="ajanlo">
#       Az összeg több mint 80 százaléka a jegyeladásokból folyt be.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717437000">
#         1 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/futball/2024/06/03/kylian-mbappe-psg-real-madrid-atigazolas-hivatalos/" title="Véget ért a többéves szappanopera: Kylian Mbappé a Real Madrid játékosa lett">
# <img alt="Véget ért a többéves szappanopera: Kylian Mbappé a Real Madrid játékosa lett" loading="lazy" src="https://kep.index.hu/1/0/5663/56635/566350/56635041_4187617_2ba75099402637ec70209c8fcb01ae13_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/futball/2024/06/03/kylian-mbappe-psg-real-madrid-atigazolas-hivatalos/" title="Véget ért a többéves szappanopera: Kylian Mbappé a Real Madrid játékosa lett">
#        Véget ért a többéves szappanopera: Kylian Mbappé a Real Madrid játékosa lett
#       </a>
# </h2>
# <div class="ajanlo">
#       A friss BL-győztes hivatalosan is bejelentette a világbajnok francia támadó érkezését.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717436520">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/03/tompos-katya-gyertyagyujtas/" title="Nyilvános gyertyagyújtással emlékeznek Tompos Kátyára">
# <img alt="Nyilvános gyertyagyújtással emlékeznek Tompos Kátyára" loading="lazy" src="https://kep.index.hu/1/0/5663/56634/566347/56634797_4187599_bd6b6f19c529253059b7084c34a3c4b8_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/03/tompos-katya-gyertyagyujtas/" title="Nyilvános gyertyagyújtással emlékeznek Tompos Kátyára">
#        Nyilvános gyertyagyújtással emlékeznek Tompos Kátyára
#       </a>
# </h2>
# <div class="ajanlo">
#       A hírt a színésznő jóbarátja közölte.
#      </div>
# </article>, <article class="rovatajanlo normal right">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717435804">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/03/maya-hawke-szineszno-nepo-baby-uma-thurman-ethan-hawke/" title="Maya Hawke-ot nem zavarja, hogy csak azért kapott szerepet egy nagysikerű filmben, mert híresek a szülei">
#        Maya Hawke-ot nem zavarja, hogy csak azért kapott szerepet egy nagysikerű filmben, mert híresek a szülei
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717433520">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/zene/2024/06/03/pickup-stenk-divent-foreland-nagy-dani/" title="Van, aki partival készül a nyárra, míg egyesek arcokat tépnek">
# <img alt="Van, aki partival készül a nyárra, míg egyesek arcokat tépnek" loading="lazy" src="https://kep.index.hu/1/0/5659/56594/565941/56594147_4184517_fead06b91977e141d7f1ff5c0b56cbec_wm.png"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/zene/2024/06/03/pickup-stenk-divent-foreland-nagy-dani/" title="Van, aki partival készül a nyárra, míg egyesek arcokat tépnek">
#        Van, aki partival készül a nyárra, míg egyesek arcokat tépnek
#       </a>
# </h2>
# <div class="ajanlo">
#       A júniusi PickUp még minket is meglepett.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717433040">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/gazdasag/2024/06/03/lakaspiac-duna-house-adas-vetel-adatok/" title="A lakáspiac eddig hozza az elvárt szintet">
# <img alt="A lakáspiac eddig hozza az elvárt szintet" loading="lazy" src="https://kep.index.hu/1/0/5663/56633/566330/56633055_4187489_b6d6563ec6312862b03b26e2f57a7c82_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/gazdasag/2024/06/03/lakaspiac-duna-house-adas-vetel-adatok/" title="A lakáspiac eddig hozza az elvárt szintet">
#        A lakáspiac eddig hozza az elvárt szintet
#       </a>
# </h2>
# <div class="ajanlo">
#       Az idei május még erősebb is volt, mint a tavalyi.
#      </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/sport/futball/2024/06/03/labdarugas-futball-bajnokok-ligaja-donto-finale-wembley-real-madrid-dortmund-denes-tamas-meszaros-abel-sportcast/" title="A Real Madrid úgy nyerte meg ezt a BL-t, hogy néhány kulcsjátékosa alig közepesen játszott">
# <img alt="A Real Madrid úgy nyerte meg ezt a BL-t, hogy néhány kulcsjátékosa alig közepesen játszott" loading="lazy" src="https://kep.index.hu/1/0/5663/56632/566328/56632857_4187473_49c3d64041bd4c4304069e6b5fbfde69_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/sport/futball/2024/06/03/labdarugas-futball-bajnokok-ligaja-donto-finale-wembley-real-madrid-dortmund-denes-tamas-meszaros-abel-sportcast/" title="A Real Madrid úgy nyerte meg ezt a BL-t, hogy néhány kulcsjátékosa alig közepesen játszott">
#         A Real Madrid úgy nyerte meg ezt a BL-t, hogy néhány kulcsjátékosa alig közepesen játszott
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/krasz_emil">
# <img alt="Krasz Emil" class="szerzo-kep" src="https://kep.index.hu/1/0/4801/48017/480174/48017456_3660610_eb13db7109a7b58dbfa1ae1579ff7144_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/krasz_emil" rel="author">
#             Krasz Emil
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1516">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.03. 18:29
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-03 20:06:43
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Átmeneti szezon ide vagy oda, a serleg ismét a rekorderhez került. Az Index Sportcastjében Dénes Tamással és Mészáros Ábellel beszélgettünk.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717432020">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/cinematrix/2024/06/03/maya-hawke-ethan-hawke-uma-thurman-nepotizmus-sztar-szulo/" title="Maya Hawke nepotizmusról beszélt, és elismerte: a neve nagyban segíti karrierjét">
# <img alt="Maya Hawke nepotizmusról beszélt, és elismerte: a neve nagyban segíti karrierjét" loading="lazy" src="https://kep.index.hu/1/0/5661/56617/566176/56617681_4186351_42a6da1af35c537e64529a47d966a30d_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/cinematrix/2024/06/03/maya-hawke-ethan-hawke-uma-thurman-nepotizmus-sztar-szulo/" title="Maya Hawke nepotizmusról beszélt, és elismerte: a neve nagyban segíti karrierjét">
#        Maya Hawke nepotizmusról beszélt, és elismerte: a neve nagyban segíti karrierjét
#       </a>
# </h2>
# <div class="ajanlo">
#       Ethan Hawke és Uma Thurman lánya biztos benne, hogy Tarantino filmjébe is emiatt került be.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717432020">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/03/nyiregyhaza-debrecen-miskolc-eger-salgotarjan-ellenzek-kormapnypartok-fuggetlenek/" title="Északkeleten viharos ellenzéki harcok várhatók, de a kormánypártokra sem süt a nap mindenhol">
# <img alt="Északkeleten viharos ellenzéki harcok várhatók, de a kormánypártokra sem süt a nap mindenhol" loading="lazy" src="https://kep.index.hu/1/0/5659/56599/565991/56599197_4184893_c3341e17936fc2618f0ac788630e3c2b_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/03/nyiregyhaza-debrecen-miskolc-eger-salgotarjan-ellenzek-kormapnypartok-fuggetlenek/" title="Északkeleten viharos ellenzéki harcok várhatók, de a kormánypártokra sem süt a nap mindenhol">
#        Északkeleten viharos ellenzéki harcok várhatók, de a kormánypártokra sem süt a nap mindenhol
#       </a>
# </h2>
# <div class="ajanlo">
#       Sorozatunk első részében az ország északkeleti részébe látogatunk el.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717431900">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/facebbok-tartalomszolgaltatas-digitalis-szolgaltatas-platform-orban-viktor/" title="Ezért törölte a Facebook Orbán Viktor beszédét – majd tette vissza">
# <img alt="Ezért törölte a Facebook Orbán Viktor beszédét – majd tette vissza" loading="lazy" src="https://kep.index.hu/1/0/5660/56609/566093/56609335_4185677_63405331c853643088fc6ee9a2c4a40e_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/facebbok-tartalomszolgaltatas-digitalis-szolgaltatas-platform-orban-viktor/" title="Ezért törölte a Facebook Orbán Viktor beszédét – majd tette vissza">
#        Ezért törölte a Facebook Orbán Viktor beszédét – majd tette vissza
#       </a>
# </h2>
# <div class="ajanlo">
#       Jogi kételyeket vet fel, hogy a Facebook – ha csak átmenetileg is, de – törölte a miniszterelnök beszédének felvételét a köztévé közösségi oldaláról.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717431600">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/cinematrix/2024/06/03/venom-tom-hardy-trailer-elozetes-marvel-trilogia/" title="Megérkezett a Venom 3. első előzetese">
# <img alt="Megérkezett a Venom 3. első előzetese" loading="lazy" src="https://kep.index.hu/1/0/5663/56633/566336/56633691_4187529_462c87591204e4de5defe6bcb12659e0_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/cinematrix/2024/06/03/venom-tom-hardy-trailer-elozetes-marvel-trilogia/" title="Megérkezett a Venom 3. első előzetese">
#        Megérkezett a Venom 3. első előzetese
#       </a>
# </h2>
# <div class="ajanlo">
#       Eddie Brock és Venom eljárja az utolsó táncát.
#      </div>
# </article>, <article class="rovatajanlo normal right">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717431318">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/03/balogh-levente-a-fizeteserol-kevesebbet-keresek-mint-egy-kereskedo-/" title="Balogh Levente a fizetéséről: „Kevesebbet keresek, mint egy kereskedő”">
#        Balogh Levente a fizetéséről: „Kevesebbet keresek, mint egy kereskedő”
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717430700">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/ep/2024/06/03/dobrev-klara-magyar-peter-valasztas-osszefogas/" title="Dobrev Klára Magyar Péterről: Azt a taktikát választotta, hogy mindenki hülye, csak ő a helikopter">
# <img alt="Dobrev Klára Magyar Péterről: Azt a taktikát választotta, hogy mindenki hülye, csak ő a helikopter" loading="lazy" src="https://kep.index.hu/1/0/4039/40395/403957/40395771_3082657_036756756acdb288fab4d0e56f709311_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/ep/2024/06/03/dobrev-klara-magyar-peter-valasztas-osszefogas/" title="Dobrev Klára Magyar Péterről: Azt a taktikát választotta, hogy mindenki hülye, csak ő a helikopter">
#        Dobrev Klára Magyar Péterről: Azt a taktikát választotta, hogy mindenki hülye, csak ő a helikopter
#       </a>
# </h2>
# <div class="ajanlo">
#       A DK EP-listavezetője inkább az összefogásban látná a megoldást.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717430220">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/futball/2024/06/03/angol-bajnoksag-vezetoedzo-premier-league-chelsea-enzo-maresca/" title="A Chelsea bejelentette új edzőjét">
# <img alt="A Chelsea bejelentette új edzőjét" loading="lazy" src="https://kep.index.hu/1/0/5663/56633/566335/56633503_4187519_0ce59d828a9a429b1dbf4e4054c8981c_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/futball/2024/06/03/angol-bajnoksag-vezetoedzo-premier-league-chelsea-enzo-maresca/" title="A Chelsea bejelentette új edzőjét">
#        A Chelsea bejelentette új edzőjét
#       </a>
# </h2>
# <div class="ajanlo">
#       Öt évre szól kontraktusa.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717429740">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/03/youtube-pewdiepie-mrbeast-t-series-feliratkozas/" title="Trónfosztás történt a YouTube-on, véget ért egy korszak">
# <img alt="Trónfosztás történt a YouTube-on, véget ért egy korszak" loading="lazy" src="https://kep.index.hu/1/0/5663/56631/566317/56631747_4187377_d5ef82a6f1b26350655f920c2b796946_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/03/youtube-pewdiepie-mrbeast-t-series-feliratkozas/" title="Trónfosztás történt a YouTube-on, véget ért egy korszak">
#        Trónfosztás történt a YouTube-on, véget ért egy korszak
#       </a>
# </h2>
# <div class="ajanlo">
#       Már nem a T-Series a legtöbb feliratkozóval rendelkező csatorna.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717429740">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/03/gaspar-gyozo-marics-peter-onkormanyzati-valasztas-2024-bocsanatkeres/" title="Gáspár Győző bocsánatot kért Marics Petitől">
# <img alt="Gáspár Győző bocsánatot kért Marics Petitől" loading="lazy" src="https://kep.index.hu/1/0/5663/56633/566334/56633477_4187517_4e0114f89d06aa6497a0f29fcf3540b8_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/03/gaspar-gyozo-marics-peter-onkormanyzati-valasztas-2024-bocsanatkeres/" title="Gáspár Győző bocsánatot kért Marics Petitől">
#        Gáspár Győző bocsánatot kért Marics Petitől
#       </a>
# </h2>
# <div class="ajanlo">
#       Furcsa kampánymódszereire értelmezhető magyarázatot ugyanakkor nem adott.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717429620">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/idojaras-katasztrofavedelem-kareset/" title="Rengeteg kárt okozott a hétvégi vihar, több mint 400 helyszínre riasztották a katasztrófavédelmet">
# <img alt="Rengeteg kárt okozott a hétvégi vihar, több mint 400 helyszínre riasztották a katasztrófavédelmet" loading="lazy" src="https://kep.index.hu/1/0/5663/56632/566326/56632615_4187455_e2828589c7c89d6d858c0e31cdcd963c_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/idojaras-katasztrofavedelem-kareset/" title="Rengeteg kárt okozott a hétvégi vihar, több mint 400 helyszínre riasztották a katasztrófavédelmet">
#        Rengeteg kárt okozott a hétvégi vihar, több mint 400 helyszínre riasztották a katasztrófavédelmet
#       </a>
# </h2>
# <div class="ajanlo">
#       A legtöbbször Debrecenben és környékén riasztották az egységeket.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717428840">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/reszeg-sofor-autobaleset-esztergom/" title="Videón, ahogy letarol egy teherkocsit egy részeg sofőr Esztergomban">
# <img alt="Videón, ahogy letarol egy teherkocsit egy részeg sofőr Esztergomban" loading="lazy" src="https://kep.index.hu/1/0/5663/56631/566318/56631843_4187385_0645f89c190c7fc7f05326e2ceeae553_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/reszeg-sofor-autobaleset-esztergom/" title="Videón, ahogy letarol egy teherkocsit egy részeg sofőr Esztergomban">
#        Videón, ahogy letarol egy teherkocsit egy részeg sofőr Esztergomban
#       </a>
# </h2>
# <div class="ajanlo">
#       A sofőr utasa súlyos sérülést szenvedett.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717428720">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/fomo/2024/06/03/embertelen-podcast-mesterseges-intelligencia-betone/" title="Két mesterséges intelligencia vitázott magyarul az eutanáziáról">
# <img alt="Két mesterséges intelligencia vitázott magyarul az eutanáziáról" loading="lazy" src="https://kep.index.hu/1/0/5663/56631/566314/56631433_4187347_79aa6b19d28ef6e10ab0362eb2483374_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/fomo/2024/06/03/embertelen-podcast-mesterseges-intelligencia-betone/" title="Két mesterséges intelligencia vitázott magyarul az eutanáziáról">
#        Két mesterséges intelligencia vitázott magyarul az eutanáziáról
#       </a>
# </h2>
# <div class="ajanlo">
#       Betti és Péter nem jutottak közös álláspontra.
#      </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/gazdasag/2024/06/03/tej-tejtermek-tej-termektanacs-uht-tej-nagy-istvan-agrar-agrartamogatasok-unios-tamogatas-nak-tejipar-tejtermelok/" title="A műhúsnak a tejimitátumoknak is hadat üzen Magyarország">
# <img alt="A műhúsnak a tejimitátumoknak is hadat üzen Magyarország" loading="lazy" src="https://kep.index.hu/1/0/5663/56633/566333/56633313_4187505_fe0a76aeb58cf254f473f8ea1fd95d3c_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/gazdasag/2024/06/03/tej-tejtermek-tej-termektanacs-uht-tej-nagy-istvan-agrar-agrartamogatasok-unios-tamogatas-nak-tejipar-tejtermelok/" title="A műhúsnak a tejimitátumoknak is hadat üzen Magyarország">
#         A műhúsnak a tejimitátumoknak is hadat üzen Magyarország
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/kaszas_gabor">
# <img alt="Kaszás Gábor" class="szerzo-kep" src="https://kep.index.hu/1/0/4574/45749/457497/45749712_3489398_310f98f708e4974afece0c9456b038b7_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/kaszas_gabor" rel="author">
#             Kaszás Gábor
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1466">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.03. 17:31
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-03 19:51:21
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Tűkön ülve várja a támogatást a tejágazat, míg a kötelező akciózást házon kívül tudná.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717428600">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/futball/2024/eb/2024/06/03/felkeszulesi-merkozes-ir-valogatott-magyar-valogatott-dublin-john-oshea-marco-rossi/" title="„Szoboszlai Dominikot nem kell bemutatni senkinek, ő a Liverpool sztárja”">
# <img alt="„Szoboszlai Dominikot nem kell bemutatni senkinek, ő a Liverpool sztárja”" loading="lazy" src="https://kep.index.hu/1/0/5663/56633/566332/56633265_4187501_6a306ce28930b4caaa413611640a9408_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/futball/2024/eb/2024/06/03/felkeszulesi-merkozes-ir-valogatott-magyar-valogatott-dublin-john-oshea-marco-rossi/" title="„Szoboszlai Dominikot nem kell bemutatni senkinek, ő a Liverpool sztárja”">
#        „Szoboszlai Dominikot nem kell bemutatni senkinek, ő a Liverpool sztárja”
#       </a>
# </h2>
# <div class="ajanlo">
#       A magyar válogatott keddi ellenfele nagyra tartja a csapatkapitányt.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717428420">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/ep/2024/06/03/orban-viktor-fidesz-kampany-nagyszalonta-valasztasok/" title="Orbán Viktor Nagyszalontán folytatta a kampányt">
# <img alt="Orbán Viktor Nagyszalontán folytatta a kampányt" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566107/56610737_4185783_a8a858c6f4015a5f517a956c11209d31_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/ep/2024/06/03/orban-viktor-fidesz-kampany-nagyszalonta-valasztasok/" title="Orbán Viktor Nagyszalontán folytatta a kampányt">
#        Orbán Viktor Nagyszalontán folytatta a kampányt
#       </a>
# </h2>
# <div class="ajanlo">
#       A kormányfő megbeszélést folytatott a Romániai Magyar Demokrata Szövetség vezetőivel.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717427220">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/03/maldiv-szigetek-tiltas-izrael-gazai-haboru/" title="A Maldív-szigetek megtiltotta az izraeli állampolgárok beutazását az országba">
# <img alt="A Maldív-szigetek megtiltotta az izraeli állampolgárok beutazását az országba" loading="lazy" src="https://kep.index.hu/1/0/5663/56632/566329/56632987_4187483_2dd5895e6101e9925ec0c3a3145f1c84_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/03/maldiv-szigetek-tiltas-izrael-gazai-haboru/" title="A Maldív-szigetek megtiltotta az izraeli állampolgárok beutazását az országba">
#        A Maldív-szigetek megtiltotta az izraeli állampolgárok beutazását az országba
#       </a>
# </h2>
# <div class="ajanlo">
#       Az izraeli külügyminisztérium nem hagyta szó nélkül a lépést.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717427100">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/idojaras-elorejelzes-radar-felhoszakadas-figyelmeztetes-zapor-zivatar-villamlas/" title="Kiadták a másodfokú figyelmeztetést, több vármegyében is leszakad az ég">
# <img alt="Kiadták a másodfokú figyelmeztetést, több vármegyében is leszakad az ég" loading="lazy" src="https://kep.index.hu/1/0/5520/55203/552037/55203739_4080193_272ee0239e8585c35d746c8967b4a6e3_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/idojaras-elorejelzes-radar-felhoszakadas-figyelmeztetes-zapor-zivatar-villamlas/" title="Kiadták a másodfokú figyelmeztetést, több vármegyében is leszakad az ég">
#        Kiadták a másodfokú figyelmeztetést, több vármegyében is leszakad az ég
#       </a>
# </h2>
# <div class="ajanlo">
#       A katasztrófavédelem is közölte a tudnivalókat.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717426860">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/cinematrix/2024/06/03/magyar-film-elso-dij-rajzfilm-fesztival-animacio-cartoon-on-the-bay-kek-pelikan/" title="Rangos nemzetközi elismerést kapott a Kék Pelikan">
# <img alt="Rangos nemzetközi elismerést kapott a Kék Pelikan" loading="lazy" src="https://kep.index.hu/1/0/5663/56630/566300/56630005_4187239_d0b9704eb48795f545dc6d948305ebf7_wm.webp"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/cinematrix/2024/06/03/magyar-film-elso-dij-rajzfilm-fesztival-animacio-cartoon-on-the-bay-kek-pelikan/" title="Rangos nemzetközi elismerést kapott a Kék Pelikan">
#        Rangos nemzetközi elismerést kapott a Kék Pelikan
#       </a>
# </h2>
# <div class="ajanlo">
#       A csalás nemcsak kalandokat, de díjakat is hozott.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717426140">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-rovat-light" href="https://index.hu/zold/">
#           Zöld Index
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/zoldhidrogen-uzem-bukkabranyi-energiapark-napelem-megujulo-energia/" title="Átadták Magyarország első zöldhidrogén üzemét">
# <img alt="Átadták Magyarország első zöldhidrogén üzemét" loading="lazy" src="https://kep.index.hu/1/0/5663/56632/566325/56632509_4187445_6ff6747b587e0be683262c986dde0faa_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/zoldhidrogen-uzem-bukkabranyi-energiapark-napelem-megujulo-energia/" title="Átadták Magyarország első zöldhidrogén üzemét">
#        Átadták Magyarország első zöldhidrogén üzemét
#       </a>
# </h2>
# <div class="ajanlo">
#       A létesítmény a helyi napelempark által termelt megújuló energiával állít majd elő hidrogént.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717425960">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/fomo/2024/06/03/szupercella-jegvihar-maga-zoltan-koncert/" title="Szupercellás jégvihar tette tönkre Mága Zoltán nagy értékű hangszereit">
# <img alt="Szupercellás jégvihar tette tönkre Mága Zoltán nagy értékű hangszereit" loading="lazy" src="https://kep.index.hu/1/0/5663/56632/566325/56632567_4187449_1a58a35e07e19218288329fea46e7978_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/fomo/2024/06/03/szupercella-jegvihar-maga-zoltan-koncert/" title="Szupercellás jégvihar tette tönkre Mága Zoltán nagy értékű hangszereit">
#        Szupercellás jégvihar tette tönkre Mága Zoltán nagy értékű hangszereit
#       </a>
# </h2>
# <div class="ajanlo">
#       Technikai berendezések és kották is megrongálódtak.
#      </div>
# </article>, <article class="rovatajanlo normal right">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717425916">
#         5 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/03/jennifer-lopez-ben-affleck-valas-lesifoto-kinos/" title="Jennifer Lopez és Ben Affleck kínos lesifotói végig söpörtek az interneten">
#        Jennifer Lopez és Ben Affleck kínos lesifotói végig söpörtek az interneten
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/kulfold/2024/06/03/europai-unio-valasztas-kampanytamogatas-jobboldal-baloldal-populista/" title="A jobbszél, a balszél és a populisták kapják az uniós kampánypénzek negyedét">
# <img alt="A jobbszél, a balszél és a populisták kapják az uniós kampánypénzek negyedét" loading="lazy" src="https://kep.index.hu/1/0/5658/56580/565800/56580087_4183491_c6b77f136b73e61cfdee55e5983a8ce2_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/03/europai-unio-valasztas-kampanytamogatas-jobboldal-baloldal-populista/" title="A jobbszél, a balszél és a populisták kapják az uniós kampánypénzek negyedét">
#         A jobbszél, a balszél és a populisták kapják az uniós kampánypénzek negyedét
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# ...
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717422300">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/kezilabda/2024/06/03/bajnokok-ligaja-telekom-veszprem-edzovaltas-xavi-pasqual-momir-ilic/" title="Mégis távozik Ilics, az új vezetőedzőt kivásárolja szerződéséből a Veszprém">
# <img alt="Mégis távozik Ilics, az új vezetőedzőt kivásárolja szerződéséből a Veszprém" loading="lazy" src="https://kep.index.hu/1/0/5663/56632/566320/56632075_4187405_0f908e4597d28b23dac8c2f9c96a9362_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/kezilabda/2024/06/03/bajnokok-ligaja-telekom-veszprem-edzovaltas-xavi-pasqual-momir-ilic/" title="Mégis távozik Ilics, az új vezetőedzőt kivásárolja szerződéséből a Veszprém">
#        Mégis távozik Ilics, az új vezetőedzőt kivásárolja szerződéséből a Veszprém
#       </a>
# </h2>
# <div class="ajanlo">
#       Négy évre kötelezte el magát.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717422240">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/gazdasag/2024/06/03/nagy-marton-4ig-egyiptom-kormany-egyuttmukodes-kozel-kelet/" title="A kormány újabb országot vett célba, tenger alatti kábelrendszert fektetnének le">
# <img alt="A kormány újabb országot vett célba, tenger alatti kábelrendszert fektetnének le" loading="lazy" src="https://kep.index.hu/1/0/4627/46274/462740/46274054_3528820_d7b3801f5a7f88d7262a414b7442cc5c_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/gazdasag/2024/06/03/nagy-marton-4ig-egyiptom-kormany-egyuttmukodes-kozel-kelet/" title="A kormány újabb országot vett célba, tenger alatti kábelrendszert fektetnének le">
#        A kormány újabb országot vett célba, tenger alatti kábelrendszert fektetnének le
#       </a>
# </h2>
# <div class="ajanlo">
#       A delegáció már napok óta ezekről tárgyal.
#      </div>
# </article>, <article class="rovatajanlo normal left">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717421104">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/03/meszaros-lili-fogyni-szeretne-kulfoldi-modellkarrierje-elott-drasztikusan-hangozhat-de-minden-kilo-szamit/" title="Mészáros Lili fogyni szeretne külföldi modellkarrierje előtt: Drasztikusan hangozhat, de minden kiló számít">
#        Mészáros Lili fogyni szeretne külföldi modellkarrierje előtt: Drasztikusan hangozhat, de minden kiló számít
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717420860">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/vona-gabor-magyar-peter-peticio-gyermekvedelem-nepszavazas/" title="Népszavazás keretében fogna össze Vona Gábor Magyar Péterrel">
# <img alt="Népszavazás keretében fogna össze Vona Gábor Magyar Péterrel" loading="lazy" src="https://kep.index.hu/1/0/5480/54803/548038/54803881_4049829_f2e13c9c7795383165977ce87bab77bf_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/vona-gabor-magyar-peter-peticio-gyermekvedelem-nepszavazas/" title="Népszavazás keretében fogna össze Vona Gábor Magyar Péterrel">
#        Népszavazás keretében fogna össze Vona Gábor Magyar Péterrel
#       </a>
# </h2>
# <div class="ajanlo">
#       A pártelnök nyílt levélben fejtette ki a véleményét a Tisza Párt alelnökének szombati bejelentéséről.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717420740">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/futball/2024/06/03/bajnokok-ligaja-donto-unneples-real-madrid-bvb-dortmund-unneples-carlo-ancelotti-antonio-rudiger/" title="Carvajal édesapja felvezette a buszt, Ancelotti szivarozott – így telt a Real Madrid 15. BL-trófeájának ünneplése">
# <img alt="Carvajal édesapja felvezette a buszt, Ancelotti szivarozott – így telt a Real Madrid 15. BL-trófeájának ünneplése" loading="lazy" src="https://kep.index.hu/1/0/5663/56631/566314/56631467_4187351_ec7964ed2f41df47f7a5044541e707ee_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/futball/2024/06/03/bajnokok-ligaja-donto-unneples-real-madrid-bvb-dortmund-unneples-carlo-ancelotti-antonio-rudiger/" title="Carvajal édesapja felvezette a buszt, Ancelotti szivarozott – így telt a Real Madrid 15. BL-trófeájának ünneplése">
#        Carvajal édesapja felvezette a buszt, Ancelotti szivarozott – így telt a Real Madrid 15. BL-trófeájának ünneplése
#       </a>
# </h2>
# <div class="ajanlo">
#       Rüdiger azt mondta a közönségnek, „itt vagyok én, az őrült.”
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717420200">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/03/dobrev-klara-demokratikus-koalicio-kampanyzaro-korut-orszagjaras/" title="Dobrev Klára 36 órás országjáró körúttal zárja a kampányt">
# <img alt="Dobrev Klára 36 órás országjáró körúttal zárja a kampányt" loading="lazy" src="https://kep.index.hu/1/0/5663/56631/566310/56631057_4187323_5d08321c933c648353dc1774ec280302_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/03/dobrev-klara-demokratikus-koalicio-kampanyzaro-korut-orszagjaras/" title="Dobrev Klára 36 órás országjáró körúttal zárja a kampányt">
#        Dobrev Klára 36 órás országjáró körúttal zárja a kampányt
#       </a>
# </h2>
# <div class="ajanlo">
#       A DK listavezetője szerint náluk ez már hagyomány.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717419960">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/03/onkormanyzati-valasztas-2024-fopolgarmester-jelolt-kampany/" title="Elstartolt az utolsó kampányhét, bedobták magukat a főpolgármester-jelöltek">
# <img alt="Elstartolt az utolsó kampányhét, bedobták magukat a főpolgármester-jelöltek" loading="lazy" src="https://kep.index.hu/1/0/5601/56015/560157/56015767_4141541_515a67b7aa9b0c3d4badbfcebbe4051c_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/03/onkormanyzati-valasztas-2024-fopolgarmester-jelolt-kampany/" title="Elstartolt az utolsó kampányhét, bedobták magukat a főpolgármester-jelöltek">
#        Elstartolt az utolsó kampányhét, bedobták magukat a főpolgármester-jelöltek
#       </a>
# </h2>
# <div class="ajanlo">
#       Csak úgy záporoznak a választóknak szóló üzenetek.
#      </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/kulfold/usa/feher_haz/2024/06/03/valasztas-wisconsin-egyesult-allamok-donald-trump-joe-biden/" title="Ők azok, akik eldönthetik, ki legyen a világ legnagyobb hatalommal rendelkező embere">
# <img alt="Ők azok, akik eldönthetik, ki legyen a világ legnagyobb hatalommal rendelkező embere" loading="lazy" src="https://kep.index.hu/1/0/5661/56615/566155/56615567_4186185_c238c343fe4e2453ed3c7a173e7a0cca_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/kulfold/usa/feher_haz/2024/06/03/valasztas-wisconsin-egyesult-allamok-donald-trump-joe-biden/" title="Ők azok, akik eldönthetik, ki legyen a világ legnagyobb hatalommal rendelkező embere">
#         Ők azok, akik eldönthetik, ki legyen a világ legnagyobb hatalommal rendelkező embere
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/kovacs_ferenc">
# <img alt="Kovács Ferenc" class="szerzo-kep" src="https://kep.index.hu/1/0/3491/34914/349140/34914065_2672211_e0721dac08463d57ec82f5c7ea99423a_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/kovacs_ferenc" rel="author">
#             Kovács Ferenc
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1115">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.03. 15:05
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-03 16:12:27
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Melyik amerikai államokban számítanak a vidéki fehér szavazók voksai?
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717419420">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/orszagos-vizugyi-foigazgatosag-ovf-duna-arhullam/" title="Jön az árhullám a Dunán, hétvégén már Budapestet is elérheti">
# <img alt="Jön az árhullám a Dunán, hétvégén már Budapestet is elérheti" loading="lazy" src="https://kep.index.hu/1/0/5414/54143/541439/54143923_3998689_d795526e21f5f6c2df45db161000c27a_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/orszagos-vizugyi-foigazgatosag-ovf-duna-arhullam/" title="Jön az árhullám a Dunán, hétvégén már Budapestet is elérheti">
#        Jön az árhullám a Dunán, hétvégén már Budapestet is elérheti
#       </a>
# </h2>
# <div class="ajanlo">
#       A vízügy szakemberei a nap 24 órájában követik az adatokat, figyelik a folyót.
#      </div>
# </article>, <article class="rovatajanlo normal right">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717418880">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/nebih-tesco-bab-visszahivas/" title="Vörös vesebabot hívott vissza a Nébih, növényvédőszert tartalmazhat">
#        Vörös vesebabot hívott vissza a Nébih, növényvédőszert tartalmazhat
#       </a>
# </h2>
# <div class="ajanlo">
#       A termék bármelyik Tesco-üzletbe visszavihető.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717418280">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/forma1/2024/06/03/formula-1-alpine-esteben-ocon-tavozas-2024-pilotavaltas/" title="Eldőlt Esteban Ocon sokat vitatott jövője az Alpine csapatánál">
# <img alt="Eldőlt Esteban Ocon sokat vitatott jövője az Alpine csapatánál" loading="lazy" src="https://kep.index.hu/1/0/5663/56630/566309/56630913_4187307_ed17589c07ef6097bf55826df5ea3d68_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/forma1/2024/06/03/formula-1-alpine-esteben-ocon-tavozas-2024-pilotavaltas/" title="Eldőlt Esteban Ocon sokat vitatott jövője az Alpine csapatánál">
#        Eldőlt Esteban Ocon sokat vitatott jövője az Alpine csapatánál
#       </a>
# </h2>
# <div class="ajanlo">
#       Korábban is kétséges volt, de a Monacói Nagydíj után napi szintű témává vált.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717418160">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/yettel-online-csalas-atveres/" title="Figyelmeztetett a Yettel: újabb módszerrel próbálkoznak a csalók">
# <img alt="Figyelmeztetett a Yettel: újabb módszerrel próbálkoznak a csalók" loading="lazy" src="https://kep.index.hu/1/0/5663/56630/566307/56630767_4187297_14d10ac0a01947b2cae9eec8cefc9890_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/yettel-online-csalas-atveres/" title="Figyelmeztetett a Yettel: újabb módszerrel próbálkoznak a csalók">
#        Figyelmeztetett a Yettel: újabb módszerrel próbálkoznak a csalók
#       </a>
# </h2>
# <div class="ajanlo">
#       Az ügyfelek adatait akarják megszerezni.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717417260">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/techtud/2024/06/03/haztartas-tisztitoszar-praktika-eset-szodabikarbona-keverek-latvanyos-felesleges/" title="Ez a praktikus házi tisztítószer-keverék valójában nem tisztít">
# <img alt="Ez a praktikus házi tisztítószer-keverék valójában nem tisztít" loading="lazy" src="https://kep.index.hu/1/0/5659/56596/565966/56596687_4184687_567220a557403e33d432e14d5fff0715_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/techtud/2024/06/03/haztartas-tisztitoszar-praktika-eset-szodabikarbona-keverek-latvanyos-felesleges/" title="Ez a praktikus házi tisztítószer-keverék valójában nem tisztít">
#        Ez a praktikus házi tisztítószer-keverék valójában nem tisztít
#       </a>
# </h2>
# <div class="ajanlo">
#       Az ecet és szódabikarbóna keverése inkább csak látványosságnak jó.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-03" data-datestamp="1717417140">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/03/magyar-orszagos-kozjegyzoi-kamara-orokles-vegrendelet-felmeres/" title="Rengeteg mindent rosszul tudunk az öröklési szabályokról, pedig milliók múlhatnak rajta">
# <img alt="Rengeteg mindent rosszul tudunk az öröklési szabályokról, pedig milliók múlhatnak rajta" loading="lazy" src="https://kep.index.hu/1/0/4901/49013/490134/49013414_3736434_2a015e6cc241af0ddaf35c9a3f26fd41_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/03/magyar-orszagos-kozjegyzoi-kamara-orokles-vegrendelet-felmeres/" title="Rengeteg mindent rosszul tudunk az öröklési szabályokról, pedig milliók múlhatnak rajta">
#        Rengeteg mindent rosszul tudunk az öröklési szabályokról, pedig milliók múlhatnak rajta
#       </a>
# </h2>
# <div class="ajanlo">
#       Sokan nincsenek tisztában azzal, milyen öröklési szabályok vonatkoznak a különböző vagyontárgyakra.
#      </div>
# </article>]

# %%
print(articles[0])
# Out:
# <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/kulfold/2024/06/03/afrika-szudan-polgarhaboru-nepirtas-egyesult-allamok-ensz-beavatkozas-konfliktus-valsag/" title="Népirtás készülődik Szudánban megint, amikor a világ éppen másfelé figyel">
# <img alt="Népirtás készülődik Szudánban megint, amikor a világ éppen másfelé figyel" loading="lazy" src="https://kep.index.hu/1/0/5658/56584/565848/56584891_4183845_2f9d4833e1dbaf33605fb97af588f7a2_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/03/afrika-szudan-polgarhaboru-nepirtas-egyesult-allamok-ensz-beavatkozas-konfliktus-valsag/" title="Népirtás készülődik Szudánban megint, amikor a világ éppen másfelé figyel">
#         Népirtás készülődik Szudánban megint, amikor a világ éppen másfelé figyel
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo kep-nelkul">
# <div class="kovetes nem-kovetheto">
#            Marton Máté
#           </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.03. 20:49
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-03 21:01:41
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Milliók élete forog kockán.
#      </div>
# <div class="iap iap--ado roadblock" data-id="adoceanindexhundcjqssfzl" id="adoceanindexhundcjqssfzl">
# <script class="iap-script">
#        window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhundcjqssfzl","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_RB_A","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#       </script>
# </div>
# </article>

# %% [markdown]
# ## Egy darab cikk adatainak kinyerése

# %%
author = articles[0].find("div", class_="szerzo").text.strip()
date = articles[0].find("div", class_="datum")
published = date.contents[0].strip()
title = articles[0].find("a").get("title")
subtitle = articles[0].find("div", class_="ajanlo").text.strip()
url = articles[0].find("a").get("href")

print("Szerző: " + author)
print("Dátum: " + published)
print("Cím: " + title)
print("Alcím: " + subtitle)
print("url: " + url)
# Out:
# Szerző: Marton Máté
# Dátum: 2024.06.03. 20:49
# Cím: Népirtás készülődik Szudánban megint, amikor a világ éppen másfelé figyel
# Alcím: Milliók élete forog kockán.
# url: https://index.hu/kulfold/2024/06/03/afrika-szudan-polgarhaboru-nepirtas-egyesult-allamok-ensz-beavatkozas-konfliktus-valsag/

# %% [markdown]
# ## Összes cikk kinyerése a főoldalról

# %%
content = []

for article in articles:
    url = article.find("a").get("href")
    if url == "http://index.hu/mindekozben":
        continue

    if article.find("div", class_="szerzo") == None:
        author = ""
    else:
        author = article.find("div", class_="szerzo").text.strip()

    if article.find("div", class_="datum") == None:
        published = ""
    else:
        date = article.find("div", class_="datum")
        published = date.contents[0].strip()

    if article.find("a").get("title") == None:
        title = ""
    else:
        title = article.find("a").get("title")

    subtitle = article.find("div", class_="ajanlo").text.strip()

    content.append((author, published, title, subtitle, url))

for item in content:
    print(item)
# Out:
# ('Marton Máté', '2024.06.03. 20:49', 'Népirtás készülődik Szudánban megint, amikor a világ éppen másfelé figyel', 'Milliók élete forog kockán.', 'https://index.hu/kulfold/2024/06/03/afrika-szudan-polgarhaboru-nepirtas-egyesult-allamok-ensz-beavatkozas-konfliktus-valsag/')
# ('', '', 'Ők az idei Dining Guide Év Étterme gála díjazottjai', 'Idén jelentősen megváltozott a díj odaítélésének feltételrendszere.', 'https://index.hu/kultur/degusztator/2024/06/03/salt-budapest-ev-etterme-dining-guide-gala-dijazottak/')
# ('', '', 'Újabb kibertámadások érték a kulcsfontosságú infrastruktúrát Lengyelországban', 'A miniszter szerint az incidens célja pánikkeltés, valamint a rendszer összezavarása volt.', 'https://index.hu/kulfold/2024/06/03/lengyelorszag-kibertamadas-krzysztof-gawkowski/')
# ('', '', 'Halálos baleset történt Kistelek közelében', 'Egy motorkerékpár és egy személygépkocsi összeütközött.', 'https://index.hu/belfold/2024/06/03/halalos-baleset-kozlekedes-5-os-fout-kistelek-karambol-utkozes/')
# ('', '', 'Országszerte sok munkát adott a viharos időjárás a tűzoltóknak', 'Kaposvárott egy tizenöt méteres fa fordult ki gyökerestől a földből, és hat autóban tett kárt.', 'https://index.hu/belfold/2024/06/03/idojaras-vihar-tuzoltosag-katasztrofavedelem/')
# ('Borbély László', '2024.06.03. 20:25', 'Övék a világ legerősebb kerete, mégis biztosra vehető, hogy valahogyan úgyis elbuknak', 'Egy meglepetésbajnok és a magyar válogatott selejtezős riválisa is a favorit csoportjában.', 'https://index.hu/sport/futball/2024/eb/2024/06/03/eb-2024-c-csoport-beharangozo-anglia-dania-szerbia-szlovenia/')
# ('', '', 'Letartóztatták a klímaaktivistát, miután megrongált egy Monet-festményt Párizsban', 'Úgy tudni, nem védte üveg a festményt.', 'https://index.hu/kultur/2024/06/03/vandalizmus-rongalas-klimaaktivista-food-response-monet-festmeny-pipacsmezo/')
# ('', '', 'Nincs több titok, ilyen évet produkáltak tavaly Kasza Tibor cégei', 'De Majka és Sebestyén Balázs cégei is jól működnek.', 'https://index.hu/gazdasag/2024/06/03/celeb-cegek-nyereseg-kasza-tibor-majka-sebestyen-balazs/')
# ('', '', 'J. Robert Oppenheimer unokája Hirosimában találkozott az atomtámadás túlélőjével', 'Ogura Keikó nyolcéves kislányként élte túl az atomtámadást.', 'https://index.hu/kulfold/2024/06/03/robert-oppenheimer-hirosima-atomtamadas-tulelo/')
# ('', '', 'Bátran döntögeti a tabukat a Netflix új sorozata', 'A Geek Girl meglepően komoly néznivaló lett.', 'https://index.hu/kultur/cinematrix/2024/06/03/geek-girl-netflix-teve-sorozat-pilot-evadkezdes-streaming-young-adult-regeny-adaptacio-kritika/')
# ('Harnisch Kitti', '2024.06.03. 20:05', 'Mai napig rejtély övezi Európa egyik legnagyobb katasztrófáját', 'Idén lesz 30 éve, hogy Tallin és Stockholm között elsüllyedt az Estonia komphajó.', 'https://index.hu/fomo/2024/06/03/estonia-kompkatasztrofa-rtl-sorozat/')
# ('', '', 'Majdnem hárommilliárd forint bevételt hozott az atlétikai világbajnokság', 'Az összeg több mint 80 százaléka a jegyeladásokból folyt be.', 'https://index.hu/gazdasag/2024/06/03/atletikai-vb-budapest-bevetel-budapest-2023-zrt/')
# ('', '', 'Véget ért a többéves szappanopera: Kylian Mbappé a Real Madrid játékosa lett', 'A friss BL-győztes hivatalosan is bejelentette a világbajnok francia támadó érkezését.', 'https://index.hu/sport/futball/2024/06/03/kylian-mbappe-psg-real-madrid-atigazolas-hivatalos/')
# ('', '', 'Nyilvános gyertyagyújtással emlékeznek Tompos Kátyára', 'A hírt a színésznő jóbarátja közölte.', 'https://index.hu/kultur/2024/06/03/tompos-katya-gyertyagyujtas/')
# ('', '', 'Van, aki partival készül a nyárra, míg egyesek arcokat tépnek', 'A júniusi PickUp még minket is meglepett.', 'https://index.hu/kultur/zene/2024/06/03/pickup-stenk-divent-foreland-nagy-dani/')
# ('', '', 'A lakáspiac eddig hozza az elvárt szintet', 'Az idei május még erősebb is volt, mint a tavalyi.', 'https://index.hu/gazdasag/2024/06/03/lakaspiac-duna-house-adas-vetel-adatok/')
# ('Krasz Emil', '2024.06.03. 18:29', 'A Real Madrid úgy nyerte meg ezt a BL-t, hogy néhány kulcsjátékosa alig közepesen játszott', 'Átmeneti szezon ide vagy oda, a serleg ismét a rekorderhez került. Az Index Sportcastjében Dénes Tamással és Mészáros Ábellel beszélgettünk.', 'https://index.hu/sport/futball/2024/06/03/labdarugas-futball-bajnokok-ligaja-donto-finale-wembley-real-madrid-dortmund-denes-tamas-meszaros-abel-sportcast/')
# ('', '', 'Maya Hawke nepotizmusról beszélt, és elismerte: a neve nagyban segíti karrierjét', 'Ethan Hawke és Uma Thurman lánya biztos benne, hogy Tarantino filmjébe is emiatt került be.', 'https://index.hu/kultur/cinematrix/2024/06/03/maya-hawke-ethan-hawke-uma-thurman-nepotizmus-sztar-szulo/')
# ('', '', 'Északkeleten viharos ellenzéki harcok várhatók, de a kormánypártokra sem süt a nap mindenhol', 'Sorozatunk első részében az ország északkeleti részébe látogatunk el.', 'https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/03/nyiregyhaza-debrecen-miskolc-eger-salgotarjan-ellenzek-kormapnypartok-fuggetlenek/')
# ('', '', 'Ezért törölte a Facebook Orbán Viktor beszédét – majd tette vissza', 'Jogi kételyeket vet fel, hogy a Facebook – ha csak átmenetileg is, de – törölte a miniszterelnök beszédének felvételét a köztévé közösségi oldaláról.', 'https://index.hu/belfold/2024/06/03/facebbok-tartalomszolgaltatas-digitalis-szolgaltatas-platform-orban-viktor/')
# ('', '', 'Megérkezett a Venom 3. első előzetese', 'Eddie Brock és Venom eljárja az utolsó táncát.', 'https://index.hu/kultur/cinematrix/2024/06/03/venom-tom-hardy-trailer-elozetes-marvel-trilogia/')
# ('', '', 'Dobrev Klára Magyar Péterről: Azt a taktikát választotta, hogy mindenki hülye, csak ő a helikopter', 'A DK EP-listavezetője inkább az összefogásban látná a megoldást.', 'https://index.hu/kulfold/ep/2024/06/03/dobrev-klara-magyar-peter-valasztas-osszefogas/')
# ('', '', 'A Chelsea bejelentette új edzőjét', 'Öt évre szól kontraktusa.', 'https://index.hu/sport/futball/2024/06/03/angol-bajnoksag-vezetoedzo-premier-league-chelsea-enzo-maresca/')
# ('', '', 'Trónfosztás történt a YouTube-on, véget ért egy korszak', 'Már nem a T-Series a legtöbb feliratkozóval rendelkező csatorna.', 'https://index.hu/kulfold/2024/06/03/youtube-pewdiepie-mrbeast-t-series-feliratkozas/')
# ('', '', 'Gáspár Győző bocsánatot kért Marics Petitől', 'Furcsa kampánymódszereire értelmezhető magyarázatot ugyanakkor nem adott.', 'https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/03/gaspar-gyozo-marics-peter-onkormanyzati-valasztas-2024-bocsanatkeres/')
# ('', '', 'Rengeteg kárt okozott a hétvégi vihar, több mint 400 helyszínre riasztották a katasztrófavédelmet', 'A legtöbbször Debrecenben és környékén riasztották az egységeket.', 'https://index.hu/belfold/2024/06/03/idojaras-katasztrofavedelem-kareset/')
# ('', '', 'Videón, ahogy letarol egy teherkocsit egy részeg sofőr Esztergomban', 'A sofőr utasa súlyos sérülést szenvedett.', 'https://index.hu/belfold/2024/06/03/reszeg-sofor-autobaleset-esztergom/')
# ('', '', 'Két mesterséges intelligencia vitázott magyarul az eutanáziáról', 'Betti és Péter nem jutottak közös álláspontra.', 'https://index.hu/fomo/2024/06/03/embertelen-podcast-mesterseges-intelligencia-betone/')
# ('Kaszás Gábor', '2024.06.03. 17:31', 'A műhúsnak a tejimitátumoknak is hadat üzen Magyarország', 'Tűkön ülve várja a támogatást a tejágazat, míg a kötelező akciózást házon kívül tudná.', 'https://index.hu/gazdasag/2024/06/03/tej-tejtermek-tej-termektanacs-uht-tej-nagy-istvan-agrar-agrartamogatasok-unios-tamogatas-nak-tejipar-tejtermelok/')
# ('', '', '„Szoboszlai Dominikot nem kell bemutatni senkinek, ő a Liverpool sztárja”', 'A magyar válogatott keddi ellenfele nagyra tartja a csapatkapitányt.', 'https://index.hu/sport/futball/2024/eb/2024/06/03/felkeszulesi-merkozes-ir-valogatott-magyar-valogatott-dublin-john-oshea-marco-rossi/')
# ('', '', 'Orbán Viktor Nagyszalontán folytatta a kampányt', 'A kormányfő megbeszélést folytatott a Romániai Magyar Demokrata Szövetség vezetőivel.', 'https://index.hu/kulfold/ep/2024/06/03/orban-viktor-fidesz-kampany-nagyszalonta-valasztasok/')
# ('', '', 'A Maldív-szigetek megtiltotta az izraeli állampolgárok beutazását az országba', 'Az izraeli külügyminisztérium nem hagyta szó nélkül a lépést.', 'https://index.hu/kulfold/2024/06/03/maldiv-szigetek-tiltas-izrael-gazai-haboru/')
# ('', '', 'Kiadták a másodfokú figyelmeztetést, több vármegyében is leszakad az ég', 'A katasztrófavédelem is közölte a tudnivalókat.', 'https://index.hu/belfold/2024/06/03/idojaras-elorejelzes-radar-felhoszakadas-figyelmeztetes-zapor-zivatar-villamlas/')
# ('', '', 'Rangos nemzetközi elismerést kapott a Kék Pelikan', 'A csalás nemcsak kalandokat, de díjakat is hozott.', 'https://index.hu/kultur/cinematrix/2024/06/03/magyar-film-elso-dij-rajzfilm-fesztival-animacio-cartoon-on-the-bay-kek-pelikan/')
# ('', '', '', 'A létesítmény a helyi napelempark által termelt megújuló energiával állít majd elő hidrogént.', 'https://index.hu/zold/')
# ('', '', 'Szupercellás jégvihar tette tönkre Mága Zoltán nagy értékű hangszereit', 'Technikai berendezések és kották is megrongálódtak.', 'https://index.hu/fomo/2024/06/03/szupercella-jegvihar-maga-zoltan-koncert/')
# ('Siklós András', '2024.06.03. 16:40', 'A jobbszél, a balszél és a populisták kapják az uniós kampánypénzek negyedét', 'Egy 25 ország 200 pártjának finanszírozását követő felmérés mutatja be, miként változott a támogató pénzek iránya és aránya.', 'https://index.hu/kulfold/2024/06/03/europai-unio-valasztas-kampanytamogatas-jobboldal-baloldal-populista/')
# ('', '', 'Alig három óra alatt három ittas vezető okozott balesetet Debrecenben', 'Kettejüknél a bűncselekményi értékhatár közel négyszeresét mutatta ki a szonda.', 'https://index.hu/belfold/2024/06/03/debrecen-ittas-vezetes-jarmuvezeto-sofor-baleset-rendorseg-buntetoeljaras/')
# ('', '', 'Ferenc Pápától kérnek segítséget a győri katolikus hívek', '', 'https://index.hu/belfold/2024/06/03/ferenc-papa-gyor-level-katolikus-egyhaz-nyugdij-benkovich-ferenc-plebanos-veres-andras/')
# ('Ambrus Balázs', '2024.06.03. 16:11', 'Hogyan fejezhető ki pénzben egy emberi élet? – egy zuglói haláleset most megmutatja', 'Egy asszonyt megölt a felújítatlan önkormányzati lakás rossz villamoshálózata. Zugló a kért sérelemdíjat lealkudta.', 'https://index.hu/belfold/2024/06/03/birosag-zuglo-serelemdij-onkormanyzat-lakas-halal/')
# ('', '', 'Két olimpiát is nyert ebben a számban, mégsem ez volt a kedvence', 'Exkluzív interjú Sebastian Coe-val, a WA elnökével, aki nem jósol Jakob Ingebrigtsen és Josh Kerr párharcában.', 'https://index.hu/sport/atletika/2024/06/03/atletika-vilagdonto-world-athletics-wa-sebastian-coe-1500-m-olimpiai-bajnok-budapest-continental-tour/')
# ('', '', 'Az LMP lezárta a gödi akkumulátorgyárat', 'Hangsúlyozták, az ott élők egészsége fontosabb, mint a gyár profitja.', 'https://index.hu/belfold/2024/06/03/lmp-godi-akkumulatorgyar-lezaras-csardi-antal-demonstracio/')
# ('', '', 'Mégis távozik Ilics, az új vezetőedzőt kivásárolja szerződéséből a Veszprém', 'Négy évre kötelezte el magát.', 'https://index.hu/sport/kezilabda/2024/06/03/bajnokok-ligaja-telekom-veszprem-edzovaltas-xavi-pasqual-momir-ilic/')
# ('', '', 'A kormány újabb országot vett célba, tenger alatti kábelrendszert fektetnének le', 'A delegáció már napok óta ezekről tárgyal.', 'https://index.hu/gazdasag/2024/06/03/nagy-marton-4ig-egyiptom-kormany-egyuttmukodes-kozel-kelet/')
# ('', '', 'Népszavazás keretében fogna össze Vona Gábor Magyar Péterrel', 'A pártelnök nyílt levélben fejtette ki a véleményét a Tisza Párt alelnökének szombati bejelentéséről.', 'https://index.hu/belfold/2024/06/03/vona-gabor-magyar-peter-peticio-gyermekvedelem-nepszavazas/')
# ('', '', 'Carvajal édesapja felvezette a buszt, Ancelotti szivarozott – így telt a Real Madrid 15. BL-trófeájának ünneplése', 'Rüdiger azt mondta a közönségnek, „itt vagyok én, az őrült.”', 'https://index.hu/sport/futball/2024/06/03/bajnokok-ligaja-donto-unneples-real-madrid-bvb-dortmund-unneples-carlo-ancelotti-antonio-rudiger/')
# ('', '', 'Dobrev Klára 36 órás országjáró körúttal zárja a kampányt', 'A DK listavezetője szerint náluk ez már hagyomány.', 'https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/03/dobrev-klara-demokratikus-koalicio-kampanyzaro-korut-orszagjaras/')
# ('', '', 'Elstartolt az utolsó kampányhét, bedobták magukat a főpolgármester-jelöltek', 'Csak úgy záporoznak a választóknak szóló üzenetek.', 'https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/03/onkormanyzati-valasztas-2024-fopolgarmester-jelolt-kampany/')
# ('Kovács Ferenc', '2024.06.03. 15:05', 'Ők azok, akik eldönthetik, ki legyen a világ legnagyobb hatalommal rendelkező embere', 'Melyik amerikai államokban számítanak a vidéki fehér szavazók voksai?', 'https://index.hu/kulfold/usa/feher_haz/2024/06/03/valasztas-wisconsin-egyesult-allamok-donald-trump-joe-biden/')
# ('', '', 'Jön az árhullám a Dunán, hétvégén már Budapestet is elérheti', 'A vízügy szakemberei a nap 24 órájában követik az adatokat, figyelik a folyót.', 'https://index.hu/belfold/2024/06/03/orszagos-vizugyi-foigazgatosag-ovf-duna-arhullam/')
# ('', '', 'Vörös vesebabot hívott vissza a Nébih, növényvédőszert tartalmazhat', 'A termék bármelyik Tesco-üzletbe visszavihető.', 'https://index.hu/belfold/2024/06/03/nebih-tesco-bab-visszahivas/')
# ('', '', 'Eldőlt Esteban Ocon sokat vitatott jövője az Alpine csapatánál', 'Korábban is kétséges volt, de a Monacói Nagydíj után napi szintű témává vált.', 'https://index.hu/sport/forma1/2024/06/03/formula-1-alpine-esteben-ocon-tavozas-2024-pilotavaltas/')
# ('', '', 'Figyelmeztetett a Yettel: újabb módszerrel próbálkoznak a csalók', 'Az ügyfelek adatait akarják megszerezni.', 'https://index.hu/belfold/2024/06/03/yettel-online-csalas-atveres/')
# ('', '', 'Ez a praktikus házi tisztítószer-keverék valójában nem tisztít', 'Az ecet és szódabikarbóna keverése inkább csak látványosságnak jó.', 'https://index.hu/techtud/2024/06/03/haztartas-tisztitoszar-praktika-eset-szodabikarbona-keverek-latvanyos-felesleges/')
# ('', '', 'Rengeteg mindent rosszul tudunk az öröklési szabályokról, pedig milliók múlhatnak rajta', 'Sokan nincsenek tisztában azzal, milyen öröklési szabályok vonatkoznak a különböző vagyontárgyakra.', 'https://index.hu/belfold/2024/06/03/magyar-orszagos-kozjegyzoi-kamara-orokles-vegrendelet-felmeres/')

# %% [markdown]
# ## Fájlkezelés

# %%
if os.path.exists("output_index.csv"):
    os.remove("output_index.csv")

with open("output_index.csv", "a", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["author", "published", "title", "subtitle", "url"])
    writer.writerows(content)
    print("Fájl írása kész!")
# Out:
# Fájl írása kész!
