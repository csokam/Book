# %% [markdown]
# # Index híreinek kigyűjtése
#
# A <a href="https://index.hu/24ora/">index.hu/24ora</a> struktúrája szintén kellemes, gyakorlásra alkalmas.

# %% [markdown]
# ## Szükséges könyvtárak letöltése, importálása

# %%
# %pip install bs4

# %%
import os
import csv
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## Weboldal HTML struktúrájának letöltése

# %%
url = "https://index.hu/24ora/"
page = requests.get(url)
soup = bs(page.text, "html.parser")

print(soup)

with open("sample_index.html", "w", encoding="utf-8") as file:
    file.write(soup.prettify())
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="hu" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <head>
# <title>Hírek - 24 óra - Index.hu</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=EmulateIE11" http-equiv="X-UA-Compatible"/>
# <!-- [if IE]>
#         <meta http-equiv="imagetoolbar" content="no" />
#         <meta name="MSSmartTagsPreventParsing" content="true" />
#         <meta http-equiv="X-UA-Compatible" content="IE=Edge">
#         <![endif]-->
# <meta content="1717276106" name="manis:deploy">
# <meta name="manis:breakpoint"/>
# <meta name="manis:breakpoints"/>
# <meta content="https://index.hu/copyright/" name="copyright">
# <meta content="unsafe-url" name="referrer"/>
# <meta content="app-id=480103271" name="apple-itunes-app"/>
# <meta content="app-id=com.aff.index.main" name="google-play-app"/>
# <meta content="noindex" name="robots"/> <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <meta content="330827937019153" property="fb:app_id"><meta content="667823645" property="fb:admins"><meta content="560525343980775,348326671885918" property="fb:pages"><meta content="Friss hírek és információk az Indexen" name="description"> <meta content="https://index.hu/assets/images/facebook_logo.png?v5" property="og:image"/><meta content="https://www.facebook.com/Indexhu" property="article:publisher"/><meta content="summary_large_image" name="twitter:card"/><meta content="@indexhu" name="twitter:site"/><meta content="https://index.hu/assets/images/facebook_logo.png" name="twitter:image:src"/> <link href="/assets/static/opensearch.xml" rel="search" title="Index" type="application/opensearchdescription+xml"/>
# <link href="/copyright/" rel="copyright" title="Szerzői jogok"/>
# <link href="/impresszum/" rel="author" title="Impresszum"/>
# <link href="/" id="homelink" rel="home" title=""/>
# <link href="/assets/images/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/assets/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/assets/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/assets/images/favicons/manifest.json" rel="manifest"/>
# <link href="/assets/images/favicons/favicon.ico" rel="shortcut icon"/>
# <link color="#ff9900" href="/assets/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="Index" name="apple-mobile-web-app-title"/>
# <meta content="Index" name="application-name"/>
# <meta content="#ffffff" name="theme-color"/>
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <link href="https://index.hu/assets/static/indexnew_css/public/global.css?v=1717276080" rel="stylesheet" type="text/css"><link href="https://index.hu/assets/static/indexnew_css/public/index-global.css?v=1717276080" rel="stylesheet" type="text/css"> <link href="https://index.hu/assets/static/indexnew_css/public/rovat.css?v=1717276080" rel="stylesheet" type="text/css">
# <link href="https://index.hu/assets/static/indexnew_css/public/fixed_header.css?v=1717276080" rel="stylesheet" type="text/css">
# <link href="https://index.hu/assets/static/indexnew_css/public/24ora.css?v=1717276080" rel="stylesheet" type="text/css">
# <link href="/24ora/rss/" rel="alternate" title="24óra cikkek" type="application/rss+xml">
# <meta content="1" name="logcustomtarget">
# <!-- i8 -->
# <script src="https://index.hu/ident/getall/?c=aTg=" type="text/javascript"></script>
# <script src="https://index.hu/assets/static/js/public/index_vendor.ugly.js?v=1717276081" type="text/javascript"></script>
# <script src="https://index.hu/assets/static/js/public/index_base.ugly.js?v=1717276081" type="text/javascript"></script>
# <script src="https://index.hu/assets/static/js/public/index_election.ugly.js?v=1717276081" type="text/javascript"></script>
# <script src="https://index.hu/assets/static/js/public/cemp_fejlec.ugly.js?v=1717276081" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/index.rovat.min.js?v=1710407521" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/autocomplete.min.js?v=1717276106" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/calendar.min.js?v=1717276106" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/chosen2.min.js?v=1717276106" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/jquery-ui.min.js?v=1717276106" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/index.24ora.min.js?v=1717276106" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/scrolling_shadow.js?v=1717276106" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/pip_video.min.js?v=1717276106" type="text/javascript"></script>
# <script type="text/javascript">
#         var _gaq = { push: function() {} };
#         ( function( i, s, o, g, r, a, m ) {
#             i[ 'GoogleAnalyticsObject' ] = r;
#             i[ r ] = i[ r ] || function() {
#                 ( i[ r ].q = i[ r ].q || [] ).push( arguments )
#             }, i[ r ].l = 1 * new Date();
#             a = s.createElement( o ), m = s.getElementsByTagName( o )[ 0 ];
#             a.async = 1;
#             a.src=g;
#             m.parentNode.insertBefore( a, m )
#         } )( window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga' );
#         var oldaltipus = '24ora_cimlap';
#         ( function( $ ) {
#             window.scrollTrackerEnabled = 1;
#             window.Analytics = {
#                 add: function( command, params, target ) {
#                     if( typeof command === 'undefined' || typeof params === 'undefined' || !command || !params ) {
#                         return this;
#                     }
#                     params.location = ( params.location || document.location.href ).replace( '//m.', '//' );
#                     if( this.loaded ) {
#                         if( typeof target !== 'undefined' ) {
#                             command = target + '.' + command;
#                         }
#                         ga( command, params );
#                     }
#                     else {
#                         this.stack.push( [ command, $.extend( {}, params ), target ] );
#                     }
#                     return this;
#                 },
#                 process: function() {
#                     if( this.loaded ) {
#                         return;
#                     }
#                     var arg;
#                     while( this.stack.length ) {
#                         arg = this.stack.shift();
#                         if( typeof arg[ 2 ] !== 'undefined' && Common[ 'ga_' + arg[ 2 ] ] === true ) {
#                             arg[ 0 ] = arg[ 2 ] + '.' + arg[ 0 ];
#                         }
#                         ga( arg[ 0 ], arg[ 1 ] );
#                     }
#                     this.loaded = true;
#                 },
#                 stack: []
#             };
#             $( document ).on( 'ready', function() {
#                 if( typeof window.Common === 'undefined' ) {
#                     window.Common = {
#                         ga_secondary: false
#                     };
#                 }
#                 if( typeof __passportHeader_config === 'undefined' ) {
#                     __passportHeader_config = {};
#                 }
#                 Common.ga_secondary = false;
#                 var ga_base_config = {
#                     sampleRate: 100,
#                     trackingId: 'UA-181415-27'
#                 };
#                 var ga_set_config = {
#                     dimension1: '24ora_cimlap',
#                     dimension2: ( __passportHeader_config.loggedIn ? '' : 'Not' ) + 'LoggedIn',
#                                             dimension3: Page.getLayout(),
#                                                                                 language: document.domain === 'totalcarmagazine.com' ? 'en-us' : 'hu-hu',
#                     location: document.location.href.replace( '//m.', '//' )
#                 };
#                 if( typeof __passportHeaderUserId !== 'undefined' ) {
#                     ga_base_config.userId = __passportHeaderUserId;
#                 }
#                 ga( 'create', ga_base_config );
#                 ga( 'require', 'displayfeatures' );
#                 ga( 'set', ga_set_config );
#                                     Common.ga_secondary = true;
#                     var ga_secondary_config = $.extend( {}, ga_base_config );
#                     ga_secondary_config.name = 'secondary';
#                     ga_secondary_config.trackingId = 'UA-181415-11';
#                     ga_secondary_config.sampleRate = 10;
#                     ga( 'create', ga_secondary_config );
#                     ga( 'secondary.require', 'displayfeatures' );
#                     ga( 'secondary.set', ga_set_config );
#                                 ga('set', 'anonymizeIp', true);
#                 // cross_site ajanlo kivetelkezelese
#                 if(
#                     (
#                         $( '#passportHeader, #_iph_fixed-header' ).length ||
#                         $( '#inforadio_audioplayer1' ).length ||
#                         $( '.header_send').length ||
#                         document.location.host.indexOf( 'm.' ) === 0 ||
#                         document.location.host.substring( document.location.host.length - 4 ) === '.com'
#                     ) &&
#                     ((Common.topfolder !== 'i2' && Common.topfolder !== 'index2') || !Common.parsed_url.hash || Common.parsed_url.hash.indexOf( '#bloghu' ) !== 0 )
#                 ) {
#                     ga( 'send', 'pageview' );
#                     if( Common.ga_secondary ) {
#                         ga( 'secondary.send', 'pageview' );
#                     }
#                 }
#                 Analytics.process();
#             } );
#         } )( jQuery );
#     </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-7GR3T85C96"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         var ga4params = {"content_group":"24ora\/","rovat":"24\u00f3ra","oldaltipus":"24ora_cimlap","cikktipus":"Keres\u0151"};
#         ga4params.layout = Page.getLayout();
#         ga4params.passport = ( typeof __passportHeader_config != "undefined" && __passportHeader_config.loggedIn ? '' : 'Not' ) + 'LoggedIn';
#         gtag('js', new Date());
#         gtag('config', 'G-7GR3T85C96', ga4params);
#     </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-PPDGL3DR');</script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript">
#         Common.folder_id = 267;
#         Common.folder_parent_ids = [ 261 ];
#         Common.is_new_design = 1;
#     </script>
# <script>
#     window.fbAsyncInit = function() {
#         FB.init({
#             appId      : '330827937019153',
#             xfbml      : true,
#             status     : false,
#             version    : 'v5.0'
#         });
#         window.fb_initialized = true;
#     };
#
#     (function(d, s, id) {
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) return;
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/hu_HU/sdk.js";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
# </script>
# <script type="text/javascript">
#         $(function () {
#             window.LinkPreview && window.LinkPreview.init();
#         });
#     </script>
# <script type="text/javascript"><!--//--><![CDATA[//><!--
#     var IndexStatConfig = {
#         pixels: [ { id: 267, type: 2 }, { id: 261, type: 3 }, { id: 1, type: 5 }, { id: 2, type: 4 }],
#         device: 'desktop'
#     }
#     //--><!]]>
# </script>
# <script async="" src="//indexstat.index.hu/stat.min.js?dd=20240602" type="text/javascript"></script>
# <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script async="true" type="text/javascript">
#     var nuCmp = true; try { Promise.resolve(1).finally() } catch(e) { nuCmp = false; }
#     if (nuCmp) {
#         (function() {
#             var host = 'index.hu';
#             var element = document.createElement('script');
#             var firstScript = document.getElementsByTagName('script')[0];
#             var url = 'https://cmp.quantcast.com'
#                 .concat('/choice/', '4z9XXyvnuPTjK', '/', host, '/choice.js?tag_version=V2');
#             var uspTries = 0;
#             var uspTriesLimit = 3;
#             element.async = true;
#             element.type = 'text/javascript';
#             element.src = url;
#
#             firstScript.parentNode.insertBefore(element, firstScript);
#
#             function makeStub() {
#                 var TCF_LOCATOR_NAME = '__tcfapiLocator';
#                 var queue = [];
#                 var win = window;
#                 var cmpFrame;
#
#                 function addFrame() {
#                     var doc = win.document;
#                     var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#                     if (!otherCMP) {
#                         if (doc.body) {
#                             var iframe = doc.createElement('iframe');
#
#                             iframe.style.cssText = 'display:none';
#                             iframe.name = TCF_LOCATOR_NAME;
#                             doc.body.appendChild(iframe);
#                         } else {
#                             setTimeout(addFrame, 5);
#                         }
#                     }
#                     return !otherCMP;
#                 }
#
#                 function tcfAPIHandler() {
#                     var gdprApplies;
#                     var args = arguments;
#
#                     if (!args.length) {
#                         return queue;
#                     } else if (args[0] === 'setGdprApplies') {
#                         if (
#                             args.length > 3 &&
#                             args[2] === 2 &&
#                             typeof args[3] === 'boolean'
#                         ) {
#                             gdprApplies = args[3];
#                             if (typeof args[2] === 'function') {
#                                 args[2]('set', true);
#                             }
#                         }
#                     } else if (args[0] === 'ping') {
#                         var retr = {
#                             gdprApplies: gdprApplies,
#                             cmpLoaded: false,
#                             cmpStatus: 'stub'
#                         };
#
#                         if (typeof args[2] === 'function') {
#                             args[2](retr);
#                         }
#                     } else {
#                         if(args[0] === 'init' && typeof args[3] === 'object') {
#                             args[3] = { ...args[3], tag_version: 'V2' };
#                         }
#                         queue.push(args);
#                     }
#                 }
#
#                 function postMessageEventHandler(event) {
#                     var msgIsString = typeof event.data === 'string';
#                     var json = {};
#
#                     try {
#                         if (msgIsString) {
#                             json = JSON.parse(event.data);
#                         } else {
#                             json = event.data;
#                         }
#                     } catch (ignore) {}
#
#                     var payload = json.__tcfapiCall;
#
#                     if (payload) {
#                         window.__tcfapi(
#                             payload.command,
#                             payload.version,
#                             function(retValue, success) {
#                                 var returnMsg = {
#                                     __tcfapiReturn: {
#                                         returnValue: retValue,
#                                         success: success,
#                                         callId: payload.callId
#                                     }
#                                 };
#                                 if (msgIsString) {
#                                     returnMsg = JSON.stringify(returnMsg);
#                                 }
#                                 if (event && event.source && event.source.postMessage) {
#                                     event.source.postMessage(returnMsg, '*');
#                                 }
#                             },
#                             payload.parameter
#                         );
#                     }
#                 }
#
#                 while (win) {
#                     try {
#                         if (win.frames[TCF_LOCATOR_NAME]) {
#                             cmpFrame = win;
#                             break;
#                         }
#                     } catch (ignore) {}
#
#                     if (win === window.top) {
#                         break;
#                     }
#                     win = win.parent;
#                 }
#                 if (!cmpFrame) {
#                     addFrame();
#                     win.__tcfapi = tcfAPIHandler;
#                     win.addEventListener('message', postMessageEventHandler, false);
#                 }
#             };
#
#             makeStub();
#
#             var uspStubFunction = function() {
#                 var arg = arguments;
#                 if (typeof window.__uspapi !== uspStubFunction) {
#                     setTimeout(function() {
#                         if (typeof window.__uspapi !== 'undefined') {
#                             window.__uspapi.apply(window.__uspapi, arg);
#                         }
#                     }, 500);
#                 }
#             };
#
#             var checkIfUspIsReady = function() {
#                 uspTries++;
#                 if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#                     console.warn('USP is not accessible');
#                 } else {
#                     clearInterval(uspInterval);
#                 }
#             };
#
#             if (typeof window.__uspapi === 'undefined') {
#                 window.__uspapi = uspStubFunction;
#                 var uspInterval = setInterval(checkIfUspIsReady, 6000);
#             }
#         })();
#     }
# </script>
# <!-- End Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script src="//indexhu.adocean.pl/files/js/ado.js" type="text/javascript"></script>
# <script>
#     window.adocf = {};
#     window.adocf.useDOMContentLoaded = true;
#     window.iap_base = 'https://index.hu/';
#     var tagStr = document.querySelector('meta[name="keywords"]') ? document.querySelector('meta[name="keywords"]').getAttribute("content").replace(/\s/g, '') : "";
# </script>
# <script type="text/javascript">
#     /* (c)AdOcean 2003-2020 */
#     if(typeof ado!=="object"){ado={};ado.config=ado.preview=ado.placement=ado.master=ado.slave=function(){};}
#     ado.config({mode: "new", xml: false, consent: true, characterEncoding: true, attachReferrer: true, fpc: "auto" , defaultServer:"indexhu.adocean.pl" ,cookieDomain:"SLD"});
#     ado.preview({enabled: true});
#     /* (c)AdOcean 2003-2020, MASTER: c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87 */
#     ado.master({id: 'c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87', server: 'indexhu.adocean.pl', vars: typeof customTargetAdocean !== "undefined" ? customTargetAdocean : '', keys: tagStr });
# </script>
# <script type="module">
#     document.addEventListener('DOMContentLoaded', async () => {
#         const { Loader } = await (await import('https://iap.cdn.indexvas.hu/Scripts.js')).default;
#         window.GoaLoader = new Loader({"debug":false,"engine":"AdOcean","master":"c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87","stat":true})
#     })
# </script>
# <script type="text/javascript">
#     Common.maxFeedAjanloLoadCount = 1;
#     Common.feedAjanloLoadCount = 3;
#     Common.feedAjanloMoreButton = 1;
#     Common.feedAjanloTovabbUrl = "https://index.hu/24ora/";
# </script>
# <link href="/manifest.json" rel="manifest"/>
# <script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js"></script>
# <script>
#     var OneSignal = window.OneSignal || [];
#     OneSignal.push(function() {
#         OneSignal.sendTags({
#             is_web: true
#         });
#         OneSignal.init({
#             appId: "bd30d7a1-7b22-4adb-bacf-e4bf80d25bf7",
#             autoRegister: false,
#             notifyButton: {
#                 enable: true
#             }
#         });
#     });
# </script>
# <script>
#     window.googletag = window.googletag || {cmd: []};
#     googletag.cmd.push(function() {
#                 googletag.pubads().enableSingleRequest();
#                 googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#             if(!event.isEmpty) {
#                 $(document.getElementById(event.slot.getSlotElementId())).closest(".mobile-sticky").show().find("button.mobile-sticky-closing").on("click", function(){
#                     $(this).closest(".mobile-sticky").hide();
#                 });
#             }
#         });
#         googletag.enableServices();
#     });
# </script>
# </meta></link></link></link></link></link></link></meta></meta></meta></meta></meta></meta></meta></head>
# <body class="device_desktop indexhu rovat h24ora rovat_24ora iframe_disallowed">
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PPDGL3DR" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div id="fb-root"></div>
# <script>(function() {
#   var _fbq = window._fbq || (window._fbq = []);
#   if (!_fbq.loaded) {
#     var fbds = document.createElement('script');
#     fbds.async = true;
#     fbds.src = '//connect.facebook.net/en_US/fbds.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(fbds, s);
#     _fbq.loaded = true;
#   }
#   _fbq.push(['addPixelId', '551982981568628']);
# })();
# window._fbq = window._fbq || [];
# window._fbq.push(['track', 'PixelInitialized', {}]);
# </script>
# <noscript><img alt="" height="1" src="https://www.facebook.com/tr?id=551982981568628&amp;ev=PixelInitialized" style="display:none" width="1"/></noscript>
# <div class="layer xl_layer">
# <div class="iap iap--ado ad-label--hidden no-padding no-margin" data-id="adoceanindexhulmgghmhsud" id="adoceanindexhulmgghmhsud">
# <script class="iap-script">
#                                                             window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhulmgghmhsud","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_Layer","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#                                                         </script>
# </div>
# <div class="iap iap--ado ad-label--hidden no-padding no-margin" data-id="ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7" id="ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7">
# <script class="iap-script">
#                                                             window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7","empty":true,"lazy":false,"quality":false,"masterless":true,"area":"Index_Aloldalak_Layer_gde_test","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#                                                         </script>
# </div>
# </div>
# <div class="sticky">
# </div>
# <div class="container" id="ad_null_position">
# </div>
# <div aria-hidden="true" class="m-cf-search modal" data-backdrop="false" data-js-modal-window="search" role="dialog" style="display: none" tabindex="-1">
# <div class="m-cf-search_wrapper">
# <div class="m-cf-search_wrapper_container" data-js-cemp-search="container">
# <form action="https://index.hu/24ora/" class="m-cf-search_wrapper_container_form" method="get">
# <input name="word" type="hidden" value="1"/>
# <input name="pepe" type="hidden" value="1"/>
# <input name="tol" type="hidden" value="1999-01-01"/>
# <input name="ig" type="hidden" value="2024-06-02"/>
# <input class="m-cf-search_wrapper_container_form_input" data-js-cemp-search="input" name="s" placeholder="Keresés" tabindex="0" type="search"/>
# <button class="m-cf-search_wrapper_container_form_button" type="submit">
# <span class="m-cf-search_wrapper_container_form_button_wrapper">
# <svg class="m-cf-search_wrapper_container_form_button_wrapper_icon" style="height:21px;width:21px;" viewbox="0 0 21 21"><path d="M20.8 18.867c.267.267.267.7 0 .967l-.966.967c-.267.267-.7.267-.966 0L13.5 15.434c-.073-.074-.122-.16-.155-.253-1.39 1.014-3.094 1.62-4.944 1.62-4.64 0-8.4-3.76-8.4-8.4C0 3.76 3.76 0 8.4 0c4.64 0 8.4 3.76 8.4 8.4 0 1.85-.606 3.556-1.62 4.945.092.032.18.08.253.155l5.368 5.367zM8.4 2.8c-3.093 0-5.6 2.507-5.6 5.6 0 3.093 2.507 5.6 5.6 5.6 3.093 0 5.6-2.507 5.6-5.6 0-3.093-2.507-5.6-5.6-5.6z"></path></svg>
# <span class="m-cf-search_wrapper_container_form_button_wrapper_label h-visibility-off_small-down">Keresés</span>
# </span>
# </button>
# </form>
# </div>
# </div>
# </div>
# <div class="m-cf-indalista" data-js-dropdown="inda">
# <div class="m-cf-indalista_container">
# <ul class="m-cf-indalista_container_list">
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="blog.hu" href="https://blog.hu/" target="_blank">Blog.hu</a>
# </li>
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="forum" href="http://forum.index.hu/Topic/showTopicList" target="_blank">Fórum</a>
# </li>
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="indavideo" href="http://indavideo.hu/" target="_blank">Indavideó</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-cf-kiadvanylista">
# <div class="m-cf-kiadvanylista_container">
# <ul class="m-cf-kiadvanylista_container_list">
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Economx" data-target="economx" href="https://www.economx.hu" target="_blank">Economx</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Dívány" data-target="divany" href="https://divany.hu/" target="_blank">Dívány</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Totalcar" data-target="totalcar" href="https://totalcar.hu/" target="_blank">Totalcar</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Femina" data-target="femina" href="https://femina.hu/" target="_blank">Femina</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Port" data-target="port" href="https://port.hu/" target="_blank">Port</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="We ❤︎ Budapest" data-target="we_x2764_xfe0e_budapest" href="https://welovebudapest.com/" target="_blank">We ❤︎ Budapest</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Velvet" data-target="velvet" href="https://velvet.hu/" target="_blank">Velvet</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <button class="m-cf-kiadvanylista_container_list_item_inda" data-target="[data-js-dropdown=inda]" data-toggle="dropdown" type="button">
# <span class="m-cf-kiadvanylista_container_list_item_inda_container">
# <span class="m-cf-kiadvanylista_container_list_item_inda_container_label">Inda</span>
# <svg class="m-cf-kiadvanylista_container_list_item_inda_container_icon" viewbox="0 0 11 7">
# <path d="M5.5 5.125L1.032.657C.846.47.534.467.344.657c-.185.184-.19.497 0 .687l4.812 4.812c.092.092.217.14.342.14.125 0 .25-.045.346-.14l4.812-4.812c.185-.185.19-.498 0-.688-.184-.184-.498-.19-.688 0L5.5 5.127z"></path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-cf-fejlec">
# <div class="m-cf-fejlec_container">
# <div class="m-cf-fejlec_container_wrapper">
# <ul class="m-cf-fejlec_container_links">
# <li class="m-cf-fejlec_container_links_item itemCover">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Címlap" href="https://dex.hu/x.php?id=fxdfejlecpnc&amp;url=https%3A%2F%2Findex.hu%2F">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_logo" viewbox="-54 12 8 20"><path class="m-cf-fejlec_container_links_item_link_container_logo_stem" d="M-54 18h8v14h-8V18z"></path><path class="m-cf-fejlec_container_links_item_link_container_logo_dot" d="M-54 12h8v4h-8v-4z"></path></svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">Címlap</span>
# </span>
# </a>
# </li>
# <li class="m-cf-fejlec_container_links_item itemHeadings">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Rovatok" href="https://dex.hu/x.php?id=fxdfejlec&amp;url=https%3A%2F%2Findex.hu%2Frovatok">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_icon iconHamburger" viewbox="0 0 22 17">
# <path d="M0 1.5C0 .672.67 0 1.495 0h19.01C21.33 0 22 .666 22 1.5c0 .828-.67 1.5-1.495 1.5H1.495C.67 3 0 2.334 0 1.5zm0 7C0 7.672.67 7 1.495 7h19.01C21.33 7 22 7.666 22 8.5c0 .828-.67 1.5-1.495 1.5H1.495C.67 10 0 9.334 0 8.5zm0 7c0-.828.67-1.5 1.495-1.5h19.01c.826 0 1.495.666 1.495 1.5 0 .828-.67 1.5-1.495 1.5H1.495C.67 17 0 16.334 0 15.5z"></path>
# </svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">Rovatok</span>
# </span>
# </a>
# </li>
# <li class="m-cf-fejlec_container_links_item itemLatest">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Legfrissebbek" href="https://dex.hu/x.php?id=fxdfejlec&amp;url=https%3A%2F%2Findex.hu%2F24ora">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_icon iconClock" viewbox="0 0 22 22"><path d="M11 19.25c-4.557 0-8.25-3.693-8.25-8.25S6.443 2.75 11 2.75s8.25 3.693 8.25 8.25-3.693 8.25-8.25 8.25M11 0C4.925 0 0 4.925 0 11s4.925 11 11 11 11-4.925 11-11S17.075 0 11 0"></path><path d="M12.833 10.89V6.874c0-.76-.616-1.375-1.375-1.375-.76 0-1.375.616-1.375 1.375v5.04h.11l-.11.113 2.27 2.27c.536.535 1.406.535 1.943 0 .538-.538.538-1.41 0-1.946l-1.463-1.463z"></path></svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">Friss hírek</span>
# </span>
# </a>
# </li> </ul>
# </div>
# <div class="m-cf-fejlec_container_inda">
# <ul class="m-cf-fejlec_container_inda_kiadvanyok">
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Economx" data-target="economx" href="https://www.economx.hu" target="_blank">Economx</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Dívány" data-target="divany" href="https://divany.hu/" target="_blank">Dívány</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Totalcar" data-target="totalcar" href="https://totalcar.hu/" target="_blank">Totalcar</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Femina" data-target="femina" href="https://femina.hu/" target="_blank">Femina</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Port" data-target="port" href="https://port.hu/" target="_blank">Port</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="We ❤︎ Budapest" data-target="we_x2764_xfe0e_budapest" href="https://welovebudapest.com/" target="_blank">We ❤︎ Budapest</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Velvet" data-target="velvet" href="https://velvet.hu/" target="_blank">Velvet</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <button class="m-cf-fejlec_container_inda_kiadvanyok_item_inda" data-target="[data-js-dropdown=inda]" data-toggle="dropdown" type="button">
# <span class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container">
# <span class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container_label">Inda</span>
# <svg class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container_icon" viewbox="0 0 11 7">
# <path d="M5.5 5.125L1.032.657C.846.47.534.467.344.657c-.185.184-.19.497 0 .687l4.812 4.812c.092.092.217.14.342.14.125 0 .25-.045.346-.14l4.812-4.812c.185-.185.19-.498 0-.688-.184-.184-.498-.19-.688 0L5.5 5.127z"></path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# <ul class="m-cf-fejlec_container_inda_actions">
# <li class="m-cf-fejlec_container_inda_actions_item itemSearch">
# <button class="m-cf-fejlec_container_inda_actions_item_button" data-ga-category="Keresés" data-js-cemp-search="button" data-target="[data-js-modal-window=search]" data-toggle="modal" type="button">
# <span class="m-cf-fejlec_container_inda_actions_item_button_wrapper">
# <svg class="m-cf-fejlec_container_inda_actions_item_button_wrapper_icon" viewbox="0 0 21 21">
# <path d="M20.8 18.867c.267.267.267.7 0 .967l-.966.967c-.267.267-.7.267-.966 0L13.5 15.434c-.073-.074-.122-.16-.155-.253-1.39 1.014-3.094 1.62-4.944 1.62-4.64 0-8.4-3.76-8.4-8.4C0 3.76 3.76 0 8.4 0c4.64 0 8.4 3.76 8.4 8.4 0 1.85-.606 3.556-1.62 4.945.092.032.18.08.253.155l5.368 5.367zM8.4 2.8c-3.093 0-5.6 2.507-5.6 5.6 0 3.093 2.507 5.6 5.6 5.6 3.093 0 5.6-2.507 5.6-5.6 0-3.093-2.507-5.6-5.6-5.6z"></path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# <div class="fixed-header">
# <script type="text/javascript">
#
#     (function() {
#         var sc = document.createElement('script'); sc.type = 'text/javascript'; sc.async = true;
#         sc.src = __passportHeader_config.HEADER_URL + 'passportHeader.js';
#        var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sc, s);
#     })();    </script>
# <div id="passportHeader" style="height: 36px; visibility: hidden;"></div></div>
# </div>
# </div>
# </div>
# <section class="blokk hajtas-felett container index-header cimlap-blokk-index">
# <div class="index-header-wrapper">
# <a class="logo" data-ga-category="Index logó" href="/"></a>
# <ul class="trending-topics">
# <li stamp-index="0">
# <a class="cimke cimke-mufaj cimke-199435" href="https://dex.hu/x.php?id=inxcl_stamp&amp;url=https%3A%2F%2Findex.hu%2Fbajnokokligaja%23">Bajnokok Ligája</a>
# </li> </ul>
# <div class="header-parts">
# <div class="calendar">
# <time datetime="2024-06-02" title="22. hét">2024. 06. 02. vasárnap</time>
# <div id="name-day">Anita, Kármen</div>
# </div>
# <section class="exchange njs-carousel">
# <a class="exchange-ticker" data-g-category="Árfolyam" href="https://dex.hu/x.php?id=inxfejlec&amp;url=http%3A%2F%2Fportfoliofinancial.hu%2F" target="_blank" title="Forrás: portfoliofinancial.hu">
# <span class="currency-item goood">
# <span class="ticker">EUR</span>
# <span class="price">
#                     389,48                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="currency-item baaad">
# <span class="ticker">USD</span>
# <span class="price">
#                     359,02                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="currency-item baaad">
# <span class="ticker">GBP</span>
# <span class="price">
#                     457,49                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="exchange-item baaad">
# <span class="ticker">BUX</span>
# <span class="price">
#                     67 907                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="exchange-item baaad">
# <span class="ticker">OTP</span>
# <span class="price">
#                     17 310                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="exchange-item baaad">
# <span class="ticker">MOL</span>
# <span class="price">
#                     2 790                    <span class="forint">Ft</span>
# </span>
# </span>
# </a>
# </section>
# <a class="weather" data-ga-category="Időjárás" data-temprature="19.9" href="https://dex.hu/x.php?id=inxcl_idojaras&amp;url=https://index.hu/idojaras" title="most: 19,9 °C">
# <div class="temperature">
# <div class="night">12 °C</div>
# <div class="day">25 °C</div>
# </div>
# <div class="weather-icon">
# <ul>
# <li class="icon-cloud"></li>
# </ul>
# </div>
# </a>
# </div>
# <nav id="index-rovatok">
# <a class="rovat-link navi_belfold" data-ga-category="Belföld" data-rovat-dropdown="" href="#" id="belfold">
#                 Belföld            </a>
# <a class="rovat-link navi_kulfold" data-ga-category="Külföld" data-rovat-dropdown="" href="#" id="kulfold">
#                 Külföld            </a>
# <a class="rovat-link navi_gazdasag" data-ga-category="Gazdaság" data-rovat-dropdown="" href="#" id="gazdasag">
#                 Gazdaság            </a>
# <a class="rovat-link navi_kultur" data-ga-category="Kult" data-rovat-dropdown="" href="#" id="kultur">
#                 Kult            </a>
# <a class="rovat-link navi_velemeny" data-ga-category="Vélemény" data-rovat-dropdown="" href="#" id="velemeny">
#                 Vélemény            </a>
# <a class="rovat-link navi_techtud" data-ga-category="Tech-Tud" data-rovat-dropdown="" href="#" id="techtud">
#                 Tech-Tud            </a>
# <a class="rovat-link navi_sport" data-ga-category="Sport" data-rovat-dropdown="" href="#" id="sport">
#                 Sport            </a>
# <a class="rovat-link navi_fomo" data-ga-category="Fomo" data-rovat-dropdown="" href="#" id="fomo">
#                 Fomo            </a>
# <a class="rovat-link navi_24ora selected" data-ga-category="24 Óra" data-rovat-dropdown="" href="#" id="24ora">
#                 24 Óra            </a>
# <a class="rovat-link navi_blog notification" data-ga-category="Blog" data-rovat-dropdown="" href="#" id="blog">
#                 Blog            </a>
# <a class="rovat-link navi_video notification" data-ga-category="Videó" data-rovat-dropdown="" href="#" id="video">
#                 Videó            </a>
# <a class="rovat-link navi_podcast notification" data-ga-category="Podcast" data-rovat-dropdown="" href="#" id="podcast">
#                 Podcast            </a>
# <a class="rovat-icon navi_twitter" data-ga-category="Twitter" href="https://twitter.com/indexhu" id="twitter" target="_blank"></a>
# <a class="rovat-icon navi_socials" data-ga-category="Socials" data-rovat-dropdown="" href="#" id="socials"></a>
# </nav>
# <div class="dropdown-container" hidden="" id="dropdown-menu-wrapper">
# <div class="loader animating">
# <span class="loader-item"></span>
# <span class="loader-item"></span>
# <span class="loader-item"></span>
# </div>
# </div>
# <script>
#     document.addEventListener('DOMContentLoaded', () => {
#         window.rovatDropdown = new RovatDropdown({
#             base_url: 'https://index.hu/',
#             callbacks: {
#                 video: function(element) {
#                     window.video_slider = new DropdownSlider(element.querySelector('.slider'), { threshold: 0 });
#                 }
#             }
#         });
#     });
# </script>
# </div>
# </section>
# <div class="container top_szponzor adverticum-kapubanner">
# <div class="ad-container">
# <div class="iap iap--ado" data-id="adoceanindexhuqclsmvirum" id="adoceanindexhuqclsmvirum">
# <script class="iap-script">
#                                                             window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhuqclsmvirum","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_LB","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#                                                         </script>
# </div>
# </div>
# </div>
# <div class="container border rovat-container">
# <div id="js_content_template_normal">
# <!--
#         <article class="rovatajanlo unordered not-important normal">
#             <header class="rovat-cikk-head">
#                 <h3>
#                     <span class="separator-box"></span>
#                         <span class="cikk-date-label" data-datestamp="{{Puzzler.ccd.ts}}" data-date="{{Puzzler.timestampToDate( Puzzler.ccd.ts )}}">{{Puzzler.ccd.datum}}</span>
#                     <span class="separator"></span>
#                     {{Puzzler.isMindekozben( Puzzler.ccd.url ) ? '<ul class="cikk-cimkek"><li><a href="http://index.hu/mindekozben" class="cimke cimke-mufaj">Mindeközben</a></li></ul>' : ''}}
#                     {{ Puzzler.ccd.kiadvany_csoki ? Puzzler.ccd.kiadvany_csoki : ''; }}
#                 </h3>
#                 <div class="clearfix"></div>
#             </header>
#
#             <h2>
#                 {{Puzzler.ccd.kep ? '<a href="' + Puzzler.ccd.url + '"  title="' + Puzzler.ccd.cim + '"><img class="need_to_load" src="' + Puzzler.ccd.kep + '" alt="' + Puzzler.ccd.cim + '" /></a>' : '' }}
#                 <a href="{{Puzzler.ccd.url}}" class="cim" title="{{Puzzler.ccd.cim}}">{{Puzzler.ccd.cim}}</a>
#             </h2>
#             {{Puzzler.ccd.ajanlo ? '<div class="ajanlo">' + Puzzler.ccd.ajanlo + '</div>' : '' }}
#         </article>
# -->
# </div>
# <div id="js_content_template_lead">
# <!--
#         <article class="rovatajanlo vezeto keppel not-important">
#             <div class="article-container">
#                 <a href="{{Puzzler.ccd.url}}"  title="{{Puzzler.ccd.cim}}">
#                     <img src="{{Puzzler.ccd.kep}}" alt="{{Puzzler.ccd.cim}}">
#                 </a>
#                 <h2>
#                     <a href="{{Puzzler.ccd.url}}" class="cim"  title="{{Puzzler.ccd.cim}}">{{Puzzler.ccd.cim}}</a>
#                 </h2>
#             </div>
#             <div class="author-share-date-container">
#             <div class="author-share-date">
#                 <div class="bal-hasab">
#                     <div class="szerzok_container">
#                             {{Puzzler.ccd.alnevek.replace(/\\(.)/mg, "$1")}}
#                     </div>
#                     <div class="datum">
#                         {{Puzzler.ccd.datum}}
#                     </div>
#                 </div>
#                 <div class="jobb-hasab">
#                     <div class="megoszt ">
#                         <div class="fb-share" data-action="recommend" data-href="{{Puzzler.ccd.url}}"> {{Puzzler.ccd.actual_fb_like}} </div>
#                 <div class="index-social-box cikk-top-box">
#                     <a href="#" class="megosztas-gomb"></a>
#                     <ul class="megosztas-doboz">
#                         <li class="mail">
#                             <a class="email" href="mailto:ugyelet@NEMSPA_M.mail.index.hu?subject={{Puzzler.ccd.cim}}&amp;body=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                             <li class="facebook">
#                                 <a href="https://www.facebook.com/sharer/sharer.php?u=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                             </li>
#                         <li class="twitter">
#                             <a href="http://twitter.com/share?lang=hu&amp;text={{Puzzler.ccd.cim}}&amp;url=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                         <li class="tumblr">
#                             <a href="http://www.tumblr.com/share/link?url=http:{{Puzzler.ccd.url}}&amp;name={{Puzzler.ccd.cim}}&amp;description=%28via+%3Ca+href%3D%22http%3A%2F%2Findex.hu%2F%22%3EIndex%3C%2Fa%3E%29" target="_blank"></a>
#                         </li>
#                         <li class="google-plus">
#                             <a href="https://plus.google.com/share?url=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                     </ul>
#                 </div>
#                             <div class="hozzaszolasok"></div>
#                    </div>
#
#                                 </div>
#                             </div>
#             </div>
#             <div class="ajanlo">{{Puzzler.ccd.ajanlo}}</div>
#         </article>
# -->
# </div>
# <div id="js_content_template_datumcsik">
# <!--
#         <div class="datumcsik clearfix">{{Puzzler.ccd.month ? Puzzler.ccd.month : Puzzler.timestampToDate( Puzzler.ccd.ts, true )}}</div>
# -->
# </div>
# <div class="kereses-urlap">
# <h3>Keresés</h3>
# <form action="" id="kereses-urlap">
# <div class="mezocsoport alap-kereso">
# <div class="kereses-wrapper">
# <input id="kereses-mezo" name="s" placeholder="Keresés" type="text" value=""/>
# </div>
# <div class="kereses-gomb-wrapper">
# <input class="gomb-elsodleges kereses-ikon" type="submit" value=""/>
# </div>
# </div>
# <div class="reszletes-kereses-gomb-container">
# <button class="gomb-masodlagos reszletes-kereses-gomb" href="#">Részletes keresés</button>
# </div>
# <div class="reszletes-kereses-container">
# <div class="datum-container">
# <div class="mezocsoport">
# <div class="datum-wrapper">
# <input autocomplete="off" class="date-selector" id="datum-tol" name="tol" type="text" value="1999-01-01"/>
# </div>
# <div class="datum-label-wrapper">
# <label for="datum-tol">-tól</label>
# </div>
# </div>
# <div class="mezocsoport">
# <div class="datum-wrapper">
# <input autocomplete="off" class="date-selector" id="datum-ig" name="ig" type="text" value="2024-06-02"/>
# </div>
# <div class="datum-label-wrapper">
# <label for="datum-ig">-ig</label>
# </div>
# </div>
# </div>
# <div class="onthisday-container">
# <input class="onthisday-kapcsolo" id="onthisday" name="onthisday" type="checkbox" value="1"/>
# <label class="onthisday-label" for="onthisday">Ezen a napon<span></span></label>
# </div>
# <div class="tarskiadvany-container">
# <input class="tarskiadvany-kapcsolo" id="tarskiadvanyokbanis" name="tarskiadvanyokbanis" type="checkbox" value="1"/>
# <label class="tarskiadvany-label" for="tarskiadvanyokbanis">Az Index környékéről is<span>Totalcar, Totalbike, Velvet, Dívány, Comment:Com, Könyvesblog, Tékozló Homár</span></label>
# <div class="tarskiadvany-opciok">
# <div class="szerzo-rovat-container">
# <div class="mezocsoport">
# <div class="input-wrapper">
# <select class="chosen-select" data-placeholder="Szerzők" name="profil">
# <option value=""></option>
# <option value="">Összes</option>
# <option value="acs_daniel">Ács Dániel</option>
# <option value="acs_tibor">Ács Tibor</option>
# <option value="adamek_alma">Adamek Alma</option>
# <option value="aghassi_attila">Ághassi Attila</option>
# <option value="ago_bela">Ágó Béla</option>
# <option value="agoston_zoltan">Ágoston Zoltán</option>
# <option value="ajpek_orsi">Ajpek Orsi</option>
# <option value="ambrus_adam">Ambrus Ádám</option>
# <option value="ambrus_balazs">Ambrus Balázs</option>
# <option value="andacs_botond">Andacs Botond</option>
# <option value="androczi_balazs">Andróczi Balázs</option>
# <option value="antalics_adam">Antalics Ádám</option>
# <option value="aradi_laszlo">Aradi László</option>
# <option value="aranyi_vanda">Arányi Vanda</option>
# <option value="arato_laszlo">Arató László</option>
# <option value="arnotszky_janka_judi">Arnótszky Judit Janka</option>
# <option value="arvai_peter">Árvai Péter</option>
# <option value="bacsanyi_peter">Bacsányi Péter</option>
# <option value="bakcsy_arpad">Bakcsy Árpád</option>
# <option value="bakro-nagy_ferenc">Bakró-Nagy Ferenc</option>
# <option value="baksa_roland">Baksa Roland</option>
# <option value="balazs_barbara">Balázs Barbara</option>
# <option value="balazsi_levente">Balázsi Levente</option>
# <option value="balint_agnes">Bálint Ágnes</option>
# <option value="balint_lilla">Bálint Lilla</option>
# ...
#                 Settenkedő járművek veszélyeztetik a gyalogosokat, de van megoldás            </a>
# </h2>
# <div class="ajanlo">
#             Rászokunk a fülelésre.        </div>
# </article>
# <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717255380">tegnap, 17:23</span>
# <span class="separator"></span>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/amerikai-egyesult-allamok-korrupcio-botrany-vesztegetes-robert-burke-haditengereszet-admiralis/" title="Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát">
# <img alt="Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566104/56610407_4185763_cb0fbc3a19102aa68e51461586144fba_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/amerikai-egyesult-allamok-korrupcio-botrany-vesztegetes-robert-burke-haditengereszet-admiralis/" title="Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát">
#                 Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát            </a>
# </h2>
# <div class="ajanlo">
#             Átszámítva 180 millió forintos éves fizetéssel sikerült lekenyerezni.        </div>
# </article>
# <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717254240">tegnap, 17:04</span>
# <span class="separator"></span>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a href="https://index.hu/sport/atletika/2024/06/01/atletika-olimpiai-bajnok-atlanta-gatfutas-sydney-mclaughlin-levrone-edwin-moses-classic/" title="Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle">
# <img alt="Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle" loading="lazy" src="https://kep.index.hu/1/0/5660/56609/566095/56609519_4185695_c38d52cdd5b5c69339ebe99487f2e8a4_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/atletika/2024/06/01/atletika-olimpiai-bajnok-atlanta-gatfutas-sydney-mclaughlin-levrone-edwin-moses-classic/" title="Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle">
#                 Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle            </a>
# </h2>
# <div class="ajanlo">
#             Az amerikai világcsúcstartó legutóbb 2022 augusztusában állt rajthoz ebben a számban.        </div>
# </article>
# <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717254180">tegnap, 17:03</span>
# <span class="separator"></span>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/tompos-katya-szineszno-halala-utolso-interju/" title="Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában">
# <img alt="Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566102/56610275_4185755_e063e7ef91d269bd87be58cfc9e5a77b_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/tompos-katya-szineszno-halala-utolso-interju/" title="Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában">
#                 Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában            </a>
# </h2>
# <div class="ajanlo">
#             Több mint egy éve készült a műsor.        </div>
# </article>
# <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717254120">tegnap, 17:02</span>
# <span class="separator"></span>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/haboru-oroszorszag-ukrajna-europai-csapatok-ukrajnaban-glen-grant-brit-ezredes/" title="Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni">
# <img alt="Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566102/56610249_4185753_ca26c56dc70528826639b79b2478b300_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/haboru-oroszorszag-ukrajna-europai-csapatok-ukrajnaban-glen-grant-brit-ezredes/" title="Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni">
#                 Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni            </a>
# </h2>
# <div class="ajanlo">
#             „Amit eddig tettek, az nem volt elég hatással Oroszországra” – mondta.        </div>
# </article>
# <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717253940">tegnap, 16:59</span>
# <span class="separator"></span>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/magyar-peter-partizan-gulyas-marton-tisza-program/" title="Nem kímélték Magyar Pétert, minden kikerült az asztalra">
# <img alt="Nem kímélték Magyar Pétert, minden kikerült az asztalra" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566101/56610107_4185741_d13245e341d14d4d2d4b900e83fd0ff8_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/magyar-peter-partizan-gulyas-marton-tisza-program/" title="Nem kímélték Magyar Pétert, minden kikerült az asztalra">
#                 Nem kímélték Magyar Pétert, minden kikerült az asztalra            </a>
# </h2>
# <div class="ajanlo">
#             Gulyás Márton szerint hajlamos a nagyotmondásra a Tisza Párt alelnöke.        </div>
# </article>
# <article class="rovatajanlo normal left">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717253700">tegnap, 16:55</span>
# <span class="separator"></span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">Mindeközben</a>
# </li>
# </ul>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/kiraly-viktor-magyar-akcentus-parodia/" title="Király Viktor kiparodizálta a magyarok akcentusos angolját">
#                 Király Viktor kiparodizálta a magyarok akcentusos angolját            </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>
# <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/belfold/2024/06/01/orban-viktor-beszed-bekemenet-valasztasok-haboru/" title="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje">
# <img alt="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje" loading="lazy" src="https://kep.index.hu/1/0/5660/56609/566098/56609867_4185723_e6b8b4d0d0ff561d1f7cbd755727a428_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/orban-viktor-beszed-bekemenet-valasztasok-haboru/" title="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje">
#                         Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje                    </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/peter_alvarez">
# <img alt="Péter Alvarez" class="szerzo-kep" src="https://kep.index.hu/1/0/4903/49034/490344/49034444_3737960_b998b0087613d5288b147749af5e46d1_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/peter_alvarez" rel="author">Péter Alvarez</a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1532"></span>
# </div>
# </div>
# </div>
# <div class="datum">
#                         2024.06.01. 16:52                        <span class="modositas-datuma-gomb" title="Módosítás dátuma">Módosítva: 2024-06-02 06:58:29</span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#             A miniszterelnök beszédével ért véget a Békemenet.        </div>
# </article>
# </main>
# <div class="clear"></div>
# </div>
# <footer class="m-page-footer">
# <div class="container m-page-footer_container">
# <ul class="m-page-footer_container_list">
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fimpresszum%2F">Impresszum</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findamediasales.hu%2F">Médiaajánlat</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fcopyright%2F">Szerzői jogok</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fadatvedelem%2F">Adatvédelmi elvek</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fsutiszabalyzat%2F">Süti szabályzat</a>
# </li>
# <li class="m-page-footer_container_list_item hasText">
# <a class="change-consent m-page-footer_container_list_item_link" onclick="window.__tcfapi('displayConsentUi', 2, function() {} );">Süti beállítások</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2F24ora%2Frss%2F">RSS</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Finfo%2Fallas%2F">Állás</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Fajanlat.indamediasales.hu%2Fmarkabiztonsag%2FIndamedia_Sales_Markabiztonsagi_nyilatkozat.pdf">Márkabiztonság</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fdsa" target="_blank">DSA</a>
# </li>
# <li class="m-page-footer_container_list_item hasText">
# <span class="m-page-footer_container_list_item_text">© 1999-2024 <span>Index.hu</span> Zrt.</span>
# </li>
# </ul>
# </div>
# </footer>
# <div class="layout_watcher phone"></div>
# <div class="layout_watcher portrait-tablet"></div>
# <div class="layout_watcher landscape-tablet"></div>
# <div class="layout_watcher desktop"></div>
# <div class="newsletter_modal" id="newsletterModal"></div>
# <script>
#     new NewsletterModal( document.getElementById('newsletterModal'), {'assetUrl': 'https://index.hu/assets/'});
# </script>
# <script>
#         var bodyContent = '';
#         $emailAdress = 'bla';
#                 bodyContent = 'Olvasói levelet, meghívót, sajtóközleményt készül küldeni a(z) <strong><a href="mailto:{emailAddress}" target="_blank" class="email">{emailShow}</a></strong> címen a szerkesztőségnek. Fontos nekünk, ezért az adataira is nagyon vigyázunk, ahogy az <a href="https://index.hu/adatvedelem" target="_blank">adatvédelmi tájékoztatónkban</a> részletezzük is. Ha Önnek is oké, kattintson az OK gombra.';
#         bodyContentMeghivo = 'Nyilatkozatot, bejelentést, vagy felhasználási kérelmet készül küldeni a(z) <strong><a href="mailto:{emailAddress}" target="_blank" class="email">{emailShow}</a></strong> címen a lapigazgatónak.Fontos nekünk, ezért az adataira is nagyon vigyázunk, ahogy az <a href="https://index.hu/adatvedelem" target="_blank">adatvédelmi tájékoztatónkban</a> részletezzük is. Ha Önnek is oké, kattintson az OK gombra.'
#
#         $(document).ready(function() {
#
#             $('a.email').on('click', function(e) {
#                 e.preventDefault();
#
#                 if (
#                     // Csak akkor jelenítjük meg a modal ablakot, ha ezeknek a feltételeknek valamelyike teljesül
#                     $(this).hasClass('irok_neki') ||               // Ha írok neki típusú a link vagy
#                     $(this).attr('href').indexOf('mailto:') !== -1  // van mailto link a href-ben
#                 ) {
#
#
#                     var emailAddress = $(this).attr('href')
#                         .replace('mailto:', '')
#                         .replace('NEMSPA_M.', '');
#
#                     var emailShow = emailAddress.match(/([a-zA-Z0-9._+-]+@[a-zA-Z0-9._-]+\.[a-zA-Z0-9._-]+)/)[0];
#
#                     var content = $(e.target).hasClass('meghivo') ? bodyContentMeghivo.replace(/{emailAddress}/gi, emailAddress).replace(/{emailShow}/g, emailShow) : bodyContent.replace(/{emailAddress}/gi, emailAddress).replace(/{emailShow}/g, emailShow);
#
#                     var mailtoModal = new vModal({
#                         title: 'Adatvédelmi tájékoztatás',
#                         body: content,
#                         buttons: {
#                             more: 'Vissza',
#                             confirm: 'OK'
#                         },
#                         className: 'vanilla_modal--basic',
#                         events: {
#                             confirm: function() {
#                                 //chrome miatt kell új lapon megnyitni, különben nem működik!
#                                 window.open('mailto:' + emailAddress, '_blank');
#                             }
#                         }
#                     });
#
#                     mailtoModal.open();
#
#                 }
#
#             });
#
#         });
#     </script>
# <script type="text/javascript">
#             <!--//--><![CDATA[//><!--
#             var pp_gemius_identifier = pp_gemius_original_identifier = new String('B9OVVi_kSaN4kjyXnmrlRnaITKLZOwR45wv6Si7xT2f.S7'); <!-- 24 óra -->
#             var pp_gemius_use_cmp = true;
#             var pp_gemius_cmp_timeout = Infinity;
#             //--><!]]>
#         </script>
# <script type="text/javascript">
#             <!--//--><![CDATA[//><!--
#             function gemius_pending(i) { window[i] = window[i] || function() {var x = window[i+'_pdata'] = window[i+'_pdata'] || []; x[x.length]=arguments;};};
#             gemius_pending('gemius_hit'); gemius_pending('gemius_event');
#             gemius_pending('pp_gemius_hit'); gemius_pending('pp_gemius_event');
#
#             (function(d,t) {try {
#             var gt=d.createElement(t),s=d.getElementsByTagName(t)[0],l='http'+((location.protocol=='https:')?'s':'');
#             gt.setAttribute('async','async');
#             gt.setAttribute('defer','defer');
#             gt.src=l+'://gahu.hit.gemius.pl/xgemius.js';
#             s.parentNode.insertBefore(gt,s);}
#             catch (e) {}})(document,'script');
#             //--><!]]>
#         </script>
# <script type="text/javascript">
#             var gemABObj = {
#                 docBody: document.getElementsByTagName('body')[0],
#                 incScript: document.createElement('SCRIPT'),
#                 checkIt: function(){document.getElementById("mnxHDozyKPjB")?pp_gemius_hit("nSdFzTtkvTTrx.B7K13yyfU378aFPueKFs36aeS6yET.A7","addon=no-adblock"):pp_gemius_hit("nSzrCTsGCKuF9KNE6iWTitVrzbu1Eg8GQHsHaml5W8n.b7","addon=adblock")}
#             };
#             gemABObj.incScript.src = '//indexhu.adocean.pl/files/x/mof/ghshscq/xajkevmjdv/ads.js';
#             gemABObj.docBody.appendChild(gemABObj.incScript);
#
#             window.addEventListener("load",gemABObj.checkIt);
#         </script>
# </body>
# </html>

# %%
f = open("sample_index.html", "r", encoding="utf-8")
soup = bs(f, "html.parser")

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="hu" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <head>
# <title>
#    Hírek - 24 óra - Index.hu
#   </title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=EmulateIE11" http-equiv="X-UA-Compatible"/>
# <!-- [if IE]>
#         <meta http-equiv="imagetoolbar" content="no" />
#         <meta name="MSSmartTagsPreventParsing" content="true" />
#         <meta http-equiv="X-UA-Compatible" content="IE=Edge">
#         <![endif]-->
# <meta content="1717276106" name="manis:deploy"/>
# <meta name="manis:breakpoint">
# <meta name="manis:breakpoints"/>
# <meta content="https://index.hu/copyright/" name="copyright"/>
# <meta content="unsafe-url" name="referrer">
# <meta content="app-id=480103271" name="apple-itunes-app"/>
# <meta content="app-id=com.aff.index.main" name="google-play-app"/>
# <meta content="noindex" name="robots"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="330827937019153" property="fb:app_id"/>
# <meta content="667823645" property="fb:admins"/>
# <meta content="560525343980775,348326671885918" property="fb:pages"/>
# <meta content="Friss hírek és információk az Indexen" name="description"/>
# <meta content="https://index.hu/assets/images/facebook_logo.png?v5" property="og:image">
# <meta content="https://www.facebook.com/Indexhu" property="article:publisher">
# <meta content="summary_large_image" name="twitter:card">
# <meta content="@indexhu" name="twitter:site">
# <meta content="https://index.hu/assets/images/facebook_logo.png" name="twitter:image:src">
# <link href="/assets/static/opensearch.xml" rel="search" title="Index" type="application/opensearchdescription+xml"/>
# <link href="/copyright/" rel="copyright" title="Szerzői jogok"/>
# <link href="/impresszum/" rel="author" title="Impresszum"/>
# <link href="/" id="homelink" rel="home" title=""/>
# <link href="/assets/images/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/assets/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/assets/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/assets/images/favicons/manifest.json" rel="manifest"/>
# <link href="/assets/images/favicons/favicon.ico" rel="shortcut icon"/>
# <link color="#ff9900" href="/assets/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="Index" name="apple-mobile-web-app-title"/>
# <meta content="Index" name="application-name"/>
# <meta content="#ffffff" name="theme-color"/>
# <script type="text/javascript">
#           var _sf_startpt=(new Date()).getTime()
#          </script>
# <link href="https://index.hu/assets/static/indexnew_css/public/global.css?v=1717276080" rel="stylesheet" type="text/css"/>
# <link href="https://index.hu/assets/static/indexnew_css/public/index-global.css?v=1717276080" rel="stylesheet" type="text/css"/>
# <link href="https://index.hu/assets/static/indexnew_css/public/rovat.css?v=1717276080" rel="stylesheet" type="text/css"/>
# <link href="https://index.hu/assets/static/indexnew_css/public/fixed_header.css?v=1717276080" rel="stylesheet" type="text/css"/>
# <link href="https://index.hu/assets/static/indexnew_css/public/24ora.css?v=1717276080" rel="stylesheet" type="text/css"/>
# <link href="/24ora/rss/" rel="alternate" title="24óra cikkek" type="application/rss+xml"/>
# <meta content="1" name="logcustomtarget"/>
# <!-- i8 -->
# <script src="https://index.hu/ident/getall/?c=aTg=" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/static/js/public/index_vendor.ugly.js?v=1717276081" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/static/js/public/index_base.ugly.js?v=1717276081" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/static/js/public/index_election.ugly.js?v=1717276081" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/static/js/public/cemp_fejlec.ugly.js?v=1717276081" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/index.rovat.min.js?v=1710407521" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/autocomplete.min.js?v=1717276106" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/calendar.min.js?v=1717276106" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/chosen2.min.js?v=1717276106" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/jquery-ui.min.js?v=1717276106" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/index.24ora.min.js?v=1717276106" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/scrolling_shadow.js?v=1717276106" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/pip_video.min.js?v=1717276106" type="text/javascript">
# </script>
# <script type="text/javascript">
#                  var _gaq = { push: function() {} };
#         ( function( i, s, o, g, r, a, m ) {
#             i[ 'GoogleAnalyticsObject' ] = r;
#             i[ r ] = i[ r ] || function() {
#                 ( i[ r ].q = i[ r ].q || [] ).push( arguments )
#             }, i[ r ].l = 1 * new Date();
#             a = s.createElement( o ), m = s.getElementsByTagName( o )[ 0 ];
#             a.async = 1;
#             a.src=g;
#             m.parentNode.insertBefore( a, m )
#         } )( window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga' );
#         var oldaltipus = '24ora_cimlap';
#         ( function( $ ) {
#             window.scrollTrackerEnabled = 1;
#             window.Analytics = {
#                 add: function( command, params, target ) {
#                     if( typeof command === 'undefined' || typeof params === 'undefined' || !command || !params ) {
#                         return this;
#                     }
#                     params.location = ( params.location || document.location.href ).replace( '//m.', '//' );
#                     if( this.loaded ) {
#                         if( typeof target !== 'undefined' ) {
#                             command = target + '.' + command;
#                         }
#                         ga( command, params );
#                     }
#                     else {
#                         this.stack.push( [ command, $.extend( {}, params ), target ] );
#                     }
#                     return this;
#                 },
#                 process: function() {
#                     if( this.loaded ) {
#                         return;
#                     }
#                     var arg;
#                     while( this.stack.length ) {
#                         arg = this.stack.shift();
#                         if( typeof arg[ 2 ] !== 'undefined' && Common[ 'ga_' + arg[ 2 ] ] === true ) {
#                             arg[ 0 ] = arg[ 2 ] + '.' + arg[ 0 ];
#                         }
#                         ga( arg[ 0 ], arg[ 1 ] );
#                     }
#                     this.loaded = true;
#                 },
#                 stack: []
#             };
#             $( document ).on( 'ready', function() {
#                 if( typeof window.Common === 'undefined' ) {
#                     window.Common = {
#                         ga_secondary: false
#                     };
#                 }
#                 if( typeof __passportHeader_config === 'undefined' ) {
#                     __passportHeader_config = {};
#                 }
#                 Common.ga_secondary = false;
#                 var ga_base_config = {
#                     sampleRate: 100,
#                     trackingId: 'UA-181415-27'
#                 };
#                 var ga_set_config = {
#                     dimension1: '24ora_cimlap',
#                     dimension2: ( __passportHeader_config.loggedIn ? '' : 'Not' ) + 'LoggedIn',
#                                             dimension3: Page.getLayout(),
#                                                                                 language: document.domain === 'totalcarmagazine.com' ? 'en-us' : 'hu-hu',
#                     location: document.location.href.replace( '//m.', '//' )
#                 };
#                 if( typeof __passportHeaderUserId !== 'undefined' ) {
#                     ga_base_config.userId = __passportHeaderUserId;
#                 }
#                 ga( 'create', ga_base_config );
#                 ga( 'require', 'displayfeatures' );
#                 ga( 'set', ga_set_config );
#                                     Common.ga_secondary = true;
#                     var ga_secondary_config = $.extend( {}, ga_base_config );
#                     ga_secondary_config.name = 'secondary';
#                     ga_secondary_config.trackingId = 'UA-181415-11';
#                     ga_secondary_config.sampleRate = 10;
#                     ga( 'create', ga_secondary_config );
#                     ga( 'secondary.require', 'displayfeatures' );
#                     ga( 'secondary.set', ga_set_config );
#                                 ga('set', 'anonymizeIp', true);
#                 // cross_site ajanlo kivetelkezelese
#                 if(
#                     (
#                         $( '#passportHeader, #_iph_fixed-header' ).length ||
#                         $( '#inforadio_audioplayer1' ).length ||
#                         $( '.header_send').length ||
#                         document.location.host.indexOf( 'm.' ) === 0 ||
#                         document.location.host.substring( document.location.host.length - 4 ) === '.com'
#                     ) &&
#                     ((Common.topfolder !== 'i2' && Common.topfolder !== 'index2') || !Common.parsed_url.hash || Common.parsed_url.hash.indexOf( '#bloghu' ) !== 0 )
#                 ) {
#                     ga( 'send', 'pageview' );
#                     if( Common.ga_secondary ) {
#                         ga( 'secondary.send', 'pageview' );
#                     }
#                 }
#                 Analytics.process();
#             } );
#         } )( jQuery );
#                 </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-7GR3T85C96">
# </script>
# <script>
#                  window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         var ga4params = {"content_group":"24ora\/","rovat":"24\u00f3ra","oldaltipus":"24ora_cimlap","cikktipus":"Keres\u0151"};
#         ga4params.layout = Page.getLayout();
#         ga4params.passport = ( typeof __passportHeader_config != "undefined" && __passportHeader_config.loggedIn ? '' : 'Not' ) + 'LoggedIn';
#         gtag('js', new Date());
#         gtag('config', 'G-7GR3T85C96', ga4params);
#                 </script>
# <!-- Google Tag Manager -->
# <script>
#                  (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-PPDGL3DR');
#                 </script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript">
#                  Common.folder_id = 267;
#         Common.folder_parent_ids = [ 261 ];
#         Common.is_new_design = 1;
#                 </script>
# <script>
#                  window.fbAsyncInit = function() {
#         FB.init({
#             appId      : '330827937019153',
#             xfbml      : true,
#             status     : false,
#             version    : 'v5.0'
#         });
#         window.fb_initialized = true;
#     };
#
#     (function(d, s, id) {
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) return;
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/hu_HU/sdk.js";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
#                 </script>
# <script type="text/javascript">
#                  $(function () {
#             window.LinkPreview && window.LinkPreview.init();
#         });
#                 </script>
# <script type="text/javascript">
#                  <!--//--><![CDATA[//><!--
#     var IndexStatConfig = {
#         pixels: [ { id: 267, type: 2 }, { id: 261, type: 3 }, { id: 1, type: 5 }, { id: 2, type: 4 }],
#         device: 'desktop'
#     }
#     //--><!]]>
#                 </script>
# <script async="" src="//indexstat.index.hu/stat.min.js?dd=20240602" type="text/javascript">
# </script>
# <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script async="true" type="text/javascript">
#                  var nuCmp = true; try { Promise.resolve(1).finally() } catch(e) { nuCmp = false; }
#     if (nuCmp) {
#         (function() {
#             var host = 'index.hu';
#             var element = document.createElement('script');
#             var firstScript = document.getElementsByTagName('script')[0];
#             var url = 'https://cmp.quantcast.com'
#                 .concat('/choice/', '4z9XXyvnuPTjK', '/', host, '/choice.js?tag_version=V2');
#             var uspTries = 0;
#             var uspTriesLimit = 3;
#             element.async = true;
#             element.type = 'text/javascript';
#             element.src = url;
#
#             firstScript.parentNode.insertBefore(element, firstScript);
#
#             function makeStub() {
#                 var TCF_LOCATOR_NAME = '__tcfapiLocator';
#                 var queue = [];
#                 var win = window;
#                 var cmpFrame;
#
#                 function addFrame() {
#                     var doc = win.document;
#                     var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#                     if (!otherCMP) {
#                         if (doc.body) {
#                             var iframe = doc.createElement('iframe');
#
#                             iframe.style.cssText = 'display:none';
#                             iframe.name = TCF_LOCATOR_NAME;
#                             doc.body.appendChild(iframe);
#                         } else {
#                             setTimeout(addFrame, 5);
#                         }
#                     }
#                     return !otherCMP;
#                 }
#
#                 function tcfAPIHandler() {
#                     var gdprApplies;
#                     var args = arguments;
#
#                     if (!args.length) {
#                         return queue;
#                     } else if (args[0] === 'setGdprApplies') {
#                         if (
#                             args.length > 3 &&
#                             args[2] === 2 &&
#                             typeof args[3] === 'boolean'
#                         ) {
#                             gdprApplies = args[3];
#                             if (typeof args[2] === 'function') {
#                                 args[2]('set', true);
#                             }
#                         }
#                     } else if (args[0] === 'ping') {
#                         var retr = {
#                             gdprApplies: gdprApplies,
#                             cmpLoaded: false,
#                             cmpStatus: 'stub'
#                         };
#
#                         if (typeof args[2] === 'function') {
#                             args[2](retr);
#                         }
#                     } else {
#                         if(args[0] === 'init' && typeof args[3] === 'object') {
#                             args[3] = { ...args[3], tag_version: 'V2' };
#                         }
#                         queue.push(args);
#                     }
#                 }
#
#                 function postMessageEventHandler(event) {
#                     var msgIsString = typeof event.data === 'string';
#                     var json = {};
#
#                     try {
#                         if (msgIsString) {
#                             json = JSON.parse(event.data);
#                         } else {
#                             json = event.data;
#                         }
#                     } catch (ignore) {}
#
#                     var payload = json.__tcfapiCall;
#
#                     if (payload) {
#                         window.__tcfapi(
#                             payload.command,
#                             payload.version,
#                             function(retValue, success) {
#                                 var returnMsg = {
#                                     __tcfapiReturn: {
#                                         returnValue: retValue,
#                                         success: success,
#                                         callId: payload.callId
#                                     }
#                                 };
#                                 if (msgIsString) {
#                                     returnMsg = JSON.stringify(returnMsg);
#                                 }
#                                 if (event && event.source && event.source.postMessage) {
#                                     event.source.postMessage(returnMsg, '*');
#                                 }
#                             },
#                             payload.parameter
#                         );
#                     }
#                 }
#
#                 while (win) {
#                     try {
#                         if (win.frames[TCF_LOCATOR_NAME]) {
#                             cmpFrame = win;
#                             break;
#                         }
#                     } catch (ignore) {}
#
#                     if (win === window.top) {
#                         break;
#                     }
#                     win = win.parent;
#                 }
#                 if (!cmpFrame) {
#                     addFrame();
#                     win.__tcfapi = tcfAPIHandler;
#                     win.addEventListener('message', postMessageEventHandler, false);
#                 }
#             };
#
#             makeStub();
#
#             var uspStubFunction = function() {
#                 var arg = arguments;
#                 if (typeof window.__uspapi !== uspStubFunction) {
#                     setTimeout(function() {
#                         if (typeof window.__uspapi !== 'undefined') {
#                             window.__uspapi.apply(window.__uspapi, arg);
#                         }
#                     }, 500);
#                 }
#             };
#
#             var checkIfUspIsReady = function() {
#                 uspTries++;
#                 if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#                     console.warn('USP is not accessible');
#                 } else {
#                     clearInterval(uspInterval);
#                 }
#             };
#
#             if (typeof window.__uspapi === 'undefined') {
#                 window.__uspapi = uspStubFunction;
#                 var uspInterval = setInterval(checkIfUspIsReady, 6000);
#             }
#         })();
#     }
#                 </script>
# <!-- End Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script src="//indexhu.adocean.pl/files/js/ado.js" type="text/javascript">
# </script>
# <script>
#                  window.adocf = {};
#     window.adocf.useDOMContentLoaded = true;
#     window.iap_base = 'https://index.hu/';
#     var tagStr = document.querySelector('meta[name="keywords"]') ? document.querySelector('meta[name="keywords"]').getAttribute("content").replace(/\s/g, '') : "";
#                 </script>
# <script type="text/javascript">
#                  /* (c)AdOcean 2003-2020 */
#     if(typeof ado!=="object"){ado={};ado.config=ado.preview=ado.placement=ado.master=ado.slave=function(){};}
#     ado.config({mode: "new", xml: false, consent: true, characterEncoding: true, attachReferrer: true, fpc: "auto" , defaultServer:"indexhu.adocean.pl" ,cookieDomain:"SLD"});
#     ado.preview({enabled: true});
#     /* (c)AdOcean 2003-2020, MASTER: c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87 */
#     ado.master({id: 'c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87', server: 'indexhu.adocean.pl', vars: typeof customTargetAdocean !== "undefined" ? customTargetAdocean : '', keys: tagStr });
#                 </script>
# <script type="module">
#                  document.addEventListener('DOMContentLoaded', async () => {
#         const { Loader } = await (await import('https://iap.cdn.indexvas.hu/Scripts.js')).default;
#         window.GoaLoader = new Loader({"debug":false,"engine":"AdOcean","master":"c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87","stat":true})
#     })
#                 </script>
# <script type="text/javascript">
#                  Common.maxFeedAjanloLoadCount = 1;
#     Common.feedAjanloLoadCount = 3;
#     Common.feedAjanloMoreButton = 1;
#     Common.feedAjanloTovabbUrl = "https://index.hu/24ora/";
#                 </script>
# <link href="/manifest.json" rel="manifest">
# <script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js">
# </script>
# <script>
#                  var OneSignal = window.OneSignal || [];
#     OneSignal.push(function() {
#         OneSignal.sendTags({
#             is_web: true
#         });
#         OneSignal.init({
#             appId: "bd30d7a1-7b22-4adb-bacf-e4bf80d25bf7",
#             autoRegister: false,
#             notifyButton: {
#                 enable: true
#             }
#         });
#     });
#                 </script>
# <script>
#                  window.googletag = window.googletag || {cmd: []};
#     googletag.cmd.push(function() {
#                 googletag.pubads().enableSingleRequest();
#                 googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#             if(!event.isEmpty) {
#                 $(document.getElementById(event.slot.getSlotElementId())).closest(".mobile-sticky").show().find("button.mobile-sticky-closing").on("click", function(){
#                     $(this).closest(".mobile-sticky").hide();
#                 });
#             }
#         });
#         googletag.enableServices();
#     });
#                 </script>
# </link>
# </meta>
# </meta>
# </meta>
# </meta>
# </meta>
# </meta>
# </meta>
# </head>
# <body class="device_desktop indexhu rovat h24ora rovat_24ora iframe_disallowed">
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PPDGL3DR" style="display:none;visibility:hidden" width="0">
# </iframe>
# </noscript>
# <div id="fb-root">
# </div>
# <script>
#    (function() {
#   var _fbq = window._fbq || (window._fbq = []);
#   if (!_fbq.loaded) {
#     var fbds = document.createElement('script');
#     fbds.async = true;
#     fbds.src = '//connect.facebook.net/en_US/fbds.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(fbds, s);
#     _fbq.loaded = true;
#   }
#   _fbq.push(['addPixelId', '551982981568628']);
# })();
# window._fbq = window._fbq || [];
# window._fbq.push(['track', 'PixelInitialized', {}]);
#   </script>
# <noscript>
# <img alt="" height="1" src="https://www.facebook.com/tr?id=551982981568628&amp;ev=PixelInitialized" style="display:none" width="1"/>
# </noscript>
# <div class="layer xl_layer">
# <div class="iap iap--ado ad-label--hidden no-padding no-margin" data-id="adoceanindexhulmgghmhsud" id="adoceanindexhulmgghmhsud">
# <script class="iap-script">
#      window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhulmgghmhsud","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_Layer","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#     </script>
# </div>
# <div class="iap iap--ado ad-label--hidden no-padding no-margin" data-id="ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7" id="ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7">
# <script class="iap-script">
#      window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7","empty":true,"lazy":false,"quality":false,"masterless":true,"area":"Index_Aloldalak_Layer_gde_test","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#     </script>
# </div>
# </div>
# <div class="sticky">
# </div>
# <div class="container" id="ad_null_position">
# </div>
# <div aria-hidden="true" class="m-cf-search modal" data-backdrop="false" data-js-modal-window="search" role="dialog" style="display: none" tabindex="-1">
# <div class="m-cf-search_wrapper">
# <div class="m-cf-search_wrapper_container" data-js-cemp-search="container">
# <form action="https://index.hu/24ora/" class="m-cf-search_wrapper_container_form" method="get">
# <input name="word" type="hidden" value="1"/>
# <input name="pepe" type="hidden" value="1"/>
# <input name="tol" type="hidden" value="1999-01-01"/>
# <input name="ig" type="hidden" value="2024-06-02"/>
# <input class="m-cf-search_wrapper_container_form_input" data-js-cemp-search="input" name="s" placeholder="Keresés" tabindex="0" type="search"/>
# <button class="m-cf-search_wrapper_container_form_button" type="submit">
# <span class="m-cf-search_wrapper_container_form_button_wrapper">
# <svg class="m-cf-search_wrapper_container_form_button_wrapper_icon" style="height:21px;width:21px;" viewbox="0 0 21 21">
# <path d="M20.8 18.867c.267.267.267.7 0 .967l-.966.967c-.267.267-.7.267-.966 0L13.5 15.434c-.073-.074-.122-.16-.155-.253-1.39 1.014-3.094 1.62-4.944 1.62-4.64 0-8.4-3.76-8.4-8.4C0 3.76 3.76 0 8.4 0c4.64 0 8.4 3.76 8.4 8.4 0 1.85-.606 3.556-1.62 4.945.092.032.18.08.253.155l5.368 5.367zM8.4 2.8c-3.093 0-5.6 2.507-5.6 5.6 0 3.093 2.507 5.6 5.6 5.6 3.093 0 5.6-2.507 5.6-5.6 0-3.093-2.507-5.6-5.6-5.6z">
# </path>
# </svg>
# <span class="m-cf-search_wrapper_container_form_button_wrapper_label h-visibility-off_small-down">
#          Keresés
#         </span>
# </span>
# </button>
# </form>
# </div>
# </div>
# </div>
# <div class="m-cf-indalista" data-js-dropdown="inda">
# <div class="m-cf-indalista_container">
# <ul class="m-cf-indalista_container_list">
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="blog.hu" href="https://blog.hu/" target="_blank">
#        Blog.hu
#       </a>
# </li>
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="forum" href="http://forum.index.hu/Topic/showTopicList" target="_blank">
#        Fórum
#       </a>
# </li>
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="indavideo" href="http://indavideo.hu/" target="_blank">
#        Indavideó
#       </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-cf-kiadvanylista">
# <div class="m-cf-kiadvanylista_container">
# <ul class="m-cf-kiadvanylista_container_list">
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Economx" data-target="economx" href="https://www.economx.hu" target="_blank">
#        Economx
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Dívány" data-target="divany" href="https://divany.hu/" target="_blank">
#        Dívány
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Totalcar" data-target="totalcar" href="https://totalcar.hu/" target="_blank">
#        Totalcar
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Femina" data-target="femina" href="https://femina.hu/" target="_blank">
#        Femina
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Port" data-target="port" href="https://port.hu/" target="_blank">
#        Port
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="We ❤︎ Budapest" data-target="we_x2764_xfe0e_budapest" href="https://welovebudapest.com/" target="_blank">
#        We ❤︎ Budapest
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Velvet" data-target="velvet" href="https://velvet.hu/" target="_blank">
#        Velvet
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <button class="m-cf-kiadvanylista_container_list_item_inda" data-target="[data-js-dropdown=inda]" data-toggle="dropdown" type="button">
# <span class="m-cf-kiadvanylista_container_list_item_inda_container">
# <span class="m-cf-kiadvanylista_container_list_item_inda_container_label">
#          Inda
#         </span>
# <svg class="m-cf-kiadvanylista_container_list_item_inda_container_icon" viewbox="0 0 11 7">
# <path d="M5.5 5.125L1.032.657C.846.47.534.467.344.657c-.185.184-.19.497 0 .687l4.812 4.812c.092.092.217.14.342.14.125 0 .25-.045.346-.14l4.812-4.812c.185-.185.19-.498 0-.688-.184-.184-.498-.19-.688 0L5.5 5.127z">
# </path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-cf-fejlec">
# <div class="m-cf-fejlec_container">
# <div class="m-cf-fejlec_container_wrapper">
# <ul class="m-cf-fejlec_container_links">
# <li class="m-cf-fejlec_container_links_item itemCover">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Címlap" href="https://dex.hu/x.php?id=fxdfejlecpnc&amp;url=https%3A%2F%2Findex.hu%2F">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_logo" viewbox="-54 12 8 20">
# <path class="m-cf-fejlec_container_links_item_link_container_logo_stem" d="M-54 18h8v14h-8V18z">
# </path>
# <path class="m-cf-fejlec_container_links_item_link_container_logo_dot" d="M-54 12h8v4h-8v-4z">
# </path>
# </svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">
#           Címlap
#          </span>
# </span>
# </a>
# </li>
# <li class="m-cf-fejlec_container_links_item itemHeadings">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Rovatok" href="https://dex.hu/x.php?id=fxdfejlec&amp;url=https%3A%2F%2Findex.hu%2Frovatok">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_icon iconHamburger" viewbox="0 0 22 17">
# <path d="M0 1.5C0 .672.67 0 1.495 0h19.01C21.33 0 22 .666 22 1.5c0 .828-.67 1.5-1.495 1.5H1.495C.67 3 0 2.334 0 1.5zm0 7C0 7.672.67 7 1.495 7h19.01C21.33 7 22 7.666 22 8.5c0 .828-.67 1.5-1.495 1.5H1.495C.67 10 0 9.334 0 8.5zm0 7c0-.828.67-1.5 1.495-1.5h19.01c.826 0 1.495.666 1.495 1.5 0 .828-.67 1.5-1.495 1.5H1.495C.67 17 0 16.334 0 15.5z">
# </path>
# </svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">
#           Rovatok
#          </span>
# </span>
# </a>
# </li>
# <li class="m-cf-fejlec_container_links_item itemLatest">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Legfrissebbek" href="https://dex.hu/x.php?id=fxdfejlec&amp;url=https%3A%2F%2Findex.hu%2F24ora">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_icon iconClock" viewbox="0 0 22 22">
# <path d="M11 19.25c-4.557 0-8.25-3.693-8.25-8.25S6.443 2.75 11 2.75s8.25 3.693 8.25 8.25-3.693 8.25-8.25 8.25M11 0C4.925 0 0 4.925 0 11s4.925 11 11 11 11-4.925 11-11S17.075 0 11 0">
# </path>
# <path d="M12.833 10.89V6.874c0-.76-.616-1.375-1.375-1.375-.76 0-1.375.616-1.375 1.375v5.04h.11l-.11.113 2.27 2.27c.536.535 1.406.535 1.943 0 .538-.538.538-1.41 0-1.946l-1.463-1.463z">
# </path>
# </svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">
#           Friss hírek
#          </span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# <div class="m-cf-fejlec_container_inda">
# <ul class="m-cf-fejlec_container_inda_kiadvanyok">
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Economx" data-target="economx" href="https://www.economx.hu" target="_blank">
#         Economx
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Dívány" data-target="divany" href="https://divany.hu/" target="_blank">
#         Dívány
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Totalcar" data-target="totalcar" href="https://totalcar.hu/" target="_blank">
#         Totalcar
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Femina" data-target="femina" href="https://femina.hu/" target="_blank">
#         Femina
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Port" data-target="port" href="https://port.hu/" target="_blank">
#         Port
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="We ❤︎ Budapest" data-target="we_x2764_xfe0e_budapest" href="https://welovebudapest.com/" target="_blank">
#         We ❤︎ Budapest
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Velvet" data-target="velvet" href="https://velvet.hu/" target="_blank">
#         Velvet
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <button class="m-cf-fejlec_container_inda_kiadvanyok_item_inda" data-target="[data-js-dropdown=inda]" data-toggle="dropdown" type="button">
# <span class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container">
# <span class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container_label">
#           Inda
#          </span>
# <svg class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container_icon" viewbox="0 0 11 7">
# <path d="M5.5 5.125L1.032.657C.846.47.534.467.344.657c-.185.184-.19.497 0 .687l4.812 4.812c.092.092.217.14.342.14.125 0 .25-.045.346-.14l4.812-4.812c.185-.185.19-.498 0-.688-.184-.184-.498-.19-.688 0L5.5 5.127z">
# </path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# <ul class="m-cf-fejlec_container_inda_actions">
# <li class="m-cf-fejlec_container_inda_actions_item itemSearch">
# <button class="m-cf-fejlec_container_inda_actions_item_button" data-ga-category="Keresés" data-js-cemp-search="button" data-target="[data-js-modal-window=search]" data-toggle="modal" type="button">
# <span class="m-cf-fejlec_container_inda_actions_item_button_wrapper">
# <svg class="m-cf-fejlec_container_inda_actions_item_button_wrapper_icon" viewbox="0 0 21 21">
# <path d="M20.8 18.867c.267.267.267.7 0 .967l-.966.967c-.267.267-.7.267-.966 0L13.5 15.434c-.073-.074-.122-.16-.155-.253-1.39 1.014-3.094 1.62-4.944 1.62-4.64 0-8.4-3.76-8.4-8.4C0 3.76 3.76 0 8.4 0c4.64 0 8.4 3.76 8.4 8.4 0 1.85-.606 3.556-1.62 4.945.092.032.18.08.253.155l5.368 5.367zM8.4 2.8c-3.093 0-5.6 2.507-5.6 5.6 0 3.093 2.507 5.6 5.6 5.6 3.093 0 5.6-2.507 5.6-5.6 0-3.093-2.507-5.6-5.6-5.6z">
# </path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# <div class="fixed-header">
# <script type="text/javascript">
#        (function() {
#         var sc = document.createElement('script'); sc.type = 'text/javascript'; sc.async = true;
#         sc.src = __passportHeader_config.HEADER_URL + 'passportHeader.js';
#        var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sc, s);
#     })();
#       </script>
# <div id="passportHeader" style="height: 36px; visibility: hidden;">
# </div>
# </div>
# </div>
# </div>
# </div>
# <section class="blokk hajtas-felett container index-header cimlap-blokk-index">
# <div class="index-header-wrapper">
# <a class="logo" data-ga-category="Index logó" href="/">
# </a>
# <ul class="trending-topics">
# <li stamp-index="0">
# <a class="cimke cimke-mufaj cimke-199435" href="https://dex.hu/x.php?id=inxcl_stamp&amp;url=https%3A%2F%2Findex.hu%2Fbajnokokligaja%23">
#        Bajnokok Ligája
#       </a>
# </li>
# </ul>
# <div class="header-parts">
# <div class="calendar">
# <time datetime="2024-06-02" title="22. hét">
#        2024. 06. 02. vasárnap
#       </time>
# <div id="name-day">
#        Anita, Kármen
#       </div>
# </div>
# <section class="exchange njs-carousel">
# <a class="exchange-ticker" data-g-category="Árfolyam" href="https://dex.hu/x.php?id=inxfejlec&amp;url=http%3A%2F%2Fportfoliofinancial.hu%2F" target="_blank" title="Forrás: portfoliofinancial.hu">
# <span class="currency-item goood">
# <span class="ticker">
#          EUR
#         </span>
# <span class="price">
#          389,48
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="currency-item baaad">
# <span class="ticker">
#          USD
#         </span>
# <span class="price">
#          359,02
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="currency-item baaad">
# <span class="ticker">
#          GBP
#         </span>
# <span class="price">
#          457,49
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="exchange-item baaad">
# <span class="ticker">
#          BUX
#         </span>
# <span class="price">
#          67 907
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="exchange-item baaad">
# <span class="ticker">
#          OTP
#         </span>
# <span class="price">
#          17 310
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="exchange-item baaad">
# <span class="ticker">
#          MOL
#         </span>
# <span class="price">
#          2 790
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# </a>
# </section>
# <a class="weather" data-ga-category="Időjárás" data-temprature="19.9" href="https://dex.hu/x.php?id=inxcl_idojaras&amp;url=https://index.hu/idojaras" title="most: 19,9 °C">
# <div class="temperature">
# <div class="night">
#         12 °C
#        </div>
# <div class="day">
#         25 °C
#        </div>
# </div>
# <div class="weather-icon">
# <ul>
# <li class="icon-cloud">
# </li>
# </ul>
# </div>
# </a>
# </div>
# <nav id="index-rovatok">
# <a class="rovat-link navi_belfold" data-ga-category="Belföld" data-rovat-dropdown="" href="#" id="belfold">
#       Belföld
#      </a>
# <a class="rovat-link navi_kulfold" data-ga-category="Külföld" data-rovat-dropdown="" href="#" id="kulfold">
#       Külföld
#      </a>
# <a class="rovat-link navi_gazdasag" data-ga-category="Gazdaság" data-rovat-dropdown="" href="#" id="gazdasag">
#       Gazdaság
#      </a>
# <a class="rovat-link navi_kultur" data-ga-category="Kult" data-rovat-dropdown="" href="#" id="kultur">
#       Kult
#      </a>
# <a class="rovat-link navi_velemeny" data-ga-category="Vélemény" data-rovat-dropdown="" href="#" id="velemeny">
#       Vélemény
#      </a>
# <a class="rovat-link navi_techtud" data-ga-category="Tech-Tud" data-rovat-dropdown="" href="#" id="techtud">
#       Tech-Tud
#      </a>
# <a class="rovat-link navi_sport" data-ga-category="Sport" data-rovat-dropdown="" href="#" id="sport">
#       Sport
#      </a>
# <a class="rovat-link navi_fomo" data-ga-category="Fomo" data-rovat-dropdown="" href="#" id="fomo">
#       Fomo
#      </a>
# <a class="rovat-link navi_24ora selected" data-ga-category="24 Óra" data-rovat-dropdown="" href="#" id="24ora">
#       24 Óra
#      </a>
# <a class="rovat-link navi_blog notification" data-ga-category="Blog" data-rovat-dropdown="" href="#" id="blog">
#       Blog
#      </a>
# <a class="rovat-link navi_video notification" data-ga-category="Videó" data-rovat-dropdown="" href="#" id="video">
#       Videó
#      </a>
# <a class="rovat-link navi_podcast notification" data-ga-category="Podcast" data-rovat-dropdown="" href="#" id="podcast">
#       Podcast
#      </a>
# <a class="rovat-icon navi_twitter" data-ga-category="Twitter" href="https://twitter.com/indexhu" id="twitter" target="_blank">
# </a>
# <a class="rovat-icon navi_socials" data-ga-category="Socials" data-rovat-dropdown="" href="#" id="socials">
# </a>
# </nav>
# <div class="dropdown-container" hidden="" id="dropdown-menu-wrapper">
# <div class="loader animating">
# <span class="loader-item">
# </span>
# <span class="loader-item">
# </span>
# <span class="loader-item">
# </span>
# </div>
# </div>
# <script>
#      document.addEventListener('DOMContentLoaded', () => {
#         window.rovatDropdown = new RovatDropdown({
#             base_url: 'https://index.hu/',
#             callbacks: {
#                 video: function(element) {
#                     window.video_slider = new DropdownSlider(element.querySelector('.slider'), { threshold: 0 });
#                 }
#             }
#         });
#     });
#     </script>
# </div>
# </section>
# <div class="container top_szponzor adverticum-kapubanner">
# <div class="ad-container">
# <div class="iap iap--ado" data-id="adoceanindexhuqclsmvirum" id="adoceanindexhuqclsmvirum">
# <script class="iap-script">
#       window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhuqclsmvirum","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_LB","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#      </script>
# </div>
# </div>
# </div>
# <div class="container border rovat-container">
# <div id="js_content_template_normal">
# <!--
#         <article class="rovatajanlo unordered not-important normal">
#             <header class="rovat-cikk-head">
#                 <h3>
#                     <span class="separator-box"></span>
#                         <span class="cikk-date-label" data-datestamp="{{Puzzler.ccd.ts}}" data-date="{{Puzzler.timestampToDate( Puzzler.ccd.ts )}}">{{Puzzler.ccd.datum}}</span>
#                     <span class="separator"></span>
#                     {{Puzzler.isMindekozben( Puzzler.ccd.url ) ? '<ul class="cikk-cimkek"><li><a href="http://index.hu/mindekozben" class="cimke cimke-mufaj">Mindeközben</a></li></ul>' : ''}}
#                     {{ Puzzler.ccd.kiadvany_csoki ? Puzzler.ccd.kiadvany_csoki : ''; }}
#                 </h3>
#                 <div class="clearfix"></div>
#             </header>
#
#             <h2>
#                 {{Puzzler.ccd.kep ? '<a href="' + Puzzler.ccd.url + '"  title="' + Puzzler.ccd.cim + '"><img class="need_to_load" src="' + Puzzler.ccd.kep + '" alt="' + Puzzler.ccd.cim + '" /></a>' : '' }}
#                 <a href="{{Puzzler.ccd.url}}" class="cim" title="{{Puzzler.ccd.cim}}">{{Puzzler.ccd.cim}}</a>
#             </h2>
#             {{Puzzler.ccd.ajanlo ? '<div class="ajanlo">' + Puzzler.ccd.ajanlo + '</div>' : '' }}
#         </article>
# -->
# </div>
# <div id="js_content_template_lead">
# <!--
#         <article class="rovatajanlo vezeto keppel not-important">
#             <div class="article-container">
#                 <a href="{{Puzzler.ccd.url}}"  title="{{Puzzler.ccd.cim}}">
#                     <img src="{{Puzzler.ccd.kep}}" alt="{{Puzzler.ccd.cim}}">
#                 </a>
#                 <h2>
#                     <a href="{{Puzzler.ccd.url}}" class="cim"  title="{{Puzzler.ccd.cim}}">{{Puzzler.ccd.cim}}</a>
#                 </h2>
#             </div>
#             <div class="author-share-date-container">
#             <div class="author-share-date">
#                 <div class="bal-hasab">
#                     <div class="szerzok_container">
#                             {{Puzzler.ccd.alnevek.replace(/\\(.)/mg, "$1")}}
#                     </div>
#                     <div class="datum">
#                         {{Puzzler.ccd.datum}}
#                     </div>
#                 </div>
#                 <div class="jobb-hasab">
#                     <div class="megoszt ">
#                         <div class="fb-share" data-action="recommend" data-href="{{Puzzler.ccd.url}}"> {{Puzzler.ccd.actual_fb_like}} </div>
#                 <div class="index-social-box cikk-top-box">
#                     <a href="#" class="megosztas-gomb"></a>
#                     <ul class="megosztas-doboz">
#                         <li class="mail">
#                             <a class="email" href="mailto:ugyelet@NEMSPA_M.mail.index.hu?subject={{Puzzler.ccd.cim}}&amp;body=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                             <li class="facebook">
#                                 <a href="https://www.facebook.com/sharer/sharer.php?u=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                             </li>
#                         <li class="twitter">
#                             <a href="http://twitter.com/share?lang=hu&amp;text={{Puzzler.ccd.cim}}&amp;url=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                         <li class="tumblr">
#                             <a href="http://www.tumblr.com/share/link?url=http:{{Puzzler.ccd.url}}&amp;name={{Puzzler.ccd.cim}}&amp;description=%28via+%3Ca+href%3D%22http%3A%2F%2Findex.hu%2F%22%3EIndex%3C%2Fa%3E%29" target="_blank"></a>
#                         </li>
#                         <li class="google-plus">
#                             <a href="https://plus.google.com/share?url=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                     </ul>
#                 </div>
#                             <div class="hozzaszolasok"></div>
#                    </div>
#
#                                 </div>
#                             </div>
#             </div>
#             <div class="ajanlo">{{Puzzler.ccd.ajanlo}}</div>
#         </article>
# -->
# </div>
# <div id="js_content_template_datumcsik">
# <!--
#         <div class="datumcsik clearfix">{{Puzzler.ccd.month ? Puzzler.ccd.month : Puzzler.timestampToDate( Puzzler.ccd.ts, true )}}</div>
# -->
# </div>
# <div class="kereses-urlap">
# <h3>
#      Keresés
#     </h3>
# <form action="" id="kereses-urlap">
# <div class="mezocsoport alap-kereso">
# <div class="kereses-wrapper">
# <input id="kereses-mezo" name="s" placeholder="Keresés" type="text" value=""/>
# </div>
# <div class="kereses-gomb-wrapper">
# <input class="gomb-elsodleges kereses-ikon" type="submit" value=""/>
# </div>
# </div>
# <div class="reszletes-kereses-gomb-container">
# <button class="gomb-masodlagos reszletes-kereses-gomb" href="#">
#        Részletes keresés
#       </button>
# </div>
# <div class="reszletes-kereses-container">
# <div class="datum-container">
# <div class="mezocsoport">
# <div class="datum-wrapper">
# <input autocomplete="off" class="date-selector" id="datum-tol" name="tol" type="text" value="1999-01-01"/>
# </div>
# <div class="datum-label-wrapper">
# <label for="datum-tol">
#           -tól
#          </label>
# </div>
# </div>
# <div class="mezocsoport">
# <div class="datum-wrapper">
# <input autocomplete="off" class="date-selector" id="datum-ig" name="ig" type="text" value="2024-06-02"/>
# </div>
# <div class="datum-label-wrapper">
# <label for="datum-ig">
#           -ig
#          </label>
# </div>
# </div>
# </div>
# <div class="onthisday-container">
# <input class="onthisday-kapcsolo" id="onthisday" name="onthisday" type="checkbox" value="1"/>
# <label class="onthisday-label" for="onthisday">
#         Ezen a napon
#         <span>
# </span>
# </label>
# </div>
# <div class="tarskiadvany-container">
# <input class="tarskiadvany-kapcsolo" id="tarskiadvanyokbanis" name="tarskiadvanyokbanis" type="checkbox" value="1"/>
# <label class="tarskiadvany-label" for="tarskiadvanyokbanis">
#         Az Index környékéről is
#         <span>
#          Totalcar, Totalbike, Velvet, Dívány, Comment:Com, Könyvesblog, Tékozló Homár
#         </span>
# </label>
# <div class="tarskiadvany-opciok">
# <div class="szerzo-rovat-container">
# <div class="mezocsoport">
# <div class="input-wrapper">
# <select class="chosen-select" data-placeholder="Szerzők" name="profil">
# <option value="">
# </option>
# <option value="">
#              Összes
#             </option>
# <option value="acs_daniel">
#              Ács Dániel
#             </option>
# <option value="acs_tibor">
#              Ács Tibor
#             </option>
# <option value="adamek_alma">
#              Adamek Alma
#             </option>
# <option value="aghassi_attila">
#              Ághassi Attila
#             </option>
# <option value="ago_bela">
#              Ágó Béla
#             </option>
# <option value="agoston_zoltan">
#              Ágoston Zoltán
#             </option>
# <option value="ajpek_orsi">
#              Ajpek Orsi
#             </option>
# <option value="ambrus_adam">
#              Ambrus Ádám
#             </option>
# ...
#       </a>
# </h2>
# <div class="ajanlo">
#       Rászokunk a fülelésre.
#      </div>
# </article>
# <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717255380">
#         tegnap, 17:23
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/amerikai-egyesult-allamok-korrupcio-botrany-vesztegetes-robert-burke-haditengereszet-admiralis/" title="Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát">
# <img alt="Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566104/56610407_4185763_cb0fbc3a19102aa68e51461586144fba_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/amerikai-egyesult-allamok-korrupcio-botrany-vesztegetes-robert-burke-haditengereszet-admiralis/" title="Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát">
#        Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát
#       </a>
# </h2>
# <div class="ajanlo">
#       Átszámítva 180 millió forintos éves fizetéssel sikerült lekenyerezni.
#      </div>
# </article>
# <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717254240">
#         tegnap, 17:04
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/atletika/2024/06/01/atletika-olimpiai-bajnok-atlanta-gatfutas-sydney-mclaughlin-levrone-edwin-moses-classic/" title="Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle">
# <img alt="Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle" loading="lazy" src="https://kep.index.hu/1/0/5660/56609/566095/56609519_4185695_c38d52cdd5b5c69339ebe99487f2e8a4_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/atletika/2024/06/01/atletika-olimpiai-bajnok-atlanta-gatfutas-sydney-mclaughlin-levrone-edwin-moses-classic/" title="Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle">
#        Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle
#       </a>
# </h2>
# <div class="ajanlo">
#       Az amerikai világcsúcstartó legutóbb 2022 augusztusában állt rajthoz ebben a számban.
#      </div>
# </article>
# <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717254180">
#         tegnap, 17:03
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/tompos-katya-szineszno-halala-utolso-interju/" title="Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában">
# <img alt="Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566102/56610275_4185755_e063e7ef91d269bd87be58cfc9e5a77b_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/tompos-katya-szineszno-halala-utolso-interju/" title="Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában">
#        Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában
#       </a>
# </h2>
# <div class="ajanlo">
#       Több mint egy éve készült a műsor.
#      </div>
# </article>
# <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717254120">
#         tegnap, 17:02
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/haboru-oroszorszag-ukrajna-europai-csapatok-ukrajnaban-glen-grant-brit-ezredes/" title="Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni">
# <img alt="Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566102/56610249_4185753_ca26c56dc70528826639b79b2478b300_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/haboru-oroszorszag-ukrajna-europai-csapatok-ukrajnaban-glen-grant-brit-ezredes/" title="Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni">
#        Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni
#       </a>
# </h2>
# <div class="ajanlo">
#       „Amit eddig tettek, az nem volt elég hatással Oroszországra” – mondta.
#      </div>
# </article>
# <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717253940">
#         tegnap, 16:59
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/magyar-peter-partizan-gulyas-marton-tisza-program/" title="Nem kímélték Magyar Pétert, minden kikerült az asztalra">
# <img alt="Nem kímélték Magyar Pétert, minden kikerült az asztalra" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566101/56610107_4185741_d13245e341d14d4d2d4b900e83fd0ff8_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/magyar-peter-partizan-gulyas-marton-tisza-program/" title="Nem kímélték Magyar Pétert, minden kikerült az asztalra">
#        Nem kímélték Magyar Pétert, minden kikerült az asztalra
#       </a>
# </h2>
# <div class="ajanlo">
#       Gulyás Márton szerint hajlamos a nagyotmondásra a Tisza Párt alelnöke.
#      </div>
# </article>
# <article class="rovatajanlo normal left">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717253700">
#         tegnap, 16:55
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/kiraly-viktor-magyar-akcentus-parodia/" title="Király Viktor kiparodizálta a magyarok akcentusos angolját">
#        Király Viktor kiparodizálta a magyarok akcentusos angolját
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>
# <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/belfold/2024/06/01/orban-viktor-beszed-bekemenet-valasztasok-haboru/" title="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje">
# <img alt="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje" loading="lazy" src="https://kep.index.hu/1/0/5660/56609/566098/56609867_4185723_e6b8b4d0d0ff561d1f7cbd755727a428_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/orban-viktor-beszed-bekemenet-valasztasok-haboru/" title="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje">
#         Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/peter_alvarez">
# <img alt="Péter Alvarez" class="szerzo-kep" src="https://kep.index.hu/1/0/4903/49034/490344/49034444_3737960_b998b0087613d5288b147749af5e46d1_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/peter_alvarez" rel="author">
#             Péter Alvarez
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1532">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.01. 16:52
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-02 06:58:29
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       A miniszterelnök beszédével ért véget a Békemenet.
#      </div>
# </article>
# </main>
# <div class="clear">
# </div>
# </div>
# <footer class="m-page-footer">
# <div class="container m-page-footer_container">
# <ul class="m-page-footer_container_list">
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fimpresszum%2F">
#        Impresszum
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findamediasales.hu%2F">
#        Médiaajánlat
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fcopyright%2F">
#        Szerzői jogok
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fadatvedelem%2F">
#        Adatvédelmi elvek
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fsutiszabalyzat%2F">
#        Süti szabályzat
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasText">
# <a class="change-consent m-page-footer_container_list_item_link" onclick="window.__tcfapi('displayConsentUi', 2, function() {} );">
#        Süti beállítások
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2F24ora%2Frss%2F">
#        RSS
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Finfo%2Fallas%2F">
#        Állás
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Fajanlat.indamediasales.hu%2Fmarkabiztonsag%2FIndamedia_Sales_Markabiztonsagi_nyilatkozat.pdf">
#        Márkabiztonság
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fdsa" target="_blank">
#        DSA
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasText">
# <span class="m-page-footer_container_list_item_text">
#        © 1999-2024
#        <span>
#         Index.hu
#        </span>
#        Zrt.
#       </span>
# </li>
# </ul>
# </div>
# </footer>
# <div class="layout_watcher phone">
# </div>
# <div class="layout_watcher portrait-tablet">
# </div>
# <div class="layout_watcher landscape-tablet">
# </div>
# <div class="layout_watcher desktop">
# </div>
# <div class="newsletter_modal" id="newsletterModal">
# </div>
# <script>
#    new NewsletterModal( document.getElementById('newsletterModal'), {'assetUrl': 'https://index.hu/assets/'});
#   </script>
# <script>
#    var bodyContent = '';
#         $emailAdress = 'bla';
#                 bodyContent = 'Olvasói levelet, meghívót, sajtóközleményt készül küldeni a(z) <strong><a href="mailto:{emailAddress}" target="_blank" class="email">{emailShow}</a></strong> címen a szerkesztőségnek. Fontos nekünk, ezért az adataira is nagyon vigyázunk, ahogy az <a href="https://index.hu/adatvedelem" target="_blank">adatvédelmi tájékoztatónkban</a> részletezzük is. Ha Önnek is oké, kattintson az OK gombra.';
#         bodyContentMeghivo = 'Nyilatkozatot, bejelentést, vagy felhasználási kérelmet készül küldeni a(z) <strong><a href="mailto:{emailAddress}" target="_blank" class="email">{emailShow}</a></strong> címen a lapigazgatónak.Fontos nekünk, ezért az adataira is nagyon vigyázunk, ahogy az <a href="https://index.hu/adatvedelem" target="_blank">adatvédelmi tájékoztatónkban</a> részletezzük is. Ha Önnek is oké, kattintson az OK gombra.'
#
#         $(document).ready(function() {
#
#             $('a.email').on('click', function(e) {
#                 e.preventDefault();
#
#                 if (
#                     // Csak akkor jelenítjük meg a modal ablakot, ha ezeknek a feltételeknek valamelyike teljesül
#                     $(this).hasClass('irok_neki') ||               // Ha írok neki típusú a link vagy
#                     $(this).attr('href').indexOf('mailto:') !== -1  // van mailto link a href-ben
#                 ) {
#
#
#                     var emailAddress = $(this).attr('href')
#                         .replace('mailto:', '')
#                         .replace('NEMSPA_M.', '');
#
#                     var emailShow = emailAddress.match(/([a-zA-Z0-9._+-]+@[a-zA-Z0-9._-]+\.[a-zA-Z0-9._-]+)/)[0];
#
#                     var content = $(e.target).hasClass('meghivo') ? bodyContentMeghivo.replace(/{emailAddress}/gi, emailAddress).replace(/{emailShow}/g, emailShow) : bodyContent.replace(/{emailAddress}/gi, emailAddress).replace(/{emailShow}/g, emailShow);
#
#                     var mailtoModal = new vModal({
#                         title: 'Adatvédelmi tájékoztatás',
#                         body: content,
#                         buttons: {
#                             more: 'Vissza',
#                             confirm: 'OK'
#                         },
#                         className: 'vanilla_modal--basic',
#                         events: {
#                             confirm: function() {
#                                 //chrome miatt kell új lapon megnyitni, különben nem működik!
#                                 window.open('mailto:' + emailAddress, '_blank');
#                             }
#                         }
#                     });
#
#                     mailtoModal.open();
#
#                 }
#
#             });
#
#         });
#   </script>
# <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
#             var pp_gemius_identifier = pp_gemius_original_identifier = new String('B9OVVi_kSaN4kjyXnmrlRnaITKLZOwR45wv6Si7xT2f.S7'); <!-- 24 óra -->
#             var pp_gemius_use_cmp = true;
#             var pp_gemius_cmp_timeout = Infinity;
#             //--><!]]>
#   </script>
# <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
#             function gemius_pending(i) { window[i] = window[i] || function() {var x = window[i+'_pdata'] = window[i+'_pdata'] || []; x[x.length]=arguments;};};
#             gemius_pending('gemius_hit'); gemius_pending('gemius_event');
#             gemius_pending('pp_gemius_hit'); gemius_pending('pp_gemius_event');
#
#             (function(d,t) {try {
#             var gt=d.createElement(t),s=d.getElementsByTagName(t)[0],l='http'+((location.protocol=='https:')?'s':'');
#             gt.setAttribute('async','async');
#             gt.setAttribute('defer','defer');
#             gt.src=l+'://gahu.hit.gemius.pl/xgemius.js';
#             s.parentNode.insertBefore(gt,s);}
#             catch (e) {}})(document,'script');
#             //--><!]]>
#   </script>
# <script type="text/javascript">
#    var gemABObj = {
#                 docBody: document.getElementsByTagName('body')[0],
#                 incScript: document.createElement('SCRIPT'),
#                 checkIt: function(){document.getElementById("mnxHDozyKPjB")?pp_gemius_hit("nSdFzTtkvTTrx.B7K13yyfU378aFPueKFs36aeS6yET.A7","addon=no-adblock"):pp_gemius_hit("nSzrCTsGCKuF9KNE6iWTitVrzbu1Eg8GQHsHaml5W8n.b7","addon=adblock")}
#             };
#             gemABObj.incScript.src = '//indexhu.adocean.pl/files/x/mof/ghshscq/xajkevmjdv/ads.js';
#             gemABObj.docBody.appendChild(gemABObj.incScript);
#
#             window.addEventListener("load",gemABObj.checkIt);
#   </script>
# </body>
# </html>

# %% [markdown]
# ## Cikkek adatait tároló kódrészlek kigyűjtése

# %%
articles = soup.find_all("article")

print(len(articles))
print(articles)
# Out:
# 60
# [<article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/kultur/2024/06/02/hungaria-koncert-most-vagy-soha-puskas-arena-fenyo-szikora-dolly-novai/" title="Hungária–Közönség 1–1">
# <img alt="Hungária–Közönség 1–1" loading="lazy" src="https://kep.index.hu/1/0/5661/56614/566143/56614345_4186055_32623a9d108f0271024ae135752d5a9e_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/kultur/2024/06/02/hungaria-koncert-most-vagy-soha-puskas-arena-fenyo-szikora-dolly-novai/" title="Hungária–Közönség 1–1">
#         Hungária–Közönség 1–1
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/vidacs_eva">
# <img alt="Vidacs Éva" class="szerzo-kep" src="https://kep.index.hu/1/0/5475/54750/547500/54750025_4045785_e749631ad344ea97652fef51a75c4f0d_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/vidacs_eva" rel="author">
#             Vidacs Éva
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1599">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.02. 08:52
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-02 09:39:46
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Flipper Öcsit is láttuk a koncerten.
#      </div>
# <div class="iap iap--ado roadblock" data-id="adoceanindexhundcjqssfzl" id="adoceanindexhundcjqssfzl">
# <script class="iap-script">
#        window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhundcjqssfzl","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_RB_A","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#       </script>
# </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717313640">
#         13 perce
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-rovat-light" href="https://index.hu/zold/">
#           Zöld Index
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/tudomany/2024/06/02/vasarlas-muanyag-hulladek-szen-labnyom-csomagolas-mentes/" title="Sokat nyerhet, ha ezzel a módszerrel intézi a vásárlást">
# <img alt="Sokat nyerhet, ha ezzel a módszerrel intézi a vásárlást" loading="lazy" src="https://kep.index.hu/1/0/5658/56580/565803/56580383_4183503_70afa988971e9e47eb6afd4f3adba1b4_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/tudomany/2024/06/02/vasarlas-muanyag-hulladek-szen-labnyom-csomagolas-mentes/" title="Sokat nyerhet, ha ezzel a módszerrel intézi a vásárlást">
#        Sokat nyerhet, ha ezzel a módszerrel intézi a vásárlást
#       </a>
# </h2>
# <div class="ajanlo">
#       Így spórolhat, ha hosszú távon gondolkodik.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717313280">
#         19 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/tudomany/2024/06/02/kutya-kutyak-kutyafajta-fajtatiszta-legdragabb/" title="Ezek a világ legdrágább kutyafajtái">
# <img alt="Ezek a világ legdrágább kutyafajtái" loading="lazy" src="https://kep.index.hu/1/0/5661/56615/566151/56615107_4186141_0095fd7765a8608465512292ad194bb2_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/tudomany/2024/06/02/kutya-kutyak-kutyafajta-fajtatiszta-legdragabb/" title="Ezek a világ legdrágább kutyafajtái">
#        Ezek a világ legdrágább kutyafajtái
#       </a>
# </h2>
# <div class="ajanlo">
#       Több szempont is befolyásolja az árakat.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717312320">
#         35 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/futball/2024/06/02/mls-gazdag-daniel-philadelphia-union-magyar-valogatott-legiosok/" title="A magyar válogatott támadó újabb góllal írta tovább a klubrekordot">
# <img alt="A magyar válogatott támadó újabb góllal írta tovább a klubrekordot" loading="lazy" src="https://kep.index.hu/1/0/5661/56615/566152/56615211_4186151_61eb824f21eb44d8256582d55984e17f_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/futball/2024/06/02/mls-gazdag-daniel-philadelphia-union-magyar-valogatott-legiosok/" title="A magyar válogatott támadó újabb góllal írta tovább a klubrekordot">
#        A magyar válogatott támadó újabb góllal írta tovább a klubrekordot
#       </a>
# </h2>
# <div class="ajanlo">
#       Már a 61. találatát jegyezte az együttes színeiben.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717311840">
#         43 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/fomo/2024/06/02/sean-lennon-harry-herceg-spare-me-gunyolodas-kozossegi-media/" title="Nagy botrány a briteknél, John Lennon fia beszólt Harry hercegnek">
# <img alt="Nagy botrány a briteknél, John Lennon fia beszólt Harry hercegnek" loading="lazy" src="https://kep.index.hu/1/0/5661/56614/566149/56614965_4186121_966d28265992316819e183b0989e0e83_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/fomo/2024/06/02/sean-lennon-harry-herceg-spare-me-gunyolodas-kozossegi-media/" title="Nagy botrány a briteknél, John Lennon fia beszólt Harry hercegnek">
#        Nagy botrány a briteknél, John Lennon fia beszólt Harry hercegnek
#       </a>
# </h2>
# <div class="ajanlo">
#       Sean Lennon lenyafizta Meghan Markle férjét.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717311360">
#         51 perce
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-rovat-light" href="https://index.hu/zold/">
#           Zöld Index
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/tudomany/2024/06/02/zoldseg-gyumolcs-fagyasztott-friss-vitamin-asvanyi-anyag/" title="Meglepő, de a fagyasztott gyümölcs és zöldség ugyanolyan jó lehet, mint a friss">
# <img alt="Meglepő, de a fagyasztott gyümölcs és zöldség ugyanolyan jó lehet, mint a friss" loading="lazy" src="https://kep.index.hu/1/0/5661/56614/566147/56614719_4186087_598c5ffb232e33a371640701080fe1e5_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/tudomany/2024/06/02/zoldseg-gyumolcs-fagyasztott-friss-vitamin-asvanyi-anyag/" title="Meglepő, de a fagyasztott gyümölcs és zöldség ugyanolyan jó lehet, mint a friss">
#        Meglepő, de a fagyasztott gyümölcs és zöldség ugyanolyan jó lehet, mint a friss
#       </a>
# </h2>
# <div class="ajanlo">
#       Kevesebb pazarlás, több turmix.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717310820">
#         1 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/uszas/2024/06/02/uszas-mare-nostrum-monaco-milak-kristof-vilagranglista/" title="Leborul a világ Milák Kristóf lába elé, áradoznak a nemzetközi szaklapok">
# <img alt="Leborul a világ Milák Kristóf lába elé, áradoznak a nemzetközi szaklapok" loading="lazy" src="https://kep.index.hu/1/0/5661/56614/566148/56614805_4186099_763eae27e55e89413a2541f4cde532ef_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/uszas/2024/06/02/uszas-mare-nostrum-monaco-milak-kristof-vilagranglista/" title="Leborul a világ Milák Kristóf lába elé, áradoznak a nemzetközi szaklapok">
#        Leborul a világ Milák Kristóf lába elé, áradoznak a nemzetközi szaklapok
#       </a>
# </h2>
# <div class="ajanlo">
#       Áradoznak a nemzetközi szaklapok.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717310820">
#         1 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/02/filvig-keza-kalocsa-fidesz-polgarmester-jacht/" title="Fideszes polgármester édesanyjáé lett egy több millió forintos jacht">
# <img alt="Fideszes polgármester édesanyjáé lett egy több millió forintos jacht" loading="lazy" src="https://kep.index.hu/1/0/5661/56614/566148/56614837_4186103_a44777770580b89755a7ca3eb53c51ed_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/02/filvig-keza-kalocsa-fidesz-polgarmester-jacht/" title="Fideszes polgármester édesanyjáé lett egy több millió forintos jacht">
#        Fideszes polgármester édesanyjáé lett egy több millió forintos jacht
#       </a>
# </h2>
# <div class="ajanlo">
#       A hajó fenntartása további költségeket igényelhet.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717309500">
#         1 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/techtud/2024/06/02/mentalis-egeszseg-depresszio-taplalkozasi-zavar-kozosseg-iskola-terjedes-finnorszag/" title="Közösségben terjednek a mentális betegségek?">
# <img alt="Közösségben terjednek a mentális betegségek?" loading="lazy" src="https://kep.index.hu/1/0/5659/56590/565909/56590959_4184281_24a528e0b29940696af0fa96c712a8be_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/techtud/2024/06/02/mentalis-egeszseg-depresszio-taplalkozasi-zavar-kozosseg-iskola-terjedes-finnorszag/" title="Közösségben terjednek a mentális betegségek?">
#        Közösségben terjednek a mentális betegségek?
#       </a>
# </h2>
# <div class="ajanlo">
#       Az eddigi legnagyobb kutatás finn iskolai osztályok sorsát követte.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717309140">
#         1 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/02/baumann-peter-rendor-tragedia-szulok-matyas-balazs/" title="Az Újbudán meggyilkolt rendőr családja máig nem dolgozta fel a tragédiát">
# <img alt="Az Újbudán meggyilkolt rendőr családja máig nem dolgozta fel a tragédiát" loading="lazy" src="https://kep.index.hu/1/0/4703/47035/470359/47035958_3586372_d334a234bd5d789264c7004eef66f415_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/02/baumann-peter-rendor-tragedia-szulok-matyas-balazs/" title="Az Újbudán meggyilkolt rendőr családja máig nem dolgozta fel a tragédiát">
#        Az Újbudán meggyilkolt rendőr családja máig nem dolgozta fel a tragédiát
#       </a>
# </h2>
# <div class="ajanlo">
#       Úgy élik meg a mindennapjaikat, mintha fiuk ott lenne velük.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717308900">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/02/huszik-voros-tenger-egyesult-allamok-raketatamadas-drontamadas/" title="A húszik továbbra sem nyugszanak, folyamatosan támadják az amerikai hajókat">
# <img alt="A húszik továbbra sem nyugszanak, folyamatosan támadják az amerikai hajókat" loading="lazy" src="https://kep.index.hu/1/0/5661/56614/566147/56614745_4186089_2227eae35aedd272457609b07b271095_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/02/huszik-voros-tenger-egyesult-allamok-raketatamadas-drontamadas/" title="A húszik továbbra sem nyugszanak, folyamatosan támadják az amerikai hajókat">
#        A húszik továbbra sem nyugszanak, folyamatosan támadják az amerikai hajókat
#       </a>
# </h2>
# <div class="ajanlo">
#       Drón és rakéta is megsemmisült a Vörös-tengeren.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717308300">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/02/kinai-tabornok-vadolja-az-egyesult-allamokat-csendes-ocean-nato-2.0/" title="Kínai katonai vezető: „Az Egyesült Államok a káosz és a feszültség forrása”, létrehoznának egy újabb NATO-t">
# <img alt="Kínai katonai vezető: „Az Egyesült Államok a káosz és a feszültség forrása”, létrehoznának egy újabb NATO-t" loading="lazy" src="https://kep.index.hu/1/0/5661/56614/566146/56614693_4186085_c571af5bb92b7d6f7dffa0875319b0a2_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/02/kinai-tabornok-vadolja-az-egyesult-allamokat-csendes-ocean-nato-2.0/" title="Kínai katonai vezető: „Az Egyesült Államok a káosz és a feszültség forrása”, létrehoznának egy újabb NATO-t">
#        Kínai katonai vezető: „Az Egyesült Államok a káosz és a feszültség forrása”, létrehoznának egy újabb NATO-t
#       </a>
# </h2>
# <div class="ajanlo">
#       Az altábornagy szerint az Egyesült Államok a káosz és a feszültség forrása a térségben.
#      </div>
# </article>, <article class="rovatajanlo normal left">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717308128">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/02/konyorgott-ferjenek-hogy-valjon-meg-szakallatol-aztan-rajott-hogy-elete-legnagyobb-hibajat-kovette-el/" title="Könyörgött férjének, hogy váljon meg szakállától, aztán rájött, hogy élete legnagyobb hibáját követte el">
#        Könyörgött férjének, hogy váljon meg szakállától, aztán rájött, hogy élete legnagyobb hibáját követte el
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717307280">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/02/europai-parlamenti-valasztasok-z-generacio-jeloltek/" title="A Z generáció tagjai készek átvenni a gyeplőt az Európai Unióban">
# <img alt="A Z generáció tagjai készek átvenni a gyeplőt az Európai Unióban" loading="lazy" src="https://kep.index.hu/1/0/5661/56614/566145/56614563_4186075_3852e41c15f37be43362191dc74d5af0_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/02/europai-parlamenti-valasztasok-z-generacio-jeloltek/" title="A Z generáció tagjai készek átvenni a gyeplőt az Európai Unióban">
#        A Z generáció tagjai készek átvenni a gyeplőt az Európai Unióban
#       </a>
# </h2>
# <div class="ajanlo">
#       Egyre több a fiatal a politikában.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717306080">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/02/steven-seagal-oroszorszag-ukrajna-vlagyimir-putyin-baratsag-erdemrend-orosz-ukran-haboru/" title="Steven Seagal: Ukrajna a szervkereskedelemről, a gyermekszex-kereskedelemről és a nácizmusról volt ismert">
# <img alt="Steven Seagal: Ukrajna a szervkereskedelemről, a gyermekszex-kereskedelemről és a nácizmusról volt ismert" loading="lazy" src="https://kep.index.hu/1/0/5661/56613/566139/56613911_4186027_b371dd5e6d5f3d5ab7edaf73736c6d0c_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/02/steven-seagal-oroszorszag-ukrajna-vlagyimir-putyin-baratsag-erdemrend-orosz-ukran-haboru/" title="Steven Seagal: Ukrajna a szervkereskedelemről, a gyermekszex-kereskedelemről és a nácizmusról volt ismert">
#        Steven Seagal: Ukrajna a szervkereskedelemről, a gyermekszex-kereskedelemről és a nácizmusról volt ismert
#       </a>
# </h2>
# <div class="ajanlo">
#       Mindezt azok után, hogy Vlagyimir Putyintól átvette a Barátság érdemrendet.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717306020">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/bajnokokligaja/2024/06/02/bajnokok-ligaja-bl-donto-wembley-futballhuliganizmus-real-madrid-dortmund/" title="Elszabadultak az indulatok a BL-döntő alatt, több mint 50 embert állítottak elő">
# <img alt="Elszabadultak az indulatok a BL-döntő alatt, több mint 50 embert állítottak elő" loading="lazy" src="https://kep.index.hu/1/0/5661/56614/566144/56614467_4186065_6d477e65f6b184374c0db33aa8378a5e_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/bajnokokligaja/2024/06/02/bajnokok-ligaja-bl-donto-wembley-futballhuliganizmus-real-madrid-dortmund/" title="Elszabadultak az indulatok a BL-döntő alatt, több mint 50 embert állítottak elő">
#        Elszabadultak az indulatok a BL-döntő alatt, több mint 50 embert állítottak elő
#       </a>
# </h2>
# <div class="ajanlo">
#       Hamis jegyek és mindenre elszánt rajongók akciója árnyékolta be a londoni finálét.
#      </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/gazdasag/2024/06/02/forint-euro-tozsde-moodys-adosbesorolas-bux-rekord-nemzetgazdasagi-miniszterium/" title="Ijesztő lépést tett a forint, megcsúszott a devizahegyen">
# <img alt="Ijesztő lépést tett a forint, megcsúszott a devizahegyen" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566105/56610591_4185773_48cbf61b589a79294b444c531a79512c_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/gazdasag/2024/06/02/forint-euro-tozsde-moodys-adosbesorolas-bux-rekord-nemzetgazdasagi-miniszterium/" title="Ijesztő lépést tett a forint, megcsúszott a devizahegyen">
#         Ijesztő lépést tett a forint, megcsúszott a devizahegyen
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/radi_balazs">
# <img alt="Rádi Balázs" class="szerzo-kep" src="https://kep.index.hu/1/0/4713/47131/471310/47131034_3593472_be79db7f230ec26c9357b2ee536e9463_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/radi_balazs" rel="author">
#             Rádi Balázs
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1498">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.02. 07:13
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-02 07:43:38
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Szépen indult a történet, de horrorsztori lett belőle.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717303980">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/02/noi-kiallitas-tate-now-you-see-us-lathatsz-minket-viktorianus-muvesz-festmeny-szobor-no-ferfi/" title="Nők, akik férfiak tulajdonában voltak">
# <img alt="Nők, akik férfiak tulajdonában voltak" loading="lazy" src="https://kep.index.hu/1/0/5653/56534/565341/56534101_4180073_129a92a7caab162f8de79740399909bd_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/02/noi-kiallitas-tate-now-you-see-us-lathatsz-minket-viktorianus-muvesz-festmeny-szobor-no-ferfi/" title="Nők, akik férfiak tulajdonában voltak">
#        Nők, akik férfiak tulajdonában voltak
#       </a>
# </h2>
# <div class="ajanlo">
#       Elvették az igazi nevüket is.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717301940">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/02/hetvegi-idojaras-radar-elorejelzes-zapor-zivatar/" title="Hiába a nyárias idő, így is kiadták a figyelmeztetést">
# <img alt="Hiába a nyárias idő, így is kiadták a figyelmeztetést" loading="lazy" src="https://kep.index.hu/1/0/4536/45361/453611/45361184_3460254_a19605138c0590c4bf99de0021d7a8fb_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/02/hetvegi-idojaras-radar-elorejelzes-zapor-zivatar/" title="Hiába a nyárias idő, így is kiadták a figyelmeztetést">
#        Hiába a nyárias idő, így is kiadták a figyelmeztetést
#       </a>
# </h2>
# <div class="ajanlo">
#       30 fokig is melegedhet az idő vasárnap.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717301460">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <span class="cimke cimke-mufaj">
#           Percről percre
#          </span>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/02/haboru-orosz-ukran-konfliktus-kijev-moszkva-volodimir-zelenszkij-vlagyimir-putyin-nato-europai-unio/" title="„Előbb megtalálják őt” – hollywoodi színészt fenyegetett meg Putyin szövetségese">
# <img alt="„Előbb megtalálják őt” – hollywoodi színészt fenyegetett meg Putyin szövetségese" loading="lazy" src="https://kep.index.hu/1/0/5661/56612/566120/56612095_4185887_361231b6b9e087ad42b7526fbe3b9535_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/02/haboru-orosz-ukran-konfliktus-kijev-moszkva-volodimir-zelenszkij-vlagyimir-putyin-nato-europai-unio/" title="„Előbb megtalálják őt” – hollywoodi színészt fenyegetett meg Putyin szövetségese">
#        „Előbb megtalálják őt” – hollywoodi színészt fenyegetett meg Putyin szövetségese
#       </a>
# </h2>
# <div class="ajanlo">
#       Oroszország háborúja Ukrajnában – az Index vasárnapi hírösszefoglalója.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717301460">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/02/aszteroida-vilagur-fold-kozelebe-erkezett-naprendszer-mars-jupiter/" title="Buszméretű aszteroida közelítette meg a Földet">
# <img alt="Buszméretű aszteroida közelítette meg a Földet" loading="lazy" src="https://kep.index.hu/1/0/5661/56613/566134/56613417_4185985_b02111dd12035c46bd5b8303d9bc5492_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/02/aszteroida-vilagur-fold-kozelebe-erkezett-naprendszer-mars-jupiter/" title="Buszméretű aszteroida közelítette meg a Földet">
#        Buszméretű aszteroida közelítette meg a Földet
#       </a>
# </h2>
# <div class="ajanlo">
#       Azonban nem ez volt az egyetlen, amely bolygónk közelébe érkezett.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717301400">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/02/nemetorszag-sorkatonasag-sorkotelezetseg-olaf-scholz-kancellar-boris-pitorius/" title="Kiderült, tényleg bevetik-e a sorkötelezettséget Németországban">
# <img alt="Kiderült, tényleg bevetik-e a sorkötelezettséget Németországban" loading="lazy" src="https://kep.index.hu/1/0/5661/56612/566121/56612123_4185889_fc044fec7de67c8764f662eb297dd303_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/02/nemetorszag-sorkatonasag-sorkotelezetseg-olaf-scholz-kancellar-boris-pitorius/" title="Kiderült, tényleg bevetik-e a sorkötelezettséget Németországban">
#        Kiderült, tényleg bevetik-e a sorkötelezettséget Németországban
#       </a>
# </h2>
# <div class="ajanlo">
#       Olaf Scholz szerint soha nem is volt tervben.
#      </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/sport/tenisz/2024/06/02/roland-garros-2024-novak-djokovics-lorenzo-musetti-harmadik-fordulo/" title="Éjszakai thriller Párizsban: Djokovics örökké emlékezetes módon maradt a trónon">
# <img alt="Éjszakai thriller Párizsban: Djokovics örökké emlékezetes módon maradt a trónon" loading="lazy" src="https://kep.index.hu/1/0/5661/56614/566141/56614175_4186053_7ab6247cdf808c394f11b95ba94f1056_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/sport/tenisz/2024/06/02/roland-garros-2024-novak-djokovics-lorenzo-musetti-harmadik-fordulo/" title="Éjszakai thriller Párizsban: Djokovics örökké emlékezetes módon maradt a trónon">
#         Éjszakai thriller Párizsban: Djokovics örökké emlékezetes módon maradt a trónon
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/klicasz_szpirosz_szotirisz">
# <img alt="Klicasz Szpirosz Szotirisz (Párizs)" class="szerzo-kep" src="https://kep.index.hu/1/0/3892/38925/389250/38925043_2969215_9261553097fd848efe53593c5c8f73ed_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/klicasz_szpirosz_szotirisz" rel="author">
#             Klicasz Szpirosz Szotirisz (Párizs)
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1297">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.02. 04:30
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-02 06:18:46
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       A szerb klasszis a kiesés széléről táncolt vissza a Roland Garroson.
#      </div>
# </article>, <article class="rovatajanlo normal right">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-02" data-datestamp="1717279321">
#         10 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/info/2024/06/02/lassa-a-jovot-100-millioert-/" title="LÁSSA A JÖVŐT 100 MILLIÓÉRT!">
#        LÁSSA A JÖVŐT 100 MILLIÓÉRT!
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717275420">
#         tegnap, 22:57
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/bajnokokligaja/2024/06/01/bajnokok-ligaja-2023-2024-donto-dortmund-real-madrid-osszefoglalo-edin-terzic-carlo-ancelotti/" title="A Dortmund mindent kihagyott, a Real Madrid köszönte szépen, és megnyerte a BL-t">
# <img alt="A Dortmund mindent kihagyott, a Real Madrid köszönte szépen, és megnyerte a BL-t" loading="lazy" src="https://kep.index.hu/1/0/5661/56614/566140/56614097_4186045_5cbef9a891582de6fbe2791df57abd59_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/bajnokokligaja/2024/06/01/bajnokok-ligaja-2023-2024-donto-dortmund-real-madrid-osszefoglalo-edin-terzic-carlo-ancelotti/" title="A Dortmund mindent kihagyott, a Real Madrid köszönte szépen, és megnyerte a BL-t">
#        A Dortmund mindent kihagyott, a Real Madrid köszönte szépen, és megnyerte a BL-t
#       </a>
# </h2>
# <div class="ajanlo">
#       A királyi gárda a londoni döntő végjátékában kétszer is betalált.
#      </div>
# </article>, <article class="rovatajanlo normal right">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717270209">
#         tegnap, 21:30
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/ilyen-allati-gyuruhordozokat-meg-nem-latott-a-vilag/" title="Ilyen állati gyűrűhordozókat még nem látott a világ">
#        Ilyen állati gyűrűhordozókat még nem látott a világ
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717269720">
#         tegnap, 21:22
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/tudomany/til/2024/06/01/kitorhet-e-ujra-a-badacsony-mert-a-szekely-vezuv-ugrasra-kesz/" title="Kitörhet-e újra a Badacsony? – Mert a székely Vezúv ugrásra kész">
# <img alt="Kitörhet-e újra a Badacsony? – Mert a székely Vezúv ugrásra kész" loading="lazy" src="https://kep.index.hu/1/0/5658/56582/565821/56582143_4183633_7390de9e3ed6bb5e780e73b4c3fe98f0_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/tudomany/til/2024/06/01/kitorhet-e-ujra-a-badacsony-mert-a-szekely-vezuv-ugrasra-kesz/" title="Kitörhet-e újra a Badacsony? – Mert a székely Vezúv ugrásra kész">
#        Kitörhet-e újra a Badacsony? – Mert a székely Vezúv ugrásra kész
#       </a>
# </h2>
# <div class="ajanlo">
#       Van rá kevés esély, de egy másik helyi vulkán bármikor.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717268940">
#         tegnap, 21:09
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/otos-lotto-joker-szerencsejatek-szombat-este-/" title="120 millió forintot nyert egy szerencsés magyar szombat este">
# <img alt="120 millió forintot nyert egy szerencsés magyar szombat este" loading="lazy" src="https://kep.index.hu/1/0/5661/56613/566130/56613007_4185959_37c063eace3aab9a10c3fb6f8e87083b_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/otos-lotto-joker-szerencsejatek-szombat-este-/" title="120 millió forintot nyert egy szerencsés magyar szombat este">
#        120 millió forintot nyert egy szerencsés magyar szombat este
#       </a>
# </h2>
# <div class="ajanlo">
#       26-an pedig több millió forintot nyertek. Mutatjuk az ötös lottó és a joker nyerőszámait.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717268460">
#         tegnap, 21:01
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/idojaras-radar-jegeso-debrecenben-villamarviz-pecsett/" title="Debrecenben diónyi jég esett, Pécsett villámárvíz alakult ki az extrém időjárás miatt">
# <img alt="Debrecenben diónyi jég esett, Pécsett villámárvíz alakult ki az extrém időjárás miatt" loading="lazy" src="https://kep.index.hu/1/0/5661/56612/566125/56612551_4185919_40b45b9861d374c82f69ed3cb8cdf36c_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/idojaras-radar-jegeso-debrecenben-villamarviz-pecsett/" title="Debrecenben diónyi jég esett, Pécsett villámárvíz alakult ki az extrém időjárás miatt">
#        Debrecenben diónyi jég esett, Pécsett villámárvíz alakult ki az extrém időjárás miatt
#       </a>
# </h2>
# <div class="ajanlo">
#       Fák dőltek ki, és pincéket öntött el a hirtelen lezúduló nagy mennyiségű csapadék.
#      </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/kulfold/ep/2024/valasztas/2024/06/01/ep-listavezetok-vitaja-dobrev-klara-donath-anna-le-marietta-toroczkai-laszlo/" title="Fasiztázás, orbánozás, brüsszelezés – így zajlott az EP-listavezetők vitája">
# <img alt="Fasiztázás, orbánozás, brüsszelezés – így zajlott az EP-listavezetők vitája" loading="lazy" src="https://kep.index.hu/1/0/5661/56611/566119/56611979_4185879_8a32ba02bde3051cd816847318929f8d_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/kulfold/ep/2024/valasztas/2024/06/01/ep-listavezetok-vitaja-dobrev-klara-donath-anna-le-marietta-toroczkai-laszlo/" title="Fasiztázás, orbánozás, brüsszelezés – így zajlott az EP-listavezetők vitája">
#         Fasiztázás, orbánozás, brüsszelezés – így zajlott az EP-listavezetők vitája
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/peter_alvarez">
# <img alt="Péter Alvarez" class="szerzo-kep" src="https://kep.index.hu/1/0/4903/49034/490344/49034444_3737960_b998b0087613d5288b147749af5e46d1_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/peter_alvarez" rel="author">
#             Péter Alvarez
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1532">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.01. 20:59
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-02 08:07:01
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Élő adásban csaptak össze egymással.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717267620">
#         tegnap, 20:47
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <span class="cimke cimke-mufaj">
#           Percről percre
#          </span>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/bajnokokligaja/2024/06/01/marco-reus-vagy-toni-kroos-bucsujat-aranyozza-be-a-wembley-dortmund-real-a-bl-dontoben/" title="Kroos gólpasszal tette emlékezetessé a búcsút: a Real a 15. BEK/BL-győzelmét ünnepelheti">
# <img alt="Kroos gólpasszal tette emlékezetessé a búcsút: a Real a 15. BEK/BL-győzelmét ünnepelheti" loading="lazy" src="https://kep.index.hu/1/0/5661/56613/566130/56613079_4185965_6c7d6e209abd4e889e672e14cc172867_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/bajnokokligaja/2024/06/01/marco-reus-vagy-toni-kroos-bucsujat-aranyozza-be-a-wembley-dortmund-real-a-bl-dontoben/" title="Kroos gólpasszal tette emlékezetessé a búcsút: a Real a 15. BEK/BL-győzelmét ünnepelheti">
#        Kroos gólpasszal tette emlékezetessé a búcsút: a Real a 15. BEK/BL-győzelmét ünnepelheti
#       </a>
# </h2>
# <div class="ajanlo">
#       Kroos gólpasszal tette emlékezetessé a búcsút.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717266840">
#         tegnap, 20:34
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/libri-irodalmi-dijak-balint-andras-zsuri-jaszberenyi-sandor-reakciok-irodalom-konyvek/" title="Bálint András: Ennek a díjnak rangja és értéke volt, múlt időben">
# <img alt="Bálint András: Ennek a díjnak rangja és értéke volt, múlt időben" loading="lazy" src="https://kep.index.hu/1/0/5584/55847/558475/55847575_4128837_c397d9ea5da0bf97df3424768010fa25_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/libri-irodalmi-dijak-balint-andras-zsuri-jaszberenyi-sandor-reakciok-irodalom-konyvek/" title="Bálint András: Ennek a díjnak rangja és értéke volt, múlt időben">
#        Bálint András: Ennek a díjnak rangja és értéke volt, múlt időben
#       </a>
# </h2>
# <div class="ajanlo">
#       A szakma szerint nem.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717266660">
#         tegnap, 20:31
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/motorsport/2024/06/01/ferrari-valint-bence-balaton-park-circuit-/" title="A Ferrari magyar versenyzője győzni ment a Balaton Parkba, de a szombati helyére is büszke">
# <img alt="A Ferrari magyar versenyzője győzni ment a Balaton Parkba, de a szombati helyére is büszke" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566106/56610679_4185779_89d59d1ab29dfb8a1b6b25f7315fe100_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/motorsport/2024/06/01/ferrari-valint-bence-balaton-park-circuit-/" title="A Ferrari magyar versenyzője győzni ment a Balaton Parkba, de a szombati helyére is büszke">
#        A Ferrari magyar versenyzője győzni ment a Balaton Parkba, de a szombati helyére is büszke
#       </a>
# </h2>
# <div class="ajanlo">
#       A dobogós Válint Bence dolgát a riválisok mellett az időjárás is nehezítette.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717264860">
#         tegnap, 20:01
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/bajnokokligaja/2024/06/01/real-madrid-tony-kroos-bajnokok-ligaja-futball-labdarugas/" title="Toni Kroos egyedi cipővel készült utolsó klubmérkőzésére">
# <img alt="Toni Kroos egyedi cipővel készült utolsó klubmérkőzésére" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566108/56610895_4185793_8f6497f01b307e288ea1d794ae664c5f_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/bajnokokligaja/2024/06/01/real-madrid-tony-kroos-bajnokok-ligaja-futball-labdarugas/" title="Toni Kroos egyedi cipővel készült utolsó klubmérkőzésére">
#        Toni Kroos egyedi cipővel készült utolsó klubmérkőzésére
#       </a>
# </h2>
# <div class="ajanlo">
#       A felejthetetlen zárásra különleges feliratozás dukál.
#      </div>
# </article>, <article class="rovatajanlo normal left">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717264810">
#         tegnap, 20:00
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/dave-bautistarol-elokerult-egy-kozel-40-eves-foto-alig-ismerni-ra-tinedzserkent/" title="Dave Bautistáról előkerült egy közel 40 éves fotó, alig ismerni rá tinédzserként">
#        Dave Bautistáról előkerült egy közel 40 éves fotó, alig ismerni rá tinédzserként
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717264380">
#         tegnap, 19:53
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/kutya-joga-veszelyes-betiltas-hollandia-europai-unio/" title="Veszélyes lehet a kiskutyajóga, egy politikus szerint be kellene tiltani">
# <img alt="Veszélyes lehet a kiskutyajóga, egy politikus szerint be kellene tiltani" loading="lazy" src="https://kep.index.hu/1/0/5661/56611/566118/56611861_4185871_d450785b81a85f82852001f36a82dcf7_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/kutya-joga-veszelyes-betiltas-hollandia-europai-unio/" title="Veszélyes lehet a kiskutyajóga, egy politikus szerint be kellene tiltani">
#        Veszélyes lehet a kiskutyajóga, egy politikus szerint be kellene tiltani
#       </a>
# </h2>
# <div class="ajanlo">
#       Sokan aggódnak az állatok egészsége miatt.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717263240">
#         tegnap, 19:34
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/kezilabda/2024/06/01/noi-kezilabda-bl-final-four-elodonto-metz-bietigheim/" title="A német bajnokkal és több volt játékosa ellen küzd meg a Győr a BL-döntőben">
# <img alt="A német bajnokkal és több volt játékosa ellen küzd meg a Győr a BL-döntőben" loading="lazy" src="https://kep.index.hu/1/0/5661/56611/566116/56611675_4185857_08d739fe4d9143f0c3ecef489b61285e_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/kezilabda/2024/06/01/noi-kezilabda-bl-final-four-elodonto-metz-bietigheim/" title="A német bajnokkal és több volt játékosa ellen küzd meg a Győr a BL-döntőben">
#        A német bajnokkal és több volt játékosa ellen küzd meg a Győr a BL-döntőben
#       </a>
# </h2>
# <div class="ajanlo">
#       Az esemény újonca magabiztos második félidei játékkal múlta felül francia ellenfelét.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717263000">
#         tegnap, 19:30
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/fopolgarmester-jeloltek-vitaja-budapest-vitezy-david-karacsony-gergely-ungar-peter/" title="Ungár Péter: Karácsony Gergely szavait egyszerűen nem lehet komolyan venni">
# <img alt="Ungár Péter: Karácsony Gergely szavait egyszerűen nem lehet komolyan venni" loading="lazy" src="https://kep.index.hu/1/0/5661/56611/566117/56611723_4185861_ac5160182383f0599229f70dafeda070_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/fopolgarmester-jeloltek-vitaja-budapest-vitezy-david-karacsony-gergely-ungar-peter/" title="Ungár Péter: Karácsony Gergely szavait egyszerűen nem lehet komolyan venni">
#        Ungár Péter: Karácsony Gergely szavait egyszerűen nem lehet komolyan venni
#       </a>
# </h2>
# <div class="ajanlo">
#       A Vitézy Dávidot támogató LMP-s politikus így véleményezte a jelöltek vitáját.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717261800">
#         tegnap, 19:10
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/bekemenet-andrassy-ut-budapest-buszok-parkolas-orban-viktor-biciklisav/" title="Az Andrássy út biciklisávján parkolhattak a békemenetes buszok, nagy a felháborodás">
# <img alt="Az Andrássy út biciklisávján parkolhattak a békemenetes buszok, nagy a felháborodás" loading="lazy" src="https://kep.index.hu/1/0/5661/56611/566112/56611249_4185825_bfc9d3d1d69912b40d115291eb87ed99_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/bekemenet-andrassy-ut-budapest-buszok-parkolas-orban-viktor-biciklisav/" title="Az Andrássy út biciklisávján parkolhattak a békemenetes buszok, nagy a felháborodás">
#        Az Andrássy út biciklisávján parkolhattak a békemenetes buszok, nagy a felháborodás
#       </a>
# </h2>
# <div class="ajanlo">
#       Nem volt jó ötlet ma a belvárosban kerékpározni.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717260960">
#         tegnap, 18:56
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/torok-gabor-nagy-attila-tibor-orban-viktor-beszed-reakcio/" title="Török Gábor: Orbán Viktor még soha nem emelte ilyen magasra a tétet">
# <img alt="Török Gábor: Orbán Viktor még soha nem emelte ilyen magasra a tétet" loading="lazy" src="https://kep.index.hu/1/0/4031/40317/403179/40317975_3076785_af2f983c001bad3e631b5b6f5004c0f2_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/torok-gabor-nagy-attila-tibor-orban-viktor-beszed-reakcio/" title="Török Gábor: Orbán Viktor még soha nem emelte ilyen magasra a tétet">
#        Török Gábor: Orbán Viktor még soha nem emelte ilyen magasra a tétet
#       </a>
# </h2>
# <div class="ajanlo">
#       Nagy Attila Tibor úgy látja: a kormányfő megzsarolta a választókat.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717260660">
#         tegnap, 18:51
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/futball/2024/06/01/jose-mourinho-fenerbahce-futball-labdarugas/" title="A klub megerősítette: tárgyalnak José Mario Dos Santos Mourinho Felixszel az edzői pozícióról">
# ...
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/orban-viktor-bekemenet-beszed-ellenzeki-reakciok-dk-momentum-lmp/" title="„Orbán Viktor a magyarok pénzéből finanszírozza Putyin ukrajnai háborúját” –  reakciók a kormányfő beszédére">
# <img alt="„Orbán Viktor a magyarok pénzéből finanszírozza Putyin ukrajnai háborúját” –  reakciók a kormányfő beszédére" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566107/56610737_4185783_a8a858c6f4015a5f517a956c11209d31_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/orban-viktor-bekemenet-beszed-ellenzeki-reakciok-dk-momentum-lmp/" title="„Orbán Viktor a magyarok pénzéből finanszírozza Putyin ukrajnai háborúját” –  reakciók a kormányfő beszédére">
#        „Orbán Viktor a magyarok pénzéből finanszírozza Putyin ukrajnai háborúját” –  reakciók a kormányfő beszédére
#       </a>
# </h2>
# <div class="ajanlo">
#       Befutottak a reakciók a kormányfő békemenetes beszédére.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717257840">
#         tegnap, 18:04
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/tenisz/2024/06/01/roland-garros-2024-hetedik-nap-idojaras-csapadek-esoszunet-parizs/" title="Ez már tényleg kínszenvedés: hetedik napja folyamatosan esik az eső a Roland Garroson">
# <img alt="Ez már tényleg kínszenvedés: hetedik napja folyamatosan esik az eső a Roland Garroson" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566106/56610649_4185777_a6789d595b13ba6b2afe3f08d597ada8_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/tenisz/2024/06/01/roland-garros-2024-hetedik-nap-idojaras-csapadek-esoszunet-parizs/" title="Ez már tényleg kínszenvedés: hetedik napja folyamatosan esik az eső a Roland Garroson">
#        Ez már tényleg kínszenvedés: hetedik napja folyamatosan esik az eső a Roland Garroson
#       </a>
# </h2>
# <div class="ajanlo">
#       Panaszkodnak a játékosok és a szurkolók, a szervezők tehetetlenek.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717257300">
#         tegnap, 17:55
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/01/vitezy-david-budapest-brand-marketingszervezet-kijelentes-faix-csaba/" title="Vitézy Dávidnak üzent a Budapest Brand vezérigazgatója, jött is a válasz">
# <img alt="Vitézy Dávidnak üzent a Budapest Brand vezérigazgatója, jött is a válasz" loading="lazy" src="https://kep.index.hu/1/0/5607/56073/560731/56073199_4145973_6634f40c6878d96f7a9c7e90698bf482_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/01/vitezy-david-budapest-brand-marketingszervezet-kijelentes-faix-csaba/" title="Vitézy Dávidnak üzent a Budapest Brand vezérigazgatója, jött is a válasz">
#        Vitézy Dávidnak üzent a Budapest Brand vezérigazgatója, jött is a válasz
#       </a>
# </h2>
# <div class="ajanlo">
#       A főpolgármester-jelölt szerint majd a választók eldöntik, mekkora összeg az ideális elköltésre.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717257240">
#         tegnap, 17:54
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/amerikaifutball/2024/06/01/gable-steveson-nfl-amerikai-futball-olimpia/" title="Tokióban olimpiai bajnok volt, leszerződtette az NFL-csapat">
# <img alt="Tokióban olimpiai bajnok volt, leszerződtette az NFL-csapat" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566103/56610365_4185759_6e1fdf7f80e7520e46598a63c20a98d4_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/amerikaifutball/2024/06/01/gable-steveson-nfl-amerikai-futball-olimpia/" title="Tokióban olimpiai bajnok volt, leszerződtette az NFL-csapat">
#        Tokióban olimpiai bajnok volt, leszerződtette az NFL-csapat
#       </a>
# </h2>
# <div class="ajanlo">
#       Alig várja, hogy kamatoztassa a tapasztalatait.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717256700">
#         tegnap, 17:45
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/magyar-peter-tisza-part-peticio-kampany-haboru-orban-viktor-deutsch-tamas-bekemenet/" title="Magyar Péter a Békemenet után tett bejelentést">
# <img alt="Magyar Péter a Békemenet után tett bejelentést" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566105/56610529_4185769_d5b75d4d396fedd965345bf8b86362f1_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/magyar-peter-tisza-part-peticio-kampany-haboru-orban-viktor-deutsch-tamas-bekemenet/" title="Magyar Péter a Békemenet után tett bejelentést">
#        Magyar Péter a Békemenet után tett bejelentést
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717256340">
#         tegnap, 17:39
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/olaszorszag-havazas-alpok-nyar-livigno-sondrio-megye/" title="Havazott az olasz Alpokban a nyár előestéjén">
# <img alt="Havazott az olasz Alpokban a nyár előestéjén" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566104/56610445_4185765_d3262474ec99ee27fb88425a7c0aede9_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/olaszorszag-havazas-alpok-nyar-livigno-sondrio-megye/" title="Havazott az olasz Alpokban a nyár előestéjén">
#        Havazott az olasz Alpokban a nyár előestéjén
#       </a>
# </h2>
# <div class="ajanlo">
#       A nem mindennapi időjárási jelenségről több videót is készítettek a helyiek.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717255560">
#         tegnap, 17:26
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/tudomany/2024/06/01/elektromos-auto-hibrid-baleset-zaj-kornyezet-kimelo/" title="Settenkedő járművek veszélyeztetik a gyalogosokat, de van megoldás">
# <img alt="Settenkedő járművek veszélyeztetik a gyalogosokat, de van megoldás" loading="lazy" src="https://kep.index.hu/1/0/5653/56534/565340/56534067_4180071_eda71f42656fde6173e8656bc5e48b05_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/tudomany/2024/06/01/elektromos-auto-hibrid-baleset-zaj-kornyezet-kimelo/" title="Settenkedő járművek veszélyeztetik a gyalogosokat, de van megoldás">
#        Settenkedő járművek veszélyeztetik a gyalogosokat, de van megoldás
#       </a>
# </h2>
# <div class="ajanlo">
#       Rászokunk a fülelésre.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717255380">
#         tegnap, 17:23
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/amerikai-egyesult-allamok-korrupcio-botrany-vesztegetes-robert-burke-haditengereszet-admiralis/" title="Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát">
# <img alt="Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566104/56610407_4185763_cb0fbc3a19102aa68e51461586144fba_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/amerikai-egyesult-allamok-korrupcio-botrany-vesztegetes-robert-burke-haditengereszet-admiralis/" title="Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát">
#        Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát
#       </a>
# </h2>
# <div class="ajanlo">
#       Átszámítva 180 millió forintos éves fizetéssel sikerült lekenyerezni.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717254240">
#         tegnap, 17:04
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/atletika/2024/06/01/atletika-olimpiai-bajnok-atlanta-gatfutas-sydney-mclaughlin-levrone-edwin-moses-classic/" title="Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle">
# <img alt="Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle" loading="lazy" src="https://kep.index.hu/1/0/5660/56609/566095/56609519_4185695_c38d52cdd5b5c69339ebe99487f2e8a4_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/atletika/2024/06/01/atletika-olimpiai-bajnok-atlanta-gatfutas-sydney-mclaughlin-levrone-edwin-moses-classic/" title="Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle">
#        Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle
#       </a>
# </h2>
# <div class="ajanlo">
#       Az amerikai világcsúcstartó legutóbb 2022 augusztusában állt rajthoz ebben a számban.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717254180">
#         tegnap, 17:03
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/tompos-katya-szineszno-halala-utolso-interju/" title="Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában">
# <img alt="Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566102/56610275_4185755_e063e7ef91d269bd87be58cfc9e5a77b_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/tompos-katya-szineszno-halala-utolso-interju/" title="Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában">
#        Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában
#       </a>
# </h2>
# <div class="ajanlo">
#       Több mint egy éve készült a műsor.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717254120">
#         tegnap, 17:02
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/haboru-oroszorszag-ukrajna-europai-csapatok-ukrajnaban-glen-grant-brit-ezredes/" title="Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni">
# <img alt="Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566102/56610249_4185753_ca26c56dc70528826639b79b2478b300_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/haboru-oroszorszag-ukrajna-europai-csapatok-ukrajnaban-glen-grant-brit-ezredes/" title="Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni">
#        Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni
#       </a>
# </h2>
# <div class="ajanlo">
#       „Amit eddig tettek, az nem volt elég hatással Oroszországra” – mondta.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717253940">
#         tegnap, 16:59
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/magyar-peter-partizan-gulyas-marton-tisza-program/" title="Nem kímélték Magyar Pétert, minden kikerült az asztalra">
# <img alt="Nem kímélték Magyar Pétert, minden kikerült az asztalra" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566101/56610107_4185741_d13245e341d14d4d2d4b900e83fd0ff8_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/magyar-peter-partizan-gulyas-marton-tisza-program/" title="Nem kímélték Magyar Pétert, minden kikerült az asztalra">
#        Nem kímélték Magyar Pétert, minden kikerült az asztalra
#       </a>
# </h2>
# <div class="ajanlo">
#       Gulyás Márton szerint hajlamos a nagyotmondásra a Tisza Párt alelnöke.
#      </div>
# </article>, <article class="rovatajanlo normal left">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717253700">
#         tegnap, 16:55
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/kiraly-viktor-magyar-akcentus-parodia/" title="Király Viktor kiparodizálta a magyarok akcentusos angolját">
#        Király Viktor kiparodizálta a magyarok akcentusos angolját
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/belfold/2024/06/01/orban-viktor-beszed-bekemenet-valasztasok-haboru/" title="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje">
# <img alt="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje" loading="lazy" src="https://kep.index.hu/1/0/5660/56609/566098/56609867_4185723_e6b8b4d0d0ff561d1f7cbd755727a428_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/orban-viktor-beszed-bekemenet-valasztasok-haboru/" title="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje">
#         Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/peter_alvarez">
# <img alt="Péter Alvarez" class="szerzo-kep" src="https://kep.index.hu/1/0/4903/49034/490344/49034444_3737960_b998b0087613d5288b147749af5e46d1_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/peter_alvarez" rel="author">
#             Péter Alvarez
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1532">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.01. 16:52
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-02 06:58:29
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       A miniszterelnök beszédével ért véget a Békemenet.
#      </div>
# </article>]

# %%
print(articles[0])
# Out:
# <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/kultur/2024/06/02/hungaria-koncert-most-vagy-soha-puskas-arena-fenyo-szikora-dolly-novai/" title="Hungária–Közönség 1–1">
# <img alt="Hungária–Közönség 1–1" loading="lazy" src="https://kep.index.hu/1/0/5661/56614/566143/56614345_4186055_32623a9d108f0271024ae135752d5a9e_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/kultur/2024/06/02/hungaria-koncert-most-vagy-soha-puskas-arena-fenyo-szikora-dolly-novai/" title="Hungária–Közönség 1–1">
#         Hungária–Közönség 1–1
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/vidacs_eva">
# <img alt="Vidacs Éva" class="szerzo-kep" src="https://kep.index.hu/1/0/5475/54750/547500/54750025_4045785_e749631ad344ea97652fef51a75c4f0d_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/vidacs_eva" rel="author">
#             Vidacs Éva
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1599">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.02. 08:52
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-02 09:39:46
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Flipper Öcsit is láttuk a koncerten.
#      </div>
# <div class="iap iap--ado roadblock" data-id="adoceanindexhundcjqssfzl" id="adoceanindexhundcjqssfzl">
# <script class="iap-script">
#        window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhundcjqssfzl","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_RB_A","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#       </script>
# </div>
# </article>

# %% [markdown]
# ## Egy darab cikk adatainak kinyerése

# %%
author = articles[0].find("div", class_="szerzo").text.strip()
date = articles[0].find("div", class_="datum")
published = date.contents[0].strip()
title = articles[0].find("a").get("title")
subtitle = articles[0].find("div", class_="ajanlo").text.strip()
url = articles[0].find("a").get("href")

print("Szerző: " + author)
print("Dátum: " + published)
print("Cím: " + title)
print("Alcím: " + subtitle)
print("url: " + url)
# Out:
# Szerző: Vidacs Éva
# Dátum: 2024.06.02. 08:52
# Cím: Hungária–Közönség 1–1
# Alcím: Flipper Öcsit is láttuk a koncerten.
# url: https://index.hu/kultur/2024/06/02/hungaria-koncert-most-vagy-soha-puskas-arena-fenyo-szikora-dolly-novai/

# %% [markdown]
# ## Összes cikk kinyerése a főoldalról

# %%
content = []

for article in articles:
    url = article.find("a").get("href")
    if url == "http://index.hu/mindekozben":
        continue

    if article.find("div", class_="szerzo") == None:
        author = ""
    else:
        author = article.find("div", class_="szerzo").text.strip()

    if article.find("div", class_="datum") == None:
        published = ""
    else:
        date = article.find("div", class_="datum")
        published = date.contents[0].strip()

    if article.find("a").get("title") == None:
        title = ""
    else:
        title = article.find("a").get("title")

    subtitle = article.find("div", class_="ajanlo").text.strip()

    content.append((author, published, title, subtitle, url))

for item in content:
    print(item)
# Out:
# ('Vidacs Éva', '2024.06.02. 08:52', 'Hungária–Közönség 1–1', 'Flipper Öcsit is láttuk a koncerten.', 'https://index.hu/kultur/2024/06/02/hungaria-koncert-most-vagy-soha-puskas-arena-fenyo-szikora-dolly-novai/')
# ('', '', '', 'Így spórolhat, ha hosszú távon gondolkodik.', 'https://index.hu/zold/')
# ('', '', 'Ezek a világ legdrágább kutyafajtái', 'Több szempont is befolyásolja az árakat.', 'https://index.hu/tudomany/2024/06/02/kutya-kutyak-kutyafajta-fajtatiszta-legdragabb/')
# ('', '', 'A magyar válogatott támadó újabb góllal írta tovább a klubrekordot', 'Már a 61. találatát jegyezte az együttes színeiben.', 'https://index.hu/sport/futball/2024/06/02/mls-gazdag-daniel-philadelphia-union-magyar-valogatott-legiosok/')
# ('', '', 'Nagy botrány a briteknél, John Lennon fia beszólt Harry hercegnek', 'Sean Lennon lenyafizta Meghan Markle férjét.', 'https://index.hu/fomo/2024/06/02/sean-lennon-harry-herceg-spare-me-gunyolodas-kozossegi-media/')
# ('', '', '', 'Kevesebb pazarlás, több turmix.', 'https://index.hu/zold/')
# ('', '', 'Leborul a világ Milák Kristóf lába elé, áradoznak a nemzetközi szaklapok', 'Áradoznak a nemzetközi szaklapok.', 'https://index.hu/sport/uszas/2024/06/02/uszas-mare-nostrum-monaco-milak-kristof-vilagranglista/')
# ('', '', 'Fideszes polgármester édesanyjáé lett egy több millió forintos jacht', 'A hajó fenntartása további költségeket igényelhet.', 'https://index.hu/belfold/2024/06/02/filvig-keza-kalocsa-fidesz-polgarmester-jacht/')
# ('', '', 'Közösségben terjednek a mentális betegségek?', 'Az eddigi legnagyobb kutatás finn iskolai osztályok sorsát követte.', 'https://index.hu/techtud/2024/06/02/mentalis-egeszseg-depresszio-taplalkozasi-zavar-kozosseg-iskola-terjedes-finnorszag/')
# ('', '', 'Az Újbudán meggyilkolt rendőr családja máig nem dolgozta fel a tragédiát', 'Úgy élik meg a mindennapjaikat, mintha fiuk ott lenne velük.', 'https://index.hu/belfold/2024/06/02/baumann-peter-rendor-tragedia-szulok-matyas-balazs/')
# ('', '', 'A húszik továbbra sem nyugszanak, folyamatosan támadják az amerikai hajókat', 'Drón és rakéta is megsemmisült a Vörös-tengeren.', 'https://index.hu/kulfold/2024/06/02/huszik-voros-tenger-egyesult-allamok-raketatamadas-drontamadas/')
# ('', '', 'Kínai katonai vezető: „Az Egyesült Államok a káosz és a feszültség forrása”, létrehoznának egy újabb NATO-t', 'Az altábornagy szerint az Egyesült Államok a káosz és a feszültség forrása a térségben.', 'https://index.hu/kulfold/2024/06/02/kinai-tabornok-vadolja-az-egyesult-allamokat-csendes-ocean-nato-2.0/')
# ('', '', 'A Z generáció tagjai készek átvenni a gyeplőt az Európai Unióban', 'Egyre több a fiatal a politikában.', 'https://index.hu/kulfold/2024/06/02/europai-parlamenti-valasztasok-z-generacio-jeloltek/')
# ('', '', 'Steven Seagal: Ukrajna a szervkereskedelemről, a gyermekszex-kereskedelemről és a nácizmusról volt ismert', 'Mindezt azok után, hogy Vlagyimir Putyintól átvette a Barátság érdemrendet.', 'https://index.hu/kulfold/2024/06/02/steven-seagal-oroszorszag-ukrajna-vlagyimir-putyin-baratsag-erdemrend-orosz-ukran-haboru/')
# ('', '', 'Elszabadultak az indulatok a BL-döntő alatt, több mint 50 embert állítottak elő', 'Hamis jegyek és mindenre elszánt rajongók akciója árnyékolta be a londoni finálét.', 'https://index.hu/bajnokokligaja/2024/06/02/bajnokok-ligaja-bl-donto-wembley-futballhuliganizmus-real-madrid-dortmund/')
# ('Rádi Balázs', '2024.06.02. 07:13', 'Ijesztő lépést tett a forint, megcsúszott a devizahegyen', 'Szépen indult a történet, de horrorsztori lett belőle.', 'https://index.hu/gazdasag/2024/06/02/forint-euro-tozsde-moodys-adosbesorolas-bux-rekord-nemzetgazdasagi-miniszterium/')
# ('', '', 'Nők, akik férfiak tulajdonában voltak', 'Elvették az igazi nevüket is.', 'https://index.hu/kultur/2024/06/02/noi-kiallitas-tate-now-you-see-us-lathatsz-minket-viktorianus-muvesz-festmeny-szobor-no-ferfi/')
# ('', '', 'Hiába a nyárias idő, így is kiadták a figyelmeztetést', '30 fokig is melegedhet az idő vasárnap.', 'https://index.hu/belfold/2024/06/02/hetvegi-idojaras-radar-elorejelzes-zapor-zivatar/')
# ('', '', '„Előbb megtalálják őt” – hollywoodi színészt fenyegetett meg Putyin szövetségese', 'Oroszország háborúja Ukrajnában – az Index vasárnapi hírösszefoglalója.', 'https://index.hu/kulfold/2024/06/02/haboru-orosz-ukran-konfliktus-kijev-moszkva-volodimir-zelenszkij-vlagyimir-putyin-nato-europai-unio/')
# ('', '', 'Buszméretű aszteroida közelítette meg a Földet', 'Azonban nem ez volt az egyetlen, amely bolygónk közelébe érkezett.', 'https://index.hu/kulfold/2024/06/02/aszteroida-vilagur-fold-kozelebe-erkezett-naprendszer-mars-jupiter/')
# ('', '', 'Kiderült, tényleg bevetik-e a sorkötelezettséget Németországban', 'Olaf Scholz szerint soha nem is volt tervben.', 'https://index.hu/kulfold/2024/06/02/nemetorszag-sorkatonasag-sorkotelezetseg-olaf-scholz-kancellar-boris-pitorius/')
# ('Klicasz Szpirosz Szotirisz (Párizs)', '2024.06.02. 04:30', 'Éjszakai thriller Párizsban: Djokovics örökké emlékezetes módon maradt a trónon', 'A szerb klasszis a kiesés széléről táncolt vissza a Roland Garroson.', 'https://index.hu/sport/tenisz/2024/06/02/roland-garros-2024-novak-djokovics-lorenzo-musetti-harmadik-fordulo/')
# ('', '', 'LÁSSA A JÖVŐT 100 MILLIÓÉRT!', '', 'https://index.hu/info/2024/06/02/lassa-a-jovot-100-millioert-/')
# ('', '', 'A Dortmund mindent kihagyott, a Real Madrid köszönte szépen, és megnyerte a BL-t', 'A királyi gárda a londoni döntő végjátékában kétszer is betalált.', 'https://index.hu/bajnokokligaja/2024/06/01/bajnokok-ligaja-2023-2024-donto-dortmund-real-madrid-osszefoglalo-edin-terzic-carlo-ancelotti/')
# ('', '', 'Kitörhet-e újra a Badacsony? – Mert a székely Vezúv ugrásra kész', 'Van rá kevés esély, de egy másik helyi vulkán bármikor.', 'https://index.hu/tudomany/til/2024/06/01/kitorhet-e-ujra-a-badacsony-mert-a-szekely-vezuv-ugrasra-kesz/')
# ('', '', '120 millió forintot nyert egy szerencsés magyar szombat este', '26-an pedig több millió forintot nyertek. Mutatjuk az ötös lottó és a joker nyerőszámait.', 'https://index.hu/belfold/2024/06/01/otos-lotto-joker-szerencsejatek-szombat-este-/')
# ('', '', 'Debrecenben diónyi jég esett, Pécsett villámárvíz alakult ki az extrém időjárás miatt', 'Fák dőltek ki, és pincéket öntött el a hirtelen lezúduló nagy mennyiségű csapadék.', 'https://index.hu/belfold/2024/06/01/idojaras-radar-jegeso-debrecenben-villamarviz-pecsett/')
# ('Péter Alvarez', '2024.06.01. 20:59', 'Fasiztázás, orbánozás, brüsszelezés – így zajlott az EP-listavezetők vitája', 'Élő adásban csaptak össze egymással.', 'https://index.hu/kulfold/ep/2024/valasztas/2024/06/01/ep-listavezetok-vitaja-dobrev-klara-donath-anna-le-marietta-toroczkai-laszlo/')
# ('', '', 'Kroos gólpasszal tette emlékezetessé a búcsút: a Real a 15. BEK/BL-győzelmét ünnepelheti', 'Kroos gólpasszal tette emlékezetessé a búcsút.', 'https://index.hu/bajnokokligaja/2024/06/01/marco-reus-vagy-toni-kroos-bucsujat-aranyozza-be-a-wembley-dortmund-real-a-bl-dontoben/')
# ('', '', 'Bálint András: Ennek a díjnak rangja és értéke volt, múlt időben', 'A szakma szerint nem.', 'https://index.hu/kultur/2024/06/01/libri-irodalmi-dijak-balint-andras-zsuri-jaszberenyi-sandor-reakciok-irodalom-konyvek/')
# ('', '', 'A Ferrari magyar versenyzője győzni ment a Balaton Parkba, de a szombati helyére is büszke', 'A dobogós Válint Bence dolgát a riválisok mellett az időjárás is nehezítette.', 'https://index.hu/sport/motorsport/2024/06/01/ferrari-valint-bence-balaton-park-circuit-/')
# ('', '', 'Toni Kroos egyedi cipővel készült utolsó klubmérkőzésére', 'A felejthetetlen zárásra különleges feliratozás dukál.', 'https://index.hu/bajnokokligaja/2024/06/01/real-madrid-tony-kroos-bajnokok-ligaja-futball-labdarugas/')
# ('', '', 'Veszélyes lehet a kiskutyajóga, egy politikus szerint be kellene tiltani', 'Sokan aggódnak az állatok egészsége miatt.', 'https://index.hu/kulfold/2024/06/01/kutya-joga-veszelyes-betiltas-hollandia-europai-unio/')
# ('', '', 'A német bajnokkal és több volt játékosa ellen küzd meg a Győr a BL-döntőben', 'Az esemény újonca magabiztos második félidei játékkal múlta felül francia ellenfelét.', 'https://index.hu/sport/kezilabda/2024/06/01/noi-kezilabda-bl-final-four-elodonto-metz-bietigheim/')
# ('', '', 'Ungár Péter: Karácsony Gergely szavait egyszerűen nem lehet komolyan venni', 'A Vitézy Dávidot támogató LMP-s politikus így véleményezte a jelöltek vitáját.', 'https://index.hu/belfold/2024/06/01/fopolgarmester-jeloltek-vitaja-budapest-vitezy-david-karacsony-gergely-ungar-peter/')
# ('', '', 'Az Andrássy út biciklisávján parkolhattak a békemenetes buszok, nagy a felháborodás', 'Nem volt jó ötlet ma a belvárosban kerékpározni.', 'https://index.hu/belfold/2024/06/01/bekemenet-andrassy-ut-budapest-buszok-parkolas-orban-viktor-biciklisav/')
# ('', '', 'Török Gábor: Orbán Viktor még soha nem emelte ilyen magasra a tétet', 'Nagy Attila Tibor úgy látja: a kormányfő megzsarolta a választókat.', 'https://index.hu/belfold/2024/06/01/torok-gabor-nagy-attila-tibor-orban-viktor-beszed-reakcio/')
# ('', '', 'A klub megerősítette: tárgyalnak José Mario Dos Santos Mourinho Felixszel az edzői pozícióról', 'A megállapodás, és annak bejelentése egyelőre még várat magára.', 'https://index.hu/sport/futball/2024/06/01/jose-mourinho-fenerbahce-futball-labdarugas/')
# ('Baumgartner Benita', '2024.06.01. 18:44', '„Mi vagyunk a normálisok” – ilyen volt az idei Békemenet', 'Az Index stábja az idei Békemenet szervezőit és résztvevőit faggatta a demonstráció előtt.', 'https://index.hu/belfold/2024/06/01/bekemenet-orban-viktor-fidesz-bayer-zsolt-video/')
# ('', '', '„A Fidesz túlélte a válságot, indokolt Orbán magabiztossága”', 'Horn Gáborral és Mráz Ágoston Sámuellel értékeltük a kormányfő beszédét.', 'https://index.hu/belfold/2024/06/01/orban-viktor-beszed-elemzes-beke-valasztasok-mraz-agoston-samuel-horn-gabor/')
# ('', '', 'Milák Kristóf újra a régi, világcsúcstartónk Monacóban hazavágta Hondát', 'Alakulóban egy kisebbfajta csoda: fő számában 1:54 percen belüli, remek idővel győzött.', 'https://index.hu/sport/uszas/2024/06/01/mare-nostrum-milak-kristof-kim-monaco-uszas-/')
# ('', '', 'Ez első négy percben a buszon maradtunk – az ETO edzője a BL-elődöntőről', 'Johansson szerencséjére azonban volt még másik 56 percük felülkerekedni az Esbjergen...', 'https://index.hu/sport/kezilabda/2024/06/01/noi-kezi-bajnokok-ligaja-esbjerg-gyor-ertekelesek/')
# ('', '', '„Orbán Viktor a magyarok pénzéből finanszírozza Putyin ukrajnai háborúját” –  reakciók a kormányfő beszédére', 'Befutottak a reakciók a kormányfő békemenetes beszédére.', 'https://index.hu/belfold/2024/06/01/orban-viktor-bekemenet-beszed-ellenzeki-reakciok-dk-momentum-lmp/')
# ('', '', 'Ez már tényleg kínszenvedés: hetedik napja folyamatosan esik az eső a Roland Garroson', 'Panaszkodnak a játékosok és a szurkolók, a szervezők tehetetlenek.', 'https://index.hu/sport/tenisz/2024/06/01/roland-garros-2024-hetedik-nap-idojaras-csapadek-esoszunet-parizs/')
# ('', '', 'Vitézy Dávidnak üzent a Budapest Brand vezérigazgatója, jött is a válasz', 'A főpolgármester-jelölt szerint majd a választók eldöntik, mekkora összeg az ideális elköltésre.', 'https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/01/vitezy-david-budapest-brand-marketingszervezet-kijelentes-faix-csaba/')
# ('', '', 'Tokióban olimpiai bajnok volt, leszerződtette az NFL-csapat', 'Alig várja, hogy kamatoztassa a tapasztalatait.', 'https://index.hu/sport/amerikaifutball/2024/06/01/gable-steveson-nfl-amerikai-futball-olimpia/')
# ('', '', 'Magyar Péter a Békemenet után tett bejelentést', '', 'https://index.hu/belfold/2024/06/01/magyar-peter-tisza-part-peticio-kampany-haboru-orban-viktor-deutsch-tamas-bekemenet/')
# ('', '', 'Havazott az olasz Alpokban a nyár előestéjén', 'A nem mindennapi időjárási jelenségről több videót is készítettek a helyiek.', 'https://index.hu/kulfold/2024/06/01/olaszorszag-havazas-alpok-nyar-livigno-sondrio-megye/')
# ('', '', 'Settenkedő járművek veszélyeztetik a gyalogosokat, de van megoldás', 'Rászokunk a fülelésre.', 'https://index.hu/tudomany/2024/06/01/elektromos-auto-hibrid-baleset-zaj-kornyezet-kimelo/')
# ('', '', 'Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát', 'Átszámítva 180 millió forintos éves fizetéssel sikerült lekenyerezni.', 'https://index.hu/kulfold/2024/06/01/amerikai-egyesult-allamok-korrupcio-botrany-vesztegetes-robert-burke-haditengereszet-admiralis/')
# ('', '', 'Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle', 'Az amerikai világcsúcstartó legutóbb 2022 augusztusában állt rajthoz ebben a számban.', 'https://index.hu/sport/atletika/2024/06/01/atletika-olimpiai-bajnok-atlanta-gatfutas-sydney-mclaughlin-levrone-edwin-moses-classic/')
# ('', '', 'Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában', 'Több mint egy éve készült a műsor.', 'https://index.hu/kultur/2024/06/01/tompos-katya-szineszno-halala-utolso-interju/')
# ('', '', 'Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni', '„Amit eddig tettek, az nem volt elég hatással Oroszországra” – mondta.', 'https://index.hu/kulfold/2024/06/01/haboru-oroszorszag-ukrajna-europai-csapatok-ukrajnaban-glen-grant-brit-ezredes/')
# ('', '', 'Nem kímélték Magyar Pétert, minden kikerült az asztalra', 'Gulyás Márton szerint hajlamos a nagyotmondásra a Tisza Párt alelnöke.', 'https://index.hu/belfold/2024/06/01/magyar-peter-partizan-gulyas-marton-tisza-program/')
# ('Péter Alvarez', '2024.06.01. 16:52', 'Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje', 'A miniszterelnök beszédével ért véget a Békemenet.', 'https://index.hu/belfold/2024/06/01/orban-viktor-beszed-bekemenet-valasztasok-haboru/')

# %% [markdown]
# ## Fájlkezelés

# %%
if os.path.exists("output_index.csv"):
    os.remove("output_index.csv")

with open("output_index.csv", "a", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["author", "published", "title", "subtitle", "url"])
    writer.writerows(content)
    print("Fájl írása kész!")
# Out:
# Fájl írása kész!
