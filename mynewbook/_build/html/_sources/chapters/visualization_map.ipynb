# %% [markdown]
# # Vizualizáció térképen

# %% [markdown]
# ## Szükséges könyvtárak telepítése és importálása

# %%
# %pip install folium
# %pip install geopandas
# %pip install geopy

# %%
import folium
from geopy.distance import geodesic
from folium.plugins import MarkerCluster

# %% [markdown]
# ## Szükséges változók és adatok

# %%
marker_cluster = MarkerCluster()

m = folium.Map(
    location=[47.75558, 18.12893], zoom_start=9, scrollWheelZoom=False
)  # Komárom

cities = [
    {
        "city": "Komárom",
        "location": [47.75558, 18.12893],
        "major": "Alkalmazott informatika",
        "institute": "Selye János Egyetem",
        "distance": 0,
        "midpoint": 0,
    },
    {
        "city": "Pozsony",
        "location": [48.1361, 17.1030],
        "major": "",
        "institute": "Slovenská technická univerzita v Bratislave",
        "distance": 0,
        "midpoint": 0,
    },
    {
        "city": "Nagyszombat",
        "location": [48.3791, 17.5867],
        "major": "",
        "institute": "Trnavská univerzita v Trnave",
        "distance": 0,
        "midpoint": 0,
    },
    {
        "city": "Budapest",
        "location": [47.4816, 19.1300],
        "major": "",
        "institute": "Óbudai Egyetem",
        "distance": 0,
        "midpoint": 0,
    },
    {
        "city": "Győr",
        "location": [47.69366, 17.62800],
        "major": "",
        "institute": "Széchenyi István Egyetem",
        "distance": 0,
        "midpoint": 0,
    },
    {
        "city": "Nyitra",
        "location": [48.3134, 18.0855],
        "major": "",
        "institute": "Univerzita Konštantína Filozofa v Nitre",
        "distance": 0,
        "midpoint": 0,
    },
]

# %% [markdown]
# ### Egyedi jelölő létrehozása

# %%
def create_custom_icon(color, size):
    icon_html = f"""
    <div style="background-color:{color}; width:{'10px' if size=='large' else '5px'}; height:{'10px' if size=='large' else '5px'}; 
                border-radius: {'50%'}; border-color:{"black"}"></div>
    """
    return folium.DivIcon(html=icon_html)

# %% [markdown]
# ## Jelölők elhelyezése a térképen

# %%
for city in cities:
    folium.Marker(
        color="red",
        location=city["location"],
        tooltip=city["major"],
        popup=city["city"],
        icon=create_custom_icon("red", "large"),
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6a2c990c8ea94716c9c37aec9dc769c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6a2c990c8ea94716c9c37aec9dc769c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6a2c990c8ea94716c9c37aec9dc769c = L.map(
#                 &quot;map_b6a2c990c8ea94716c9c37aec9dc769c&quot;,
#                 {
#                     center: [47.75558, 18.12893],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f79478c2bf0d950956f8d35ee99e1227 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f79478c2bf0d950956f8d35ee99e1227.addTo(map_b6a2c990c8ea94716c9c37aec9dc769c);
#
#
#             var marker_3e04cf08d44c09db249ae3eff3a95d0c = L.marker(
#                 [47.75558, 18.12893],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_b6a2c990c8ea94716c9c37aec9dc769c);
#
#
#             var div_icon_53f62f043477e2ba7ed3d0463da46ec9 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_3e04cf08d44c09db249ae3eff3a95d0c.setIcon(div_icon_53f62f043477e2ba7ed3d0463da46ec9);
#
#
#         var popup_b3d9535a517e1c3479d1e2afb5358426 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50acfa54b4c938f4c413ba99ed7d659c = $(`&lt;div id=&quot;html_50acfa54b4c938f4c413ba99ed7d659c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Komárom&lt;/div&gt;`)[0];
#                 popup_b3d9535a517e1c3479d1e2afb5358426.setContent(html_50acfa54b4c938f4c413ba99ed7d659c);
#
#
#
#         marker_3e04cf08d44c09db249ae3eff3a95d0c.bindPopup(popup_b3d9535a517e1c3479d1e2afb5358426)
#         ;
#
#
#
#
#             marker_3e04cf08d44c09db249ae3eff3a95d0c.bindTooltip(
#                 `&lt;div&gt;
#                      Alkalmazott informatika
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f7d4150b65a91dd1018096f534aae4c6 = L.marker(
#                 [48.1361, 17.103],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_b6a2c990c8ea94716c9c37aec9dc769c);
#
#
#             var div_icon_3a063732f1e9540a770de99200c83c1c = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_f7d4150b65a91dd1018096f534aae4c6.setIcon(div_icon_3a063732f1e9540a770de99200c83c1c);
#
#
#         var popup_e3f3fb801b33125c725660fa8acbcc8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c75eb3db7f943d0cb449f572c438183 = $(`&lt;div id=&quot;html_7c75eb3db7f943d0cb449f572c438183&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pozsony&lt;/div&gt;`)[0];
#                 popup_e3f3fb801b33125c725660fa8acbcc8b.setContent(html_7c75eb3db7f943d0cb449f572c438183);
#
#
#
#         marker_f7d4150b65a91dd1018096f534aae4c6.bindPopup(popup_e3f3fb801b33125c725660fa8acbcc8b)
#         ;
#
#
#
#
#             marker_f7d4150b65a91dd1018096f534aae4c6.bindTooltip(
#                 `&lt;div&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8fda5681dee56ea01156d6f7f41cf5f8 = L.marker(
#                 [48.3791, 17.5867],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_b6a2c990c8ea94716c9c37aec9dc769c);
#
#
#             var div_icon_dbf790c3802a5bc9dd02f07860fde02a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_8fda5681dee56ea01156d6f7f41cf5f8.setIcon(div_icon_dbf790c3802a5bc9dd02f07860fde02a);
#
#
#         var popup_af484d9887e202616de0f952a5549e94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48bf55ab5ecd21570649ac998b3ec96a = $(`&lt;div id=&quot;html_48bf55ab5ecd21570649ac998b3ec96a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nagyszombat&lt;/div&gt;`)[0];
#                 popup_af484d9887e202616de0f952a5549e94.setContent(html_48bf55ab5ecd21570649ac998b3ec96a);
#
#
#
#         marker_8fda5681dee5

# %% [markdown]
# ## Városok közti távolság meghatározása és városok összekötése

# %%
for city in cities:
    city["distance"] = geodesic(cities[0]["location"], city["location"]).kilometers
    city["midpoint"] = (
        (cities[0]["location"][0] + city["location"][0]) / 2,
        (cities[0]["location"][1] + city["location"][1]) / 2,
    )
    folium.PolyLine(
        locations=[cities[0]["location"], city["location"]],
        color="blue",
        dash_array="10",
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6a2c990c8ea94716c9c37aec9dc769c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6a2c990c8ea94716c9c37aec9dc769c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6a2c990c8ea94716c9c37aec9dc769c = L.map(
#                 &quot;map_b6a2c990c8ea94716c9c37aec9dc769c&quot;,
#                 {
#                     center: [47.75558, 18.12893],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f79478c2bf0d950956f8d35ee99e1227 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f79478c2bf0d950956f8d35ee99e1227.addTo(map_b6a2c990c8ea94716c9c37aec9dc769c);
#
#
#             var marker_3e04cf08d44c09db249ae3eff3a95d0c = L.marker(
#                 [47.75558, 18.12893],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_b6a2c990c8ea94716c9c37aec9dc769c);
#
#
#             var div_icon_53f62f043477e2ba7ed3d0463da46ec9 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_3e04cf08d44c09db249ae3eff3a95d0c.setIcon(div_icon_53f62f043477e2ba7ed3d0463da46ec9);
#
#
#         var popup_b3d9535a517e1c3479d1e2afb5358426 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50acfa54b4c938f4c413ba99ed7d659c = $(`&lt;div id=&quot;html_50acfa54b4c938f4c413ba99ed7d659c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Komárom&lt;/div&gt;`)[0];
#                 popup_b3d9535a517e1c3479d1e2afb5358426.setContent(html_50acfa54b4c938f4c413ba99ed7d659c);
#
#
#
#         marker_3e04cf08d44c09db249ae3eff3a95d0c.bindPopup(popup_b3d9535a517e1c3479d1e2afb5358426)
#         ;
#
#
#
#
#             marker_3e04cf08d44c09db249ae3eff3a95d0c.bindTooltip(
#                 `&lt;div&gt;
#                      Alkalmazott informatika
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f7d4150b65a91dd1018096f534aae4c6 = L.marker(
#                 [48.1361, 17.103],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_b6a2c990c8ea94716c9c37aec9dc769c);
#
#
#             var div_icon_3a063732f1e9540a770de99200c83c1c = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_f7d4150b65a91dd1018096f534aae4c6.setIcon(div_icon_3a063732f1e9540a770de99200c83c1c);
#
#
#         var popup_e3f3fb801b33125c725660fa8acbcc8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c75eb3db7f943d0cb449f572c438183 = $(`&lt;div id=&quot;html_7c75eb3db7f943d0cb449f572c438183&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pozsony&lt;/div&gt;`)[0];
#                 popup_e3f3fb801b33125c725660fa8acbcc8b.setContent(html_7c75eb3db7f943d0cb449f572c438183);
#
#
#
#         marker_f7d4150b65a91dd1018096f534aae4c6.bindPopup(popup_e3f3fb801b33125c725660fa8acbcc8b)
#         ;
#
#
#
#
#             marker_f7d4150b65a91dd1018096f534aae4c6.bindTooltip(
#                 `&lt;div&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8fda5681dee56ea01156d6f7f41cf5f8 = L.marker(
#                 [48.3791, 17.5867],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_b6a2c990c8ea94716c9c37aec9dc769c);
#
#
#             var div_icon_dbf790c3802a5bc9dd02f07860fde02a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_8fda5681dee56ea01156d6f7f41cf5f8.setIcon(div_icon_dbf790c3802a5bc9dd02f07860fde02a);
#
#
#         var popup_af484d9887e202616de0f952a5549e94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48bf55ab5ecd21570649ac998b3ec96a = $(`&lt;div id=&quot;html_48bf55ab5ecd21570649ac998b3ec96a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nagyszombat&lt;/div&gt;`)[0];
#                 popup_af484d9887e202616de0f952a5549e94.setContent(html_48bf55ab5ecd21570649ac998b3ec96a);
#
#
#
#         marker_8fda5681dee5

# %%
for i in range(1, len(cities)):
    folium.Marker(
        location=cities[i]["midpoint"],
        icon=folium.DivIcon(
            html=f'<div style="font-size: 12pt; color: black; background-color: rgba(255, 255, 255, 0.75); padding: 2px; border-radius:10px;display: inline-block;">{cities[i]["distance"]:.2f}km</div>'
        ),
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6a2c990c8ea94716c9c37aec9dc769c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6a2c990c8ea94716c9c37aec9dc769c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6a2c990c8ea94716c9c37aec9dc769c = L.map(
#                 &quot;map_b6a2c990c8ea94716c9c37aec9dc769c&quot;,
#                 {
#                     center: [47.75558, 18.12893],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f79478c2bf0d950956f8d35ee99e1227 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f79478c2bf0d950956f8d35ee99e1227.addTo(map_b6a2c990c8ea94716c9c37aec9dc769c);
#
#
#             var marker_3e04cf08d44c09db249ae3eff3a95d0c = L.marker(
#                 [47.75558, 18.12893],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_b6a2c990c8ea94716c9c37aec9dc769c);
#
#
#             var div_icon_53f62f043477e2ba7ed3d0463da46ec9 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_3e04cf08d44c09db249ae3eff3a95d0c.setIcon(div_icon_53f62f043477e2ba7ed3d0463da46ec9);
#
#
#         var popup_b3d9535a517e1c3479d1e2afb5358426 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50acfa54b4c938f4c413ba99ed7d659c = $(`&lt;div id=&quot;html_50acfa54b4c938f4c413ba99ed7d659c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Komárom&lt;/div&gt;`)[0];
#                 popup_b3d9535a517e1c3479d1e2afb5358426.setContent(html_50acfa54b4c938f4c413ba99ed7d659c);
#
#
#
#         marker_3e04cf08d44c09db249ae3eff3a95d0c.bindPopup(popup_b3d9535a517e1c3479d1e2afb5358426)
#         ;
#
#
#
#
#             marker_3e04cf08d44c09db249ae3eff3a95d0c.bindTooltip(
#                 `&lt;div&gt;
#                      Alkalmazott informatika
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f7d4150b65a91dd1018096f534aae4c6 = L.marker(
#                 [48.1361, 17.103],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_b6a2c990c8ea94716c9c37aec9dc769c);
#
#
#             var div_icon_3a063732f1e9540a770de99200c83c1c = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_f7d4150b65a91dd1018096f534aae4c6.setIcon(div_icon_3a063732f1e9540a770de99200c83c1c);
#
#
#         var popup_e3f3fb801b33125c725660fa8acbcc8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c75eb3db7f943d0cb449f572c438183 = $(`&lt;div id=&quot;html_7c75eb3db7f943d0cb449f572c438183&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pozsony&lt;/div&gt;`)[0];
#                 popup_e3f3fb801b33125c725660fa8acbcc8b.setContent(html_7c75eb3db7f943d0cb449f572c438183);
#
#
#
#         marker_f7d4150b65a91dd1018096f534aae4c6.bindPopup(popup_e3f3fb801b33125c725660fa8acbcc8b)
#         ;
#
#
#
#
#             marker_f7d4150b65a91dd1018096f534aae4c6.bindTooltip(
#                 `&lt;div&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8fda5681dee56ea01156d6f7f41cf5f8 = L.marker(
#                 [48.3791, 17.5867],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_b6a2c990c8ea94716c9c37aec9dc769c);
#
#
#             var div_icon_dbf790c3802a5bc9dd02f07860fde02a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n    \u003cdiv style=\&quot;background-color:red; width:10px; height:10px; \n                border-radius: 50%; border-color:black\&quot;\u003e\u003c/div\u003e\n    &quot;});
#             marker_8fda5681dee56ea01156d6f7f41cf5f8.setIcon(div_icon_dbf790c3802a5bc9dd02f07860fde02a);
#
#
#         var popup_af484d9887e202616de0f952a5549e94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48bf55ab5ecd21570649ac998b3ec96a = $(`&lt;div id=&quot;html_48bf55ab5ecd21570649ac998b3ec96a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nagyszombat&lt;/div&gt;`)[0];
#                 popup_af484d9887e202616de0f952a5549e94.setContent(html_48bf55ab5ecd21570649ac998b3ec96a);
#
#
#
#         marker_8fda5681dee5
