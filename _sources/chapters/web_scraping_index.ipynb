# %% [markdown]
# # Index híreinek kigyűjtése
#
# A <a href="https://index.hu/24ora/">index.hu/24ora</a> struktúrája szintén kellemes, gyakorlásra alkalmas.

# %% [markdown]
# ## Szükséges könyvtárak letöltése, importálása

# %%
# %pip install bs4

# %%
import os
import csv
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## Weboldal HTML struktúrájának letöltése

# %%
url = "https://index.hu/24ora/"
page = requests.get(url)
soup = bs(page.text, "html.parser")

print(soup)

with open("sample_index.html", "w", encoding="utf-8") as file:
    file.write(soup.prettify())
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="hu" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <head>
# <title>Hírek - 24 óra - Index.hu</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=EmulateIE11" http-equiv="X-UA-Compatible"/>
# <!-- [if IE]>
#         <meta http-equiv="imagetoolbar" content="no" />
#         <meta name="MSSmartTagsPreventParsing" content="true" />
#         <meta http-equiv="X-UA-Compatible" content="IE=Edge">
#         <![endif]-->
# <meta content="1717167770" name="manis:deploy">
# <meta name="manis:breakpoint"/>
# <meta name="manis:breakpoints"/>
# <meta content="https://index.hu/copyright/" name="copyright">
# <meta content="unsafe-url" name="referrer"/>
# <meta content="app-id=480103271" name="apple-itunes-app"/>
# <meta content="app-id=com.aff.index.main" name="google-play-app"/>
# <meta content="noindex" name="robots"/> <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <meta content="330827937019153" property="fb:app_id"><meta content="667823645" property="fb:admins"><meta content="560525343980775,348326671885918" property="fb:pages"><meta content="Friss hírek és információk az Indexen" name="description"> <meta content="https://index.hu/assets/images/facebook_logo.png?v5" property="og:image"/><meta content="https://www.facebook.com/Indexhu" property="article:publisher"/><meta content="summary_large_image" name="twitter:card"/><meta content="@indexhu" name="twitter:site"/><meta content="https://index.hu/assets/images/facebook_logo.png" name="twitter:image:src"/> <link href="/assets/static/opensearch.xml" rel="search" title="Index" type="application/opensearchdescription+xml"/>
# <link href="/copyright/" rel="copyright" title="Szerzői jogok"/>
# <link href="/impresszum/" rel="author" title="Impresszum"/>
# <link href="/" id="homelink" rel="home" title=""/>
# <link href="/assets/images/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/assets/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/assets/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/assets/images/favicons/manifest.json" rel="manifest"/>
# <link href="/assets/images/favicons/favicon.ico" rel="shortcut icon"/>
# <link color="#ff9900" href="/assets/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="Index" name="apple-mobile-web-app-title"/>
# <meta content="Index" name="application-name"/>
# <meta content="#ffffff" name="theme-color"/>
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <link href="https://index.hu/assets/static/indexnew_css/public/global.css?v=1717167720" rel="stylesheet" type="text/css"><link href="https://index.hu/assets/static/indexnew_css/public/index-global.css?v=1717167720" rel="stylesheet" type="text/css"> <link href="https://index.hu/assets/static/indexnew_css/public/rovat.css?v=1717167720" rel="stylesheet" type="text/css">
# <link href="https://index.hu/assets/static/indexnew_css/public/fixed_header.css?v=1717167720" rel="stylesheet" type="text/css">
# <link href="https://index.hu/assets/static/indexnew_css/public/24ora.css?v=1717167720" rel="stylesheet" type="text/css">
# <link href="/24ora/rss/" rel="alternate" title="24óra cikkek" type="application/rss+xml">
# <meta content="1" name="logcustomtarget">
# <!-- i8 -->
# <script src="https://index.hu/ident/getall/?c=aTg=" type="text/javascript"></script>
# <script src="https://index.hu/assets/static/js/public/index_vendor.ugly.js?v=1717167721" type="text/javascript"></script>
# <script src="https://index.hu/assets/static/js/public/index_base.ugly.js?v=1717167721" type="text/javascript"></script>
# <script src="https://index.hu/assets/static/js/public/index_election.ugly.js?v=1717167721" type="text/javascript"></script>
# <script src="https://index.hu/assets/static/js/public/cemp_fejlec.ugly.js?v=1717167721" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/index.rovat.min.js?v=1710407521" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/autocomplete.min.js?v=1717167770" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/calendar.min.js?v=1717167770" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/chosen2.min.js?v=1717167770" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/jquery-ui.min.js?v=1717167770" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/index.24ora.min.js?v=1717167770" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/scrolling_shadow.js?v=1717167770" type="text/javascript"></script>
# <script src="https://index.hu/assets/js/pip_video.min.js?v=1717167770" type="text/javascript"></script>
# <script type="text/javascript">
#         var _gaq = { push: function() {} };
#         ( function( i, s, o, g, r, a, m ) {
#             i[ 'GoogleAnalyticsObject' ] = r;
#             i[ r ] = i[ r ] || function() {
#                 ( i[ r ].q = i[ r ].q || [] ).push( arguments )
#             }, i[ r ].l = 1 * new Date();
#             a = s.createElement( o ), m = s.getElementsByTagName( o )[ 0 ];
#             a.async = 1;
#             a.src=g;
#             m.parentNode.insertBefore( a, m )
#         } )( window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga' );
#         var oldaltipus = '24ora_cimlap';
#         ( function( $ ) {
#             window.scrollTrackerEnabled = 1;
#             window.Analytics = {
#                 add: function( command, params, target ) {
#                     if( typeof command === 'undefined' || typeof params === 'undefined' || !command || !params ) {
#                         return this;
#                     }
#                     params.location = ( params.location || document.location.href ).replace( '//m.', '//' );
#                     if( this.loaded ) {
#                         if( typeof target !== 'undefined' ) {
#                             command = target + '.' + command;
#                         }
#                         ga( command, params );
#                     }
#                     else {
#                         this.stack.push( [ command, $.extend( {}, params ), target ] );
#                     }
#                     return this;
#                 },
#                 process: function() {
#                     if( this.loaded ) {
#                         return;
#                     }
#                     var arg;
#                     while( this.stack.length ) {
#                         arg = this.stack.shift();
#                         if( typeof arg[ 2 ] !== 'undefined' && Common[ 'ga_' + arg[ 2 ] ] === true ) {
#                             arg[ 0 ] = arg[ 2 ] + '.' + arg[ 0 ];
#                         }
#                         ga( arg[ 0 ], arg[ 1 ] );
#                     }
#                     this.loaded = true;
#                 },
#                 stack: []
#             };
#             $( document ).on( 'ready', function() {
#                 if( typeof window.Common === 'undefined' ) {
#                     window.Common = {
#                         ga_secondary: false
#                     };
#                 }
#                 if( typeof __passportHeader_config === 'undefined' ) {
#                     __passportHeader_config = {};
#                 }
#                 Common.ga_secondary = false;
#                 var ga_base_config = {
#                     sampleRate: 100,
#                     trackingId: 'UA-181415-27'
#                 };
#                 var ga_set_config = {
#                     dimension1: '24ora_cimlap',
#                     dimension2: ( __passportHeader_config.loggedIn ? '' : 'Not' ) + 'LoggedIn',
#                                             dimension3: Page.getLayout(),
#                                                                                 language: document.domain === 'totalcarmagazine.com' ? 'en-us' : 'hu-hu',
#                     location: document.location.href.replace( '//m.', '//' )
#                 };
#                 if( typeof __passportHeaderUserId !== 'undefined' ) {
#                     ga_base_config.userId = __passportHeaderUserId;
#                 }
#                 ga( 'create', ga_base_config );
#                 ga( 'require', 'displayfeatures' );
#                 ga( 'set', ga_set_config );
#                                     Common.ga_secondary = true;
#                     var ga_secondary_config = $.extend( {}, ga_base_config );
#                     ga_secondary_config.name = 'secondary';
#                     ga_secondary_config.trackingId = 'UA-181415-11';
#                     ga_secondary_config.sampleRate = 10;
#                     ga( 'create', ga_secondary_config );
#                     ga( 'secondary.require', 'displayfeatures' );
#                     ga( 'secondary.set', ga_set_config );
#                                 ga('set', 'anonymizeIp', true);
#                 // cross_site ajanlo kivetelkezelese
#                 if(
#                     (
#                         $( '#passportHeader, #_iph_fixed-header' ).length ||
#                         $( '#inforadio_audioplayer1' ).length ||
#                         $( '.header_send').length ||
#                         document.location.host.indexOf( 'm.' ) === 0 ||
#                         document.location.host.substring( document.location.host.length - 4 ) === '.com'
#                     ) &&
#                     ((Common.topfolder !== 'i2' && Common.topfolder !== 'index2') || !Common.parsed_url.hash || Common.parsed_url.hash.indexOf( '#bloghu' ) !== 0 )
#                 ) {
#                     ga( 'send', 'pageview' );
#                     if( Common.ga_secondary ) {
#                         ga( 'secondary.send', 'pageview' );
#                     }
#                 }
#                 Analytics.process();
#             } );
#         } )( jQuery );
#     </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-7GR3T85C96"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         var ga4params = {"content_group":"24ora\/","rovat":"24\u00f3ra","oldaltipus":"24ora_cimlap","cikktipus":"Keres\u0151"};
#         ga4params.layout = Page.getLayout();
#         ga4params.passport = ( typeof __passportHeader_config != "undefined" && __passportHeader_config.loggedIn ? '' : 'Not' ) + 'LoggedIn';
#         gtag('js', new Date());
#         gtag('config', 'G-7GR3T85C96', ga4params);
#     </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-PPDGL3DR');</script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript">
#         Common.folder_id = 267;
#         Common.folder_parent_ids = [ 261 ];
#         Common.is_new_design = 1;
#     </script>
# <script>
#     window.fbAsyncInit = function() {
#         FB.init({
#             appId      : '330827937019153',
#             xfbml      : true,
#             status     : false,
#             version    : 'v5.0'
#         });
#         window.fb_initialized = true;
#     };
#
#     (function(d, s, id) {
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) return;
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/hu_HU/sdk.js";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
# </script>
# <script type="text/javascript">
#         $(function () {
#             window.LinkPreview && window.LinkPreview.init();
#         });
#     </script>
# <script type="text/javascript"><!--//--><![CDATA[//><!--
#     var IndexStatConfig = {
#         pixels: [ { id: 267, type: 2 }, { id: 261, type: 3 }, { id: 1, type: 5 }, { id: 2, type: 4 }],
#         device: 'desktop'
#     }
#     //--><!]]>
# </script>
# <script async="" src="//indexstat.index.hu/stat.min.js?dd=20240601" type="text/javascript"></script>
# <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script async="true" type="text/javascript">
#     var nuCmp = true; try { Promise.resolve(1).finally() } catch(e) { nuCmp = false; }
#     if (nuCmp) {
#         (function() {
#             var host = 'index.hu';
#             var element = document.createElement('script');
#             var firstScript = document.getElementsByTagName('script')[0];
#             var url = 'https://cmp.quantcast.com'
#                 .concat('/choice/', '4z9XXyvnuPTjK', '/', host, '/choice.js?tag_version=V2');
#             var uspTries = 0;
#             var uspTriesLimit = 3;
#             element.async = true;
#             element.type = 'text/javascript';
#             element.src = url;
#
#             firstScript.parentNode.insertBefore(element, firstScript);
#
#             function makeStub() {
#                 var TCF_LOCATOR_NAME = '__tcfapiLocator';
#                 var queue = [];
#                 var win = window;
#                 var cmpFrame;
#
#                 function addFrame() {
#                     var doc = win.document;
#                     var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#                     if (!otherCMP) {
#                         if (doc.body) {
#                             var iframe = doc.createElement('iframe');
#
#                             iframe.style.cssText = 'display:none';
#                             iframe.name = TCF_LOCATOR_NAME;
#                             doc.body.appendChild(iframe);
#                         } else {
#                             setTimeout(addFrame, 5);
#                         }
#                     }
#                     return !otherCMP;
#                 }
#
#                 function tcfAPIHandler() {
#                     var gdprApplies;
#                     var args = arguments;
#
#                     if (!args.length) {
#                         return queue;
#                     } else if (args[0] === 'setGdprApplies') {
#                         if (
#                             args.length > 3 &&
#                             args[2] === 2 &&
#                             typeof args[3] === 'boolean'
#                         ) {
#                             gdprApplies = args[3];
#                             if (typeof args[2] === 'function') {
#                                 args[2]('set', true);
#                             }
#                         }
#                     } else if (args[0] === 'ping') {
#                         var retr = {
#                             gdprApplies: gdprApplies,
#                             cmpLoaded: false,
#                             cmpStatus: 'stub'
#                         };
#
#                         if (typeof args[2] === 'function') {
#                             args[2](retr);
#                         }
#                     } else {
#                         if(args[0] === 'init' && typeof args[3] === 'object') {
#                             args[3] = { ...args[3], tag_version: 'V2' };
#                         }
#                         queue.push(args);
#                     }
#                 }
#
#                 function postMessageEventHandler(event) {
#                     var msgIsString = typeof event.data === 'string';
#                     var json = {};
#
#                     try {
#                         if (msgIsString) {
#                             json = JSON.parse(event.data);
#                         } else {
#                             json = event.data;
#                         }
#                     } catch (ignore) {}
#
#                     var payload = json.__tcfapiCall;
#
#                     if (payload) {
#                         window.__tcfapi(
#                             payload.command,
#                             payload.version,
#                             function(retValue, success) {
#                                 var returnMsg = {
#                                     __tcfapiReturn: {
#                                         returnValue: retValue,
#                                         success: success,
#                                         callId: payload.callId
#                                     }
#                                 };
#                                 if (msgIsString) {
#                                     returnMsg = JSON.stringify(returnMsg);
#                                 }
#                                 if (event && event.source && event.source.postMessage) {
#                                     event.source.postMessage(returnMsg, '*');
#                                 }
#                             },
#                             payload.parameter
#                         );
#                     }
#                 }
#
#                 while (win) {
#                     try {
#                         if (win.frames[TCF_LOCATOR_NAME]) {
#                             cmpFrame = win;
#                             break;
#                         }
#                     } catch (ignore) {}
#
#                     if (win === window.top) {
#                         break;
#                     }
#                     win = win.parent;
#                 }
#                 if (!cmpFrame) {
#                     addFrame();
#                     win.__tcfapi = tcfAPIHandler;
#                     win.addEventListener('message', postMessageEventHandler, false);
#                 }
#             };
#
#             makeStub();
#
#             var uspStubFunction = function() {
#                 var arg = arguments;
#                 if (typeof window.__uspapi !== uspStubFunction) {
#                     setTimeout(function() {
#                         if (typeof window.__uspapi !== 'undefined') {
#                             window.__uspapi.apply(window.__uspapi, arg);
#                         }
#                     }, 500);
#                 }
#             };
#
#             var checkIfUspIsReady = function() {
#                 uspTries++;
#                 if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#                     console.warn('USP is not accessible');
#                 } else {
#                     clearInterval(uspInterval);
#                 }
#             };
#
#             if (typeof window.__uspapi === 'undefined') {
#                 window.__uspapi = uspStubFunction;
#                 var uspInterval = setInterval(checkIfUspIsReady, 6000);
#             }
#         })();
#     }
# </script>
# <!-- End Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script src="//indexhu.adocean.pl/files/js/ado.js" type="text/javascript"></script>
# <script>
#     window.adocf = {};
#     window.adocf.useDOMContentLoaded = true;
#     window.iap_base = 'https://index.hu/';
#     var tagStr = document.querySelector('meta[name="keywords"]') ? document.querySelector('meta[name="keywords"]').getAttribute("content").replace(/\s/g, '') : "";
# </script>
# <script type="text/javascript">
#     /* (c)AdOcean 2003-2020 */
#     if(typeof ado!=="object"){ado={};ado.config=ado.preview=ado.placement=ado.master=ado.slave=function(){};}
#     ado.config({mode: "new", xml: false, consent: true, characterEncoding: true, attachReferrer: true, fpc: "auto" , defaultServer:"indexhu.adocean.pl" ,cookieDomain:"SLD"});
#     ado.preview({enabled: true});
#     /* (c)AdOcean 2003-2020, MASTER: c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87 */
#     ado.master({id: 'c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87', server: 'indexhu.adocean.pl', vars: typeof customTargetAdocean !== "undefined" ? customTargetAdocean : '', keys: tagStr });
# </script>
# <script type="module">
#     document.addEventListener('DOMContentLoaded', async () => {
#         const { Loader } = await (await import('https://iap.cdn.indexvas.hu/Scripts.js')).default;
#         window.GoaLoader = new Loader({"debug":false,"engine":"AdOcean","master":"c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87","stat":true})
#     })
# </script>
# <script type="text/javascript">
#     Common.maxFeedAjanloLoadCount = 1;
#     Common.feedAjanloLoadCount = 3;
#     Common.feedAjanloMoreButton = 1;
#     Common.feedAjanloTovabbUrl = "https://index.hu/24ora/";
# </script>
# <link href="/manifest.json" rel="manifest"/>
# <script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js"></script>
# <script>
#     var OneSignal = window.OneSignal || [];
#     OneSignal.push(function() {
#         OneSignal.sendTags({
#             is_web: true
#         });
#         OneSignal.init({
#             appId: "bd30d7a1-7b22-4adb-bacf-e4bf80d25bf7",
#             autoRegister: false,
#             notifyButton: {
#                 enable: true
#             }
#         });
#     });
# </script>
# <script>
#     window.googletag = window.googletag || {cmd: []};
#     googletag.cmd.push(function() {
#                 googletag.pubads().enableSingleRequest();
#                 googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#             if(!event.isEmpty) {
#                 $(document.getElementById(event.slot.getSlotElementId())).closest(".mobile-sticky").show().find("button.mobile-sticky-closing").on("click", function(){
#                     $(this).closest(".mobile-sticky").hide();
#                 });
#             }
#         });
#         googletag.enableServices();
#     });
# </script>
# </meta></link></link></link></link></link></link></meta></meta></meta></meta></meta></meta></meta></head>
# <body class="device_desktop indexhu rovat h24ora rovat_24ora iframe_disallowed">
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PPDGL3DR" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div id="fb-root"></div>
# <script>(function() {
#   var _fbq = window._fbq || (window._fbq = []);
#   if (!_fbq.loaded) {
#     var fbds = document.createElement('script');
#     fbds.async = true;
#     fbds.src = '//connect.facebook.net/en_US/fbds.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(fbds, s);
#     _fbq.loaded = true;
#   }
#   _fbq.push(['addPixelId', '551982981568628']);
# })();
# window._fbq = window._fbq || [];
# window._fbq.push(['track', 'PixelInitialized', {}]);
# </script>
# <noscript><img alt="" height="1" src="https://www.facebook.com/tr?id=551982981568628&amp;ev=PixelInitialized" style="display:none" width="1"/></noscript>
# <div class="layer xl_layer">
# <div class="iap iap--ado ad-label--hidden no-padding no-margin" data-id="adoceanindexhulmgghmhsud" id="adoceanindexhulmgghmhsud">
# <script class="iap-script">
#                                                             window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhulmgghmhsud","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_Layer","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#                                                         </script>
# </div>
# <div class="iap iap--ado ad-label--hidden no-padding no-margin" data-id="ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7" id="ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7">
# <script class="iap-script">
#                                                             window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7","empty":true,"lazy":false,"quality":false,"masterless":true,"area":"Index_Aloldalak_Layer_gde_test","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#                                                         </script>
# </div>
# </div>
# <div class="sticky">
# </div>
# <div class="container" id="ad_null_position">
# </div>
# <div aria-hidden="true" class="m-cf-search modal" data-backdrop="false" data-js-modal-window="search" role="dialog" style="display: none" tabindex="-1">
# <div class="m-cf-search_wrapper">
# <div class="m-cf-search_wrapper_container" data-js-cemp-search="container">
# <form action="https://index.hu/24ora/" class="m-cf-search_wrapper_container_form" method="get">
# <input name="word" type="hidden" value="1"/>
# <input name="pepe" type="hidden" value="1"/>
# <input name="tol" type="hidden" value="1999-01-01"/>
# <input name="ig" type="hidden" value="2024-06-01"/>
# <input class="m-cf-search_wrapper_container_form_input" data-js-cemp-search="input" name="s" placeholder="Keresés" tabindex="0" type="search"/>
# <button class="m-cf-search_wrapper_container_form_button" type="submit">
# <span class="m-cf-search_wrapper_container_form_button_wrapper">
# <svg class="m-cf-search_wrapper_container_form_button_wrapper_icon" style="height:21px;width:21px;" viewbox="0 0 21 21"><path d="M20.8 18.867c.267.267.267.7 0 .967l-.966.967c-.267.267-.7.267-.966 0L13.5 15.434c-.073-.074-.122-.16-.155-.253-1.39 1.014-3.094 1.62-4.944 1.62-4.64 0-8.4-3.76-8.4-8.4C0 3.76 3.76 0 8.4 0c4.64 0 8.4 3.76 8.4 8.4 0 1.85-.606 3.556-1.62 4.945.092.032.18.08.253.155l5.368 5.367zM8.4 2.8c-3.093 0-5.6 2.507-5.6 5.6 0 3.093 2.507 5.6 5.6 5.6 3.093 0 5.6-2.507 5.6-5.6 0-3.093-2.507-5.6-5.6-5.6z"></path></svg>
# <span class="m-cf-search_wrapper_container_form_button_wrapper_label h-visibility-off_small-down">Keresés</span>
# </span>
# </button>
# </form>
# </div>
# </div>
# </div>
# <div class="m-cf-indalista" data-js-dropdown="inda">
# <div class="m-cf-indalista_container">
# <ul class="m-cf-indalista_container_list">
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="blog.hu" href="https://blog.hu/" target="_blank">Blog.hu</a>
# </li>
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="forum" href="http://forum.index.hu/Topic/showTopicList" target="_blank">Fórum</a>
# </li>
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="indavideo" href="http://indavideo.hu/" target="_blank">Indavideó</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-cf-kiadvanylista">
# <div class="m-cf-kiadvanylista_container">
# <ul class="m-cf-kiadvanylista_container_list">
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Economx" data-target="economx" href="https://www.economx.hu" target="_blank">Economx</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Dívány" data-target="divany" href="https://divany.hu/" target="_blank">Dívány</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Totalcar" data-target="totalcar" href="https://totalcar.hu/" target="_blank">Totalcar</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Femina" data-target="femina" href="https://femina.hu/" target="_blank">Femina</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Port" data-target="port" href="https://port.hu/" target="_blank">Port</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="We ❤︎ Budapest" data-target="we_x2764_xfe0e_budapest" href="https://welovebudapest.com/" target="_blank">We ❤︎ Budapest</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Velvet" data-target="velvet" href="https://velvet.hu/" target="_blank">Velvet</a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <button class="m-cf-kiadvanylista_container_list_item_inda" data-target="[data-js-dropdown=inda]" data-toggle="dropdown" type="button">
# <span class="m-cf-kiadvanylista_container_list_item_inda_container">
# <span class="m-cf-kiadvanylista_container_list_item_inda_container_label">Inda</span>
# <svg class="m-cf-kiadvanylista_container_list_item_inda_container_icon" viewbox="0 0 11 7">
# <path d="M5.5 5.125L1.032.657C.846.47.534.467.344.657c-.185.184-.19.497 0 .687l4.812 4.812c.092.092.217.14.342.14.125 0 .25-.045.346-.14l4.812-4.812c.185-.185.19-.498 0-.688-.184-.184-.498-.19-.688 0L5.5 5.127z"></path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-cf-fejlec">
# <div class="m-cf-fejlec_container">
# <div class="m-cf-fejlec_container_wrapper">
# <ul class="m-cf-fejlec_container_links">
# <li class="m-cf-fejlec_container_links_item itemCover">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Címlap" href="https://dex.hu/x.php?id=fxdfejlecpnc&amp;url=https%3A%2F%2Findex.hu%2F">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_logo" viewbox="-54 12 8 20"><path class="m-cf-fejlec_container_links_item_link_container_logo_stem" d="M-54 18h8v14h-8V18z"></path><path class="m-cf-fejlec_container_links_item_link_container_logo_dot" d="M-54 12h8v4h-8v-4z"></path></svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">Címlap</span>
# </span>
# </a>
# </li>
# <li class="m-cf-fejlec_container_links_item itemHeadings">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Rovatok" href="https://dex.hu/x.php?id=fxdfejlec&amp;url=https%3A%2F%2Findex.hu%2Frovatok">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_icon iconHamburger" viewbox="0 0 22 17">
# <path d="M0 1.5C0 .672.67 0 1.495 0h19.01C21.33 0 22 .666 22 1.5c0 .828-.67 1.5-1.495 1.5H1.495C.67 3 0 2.334 0 1.5zm0 7C0 7.672.67 7 1.495 7h19.01C21.33 7 22 7.666 22 8.5c0 .828-.67 1.5-1.495 1.5H1.495C.67 10 0 9.334 0 8.5zm0 7c0-.828.67-1.5 1.495-1.5h19.01c.826 0 1.495.666 1.495 1.5 0 .828-.67 1.5-1.495 1.5H1.495C.67 17 0 16.334 0 15.5z"></path>
# </svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">Rovatok</span>
# </span>
# </a>
# </li>
# <li class="m-cf-fejlec_container_links_item itemLatest">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Legfrissebbek" href="https://dex.hu/x.php?id=fxdfejlec&amp;url=https%3A%2F%2Findex.hu%2F24ora">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_icon iconClock" viewbox="0 0 22 22"><path d="M11 19.25c-4.557 0-8.25-3.693-8.25-8.25S6.443 2.75 11 2.75s8.25 3.693 8.25 8.25-3.693 8.25-8.25 8.25M11 0C4.925 0 0 4.925 0 11s4.925 11 11 11 11-4.925 11-11S17.075 0 11 0"></path><path d="M12.833 10.89V6.874c0-.76-.616-1.375-1.375-1.375-.76 0-1.375.616-1.375 1.375v5.04h.11l-.11.113 2.27 2.27c.536.535 1.406.535 1.943 0 .538-.538.538-1.41 0-1.946l-1.463-1.463z"></path></svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">Friss hírek</span>
# </span>
# </a>
# </li> </ul>
# </div>
# <div class="m-cf-fejlec_container_inda">
# <ul class="m-cf-fejlec_container_inda_kiadvanyok">
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Economx" data-target="economx" href="https://www.economx.hu" target="_blank">Economx</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Dívány" data-target="divany" href="https://divany.hu/" target="_blank">Dívány</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Totalcar" data-target="totalcar" href="https://totalcar.hu/" target="_blank">Totalcar</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Femina" data-target="femina" href="https://femina.hu/" target="_blank">Femina</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Port" data-target="port" href="https://port.hu/" target="_blank">Port</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="We ❤︎ Budapest" data-target="we_x2764_xfe0e_budapest" href="https://welovebudapest.com/" target="_blank">We ❤︎ Budapest</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Velvet" data-target="velvet" href="https://velvet.hu/" target="_blank">Velvet</a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <button class="m-cf-fejlec_container_inda_kiadvanyok_item_inda" data-target="[data-js-dropdown=inda]" data-toggle="dropdown" type="button">
# <span class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container">
# <span class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container_label">Inda</span>
# <svg class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container_icon" viewbox="0 0 11 7">
# <path d="M5.5 5.125L1.032.657C.846.47.534.467.344.657c-.185.184-.19.497 0 .687l4.812 4.812c.092.092.217.14.342.14.125 0 .25-.045.346-.14l4.812-4.812c.185-.185.19-.498 0-.688-.184-.184-.498-.19-.688 0L5.5 5.127z"></path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# <ul class="m-cf-fejlec_container_inda_actions">
# <li class="m-cf-fejlec_container_inda_actions_item itemSearch">
# <button class="m-cf-fejlec_container_inda_actions_item_button" data-ga-category="Keresés" data-js-cemp-search="button" data-target="[data-js-modal-window=search]" data-toggle="modal" type="button">
# <span class="m-cf-fejlec_container_inda_actions_item_button_wrapper">
# <svg class="m-cf-fejlec_container_inda_actions_item_button_wrapper_icon" viewbox="0 0 21 21">
# <path d="M20.8 18.867c.267.267.267.7 0 .967l-.966.967c-.267.267-.7.267-.966 0L13.5 15.434c-.073-.074-.122-.16-.155-.253-1.39 1.014-3.094 1.62-4.944 1.62-4.64 0-8.4-3.76-8.4-8.4C0 3.76 3.76 0 8.4 0c4.64 0 8.4 3.76 8.4 8.4 0 1.85-.606 3.556-1.62 4.945.092.032.18.08.253.155l5.368 5.367zM8.4 2.8c-3.093 0-5.6 2.507-5.6 5.6 0 3.093 2.507 5.6 5.6 5.6 3.093 0 5.6-2.507 5.6-5.6 0-3.093-2.507-5.6-5.6-5.6z"></path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# <div class="fixed-header">
# <script type="text/javascript">
#
#     (function() {
#         var sc = document.createElement('script'); sc.type = 'text/javascript'; sc.async = true;
#         sc.src = __passportHeader_config.HEADER_URL + 'passportHeader.js';
#        var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sc, s);
#     })();    </script>
# <div id="passportHeader" style="height: 36px; visibility: hidden;"></div></div>
# </div>
# </div>
# </div>
# <section class="blokk hajtas-felett container index-header cimlap-blokk-index">
# <div class="index-header-wrapper">
# <a class="logo" data-ga-category="Index logó" href="/"></a>
# <ul class="trending-topics">
# <li stamp-index="0">
# <a class="cimke cimke-mufaj cimke-199435" href="https://dex.hu/x.php?id=inxcl_stamp&amp;url=https%3A%2F%2Findex.hu%2Fbajnokokligaja%23">Bajnokok Ligája</a>
# </li> </ul>
# <div class="header-parts">
# <div class="calendar">
# <time datetime="2024-06-01" title="22. hét">2024. 06. 01. szombat</time>
# <div id="name-day">Tünde</div>
# </div>
# <section class="exchange njs-carousel">
# <a class="exchange-ticker" data-g-category="Árfolyam" href="https://dex.hu/x.php?id=inxfejlec&amp;url=http%3A%2F%2Fportfoliofinancial.hu%2F" target="_blank" title="Forrás: portfoliofinancial.hu">
# <span class="currency-item goood">
# <span class="ticker">EUR</span>
# <span class="price">
#                     389,48                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="currency-item baaad">
# <span class="ticker">USD</span>
# <span class="price">
#                     359,02                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="currency-item baaad">
# <span class="ticker">GBP</span>
# <span class="price">
#                     457,49                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="exchange-item baaad">
# <span class="ticker">BUX</span>
# <span class="price">
#                     67 907                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="exchange-item baaad">
# <span class="ticker">OTP</span>
# <span class="price">
#                     17 310                    <span class="forint">Ft</span>
# </span>
# </span>
# <span class="exchange-item baaad">
# <span class="ticker">MOL</span>
# <span class="price">
#                     2 790                    <span class="forint">Ft</span>
# </span>
# </span>
# </a>
# </section>
# <a class="weather" data-ga-category="Időjárás" data-temprature="20.8" href="https://dex.hu/x.php?id=inxcl_idojaras&amp;url=https://index.hu/idojaras" title="most: 20,8 °C">
# <div class="temperature">
# <div class="night">14 °C</div>
# <div class="day">23 °C</div>
# </div>
# <div class="weather-icon">
# <ul>
# <li class="icon-cloud"></li>
# </ul>
# </div>
# </a>
# </div>
# <nav id="index-rovatok">
# <a class="rovat-link navi_belfold" data-ga-category="Belföld" data-rovat-dropdown="" href="#" id="belfold">
#                 Belföld            </a>
# <a class="rovat-link navi_kulfold" data-ga-category="Külföld" data-rovat-dropdown="" href="#" id="kulfold">
#                 Külföld            </a>
# <a class="rovat-link navi_gazdasag" data-ga-category="Gazdaság" data-rovat-dropdown="" href="#" id="gazdasag">
#                 Gazdaság            </a>
# <a class="rovat-link navi_kultur" data-ga-category="Kult" data-rovat-dropdown="" href="#" id="kultur">
#                 Kult            </a>
# <a class="rovat-link navi_velemeny" data-ga-category="Vélemény" data-rovat-dropdown="" href="#" id="velemeny">
#                 Vélemény            </a>
# <a class="rovat-link navi_techtud" data-ga-category="Tech-Tud" data-rovat-dropdown="" href="#" id="techtud">
#                 Tech-Tud            </a>
# <a class="rovat-link navi_sport" data-ga-category="Sport" data-rovat-dropdown="" href="#" id="sport">
#                 Sport            </a>
# <a class="rovat-link navi_fomo" data-ga-category="Fomo" data-rovat-dropdown="" href="#" id="fomo">
#                 Fomo            </a>
# <a class="rovat-link navi_24ora selected" data-ga-category="24 Óra" data-rovat-dropdown="" href="#" id="24ora">
#                 24 Óra            </a>
# <a class="rovat-link navi_blog notification" data-ga-category="Blog" data-rovat-dropdown="" href="#" id="blog">
#                 Blog            </a>
# <a class="rovat-link navi_video notification" data-ga-category="Videó" data-rovat-dropdown="" href="#" id="video">
#                 Videó            </a>
# <a class="rovat-link navi_podcast notification" data-ga-category="Podcast" data-rovat-dropdown="" href="#" id="podcast">
#                 Podcast            </a>
# <a class="rovat-icon navi_twitter" data-ga-category="Twitter" href="https://twitter.com/indexhu" id="twitter" target="_blank"></a>
# <a class="rovat-icon navi_socials" data-ga-category="Socials" data-rovat-dropdown="" href="#" id="socials"></a>
# </nav>
# <div class="dropdown-container" hidden="" id="dropdown-menu-wrapper">
# <div class="loader animating">
# <span class="loader-item"></span>
# <span class="loader-item"></span>
# <span class="loader-item"></span>
# </div>
# </div>
# <script>
#     document.addEventListener('DOMContentLoaded', () => {
#         window.rovatDropdown = new RovatDropdown({
#             base_url: 'https://index.hu/',
#             callbacks: {
#                 video: function(element) {
#                     window.video_slider = new DropdownSlider(element.querySelector('.slider'), { threshold: 0 });
#                 }
#             }
#         });
#     });
# </script>
# </div>
# </section>
# <div class="container top_szponzor adverticum-kapubanner">
# <div class="ad-container">
# <div class="iap iap--ado" data-id="adoceanindexhuqclsmvirum" id="adoceanindexhuqclsmvirum">
# <script class="iap-script">
#                                                             window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhuqclsmvirum","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_LB","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#                                                         </script>
# </div>
# </div>
# </div>
# <div class="container border rovat-container">
# <div id="js_content_template_normal">
# <!--
#         <article class="rovatajanlo unordered not-important normal">
#             <header class="rovat-cikk-head">
#                 <h3>
#                     <span class="separator-box"></span>
#                         <span class="cikk-date-label" data-datestamp="{{Puzzler.ccd.ts}}" data-date="{{Puzzler.timestampToDate( Puzzler.ccd.ts )}}">{{Puzzler.ccd.datum}}</span>
#                     <span class="separator"></span>
#                     {{Puzzler.isMindekozben( Puzzler.ccd.url ) ? '<ul class="cikk-cimkek"><li><a href="http://index.hu/mindekozben" class="cimke cimke-mufaj">Mindeközben</a></li></ul>' : ''}}
#                     {{ Puzzler.ccd.kiadvany_csoki ? Puzzler.ccd.kiadvany_csoki : ''; }}
#                 </h3>
#                 <div class="clearfix"></div>
#             </header>
#
#             <h2>
#                 {{Puzzler.ccd.kep ? '<a href="' + Puzzler.ccd.url + '"  title="' + Puzzler.ccd.cim + '"><img class="need_to_load" src="' + Puzzler.ccd.kep + '" alt="' + Puzzler.ccd.cim + '" /></a>' : '' }}
#                 <a href="{{Puzzler.ccd.url}}" class="cim" title="{{Puzzler.ccd.cim}}">{{Puzzler.ccd.cim}}</a>
#             </h2>
#             {{Puzzler.ccd.ajanlo ? '<div class="ajanlo">' + Puzzler.ccd.ajanlo + '</div>' : '' }}
#         </article>
# -->
# </div>
# <div id="js_content_template_lead">
# <!--
#         <article class="rovatajanlo vezeto keppel not-important">
#             <div class="article-container">
#                 <a href="{{Puzzler.ccd.url}}"  title="{{Puzzler.ccd.cim}}">
#                     <img src="{{Puzzler.ccd.kep}}" alt="{{Puzzler.ccd.cim}}">
#                 </a>
#                 <h2>
#                     <a href="{{Puzzler.ccd.url}}" class="cim"  title="{{Puzzler.ccd.cim}}">{{Puzzler.ccd.cim}}</a>
#                 </h2>
#             </div>
#             <div class="author-share-date-container">
#             <div class="author-share-date">
#                 <div class="bal-hasab">
#                     <div class="szerzok_container">
#                             {{Puzzler.ccd.alnevek.replace(/\\(.)/mg, "$1")}}
#                     </div>
#                     <div class="datum">
#                         {{Puzzler.ccd.datum}}
#                     </div>
#                 </div>
#                 <div class="jobb-hasab">
#                     <div class="megoszt ">
#                         <div class="fb-share" data-action="recommend" data-href="{{Puzzler.ccd.url}}"> {{Puzzler.ccd.actual_fb_like}} </div>
#                 <div class="index-social-box cikk-top-box">
#                     <a href="#" class="megosztas-gomb"></a>
#                     <ul class="megosztas-doboz">
#                         <li class="mail">
#                             <a class="email" href="mailto:ugyelet@NEMSPA_M.mail.index.hu?subject={{Puzzler.ccd.cim}}&amp;body=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                             <li class="facebook">
#                                 <a href="https://www.facebook.com/sharer/sharer.php?u=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                             </li>
#                         <li class="twitter">
#                             <a href="http://twitter.com/share?lang=hu&amp;text={{Puzzler.ccd.cim}}&amp;url=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                         <li class="tumblr">
#                             <a href="http://www.tumblr.com/share/link?url=http:{{Puzzler.ccd.url}}&amp;name={{Puzzler.ccd.cim}}&amp;description=%28via+%3Ca+href%3D%22http%3A%2F%2Findex.hu%2F%22%3EIndex%3C%2Fa%3E%29" target="_blank"></a>
#                         </li>
#                         <li class="google-plus">
#                             <a href="https://plus.google.com/share?url=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                     </ul>
#                 </div>
#                             <div class="hozzaszolasok"></div>
#                    </div>
#
#                                 </div>
#                             </div>
#             </div>
#             <div class="ajanlo">{{Puzzler.ccd.ajanlo}}</div>
#         </article>
# -->
# </div>
# <div id="js_content_template_datumcsik">
# <!--
#         <div class="datumcsik clearfix">{{Puzzler.ccd.month ? Puzzler.ccd.month : Puzzler.timestampToDate( Puzzler.ccd.ts, true )}}</div>
# -->
# </div>
# <div class="kereses-urlap">
# <h3>Keresés</h3>
# <form action="" id="kereses-urlap">
# <div class="mezocsoport alap-kereso">
# <div class="kereses-wrapper">
# <input id="kereses-mezo" name="s" placeholder="Keresés" type="text" value=""/>
# </div>
# <div class="kereses-gomb-wrapper">
# <input class="gomb-elsodleges kereses-ikon" type="submit" value=""/>
# </div>
# </div>
# <div class="reszletes-kereses-gomb-container">
# <button class="gomb-masodlagos reszletes-kereses-gomb" href="#">Részletes keresés</button>
# </div>
# <div class="reszletes-kereses-container">
# <div class="datum-container">
# <div class="mezocsoport">
# <div class="datum-wrapper">
# <input autocomplete="off" class="date-selector" id="datum-tol" name="tol" type="text" value="1999-01-01"/>
# </div>
# <div class="datum-label-wrapper">
# <label for="datum-tol">-tól</label>
# </div>
# </div>
# <div class="mezocsoport">
# <div class="datum-wrapper">
# <input autocomplete="off" class="date-selector" id="datum-ig" name="ig" type="text" value="2024-06-01"/>
# </div>
# <div class="datum-label-wrapper">
# <label for="datum-ig">-ig</label>
# </div>
# </div>
# </div>
# <div class="onthisday-container">
# <input class="onthisday-kapcsolo" id="onthisday" name="onthisday" type="checkbox" value="1"/>
# <label class="onthisday-label" for="onthisday">Ezen a napon<span></span></label>
# </div>
# <div class="tarskiadvany-container">
# <input class="tarskiadvany-kapcsolo" id="tarskiadvanyokbanis" name="tarskiadvanyokbanis" type="checkbox" value="1"/>
# <label class="tarskiadvany-label" for="tarskiadvanyokbanis">Az Index környékéről is<span>Totalcar, Totalbike, Velvet, Dívány, Comment:Com, Könyvesblog, Tékozló Homár</span></label>
# <div class="tarskiadvany-opciok">
# <div class="szerzo-rovat-container">
# <div class="mezocsoport">
# <div class="input-wrapper">
# <select class="chosen-select" data-placeholder="Szerzők" name="profil">
# <option value=""></option>
# <option value="">Összes</option>
# <option value="acs_daniel">Ács Dániel</option>
# <option value="acs_tibor">Ács Tibor</option>
# <option value="adamek_alma">Adamek Alma</option>
# <option value="aghassi_attila">Ághassi Attila</option>
# <option value="ago_bela">Ágó Béla</option>
# <option value="agoston_zoltan">Ágoston Zoltán</option>
# <option value="ajpek_orsi">Ajpek Orsi</option>
# <option value="ambrus_adam">Ambrus Ádám</option>
# <option value="ambrus_balazs">Ambrus Balázs</option>
# <option value="andacs_botond">Andacs Botond</option>
# <option value="androczi_balazs">Andróczi Balázs</option>
# <option value="antalics_adam">Antalics Ádám</option>
# <option value="aradi_laszlo">Aradi László</option>
# <option value="aranyi_vanda">Arányi Vanda</option>
# <option value="arato_laszlo">Arató László</option>
# <option value="arnotszky_janka_judi">Arnótszky Judit Janka</option>
# <option value="arvai_peter">Árvai Péter</option>
# <option value="bacsanyi_peter">Bacsányi Péter</option>
# <option value="bakcsy_arpad">Bakcsy Árpád</option>
# <option value="bakro-nagy_ferenc">Bakró-Nagy Ferenc</option>
# <option value="baksa_roland">Baksa Roland</option>
# <option value="balazs_barbara">Balázs Barbara</option>
# <option value="balazsi_levente">Balázsi Levente</option>
# <option value="balint_agnes">Bálint Ágnes</option>
# <option value="balint_lilla">Bálint Lilla</option>
# ...
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/tompos-katya-gyasz-halal-basti-juli-szinhaz/" title="Básti Juli Tompos Kátyáról: Igazi angyalka volt, akit mindenki szeretett">
# <img alt="Básti Juli Tompos Kátyáról: Igazi angyalka volt, akit mindenki szeretett" loading="lazy" src="https://kep.index.hu/1/0/5660/56604/566045/56604563_4185297_09fb053255ee5baf361b61434739616a_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/tompos-katya-gyasz-halal-basti-juli-szinhaz/" title="Básti Juli Tompos Kátyáról: Igazi angyalka volt, akit mindenki szeretett">
#                 Básti Juli Tompos Kátyáról: Igazi angyalka volt, akit mindenki szeretett            </a>
# </h2>
# <div class="ajanlo">
#             Kollégája szerint elementáris ereje volt a nemrég meghalt színésznőnek.        </div>
# </article>
# <article class="rovatajanlo normal right">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717232408">7 órája</span>
# <span class="separator"></span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">Mindeközben</a>
# </li>
# </ul>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/valovilag12-bekoltozo-show-villalako-/" title="ValóVilág 12: újabb három villalakó-jelölt mutatkozott be, akik felkavarnák az állóvizet Valenéknél">
#                 ValóVilág 12: újabb három villalakó-jelölt mutatkozott be, akik felkavarnák az állóvizet Valenéknél            </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>
# <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717231020">7 órája</span>
# <span class="separator"></span>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/egyesult-kiralysag-mexiko-nagykovet-fegyver/" title="Elbocsátották a mexikói brit nagykövetet, miután fegyvert szegezett a követség alkalmazottjára">
# <img alt="Elbocsátották a mexikói brit nagykövetet, miután fegyvert szegezett a követség alkalmazottjára" loading="lazy" src="https://kep.index.hu/1/0/5660/56604/566048/56604891_4185321_75a94ff357ab17fc073ff7e7e742b655_wm.png"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/egyesult-kiralysag-mexiko-nagykovet-fegyver/" title="Elbocsátották a mexikói brit nagykövetet, miután fegyvert szegezett a követség alkalmazottjára">
#                 Elbocsátották a mexikói brit nagykövetet, miután fegyvert szegezett a követség alkalmazottjára            </a>
# </h2>
# <div class="ajanlo">
#             A fegyver feltehetően a diplomatát kísérő biztonságiaké volt.        </div>
# </article>
# <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717230000">7 órája</span>
# <span class="separator"></span>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/iland-videoklip-kek-gyemant-zene-videoklip/" title="Különleges gyémántra bukkantunk a Műcsarnok kiállításán">
# <img alt="Különleges gyémántra bukkantunk a Műcsarnok kiállításán" loading="lazy" src="https://kep.index.hu/1/0/5660/56604/566043/56604377_4185283_0eb44c1aaa80777d7e3d40c8532545b3_wm.png"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/iland-videoklip-kek-gyemant-zene-videoklip/" title="Különleges gyémántra bukkantunk a Műcsarnok kiállításán">
#                 Különleges gyémántra bukkantunk a Műcsarnok kiállításán            </a>
# </h2>
# <div class="ajanlo">
#             Dalban mondták el.        </div>
# </article>
# <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717228980">8 órája</span>
# <span class="separator"></span>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/01/nagy-attila-tibor-politikai-elemzo-karacsony-gergely-vitezy-david-szentkiralyi-alexandra-vita-velemeny/" title="Vitézy Dávid sziporkázott, Szentkirályi Alexandra jobban járt a távolmaradással">
# <img alt="Vitézy Dávid sziporkázott, Szentkirályi Alexandra jobban járt a távolmaradással" loading="lazy" src="https://kep.index.hu/1/0/5660/56603/566039/56603919_4185247_33c16e5b78fa41ee1914d4be70659fee_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/01/nagy-attila-tibor-politikai-elemzo-karacsony-gergely-vitezy-david-szentkiralyi-alexandra-vita-velemeny/" title="Vitézy Dávid sziporkázott, Szentkirályi Alexandra jobban járt a távolmaradással">
#                 Vitézy Dávid sziporkázott, Szentkirályi Alexandra jobban járt a távolmaradással            </a>
# </h2>
# <div class="ajanlo">
#             Nagy Attila Tibor politikai elemző értékelte az Indexnek a péntek esti vitát.        </div>
# </article>
# <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717227600">8 órája</span>
# <span class="separator"></span>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/usa/feher_haz/2024/06/01/joe-biden-donald-trump-itelet-per/" title="Joe Biden Donald Trump elítéléséről: Senki nem áll törvények felett">
# <img alt="Joe Biden Donald Trump elítéléséről: Senki nem áll törvények felett" loading="lazy" src="https://kep.index.hu/1/0/5660/56603/566038/56603839_4185241_fad17a7cc6863714a85f5b954753a914_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/usa/feher_haz/2024/06/01/joe-biden-donald-trump-itelet-per/" title="Joe Biden Donald Trump elítéléséről: Senki nem áll törvények felett">
#                 Joe Biden Donald Trump elítéléséről: Senki nem áll törvények felett            </a>
# </h2>
# <div class="ajanlo">
#             Szerinte az esküdtek körültekintő döntést hoztak.        </div>
# </article>
# <article class="rovatajanlo normal left">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box"></span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717227000">8 órája</span>
# <span class="separator"></span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">Mindeközben</a>
# </li>
# </ul>
# </h3>
# <div class="clearfix"></div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/cooky-szecsi-debora-instagram-vs-valosag-video/" title="A fél internet Cooky Instagram vs. valóság videóján nevet, a párját, Szécsi Debórát figurázta ki">
#                 A fél internet Cooky Instagram vs. valóság videóján nevet, a párját, Szécsi Debórát figurázta ki            </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>
# <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/fomo/2024/06/01/daniel-stern-reszkessetek-betorok-konyv/" title="Kis híján meghalt a Reszkessetek, betörők! ikonikus színésze">
# <img alt="Kis híján meghalt a Reszkessetek, betörők! ikonikus színésze" loading="lazy" src="https://kep.index.hu/1/0/5659/56595/565954/56595451_4184599_b0b082b5877e22c1dd3c41eb3b9ff825_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/fomo/2024/06/01/daniel-stern-reszkessetek-betorok-konyv/" title="Kis híján meghalt a Reszkessetek, betörők! ikonikus színésze">
#                         Kis híján meghalt a Reszkessetek, betörők! ikonikus színésze                    </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/harnisch_kitti">
# <img alt="Harnisch Kitti" class="szerzo-kep" src="https://kep.index.hu/1/0/4152/41525/415253/41525355_3169809_6bc9f849e6e4839cc9b4639882de03c1_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/harnisch_kitti" rel="author">Harnisch Kitti</a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1353"></span>
# </div>
# </div>
# </div>
# <div class="datum">
#                         2024.06.01. 09:27                        <span class="modositas-datuma-gomb" title="Módosítás dátuma">Módosítva: 2024-06-01 14:14:17</span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#             Daniel Stern egy forgatás során került kalamajkába.        </div>
# </article>
# </main>
# <div class="clear"></div>
# </div>
# <footer class="m-page-footer">
# <div class="container m-page-footer_container">
# <ul class="m-page-footer_container_list">
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fimpresszum%2F">Impresszum</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findamediasales.hu%2F">Médiaajánlat</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fcopyright%2F">Szerzői jogok</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fadatvedelem%2F">Adatvédelmi elvek</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fsutiszabalyzat%2F">Süti szabályzat</a>
# </li>
# <li class="m-page-footer_container_list_item hasText">
# <a class="change-consent m-page-footer_container_list_item_link" onclick="window.__tcfapi('displayConsentUi', 2, function() {} );">Süti beállítások</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2F24ora%2Frss%2F">RSS</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Finfo%2Fallas%2F">Állás</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Fajanlat.indamediasales.hu%2Fmarkabiztonsag%2FIndamedia_Sales_Markabiztonsagi_nyilatkozat.pdf">Márkabiztonság</a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fdsa" target="_blank">DSA</a>
# </li>
# <li class="m-page-footer_container_list_item hasText">
# <span class="m-page-footer_container_list_item_text">© 1999-2024 <span>Index.hu</span> Zrt.</span>
# </li>
# </ul>
# </div>
# </footer>
# <div class="layout_watcher phone"></div>
# <div class="layout_watcher portrait-tablet"></div>
# <div class="layout_watcher landscape-tablet"></div>
# <div class="layout_watcher desktop"></div>
# <div class="newsletter_modal" id="newsletterModal"></div>
# <script>
#     new NewsletterModal( document.getElementById('newsletterModal'), {'assetUrl': 'https://index.hu/assets/'});
# </script>
# <script>
#         var bodyContent = '';
#         $emailAdress = 'bla';
#                 bodyContent = 'Olvasói levelet, meghívót, sajtóközleményt készül küldeni a(z) <strong><a href="mailto:{emailAddress}" target="_blank" class="email">{emailShow}</a></strong> címen a szerkesztőségnek. Fontos nekünk, ezért az adataira is nagyon vigyázunk, ahogy az <a href="https://index.hu/adatvedelem" target="_blank">adatvédelmi tájékoztatónkban</a> részletezzük is. Ha Önnek is oké, kattintson az OK gombra.';
#         bodyContentMeghivo = 'Nyilatkozatot, bejelentést, vagy felhasználási kérelmet készül küldeni a(z) <strong><a href="mailto:{emailAddress}" target="_blank" class="email">{emailShow}</a></strong> címen a lapigazgatónak.Fontos nekünk, ezért az adataira is nagyon vigyázunk, ahogy az <a href="https://index.hu/adatvedelem" target="_blank">adatvédelmi tájékoztatónkban</a> részletezzük is. Ha Önnek is oké, kattintson az OK gombra.'
#
#         $(document).ready(function() {
#
#             $('a.email').on('click', function(e) {
#                 e.preventDefault();
#
#                 if (
#                     // Csak akkor jelenítjük meg a modal ablakot, ha ezeknek a feltételeknek valamelyike teljesül
#                     $(this).hasClass('irok_neki') ||               // Ha írok neki típusú a link vagy
#                     $(this).attr('href').indexOf('mailto:') !== -1  // van mailto link a href-ben
#                 ) {
#
#
#                     var emailAddress = $(this).attr('href')
#                         .replace('mailto:', '')
#                         .replace('NEMSPA_M.', '');
#
#                     var emailShow = emailAddress.match(/([a-zA-Z0-9._+-]+@[a-zA-Z0-9._-]+\.[a-zA-Z0-9._-]+)/)[0];
#
#                     var content = $(e.target).hasClass('meghivo') ? bodyContentMeghivo.replace(/{emailAddress}/gi, emailAddress).replace(/{emailShow}/g, emailShow) : bodyContent.replace(/{emailAddress}/gi, emailAddress).replace(/{emailShow}/g, emailShow);
#
#                     var mailtoModal = new vModal({
#                         title: 'Adatvédelmi tájékoztatás',
#                         body: content,
#                         buttons: {
#                             more: 'Vissza',
#                             confirm: 'OK'
#                         },
#                         className: 'vanilla_modal--basic',
#                         events: {
#                             confirm: function() {
#                                 //chrome miatt kell új lapon megnyitni, különben nem működik!
#                                 window.open('mailto:' + emailAddress, '_blank');
#                             }
#                         }
#                     });
#
#                     mailtoModal.open();
#
#                 }
#
#             });
#
#         });
#     </script>
# <script type="text/javascript">
#             <!--//--><![CDATA[//><!--
#             var pp_gemius_identifier = pp_gemius_original_identifier = new String('B9OVVi_kSaN4kjyXnmrlRnaITKLZOwR45wv6Si7xT2f.S7'); <!-- 24 óra -->
#             var pp_gemius_use_cmp = true;
#             var pp_gemius_cmp_timeout = Infinity;
#             //--><!]]>
#         </script>
# <script type="text/javascript">
#             <!--//--><![CDATA[//><!--
#             function gemius_pending(i) { window[i] = window[i] || function() {var x = window[i+'_pdata'] = window[i+'_pdata'] || []; x[x.length]=arguments;};};
#             gemius_pending('gemius_hit'); gemius_pending('gemius_event');
#             gemius_pending('pp_gemius_hit'); gemius_pending('pp_gemius_event');
#
#             (function(d,t) {try {
#             var gt=d.createElement(t),s=d.getElementsByTagName(t)[0],l='http'+((location.protocol=='https:')?'s':'');
#             gt.setAttribute('async','async');
#             gt.setAttribute('defer','defer');
#             gt.src=l+'://gahu.hit.gemius.pl/xgemius.js';
#             s.parentNode.insertBefore(gt,s);}
#             catch (e) {}})(document,'script');
#             //--><!]]>
#         </script>
# <script type="text/javascript">
#             var gemABObj = {
#                 docBody: document.getElementsByTagName('body')[0],
#                 incScript: document.createElement('SCRIPT'),
#                 checkIt: function(){document.getElementById("mnxHDozyKPjB")?pp_gemius_hit("nSdFzTtkvTTrx.B7K13yyfU378aFPueKFs36aeS6yET.A7","addon=no-adblock"):pp_gemius_hit("nSzrCTsGCKuF9KNE6iWTitVrzbu1Eg8GQHsHaml5W8n.b7","addon=adblock")}
#             };
#             gemABObj.incScript.src = '//indexhu.adocean.pl/files/x/mof/ghshscq/xajkevmjdv/ads.js';
#             gemABObj.docBody.appendChild(gemABObj.incScript);
#
#             window.addEventListener("load",gemABObj.checkIt);
#         </script>
# </body>
# </html>

# %%
f = open("sample_index.html", "r", encoding="utf-8")
soup = bs(f, "html.parser")

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="hu" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <head>
# <title>
#    Hírek - 24 óra - Index.hu
#   </title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=EmulateIE11" http-equiv="X-UA-Compatible"/>
# <!-- [if IE]>
#         <meta http-equiv="imagetoolbar" content="no" />
#         <meta name="MSSmartTagsPreventParsing" content="true" />
#         <meta http-equiv="X-UA-Compatible" content="IE=Edge">
#         <![endif]-->
# <meta content="1717167770" name="manis:deploy"/>
# <meta name="manis:breakpoint">
# <meta name="manis:breakpoints"/>
# <meta content="https://index.hu/copyright/" name="copyright"/>
# <meta content="unsafe-url" name="referrer">
# <meta content="app-id=480103271" name="apple-itunes-app"/>
# <meta content="app-id=com.aff.index.main" name="google-play-app"/>
# <meta content="noindex" name="robots"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="330827937019153" property="fb:app_id"/>
# <meta content="667823645" property="fb:admins"/>
# <meta content="560525343980775,348326671885918" property="fb:pages"/>
# <meta content="Friss hírek és információk az Indexen" name="description"/>
# <meta content="https://index.hu/assets/images/facebook_logo.png?v5" property="og:image">
# <meta content="https://www.facebook.com/Indexhu" property="article:publisher">
# <meta content="summary_large_image" name="twitter:card">
# <meta content="@indexhu" name="twitter:site">
# <meta content="https://index.hu/assets/images/facebook_logo.png" name="twitter:image:src">
# <link href="/assets/static/opensearch.xml" rel="search" title="Index" type="application/opensearchdescription+xml"/>
# <link href="/copyright/" rel="copyright" title="Szerzői jogok"/>
# <link href="/impresszum/" rel="author" title="Impresszum"/>
# <link href="/" id="homelink" rel="home" title=""/>
# <link href="/assets/images/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/assets/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/assets/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/assets/images/favicons/manifest.json" rel="manifest"/>
# <link href="/assets/images/favicons/favicon.ico" rel="shortcut icon"/>
# <link color="#ff9900" href="/assets/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="Index" name="apple-mobile-web-app-title"/>
# <meta content="Index" name="application-name"/>
# <meta content="#ffffff" name="theme-color"/>
# <script type="text/javascript">
#           var _sf_startpt=(new Date()).getTime()
#          </script>
# <link href="https://index.hu/assets/static/indexnew_css/public/global.css?v=1717167720" rel="stylesheet" type="text/css"/>
# <link href="https://index.hu/assets/static/indexnew_css/public/index-global.css?v=1717167720" rel="stylesheet" type="text/css"/>
# <link href="https://index.hu/assets/static/indexnew_css/public/rovat.css?v=1717167720" rel="stylesheet" type="text/css"/>
# <link href="https://index.hu/assets/static/indexnew_css/public/fixed_header.css?v=1717167720" rel="stylesheet" type="text/css"/>
# <link href="https://index.hu/assets/static/indexnew_css/public/24ora.css?v=1717167720" rel="stylesheet" type="text/css"/>
# <link href="/24ora/rss/" rel="alternate" title="24óra cikkek" type="application/rss+xml"/>
# <meta content="1" name="logcustomtarget"/>
# <!-- i8 -->
# <script src="https://index.hu/ident/getall/?c=aTg=" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/static/js/public/index_vendor.ugly.js?v=1717167721" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/static/js/public/index_base.ugly.js?v=1717167721" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/static/js/public/index_election.ugly.js?v=1717167721" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/static/js/public/cemp_fejlec.ugly.js?v=1717167721" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/index.rovat.min.js?v=1710407521" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/autocomplete.min.js?v=1717167770" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/calendar.min.js?v=1717167770" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/chosen2.min.js?v=1717167770" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/jquery-ui.min.js?v=1717167770" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/index.24ora.min.js?v=1717167770" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/scrolling_shadow.js?v=1717167770" type="text/javascript">
# </script>
# <script src="https://index.hu/assets/js/pip_video.min.js?v=1717167770" type="text/javascript">
# </script>
# <script type="text/javascript">
#                  var _gaq = { push: function() {} };
#         ( function( i, s, o, g, r, a, m ) {
#             i[ 'GoogleAnalyticsObject' ] = r;
#             i[ r ] = i[ r ] || function() {
#                 ( i[ r ].q = i[ r ].q || [] ).push( arguments )
#             }, i[ r ].l = 1 * new Date();
#             a = s.createElement( o ), m = s.getElementsByTagName( o )[ 0 ];
#             a.async = 1;
#             a.src=g;
#             m.parentNode.insertBefore( a, m )
#         } )( window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga' );
#         var oldaltipus = '24ora_cimlap';
#         ( function( $ ) {
#             window.scrollTrackerEnabled = 1;
#             window.Analytics = {
#                 add: function( command, params, target ) {
#                     if( typeof command === 'undefined' || typeof params === 'undefined' || !command || !params ) {
#                         return this;
#                     }
#                     params.location = ( params.location || document.location.href ).replace( '//m.', '//' );
#                     if( this.loaded ) {
#                         if( typeof target !== 'undefined' ) {
#                             command = target + '.' + command;
#                         }
#                         ga( command, params );
#                     }
#                     else {
#                         this.stack.push( [ command, $.extend( {}, params ), target ] );
#                     }
#                     return this;
#                 },
#                 process: function() {
#                     if( this.loaded ) {
#                         return;
#                     }
#                     var arg;
#                     while( this.stack.length ) {
#                         arg = this.stack.shift();
#                         if( typeof arg[ 2 ] !== 'undefined' && Common[ 'ga_' + arg[ 2 ] ] === true ) {
#                             arg[ 0 ] = arg[ 2 ] + '.' + arg[ 0 ];
#                         }
#                         ga( arg[ 0 ], arg[ 1 ] );
#                     }
#                     this.loaded = true;
#                 },
#                 stack: []
#             };
#             $( document ).on( 'ready', function() {
#                 if( typeof window.Common === 'undefined' ) {
#                     window.Common = {
#                         ga_secondary: false
#                     };
#                 }
#                 if( typeof __passportHeader_config === 'undefined' ) {
#                     __passportHeader_config = {};
#                 }
#                 Common.ga_secondary = false;
#                 var ga_base_config = {
#                     sampleRate: 100,
#                     trackingId: 'UA-181415-27'
#                 };
#                 var ga_set_config = {
#                     dimension1: '24ora_cimlap',
#                     dimension2: ( __passportHeader_config.loggedIn ? '' : 'Not' ) + 'LoggedIn',
#                                             dimension3: Page.getLayout(),
#                                                                                 language: document.domain === 'totalcarmagazine.com' ? 'en-us' : 'hu-hu',
#                     location: document.location.href.replace( '//m.', '//' )
#                 };
#                 if( typeof __passportHeaderUserId !== 'undefined' ) {
#                     ga_base_config.userId = __passportHeaderUserId;
#                 }
#                 ga( 'create', ga_base_config );
#                 ga( 'require', 'displayfeatures' );
#                 ga( 'set', ga_set_config );
#                                     Common.ga_secondary = true;
#                     var ga_secondary_config = $.extend( {}, ga_base_config );
#                     ga_secondary_config.name = 'secondary';
#                     ga_secondary_config.trackingId = 'UA-181415-11';
#                     ga_secondary_config.sampleRate = 10;
#                     ga( 'create', ga_secondary_config );
#                     ga( 'secondary.require', 'displayfeatures' );
#                     ga( 'secondary.set', ga_set_config );
#                                 ga('set', 'anonymizeIp', true);
#                 // cross_site ajanlo kivetelkezelese
#                 if(
#                     (
#                         $( '#passportHeader, #_iph_fixed-header' ).length ||
#                         $( '#inforadio_audioplayer1' ).length ||
#                         $( '.header_send').length ||
#                         document.location.host.indexOf( 'm.' ) === 0 ||
#                         document.location.host.substring( document.location.host.length - 4 ) === '.com'
#                     ) &&
#                     ((Common.topfolder !== 'i2' && Common.topfolder !== 'index2') || !Common.parsed_url.hash || Common.parsed_url.hash.indexOf( '#bloghu' ) !== 0 )
#                 ) {
#                     ga( 'send', 'pageview' );
#                     if( Common.ga_secondary ) {
#                         ga( 'secondary.send', 'pageview' );
#                     }
#                 }
#                 Analytics.process();
#             } );
#         } )( jQuery );
#                 </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-7GR3T85C96">
# </script>
# <script>
#                  window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         var ga4params = {"content_group":"24ora\/","rovat":"24\u00f3ra","oldaltipus":"24ora_cimlap","cikktipus":"Keres\u0151"};
#         ga4params.layout = Page.getLayout();
#         ga4params.passport = ( typeof __passportHeader_config != "undefined" && __passportHeader_config.loggedIn ? '' : 'Not' ) + 'LoggedIn';
#         gtag('js', new Date());
#         gtag('config', 'G-7GR3T85C96', ga4params);
#                 </script>
# <!-- Google Tag Manager -->
# <script>
#                  (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-PPDGL3DR');
#                 </script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript">
#                  Common.folder_id = 267;
#         Common.folder_parent_ids = [ 261 ];
#         Common.is_new_design = 1;
#                 </script>
# <script>
#                  window.fbAsyncInit = function() {
#         FB.init({
#             appId      : '330827937019153',
#             xfbml      : true,
#             status     : false,
#             version    : 'v5.0'
#         });
#         window.fb_initialized = true;
#     };
#
#     (function(d, s, id) {
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) return;
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/hu_HU/sdk.js";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
#                 </script>
# <script type="text/javascript">
#                  $(function () {
#             window.LinkPreview && window.LinkPreview.init();
#         });
#                 </script>
# <script type="text/javascript">
#                  <!--//--><![CDATA[//><!--
#     var IndexStatConfig = {
#         pixels: [ { id: 267, type: 2 }, { id: 261, type: 3 }, { id: 1, type: 5 }, { id: 2, type: 4 }],
#         device: 'desktop'
#     }
#     //--><!]]>
#                 </script>
# <script async="" src="//indexstat.index.hu/stat.min.js?dd=20240601" type="text/javascript">
# </script>
# <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script async="true" type="text/javascript">
#                  var nuCmp = true; try { Promise.resolve(1).finally() } catch(e) { nuCmp = false; }
#     if (nuCmp) {
#         (function() {
#             var host = 'index.hu';
#             var element = document.createElement('script');
#             var firstScript = document.getElementsByTagName('script')[0];
#             var url = 'https://cmp.quantcast.com'
#                 .concat('/choice/', '4z9XXyvnuPTjK', '/', host, '/choice.js?tag_version=V2');
#             var uspTries = 0;
#             var uspTriesLimit = 3;
#             element.async = true;
#             element.type = 'text/javascript';
#             element.src = url;
#
#             firstScript.parentNode.insertBefore(element, firstScript);
#
#             function makeStub() {
#                 var TCF_LOCATOR_NAME = '__tcfapiLocator';
#                 var queue = [];
#                 var win = window;
#                 var cmpFrame;
#
#                 function addFrame() {
#                     var doc = win.document;
#                     var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#                     if (!otherCMP) {
#                         if (doc.body) {
#                             var iframe = doc.createElement('iframe');
#
#                             iframe.style.cssText = 'display:none';
#                             iframe.name = TCF_LOCATOR_NAME;
#                             doc.body.appendChild(iframe);
#                         } else {
#                             setTimeout(addFrame, 5);
#                         }
#                     }
#                     return !otherCMP;
#                 }
#
#                 function tcfAPIHandler() {
#                     var gdprApplies;
#                     var args = arguments;
#
#                     if (!args.length) {
#                         return queue;
#                     } else if (args[0] === 'setGdprApplies') {
#                         if (
#                             args.length > 3 &&
#                             args[2] === 2 &&
#                             typeof args[3] === 'boolean'
#                         ) {
#                             gdprApplies = args[3];
#                             if (typeof args[2] === 'function') {
#                                 args[2]('set', true);
#                             }
#                         }
#                     } else if (args[0] === 'ping') {
#                         var retr = {
#                             gdprApplies: gdprApplies,
#                             cmpLoaded: false,
#                             cmpStatus: 'stub'
#                         };
#
#                         if (typeof args[2] === 'function') {
#                             args[2](retr);
#                         }
#                     } else {
#                         if(args[0] === 'init' && typeof args[3] === 'object') {
#                             args[3] = { ...args[3], tag_version: 'V2' };
#                         }
#                         queue.push(args);
#                     }
#                 }
#
#                 function postMessageEventHandler(event) {
#                     var msgIsString = typeof event.data === 'string';
#                     var json = {};
#
#                     try {
#                         if (msgIsString) {
#                             json = JSON.parse(event.data);
#                         } else {
#                             json = event.data;
#                         }
#                     } catch (ignore) {}
#
#                     var payload = json.__tcfapiCall;
#
#                     if (payload) {
#                         window.__tcfapi(
#                             payload.command,
#                             payload.version,
#                             function(retValue, success) {
#                                 var returnMsg = {
#                                     __tcfapiReturn: {
#                                         returnValue: retValue,
#                                         success: success,
#                                         callId: payload.callId
#                                     }
#                                 };
#                                 if (msgIsString) {
#                                     returnMsg = JSON.stringify(returnMsg);
#                                 }
#                                 if (event && event.source && event.source.postMessage) {
#                                     event.source.postMessage(returnMsg, '*');
#                                 }
#                             },
#                             payload.parameter
#                         );
#                     }
#                 }
#
#                 while (win) {
#                     try {
#                         if (win.frames[TCF_LOCATOR_NAME]) {
#                             cmpFrame = win;
#                             break;
#                         }
#                     } catch (ignore) {}
#
#                     if (win === window.top) {
#                         break;
#                     }
#                     win = win.parent;
#                 }
#                 if (!cmpFrame) {
#                     addFrame();
#                     win.__tcfapi = tcfAPIHandler;
#                     win.addEventListener('message', postMessageEventHandler, false);
#                 }
#             };
#
#             makeStub();
#
#             var uspStubFunction = function() {
#                 var arg = arguments;
#                 if (typeof window.__uspapi !== uspStubFunction) {
#                     setTimeout(function() {
#                         if (typeof window.__uspapi !== 'undefined') {
#                             window.__uspapi.apply(window.__uspapi, arg);
#                         }
#                     }, 500);
#                 }
#             };
#
#             var checkIfUspIsReady = function() {
#                 uspTries++;
#                 if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#                     console.warn('USP is not accessible');
#                 } else {
#                     clearInterval(uspInterval);
#                 }
#             };
#
#             if (typeof window.__uspapi === 'undefined') {
#                 window.__uspapi = uspStubFunction;
#                 var uspInterval = setInterval(checkIfUspIsReady, 6000);
#             }
#         })();
#     }
#                 </script>
# <!-- End Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script src="//indexhu.adocean.pl/files/js/ado.js" type="text/javascript">
# </script>
# <script>
#                  window.adocf = {};
#     window.adocf.useDOMContentLoaded = true;
#     window.iap_base = 'https://index.hu/';
#     var tagStr = document.querySelector('meta[name="keywords"]') ? document.querySelector('meta[name="keywords"]').getAttribute("content").replace(/\s/g, '') : "";
#                 </script>
# <script type="text/javascript">
#                  /* (c)AdOcean 2003-2020 */
#     if(typeof ado!=="object"){ado={};ado.config=ado.preview=ado.placement=ado.master=ado.slave=function(){};}
#     ado.config({mode: "new", xml: false, consent: true, characterEncoding: true, attachReferrer: true, fpc: "auto" , defaultServer:"indexhu.adocean.pl" ,cookieDomain:"SLD"});
#     ado.preview({enabled: true});
#     /* (c)AdOcean 2003-2020, MASTER: c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87 */
#     ado.master({id: 'c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87', server: 'indexhu.adocean.pl', vars: typeof customTargetAdocean !== "undefined" ? customTargetAdocean : '', keys: tagStr });
#                 </script>
# <script type="module">
#                  document.addEventListener('DOMContentLoaded', async () => {
#         const { Loader } = await (await import('https://iap.cdn.indexvas.hu/Scripts.js')).default;
#         window.GoaLoader = new Loader({"debug":false,"engine":"AdOcean","master":"c8z7NLqD6CQh.PLAy2LHNIP3ACtS.qMDDHXgOPwZXE..87","stat":true})
#     })
#                 </script>
# <script type="text/javascript">
#                  Common.maxFeedAjanloLoadCount = 1;
#     Common.feedAjanloLoadCount = 3;
#     Common.feedAjanloMoreButton = 1;
#     Common.feedAjanloTovabbUrl = "https://index.hu/24ora/";
#                 </script>
# <link href="/manifest.json" rel="manifest">
# <script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js">
# </script>
# <script>
#                  var OneSignal = window.OneSignal || [];
#     OneSignal.push(function() {
#         OneSignal.sendTags({
#             is_web: true
#         });
#         OneSignal.init({
#             appId: "bd30d7a1-7b22-4adb-bacf-e4bf80d25bf7",
#             autoRegister: false,
#             notifyButton: {
#                 enable: true
#             }
#         });
#     });
#                 </script>
# <script>
#                  window.googletag = window.googletag || {cmd: []};
#     googletag.cmd.push(function() {
#                 googletag.pubads().enableSingleRequest();
#                 googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#             if(!event.isEmpty) {
#                 $(document.getElementById(event.slot.getSlotElementId())).closest(".mobile-sticky").show().find("button.mobile-sticky-closing").on("click", function(){
#                     $(this).closest(".mobile-sticky").hide();
#                 });
#             }
#         });
#         googletag.enableServices();
#     });
#                 </script>
# </link>
# </meta>
# </meta>
# </meta>
# </meta>
# </meta>
# </meta>
# </meta>
# </head>
# <body class="device_desktop indexhu rovat h24ora rovat_24ora iframe_disallowed">
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PPDGL3DR" style="display:none;visibility:hidden" width="0">
# </iframe>
# </noscript>
# <div id="fb-root">
# </div>
# <script>
#    (function() {
#   var _fbq = window._fbq || (window._fbq = []);
#   if (!_fbq.loaded) {
#     var fbds = document.createElement('script');
#     fbds.async = true;
#     fbds.src = '//connect.facebook.net/en_US/fbds.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(fbds, s);
#     _fbq.loaded = true;
#   }
#   _fbq.push(['addPixelId', '551982981568628']);
# })();
# window._fbq = window._fbq || [];
# window._fbq.push(['track', 'PixelInitialized', {}]);
#   </script>
# <noscript>
# <img alt="" height="1" src="https://www.facebook.com/tr?id=551982981568628&amp;ev=PixelInitialized" style="display:none" width="1"/>
# </noscript>
# <div class="layer xl_layer">
# <div class="iap iap--ado ad-label--hidden no-padding no-margin" data-id="adoceanindexhulmgghmhsud" id="adoceanindexhulmgghmhsud">
# <script class="iap-script">
#      window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhulmgghmhsud","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_Layer","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#     </script>
# </div>
# <div class="iap iap--ado ad-label--hidden no-padding no-margin" data-id="ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7" id="ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7">
# <script class="iap-script">
#      window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"ado-1Nmmzw0l8jyCmHXpwRF2qmqk8aALgWbn0GFKI7LtzRH.k7","empty":true,"lazy":false,"quality":false,"masterless":true,"area":"Index_Aloldalak_Layer_gde_test","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#     </script>
# </div>
# </div>
# <div class="sticky">
# </div>
# <div class="container" id="ad_null_position">
# </div>
# <div aria-hidden="true" class="m-cf-search modal" data-backdrop="false" data-js-modal-window="search" role="dialog" style="display: none" tabindex="-1">
# <div class="m-cf-search_wrapper">
# <div class="m-cf-search_wrapper_container" data-js-cemp-search="container">
# <form action="https://index.hu/24ora/" class="m-cf-search_wrapper_container_form" method="get">
# <input name="word" type="hidden" value="1"/>
# <input name="pepe" type="hidden" value="1"/>
# <input name="tol" type="hidden" value="1999-01-01"/>
# <input name="ig" type="hidden" value="2024-06-01"/>
# <input class="m-cf-search_wrapper_container_form_input" data-js-cemp-search="input" name="s" placeholder="Keresés" tabindex="0" type="search"/>
# <button class="m-cf-search_wrapper_container_form_button" type="submit">
# <span class="m-cf-search_wrapper_container_form_button_wrapper">
# <svg class="m-cf-search_wrapper_container_form_button_wrapper_icon" style="height:21px;width:21px;" viewbox="0 0 21 21">
# <path d="M20.8 18.867c.267.267.267.7 0 .967l-.966.967c-.267.267-.7.267-.966 0L13.5 15.434c-.073-.074-.122-.16-.155-.253-1.39 1.014-3.094 1.62-4.944 1.62-4.64 0-8.4-3.76-8.4-8.4C0 3.76 3.76 0 8.4 0c4.64 0 8.4 3.76 8.4 8.4 0 1.85-.606 3.556-1.62 4.945.092.032.18.08.253.155l5.368 5.367zM8.4 2.8c-3.093 0-5.6 2.507-5.6 5.6 0 3.093 2.507 5.6 5.6 5.6 3.093 0 5.6-2.507 5.6-5.6 0-3.093-2.507-5.6-5.6-5.6z">
# </path>
# </svg>
# <span class="m-cf-search_wrapper_container_form_button_wrapper_label h-visibility-off_small-down">
#          Keresés
#         </span>
# </span>
# </button>
# </form>
# </div>
# </div>
# </div>
# <div class="m-cf-indalista" data-js-dropdown="inda">
# <div class="m-cf-indalista_container">
# <ul class="m-cf-indalista_container_list">
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="blog.hu" href="https://blog.hu/" target="_blank">
#        Blog.hu
#       </a>
# </li>
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="forum" href="http://forum.index.hu/Topic/showTopicList" target="_blank">
#        Fórum
#       </a>
# </li>
# <li class="m-cf-indalista_container_list_item">
# <a class="m-cf-indalista_container_list_item_link" data-target="indavideo" href="http://indavideo.hu/" target="_blank">
#        Indavideó
#       </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-cf-kiadvanylista">
# <div class="m-cf-kiadvanylista_container">
# <ul class="m-cf-kiadvanylista_container_list">
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Economx" data-target="economx" href="https://www.economx.hu" target="_blank">
#        Economx
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Dívány" data-target="divany" href="https://divany.hu/" target="_blank">
#        Dívány
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Totalcar" data-target="totalcar" href="https://totalcar.hu/" target="_blank">
#        Totalcar
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Femina" data-target="femina" href="https://femina.hu/" target="_blank">
#        Femina
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Port" data-target="port" href="https://port.hu/" target="_blank">
#        Port
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="We ❤︎ Budapest" data-target="we_x2764_xfe0e_budapest" href="https://welovebudapest.com/" target="_blank">
#        We ❤︎ Budapest
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <a class="m-cf-kiadvanylista_container_list_item_link" data-ga-category="Velvet" data-target="velvet" href="https://velvet.hu/" target="_blank">
#        Velvet
#       </a>
# </li>
# <li class="m-cf-kiadvanylista_container_list_item">
# <button class="m-cf-kiadvanylista_container_list_item_inda" data-target="[data-js-dropdown=inda]" data-toggle="dropdown" type="button">
# <span class="m-cf-kiadvanylista_container_list_item_inda_container">
# <span class="m-cf-kiadvanylista_container_list_item_inda_container_label">
#          Inda
#         </span>
# <svg class="m-cf-kiadvanylista_container_list_item_inda_container_icon" viewbox="0 0 11 7">
# <path d="M5.5 5.125L1.032.657C.846.47.534.467.344.657c-.185.184-.19.497 0 .687l4.812 4.812c.092.092.217.14.342.14.125 0 .25-.045.346-.14l4.812-4.812c.185-.185.19-.498 0-.688-.184-.184-.498-.19-.688 0L5.5 5.127z">
# </path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-cf-fejlec">
# <div class="m-cf-fejlec_container">
# <div class="m-cf-fejlec_container_wrapper">
# <ul class="m-cf-fejlec_container_links">
# <li class="m-cf-fejlec_container_links_item itemCover">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Címlap" href="https://dex.hu/x.php?id=fxdfejlecpnc&amp;url=https%3A%2F%2Findex.hu%2F">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_logo" viewbox="-54 12 8 20">
# <path class="m-cf-fejlec_container_links_item_link_container_logo_stem" d="M-54 18h8v14h-8V18z">
# </path>
# <path class="m-cf-fejlec_container_links_item_link_container_logo_dot" d="M-54 12h8v4h-8v-4z">
# </path>
# </svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">
#           Címlap
#          </span>
# </span>
# </a>
# </li>
# <li class="m-cf-fejlec_container_links_item itemHeadings">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Rovatok" href="https://dex.hu/x.php?id=fxdfejlec&amp;url=https%3A%2F%2Findex.hu%2Frovatok">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_icon iconHamburger" viewbox="0 0 22 17">
# <path d="M0 1.5C0 .672.67 0 1.495 0h19.01C21.33 0 22 .666 22 1.5c0 .828-.67 1.5-1.495 1.5H1.495C.67 3 0 2.334 0 1.5zm0 7C0 7.672.67 7 1.495 7h19.01C21.33 7 22 7.666 22 8.5c0 .828-.67 1.5-1.495 1.5H1.495C.67 10 0 9.334 0 8.5zm0 7c0-.828.67-1.5 1.495-1.5h19.01c.826 0 1.495.666 1.495 1.5 0 .828-.67 1.5-1.495 1.5H1.495C.67 17 0 16.334 0 15.5z">
# </path>
# </svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">
#           Rovatok
#          </span>
# </span>
# </a>
# </li>
# <li class="m-cf-fejlec_container_links_item itemLatest">
# <a class="m-cf-fejlec_container_links_item_link" data-ga-category="Legfrissebbek" href="https://dex.hu/x.php?id=fxdfejlec&amp;url=https%3A%2F%2Findex.hu%2F24ora">
# <span class="m-cf-fejlec_container_links_item_link_container">
# <svg class="m-cf-fejlec_container_links_item_link_container_icon iconClock" viewbox="0 0 22 22">
# <path d="M11 19.25c-4.557 0-8.25-3.693-8.25-8.25S6.443 2.75 11 2.75s8.25 3.693 8.25 8.25-3.693 8.25-8.25 8.25M11 0C4.925 0 0 4.925 0 11s4.925 11 11 11 11-4.925 11-11S17.075 0 11 0">
# </path>
# <path d="M12.833 10.89V6.874c0-.76-.616-1.375-1.375-1.375-.76 0-1.375.616-1.375 1.375v5.04h.11l-.11.113 2.27 2.27c.536.535 1.406.535 1.943 0 .538-.538.538-1.41 0-1.946l-1.463-1.463z">
# </path>
# </svg>
# <span class="m-cf-fejlec_container_links_item_link_container_label h-visibility-off_medium-down">
#           Friss hírek
#          </span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# <div class="m-cf-fejlec_container_inda">
# <ul class="m-cf-fejlec_container_inda_kiadvanyok">
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Economx" data-target="economx" href="https://www.economx.hu" target="_blank">
#         Economx
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Dívány" data-target="divany" href="https://divany.hu/" target="_blank">
#         Dívány
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Totalcar" data-target="totalcar" href="https://totalcar.hu/" target="_blank">
#         Totalcar
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Femina" data-target="femina" href="https://femina.hu/" target="_blank">
#         Femina
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Port" data-target="port" href="https://port.hu/" target="_blank">
#         Port
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="We ❤︎ Budapest" data-target="we_x2764_xfe0e_budapest" href="https://welovebudapest.com/" target="_blank">
#         We ❤︎ Budapest
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <a class="m-cf-fejlec_container_inda_kiadvanyok_item_link" data-ga-category="Velvet" data-target="velvet" href="https://velvet.hu/" target="_blank">
#         Velvet
#        </a>
# </li>
# <li class="m-cf-fejlec_container_inda_kiadvanyok_item">
# <button class="m-cf-fejlec_container_inda_kiadvanyok_item_inda" data-target="[data-js-dropdown=inda]" data-toggle="dropdown" type="button">
# <span class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container">
# <span class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container_label">
#           Inda
#          </span>
# <svg class="m-cf-fejlec_container_inda_kiadvanyok_item_inda_container_icon" viewbox="0 0 11 7">
# <path d="M5.5 5.125L1.032.657C.846.47.534.467.344.657c-.185.184-.19.497 0 .687l4.812 4.812c.092.092.217.14.342.14.125 0 .25-.045.346-.14l4.812-4.812c.185-.185.19-.498 0-.688-.184-.184-.498-.19-.688 0L5.5 5.127z">
# </path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# <ul class="m-cf-fejlec_container_inda_actions">
# <li class="m-cf-fejlec_container_inda_actions_item itemSearch">
# <button class="m-cf-fejlec_container_inda_actions_item_button" data-ga-category="Keresés" data-js-cemp-search="button" data-target="[data-js-modal-window=search]" data-toggle="modal" type="button">
# <span class="m-cf-fejlec_container_inda_actions_item_button_wrapper">
# <svg class="m-cf-fejlec_container_inda_actions_item_button_wrapper_icon" viewbox="0 0 21 21">
# <path d="M20.8 18.867c.267.267.267.7 0 .967l-.966.967c-.267.267-.7.267-.966 0L13.5 15.434c-.073-.074-.122-.16-.155-.253-1.39 1.014-3.094 1.62-4.944 1.62-4.64 0-8.4-3.76-8.4-8.4C0 3.76 3.76 0 8.4 0c4.64 0 8.4 3.76 8.4 8.4 0 1.85-.606 3.556-1.62 4.945.092.032.18.08.253.155l5.368 5.367zM8.4 2.8c-3.093 0-5.6 2.507-5.6 5.6 0 3.093 2.507 5.6 5.6 5.6 3.093 0 5.6-2.507 5.6-5.6 0-3.093-2.507-5.6-5.6-5.6z">
# </path>
# </svg>
# </span>
# </button>
# </li>
# </ul>
# <div class="fixed-header">
# <script type="text/javascript">
#        (function() {
#         var sc = document.createElement('script'); sc.type = 'text/javascript'; sc.async = true;
#         sc.src = __passportHeader_config.HEADER_URL + 'passportHeader.js';
#        var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sc, s);
#     })();
#       </script>
# <div id="passportHeader" style="height: 36px; visibility: hidden;">
# </div>
# </div>
# </div>
# </div>
# </div>
# <section class="blokk hajtas-felett container index-header cimlap-blokk-index">
# <div class="index-header-wrapper">
# <a class="logo" data-ga-category="Index logó" href="/">
# </a>
# <ul class="trending-topics">
# <li stamp-index="0">
# <a class="cimke cimke-mufaj cimke-199435" href="https://dex.hu/x.php?id=inxcl_stamp&amp;url=https%3A%2F%2Findex.hu%2Fbajnokokligaja%23">
#        Bajnokok Ligája
#       </a>
# </li>
# </ul>
# <div class="header-parts">
# <div class="calendar">
# <time datetime="2024-06-01" title="22. hét">
#        2024. 06. 01. szombat
#       </time>
# <div id="name-day">
#        Tünde
#       </div>
# </div>
# <section class="exchange njs-carousel">
# <a class="exchange-ticker" data-g-category="Árfolyam" href="https://dex.hu/x.php?id=inxfejlec&amp;url=http%3A%2F%2Fportfoliofinancial.hu%2F" target="_blank" title="Forrás: portfoliofinancial.hu">
# <span class="currency-item goood">
# <span class="ticker">
#          EUR
#         </span>
# <span class="price">
#          389,48
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="currency-item baaad">
# <span class="ticker">
#          USD
#         </span>
# <span class="price">
#          359,02
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="currency-item baaad">
# <span class="ticker">
#          GBP
#         </span>
# <span class="price">
#          457,49
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="exchange-item baaad">
# <span class="ticker">
#          BUX
#         </span>
# <span class="price">
#          67 907
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="exchange-item baaad">
# <span class="ticker">
#          OTP
#         </span>
# <span class="price">
#          17 310
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# <span class="exchange-item baaad">
# <span class="ticker">
#          MOL
#         </span>
# <span class="price">
#          2 790
#          <span class="forint">
#           Ft
#          </span>
# </span>
# </span>
# </a>
# </section>
# <a class="weather" data-ga-category="Időjárás" data-temprature="20.8" href="https://dex.hu/x.php?id=inxcl_idojaras&amp;url=https://index.hu/idojaras" title="most: 20,8 °C">
# <div class="temperature">
# <div class="night">
#         14 °C
#        </div>
# <div class="day">
#         23 °C
#        </div>
# </div>
# <div class="weather-icon">
# <ul>
# <li class="icon-cloud">
# </li>
# </ul>
# </div>
# </a>
# </div>
# <nav id="index-rovatok">
# <a class="rovat-link navi_belfold" data-ga-category="Belföld" data-rovat-dropdown="" href="#" id="belfold">
#       Belföld
#      </a>
# <a class="rovat-link navi_kulfold" data-ga-category="Külföld" data-rovat-dropdown="" href="#" id="kulfold">
#       Külföld
#      </a>
# <a class="rovat-link navi_gazdasag" data-ga-category="Gazdaság" data-rovat-dropdown="" href="#" id="gazdasag">
#       Gazdaság
#      </a>
# <a class="rovat-link navi_kultur" data-ga-category="Kult" data-rovat-dropdown="" href="#" id="kultur">
#       Kult
#      </a>
# <a class="rovat-link navi_velemeny" data-ga-category="Vélemény" data-rovat-dropdown="" href="#" id="velemeny">
#       Vélemény
#      </a>
# <a class="rovat-link navi_techtud" data-ga-category="Tech-Tud" data-rovat-dropdown="" href="#" id="techtud">
#       Tech-Tud
#      </a>
# <a class="rovat-link navi_sport" data-ga-category="Sport" data-rovat-dropdown="" href="#" id="sport">
#       Sport
#      </a>
# <a class="rovat-link navi_fomo" data-ga-category="Fomo" data-rovat-dropdown="" href="#" id="fomo">
#       Fomo
#      </a>
# <a class="rovat-link navi_24ora selected" data-ga-category="24 Óra" data-rovat-dropdown="" href="#" id="24ora">
#       24 Óra
#      </a>
# <a class="rovat-link navi_blog notification" data-ga-category="Blog" data-rovat-dropdown="" href="#" id="blog">
#       Blog
#      </a>
# <a class="rovat-link navi_video notification" data-ga-category="Videó" data-rovat-dropdown="" href="#" id="video">
#       Videó
#      </a>
# <a class="rovat-link navi_podcast notification" data-ga-category="Podcast" data-rovat-dropdown="" href="#" id="podcast">
#       Podcast
#      </a>
# <a class="rovat-icon navi_twitter" data-ga-category="Twitter" href="https://twitter.com/indexhu" id="twitter" target="_blank">
# </a>
# <a class="rovat-icon navi_socials" data-ga-category="Socials" data-rovat-dropdown="" href="#" id="socials">
# </a>
# </nav>
# <div class="dropdown-container" hidden="" id="dropdown-menu-wrapper">
# <div class="loader animating">
# <span class="loader-item">
# </span>
# <span class="loader-item">
# </span>
# <span class="loader-item">
# </span>
# </div>
# </div>
# <script>
#      document.addEventListener('DOMContentLoaded', () => {
#         window.rovatDropdown = new RovatDropdown({
#             base_url: 'https://index.hu/',
#             callbacks: {
#                 video: function(element) {
#                     window.video_slider = new DropdownSlider(element.querySelector('.slider'), { threshold: 0 });
#                 }
#             }
#         });
#     });
#     </script>
# </div>
# </section>
# <div class="container top_szponzor adverticum-kapubanner">
# <div class="ad-container">
# <div class="iap iap--ado" data-id="adoceanindexhuqclsmvirum" id="adoceanindexhuqclsmvirum">
# <script class="iap-script">
#       window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhuqclsmvirum","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_LB","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#      </script>
# </div>
# </div>
# </div>
# <div class="container border rovat-container">
# <div id="js_content_template_normal">
# <!--
#         <article class="rovatajanlo unordered not-important normal">
#             <header class="rovat-cikk-head">
#                 <h3>
#                     <span class="separator-box"></span>
#                         <span class="cikk-date-label" data-datestamp="{{Puzzler.ccd.ts}}" data-date="{{Puzzler.timestampToDate( Puzzler.ccd.ts )}}">{{Puzzler.ccd.datum}}</span>
#                     <span class="separator"></span>
#                     {{Puzzler.isMindekozben( Puzzler.ccd.url ) ? '<ul class="cikk-cimkek"><li><a href="http://index.hu/mindekozben" class="cimke cimke-mufaj">Mindeközben</a></li></ul>' : ''}}
#                     {{ Puzzler.ccd.kiadvany_csoki ? Puzzler.ccd.kiadvany_csoki : ''; }}
#                 </h3>
#                 <div class="clearfix"></div>
#             </header>
#
#             <h2>
#                 {{Puzzler.ccd.kep ? '<a href="' + Puzzler.ccd.url + '"  title="' + Puzzler.ccd.cim + '"><img class="need_to_load" src="' + Puzzler.ccd.kep + '" alt="' + Puzzler.ccd.cim + '" /></a>' : '' }}
#                 <a href="{{Puzzler.ccd.url}}" class="cim" title="{{Puzzler.ccd.cim}}">{{Puzzler.ccd.cim}}</a>
#             </h2>
#             {{Puzzler.ccd.ajanlo ? '<div class="ajanlo">' + Puzzler.ccd.ajanlo + '</div>' : '' }}
#         </article>
# -->
# </div>
# <div id="js_content_template_lead">
# <!--
#         <article class="rovatajanlo vezeto keppel not-important">
#             <div class="article-container">
#                 <a href="{{Puzzler.ccd.url}}"  title="{{Puzzler.ccd.cim}}">
#                     <img src="{{Puzzler.ccd.kep}}" alt="{{Puzzler.ccd.cim}}">
#                 </a>
#                 <h2>
#                     <a href="{{Puzzler.ccd.url}}" class="cim"  title="{{Puzzler.ccd.cim}}">{{Puzzler.ccd.cim}}</a>
#                 </h2>
#             </div>
#             <div class="author-share-date-container">
#             <div class="author-share-date">
#                 <div class="bal-hasab">
#                     <div class="szerzok_container">
#                             {{Puzzler.ccd.alnevek.replace(/\\(.)/mg, "$1")}}
#                     </div>
#                     <div class="datum">
#                         {{Puzzler.ccd.datum}}
#                     </div>
#                 </div>
#                 <div class="jobb-hasab">
#                     <div class="megoszt ">
#                         <div class="fb-share" data-action="recommend" data-href="{{Puzzler.ccd.url}}"> {{Puzzler.ccd.actual_fb_like}} </div>
#                 <div class="index-social-box cikk-top-box">
#                     <a href="#" class="megosztas-gomb"></a>
#                     <ul class="megosztas-doboz">
#                         <li class="mail">
#                             <a class="email" href="mailto:ugyelet@NEMSPA_M.mail.index.hu?subject={{Puzzler.ccd.cim}}&amp;body=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                             <li class="facebook">
#                                 <a href="https://www.facebook.com/sharer/sharer.php?u=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                             </li>
#                         <li class="twitter">
#                             <a href="http://twitter.com/share?lang=hu&amp;text={{Puzzler.ccd.cim}}&amp;url=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                         <li class="tumblr">
#                             <a href="http://www.tumblr.com/share/link?url=http:{{Puzzler.ccd.url}}&amp;name={{Puzzler.ccd.cim}}&amp;description=%28via+%3Ca+href%3D%22http%3A%2F%2Findex.hu%2F%22%3EIndex%3C%2Fa%3E%29" target="_blank"></a>
#                         </li>
#                         <li class="google-plus">
#                             <a href="https://plus.google.com/share?url=http:{{Puzzler.ccd.url}}" target="_blank"></a>
#                         </li>
#                     </ul>
#                 </div>
#                             <div class="hozzaszolasok"></div>
#                    </div>
#
#                                 </div>
#                             </div>
#             </div>
#             <div class="ajanlo">{{Puzzler.ccd.ajanlo}}</div>
#         </article>
# -->
# </div>
# <div id="js_content_template_datumcsik">
# <!--
#         <div class="datumcsik clearfix">{{Puzzler.ccd.month ? Puzzler.ccd.month : Puzzler.timestampToDate( Puzzler.ccd.ts, true )}}</div>
# -->
# </div>
# <div class="kereses-urlap">
# <h3>
#      Keresés
#     </h3>
# <form action="" id="kereses-urlap">
# <div class="mezocsoport alap-kereso">
# <div class="kereses-wrapper">
# <input id="kereses-mezo" name="s" placeholder="Keresés" type="text" value=""/>
# </div>
# <div class="kereses-gomb-wrapper">
# <input class="gomb-elsodleges kereses-ikon" type="submit" value=""/>
# </div>
# </div>
# <div class="reszletes-kereses-gomb-container">
# <button class="gomb-masodlagos reszletes-kereses-gomb" href="#">
#        Részletes keresés
#       </button>
# </div>
# <div class="reszletes-kereses-container">
# <div class="datum-container">
# <div class="mezocsoport">
# <div class="datum-wrapper">
# <input autocomplete="off" class="date-selector" id="datum-tol" name="tol" type="text" value="1999-01-01"/>
# </div>
# <div class="datum-label-wrapper">
# <label for="datum-tol">
#           -tól
#          </label>
# </div>
# </div>
# <div class="mezocsoport">
# <div class="datum-wrapper">
# <input autocomplete="off" class="date-selector" id="datum-ig" name="ig" type="text" value="2024-06-01"/>
# </div>
# <div class="datum-label-wrapper">
# <label for="datum-ig">
#           -ig
#          </label>
# </div>
# </div>
# </div>
# <div class="onthisday-container">
# <input class="onthisday-kapcsolo" id="onthisday" name="onthisday" type="checkbox" value="1"/>
# <label class="onthisday-label" for="onthisday">
#         Ezen a napon
#         <span>
# </span>
# </label>
# </div>
# <div class="tarskiadvany-container">
# <input class="tarskiadvany-kapcsolo" id="tarskiadvanyokbanis" name="tarskiadvanyokbanis" type="checkbox" value="1"/>
# <label class="tarskiadvany-label" for="tarskiadvanyokbanis">
#         Az Index környékéről is
#         <span>
#          Totalcar, Totalbike, Velvet, Dívány, Comment:Com, Könyvesblog, Tékozló Homár
#         </span>
# </label>
# <div class="tarskiadvany-opciok">
# <div class="szerzo-rovat-container">
# <div class="mezocsoport">
# <div class="input-wrapper">
# <select class="chosen-select" data-placeholder="Szerzők" name="profil">
# <option value="">
# </option>
# <option value="">
#              Összes
#             </option>
# <option value="acs_daniel">
#              Ács Dániel
#             </option>
# <option value="acs_tibor">
#              Ács Tibor
#             </option>
# <option value="adamek_alma">
#              Adamek Alma
#             </option>
# <option value="aghassi_attila">
#              Ághassi Attila
#             </option>
# <option value="ago_bela">
#              Ágó Béla
#             </option>
# <option value="agoston_zoltan">
#              Ágoston Zoltán
#             </option>
# <option value="ajpek_orsi">
#              Ajpek Orsi
#             </option>
# <option value="ambrus_adam">
#              Ambrus Ádám
#             </option>
# <option value="ambrus_balazs">
# ...
# <img alt="Básti Juli Tompos Kátyáról: Igazi angyalka volt, akit mindenki szeretett" loading="lazy" src="https://kep.index.hu/1/0/5660/56604/566045/56604563_4185297_09fb053255ee5baf361b61434739616a_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/tompos-katya-gyasz-halal-basti-juli-szinhaz/" title="Básti Juli Tompos Kátyáról: Igazi angyalka volt, akit mindenki szeretett">
#        Básti Juli Tompos Kátyáról: Igazi angyalka volt, akit mindenki szeretett
#       </a>
# </h2>
# <div class="ajanlo">
#       Kollégája szerint elementáris ereje volt a nemrég meghalt színésznőnek.
#      </div>
# </article>
# <article class="rovatajanlo normal right">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717232408">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/valovilag12-bekoltozo-show-villalako-/" title="ValóVilág 12: újabb három villalakó-jelölt mutatkozott be, akik felkavarnák az állóvizet Valenéknél">
#        ValóVilág 12: újabb három villalakó-jelölt mutatkozott be, akik felkavarnák az állóvizet Valenéknél
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>
# <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717231020">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/egyesult-kiralysag-mexiko-nagykovet-fegyver/" title="Elbocsátották a mexikói brit nagykövetet, miután fegyvert szegezett a követség alkalmazottjára">
# <img alt="Elbocsátották a mexikói brit nagykövetet, miután fegyvert szegezett a követség alkalmazottjára" loading="lazy" src="https://kep.index.hu/1/0/5660/56604/566048/56604891_4185321_75a94ff357ab17fc073ff7e7e742b655_wm.png"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/egyesult-kiralysag-mexiko-nagykovet-fegyver/" title="Elbocsátották a mexikói brit nagykövetet, miután fegyvert szegezett a követség alkalmazottjára">
#        Elbocsátották a mexikói brit nagykövetet, miután fegyvert szegezett a követség alkalmazottjára
#       </a>
# </h2>
# <div class="ajanlo">
#       A fegyver feltehetően a diplomatát kísérő biztonságiaké volt.
#      </div>
# </article>
# <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717230000">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/iland-videoklip-kek-gyemant-zene-videoklip/" title="Különleges gyémántra bukkantunk a Műcsarnok kiállításán">
# <img alt="Különleges gyémántra bukkantunk a Műcsarnok kiállításán" loading="lazy" src="https://kep.index.hu/1/0/5660/56604/566043/56604377_4185283_0eb44c1aaa80777d7e3d40c8532545b3_wm.png"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/iland-videoklip-kek-gyemant-zene-videoklip/" title="Különleges gyémántra bukkantunk a Műcsarnok kiállításán">
#        Különleges gyémántra bukkantunk a Műcsarnok kiállításán
#       </a>
# </h2>
# <div class="ajanlo">
#       Dalban mondták el.
#      </div>
# </article>
# <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717228980">
#         8 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/01/nagy-attila-tibor-politikai-elemzo-karacsony-gergely-vitezy-david-szentkiralyi-alexandra-vita-velemeny/" title="Vitézy Dávid sziporkázott, Szentkirályi Alexandra jobban járt a távolmaradással">
# <img alt="Vitézy Dávid sziporkázott, Szentkirályi Alexandra jobban járt a távolmaradással" loading="lazy" src="https://kep.index.hu/1/0/5660/56603/566039/56603919_4185247_33c16e5b78fa41ee1914d4be70659fee_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/01/nagy-attila-tibor-politikai-elemzo-karacsony-gergely-vitezy-david-szentkiralyi-alexandra-vita-velemeny/" title="Vitézy Dávid sziporkázott, Szentkirályi Alexandra jobban járt a távolmaradással">
#        Vitézy Dávid sziporkázott, Szentkirályi Alexandra jobban járt a távolmaradással
#       </a>
# </h2>
# <div class="ajanlo">
#       Nagy Attila Tibor politikai elemző értékelte az Indexnek a péntek esti vitát.
#      </div>
# </article>
# <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717227600">
#         8 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/usa/feher_haz/2024/06/01/joe-biden-donald-trump-itelet-per/" title="Joe Biden Donald Trump elítéléséről: Senki nem áll törvények felett">
# <img alt="Joe Biden Donald Trump elítéléséről: Senki nem áll törvények felett" loading="lazy" src="https://kep.index.hu/1/0/5660/56603/566038/56603839_4185241_fad17a7cc6863714a85f5b954753a914_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/usa/feher_haz/2024/06/01/joe-biden-donald-trump-itelet-per/" title="Joe Biden Donald Trump elítéléséről: Senki nem áll törvények felett">
#        Joe Biden Donald Trump elítéléséről: Senki nem áll törvények felett
#       </a>
# </h2>
# <div class="ajanlo">
#       Szerinte az esküdtek körültekintő döntést hoztak.
#      </div>
# </article>
# <article class="rovatajanlo normal left">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717227000">
#         8 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/cooky-szecsi-debora-instagram-vs-valosag-video/" title="A fél internet Cooky Instagram vs. valóság videóján nevet, a párját, Szécsi Debórát figurázta ki">
#        A fél internet Cooky Instagram vs. valóság videóján nevet, a párját, Szécsi Debórát figurázta ki
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>
# <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/fomo/2024/06/01/daniel-stern-reszkessetek-betorok-konyv/" title="Kis híján meghalt a Reszkessetek, betörők! ikonikus színésze">
# <img alt="Kis híján meghalt a Reszkessetek, betörők! ikonikus színésze" loading="lazy" src="https://kep.index.hu/1/0/5659/56595/565954/56595451_4184599_b0b082b5877e22c1dd3c41eb3b9ff825_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/fomo/2024/06/01/daniel-stern-reszkessetek-betorok-konyv/" title="Kis híján meghalt a Reszkessetek, betörők! ikonikus színésze">
#         Kis híján meghalt a Reszkessetek, betörők! ikonikus színésze
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/harnisch_kitti">
# <img alt="Harnisch Kitti" class="szerzo-kep" src="https://kep.index.hu/1/0/4152/41525/415253/41525355_3169809_6bc9f849e6e4839cc9b4639882de03c1_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/harnisch_kitti" rel="author">
#             Harnisch Kitti
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1353">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.01. 09:27
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-01 14:14:17
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Daniel Stern egy forgatás során került kalamajkába.
#      </div>
# </article>
# </main>
# <div class="clear">
# </div>
# </div>
# <footer class="m-page-footer">
# <div class="container m-page-footer_container">
# <ul class="m-page-footer_container_list">
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fimpresszum%2F">
#        Impresszum
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findamediasales.hu%2F">
#        Médiaajánlat
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fcopyright%2F">
#        Szerzői jogok
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fadatvedelem%2F">
#        Adatvédelmi elvek
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fsutiszabalyzat%2F">
#        Süti szabályzat
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasText">
# <a class="change-consent m-page-footer_container_list_item_link" onclick="window.__tcfapi('displayConsentUi', 2, function() {} );">
#        Süti beállítások
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2F24ora%2Frss%2F">
#        RSS
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Finfo%2Fallas%2F">
#        Állás
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Fajanlat.indamediasales.hu%2Fmarkabiztonsag%2FIndamedia_Sales_Markabiztonsagi_nyilatkozat.pdf">
#        Márkabiztonság
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasLink">
# <a class="m-page-footer_container_list_item_link" href="https://dex.hu/x?f=https%3A%2F%2Findex.hu%2Fdsa" target="_blank">
#        DSA
#       </a>
# </li>
# <li class="m-page-footer_container_list_item hasText">
# <span class="m-page-footer_container_list_item_text">
#        © 1999-2024
#        <span>
#         Index.hu
#        </span>
#        Zrt.
#       </span>
# </li>
# </ul>
# </div>
# </footer>
# <div class="layout_watcher phone">
# </div>
# <div class="layout_watcher portrait-tablet">
# </div>
# <div class="layout_watcher landscape-tablet">
# </div>
# <div class="layout_watcher desktop">
# </div>
# <div class="newsletter_modal" id="newsletterModal">
# </div>
# <script>
#    new NewsletterModal( document.getElementById('newsletterModal'), {'assetUrl': 'https://index.hu/assets/'});
#   </script>
# <script>
#    var bodyContent = '';
#         $emailAdress = 'bla';
#                 bodyContent = 'Olvasói levelet, meghívót, sajtóközleményt készül küldeni a(z) <strong><a href="mailto:{emailAddress}" target="_blank" class="email">{emailShow}</a></strong> címen a szerkesztőségnek. Fontos nekünk, ezért az adataira is nagyon vigyázunk, ahogy az <a href="https://index.hu/adatvedelem" target="_blank">adatvédelmi tájékoztatónkban</a> részletezzük is. Ha Önnek is oké, kattintson az OK gombra.';
#         bodyContentMeghivo = 'Nyilatkozatot, bejelentést, vagy felhasználási kérelmet készül küldeni a(z) <strong><a href="mailto:{emailAddress}" target="_blank" class="email">{emailShow}</a></strong> címen a lapigazgatónak.Fontos nekünk, ezért az adataira is nagyon vigyázunk, ahogy az <a href="https://index.hu/adatvedelem" target="_blank">adatvédelmi tájékoztatónkban</a> részletezzük is. Ha Önnek is oké, kattintson az OK gombra.'
#
#         $(document).ready(function() {
#
#             $('a.email').on('click', function(e) {
#                 e.preventDefault();
#
#                 if (
#                     // Csak akkor jelenítjük meg a modal ablakot, ha ezeknek a feltételeknek valamelyike teljesül
#                     $(this).hasClass('irok_neki') ||               // Ha írok neki típusú a link vagy
#                     $(this).attr('href').indexOf('mailto:') !== -1  // van mailto link a href-ben
#                 ) {
#
#
#                     var emailAddress = $(this).attr('href')
#                         .replace('mailto:', '')
#                         .replace('NEMSPA_M.', '');
#
#                     var emailShow = emailAddress.match(/([a-zA-Z0-9._+-]+@[a-zA-Z0-9._-]+\.[a-zA-Z0-9._-]+)/)[0];
#
#                     var content = $(e.target).hasClass('meghivo') ? bodyContentMeghivo.replace(/{emailAddress}/gi, emailAddress).replace(/{emailShow}/g, emailShow) : bodyContent.replace(/{emailAddress}/gi, emailAddress).replace(/{emailShow}/g, emailShow);
#
#                     var mailtoModal = new vModal({
#                         title: 'Adatvédelmi tájékoztatás',
#                         body: content,
#                         buttons: {
#                             more: 'Vissza',
#                             confirm: 'OK'
#                         },
#                         className: 'vanilla_modal--basic',
#                         events: {
#                             confirm: function() {
#                                 //chrome miatt kell új lapon megnyitni, különben nem működik!
#                                 window.open('mailto:' + emailAddress, '_blank');
#                             }
#                         }
#                     });
#
#                     mailtoModal.open();
#
#                 }
#
#             });
#
#         });
#   </script>
# <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
#             var pp_gemius_identifier = pp_gemius_original_identifier = new String('B9OVVi_kSaN4kjyXnmrlRnaITKLZOwR45wv6Si7xT2f.S7'); <!-- 24 óra -->
#             var pp_gemius_use_cmp = true;
#             var pp_gemius_cmp_timeout = Infinity;
#             //--><!]]>
#   </script>
# <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
#             function gemius_pending(i) { window[i] = window[i] || function() {var x = window[i+'_pdata'] = window[i+'_pdata'] || []; x[x.length]=arguments;};};
#             gemius_pending('gemius_hit'); gemius_pending('gemius_event');
#             gemius_pending('pp_gemius_hit'); gemius_pending('pp_gemius_event');
#
#             (function(d,t) {try {
#             var gt=d.createElement(t),s=d.getElementsByTagName(t)[0],l='http'+((location.protocol=='https:')?'s':'');
#             gt.setAttribute('async','async');
#             gt.setAttribute('defer','defer');
#             gt.src=l+'://gahu.hit.gemius.pl/xgemius.js';
#             s.parentNode.insertBefore(gt,s);}
#             catch (e) {}})(document,'script');
#             //--><!]]>
#   </script>
# <script type="text/javascript">
#    var gemABObj = {
#                 docBody: document.getElementsByTagName('body')[0],
#                 incScript: document.createElement('SCRIPT'),
#                 checkIt: function(){document.getElementById("mnxHDozyKPjB")?pp_gemius_hit("nSdFzTtkvTTrx.B7K13yyfU378aFPueKFs36aeS6yET.A7","addon=no-adblock"):pp_gemius_hit("nSzrCTsGCKuF9KNE6iWTitVrzbu1Eg8GQHsHaml5W8n.b7","addon=adblock")}
#             };
#             gemABObj.incScript.src = '//indexhu.adocean.pl/files/x/mof/ghshscq/xajkevmjdv/ads.js';
#             gemABObj.docBody.appendChild(gemABObj.incScript);
#
#             window.addEventListener("load",gemABObj.checkIt);
#   </script>
# </body>
# </html>

# %% [markdown]
# ## Cikkek adatait tároló kódrészlek kigyűjtése

# %%
articles = soup.find_all("article")

print(len(articles))
print(articles)
# Out:
# 60
# [<article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/belfold/2024/06/01/orban-viktor-beszed-bekemenet-valasztasok-haboru/" title="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje">
# <img alt="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje" loading="lazy" src="https://kep.index.hu/1/0/5660/56609/566098/56609867_4185723_e6b8b4d0d0ff561d1f7cbd755727a428_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/orban-viktor-beszed-bekemenet-valasztasok-haboru/" title="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje">
#         Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/peter_alvarez">
# <img alt="Péter Alvarez" class="szerzo-kep" src="https://kep.index.hu/1/0/4903/49034/490344/49034444_3737960_b998b0087613d5288b147749af5e46d1_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/peter_alvarez" rel="author">
#             Péter Alvarez
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1532">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.01. 16:52
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-01 17:11:13
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       A miniszterelnök beszédével ért véget a Békemenet.
#      </div>
# <div class="iap iap--ado roadblock" data-id="adoceanindexhundcjqssfzl" id="adoceanindexhundcjqssfzl">
# <script class="iap-script">
#        window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhundcjqssfzl","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_RB_A","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#       </script>
# </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717256700">
#         2 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/magyar-peter-tisza-part-peticio-kampany-haboru-orban-viktor-deutsch-tamas-bekemenet/" title="Magyar Péter a Békemenet után tett bejelentést">
# <img alt="Magyar Péter a Békemenet után tett bejelentést" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566105/56610529_4185769_d5b75d4d396fedd965345bf8b86362f1_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/magyar-peter-tisza-part-peticio-kampany-haboru-orban-viktor-deutsch-tamas-bekemenet/" title="Magyar Péter a Békemenet után tett bejelentést">
#        Magyar Péter a Békemenet után tett bejelentést
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717256340">
#         8 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/olaszorszag-havazas-alpok-nyar-livigno-sondrio-megye/" title="Havazott az olasz Alpokban a nyár előestéjén">
# <img alt="Havazott az olasz Alpokban a nyár előestéjén" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566104/56610445_4185765_d3262474ec99ee27fb88425a7c0aede9_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/olaszorszag-havazas-alpok-nyar-livigno-sondrio-megye/" title="Havazott az olasz Alpokban a nyár előestéjén">
#        Havazott az olasz Alpokban a nyár előestéjén
#       </a>
# </h2>
# <div class="ajanlo">
#       A nem mindennapi időjárási jelenségről több videót is készítettek a helyiek.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717255560">
#         21 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/tudomany/2024/06/01/elektromos-auto-hibrid-baleset-zaj-kornyezet-kimelo/" title="Settenkedő járművek veszélyeztetik a gyalogosokat, de van megoldás">
# <img alt="Settenkedő járművek veszélyeztetik a gyalogosokat, de van megoldás" loading="lazy" src="https://kep.index.hu/1/0/5653/56534/565340/56534067_4180071_eda71f42656fde6173e8656bc5e48b05_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/tudomany/2024/06/01/elektromos-auto-hibrid-baleset-zaj-kornyezet-kimelo/" title="Settenkedő járművek veszélyeztetik a gyalogosokat, de van megoldás">
#        Settenkedő járművek veszélyeztetik a gyalogosokat, de van megoldás
#       </a>
# </h2>
# <div class="ajanlo">
#       Rászokunk a fülelésre.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717255380">
#         24 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/amerikai-egyesult-allamok-korrupcio-botrany-vesztegetes-robert-burke-haditengereszet-admiralis/" title="Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát">
# <img alt="Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566104/56610407_4185763_cb0fbc3a19102aa68e51461586144fba_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/amerikai-egyesult-allamok-korrupcio-botrany-vesztegetes-robert-burke-haditengereszet-admiralis/" title="Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát">
#        Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát
#       </a>
# </h2>
# <div class="ajanlo">
#       Átszámítva 180 millió forintos éves fizetéssel sikerült lekenyerezni.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717254240">
#         43 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/atletika/2024/06/01/atletika-olimpiai-bajnok-atlanta-gatfutas-sydney-mclaughlin-levrone-edwin-moses-classic/" title="Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle">
# <img alt="Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle" loading="lazy" src="https://kep.index.hu/1/0/5660/56609/566095/56609519_4185695_c38d52cdd5b5c69339ebe99487f2e8a4_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/atletika/2024/06/01/atletika-olimpiai-bajnok-atlanta-gatfutas-sydney-mclaughlin-levrone-edwin-moses-classic/" title="Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle">
#        Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle
#       </a>
# </h2>
# <div class="ajanlo">
#       Az amerikai világcsúcstartó legutóbb 2022 augusztusában állt rajthoz ebben a számban.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717254180">
#         44 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/tompos-katya-szineszno-halala-utolso-interju/" title="Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában">
# <img alt="Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566102/56610275_4185755_e063e7ef91d269bd87be58cfc9e5a77b_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/tompos-katya-szineszno-halala-utolso-interju/" title="Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában">
#        Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában
#       </a>
# </h2>
# <div class="ajanlo">
#       Több mint egy éve készült a műsor.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717254120">
#         45 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/haboru-oroszorszag-ukrajna-europai-csapatok-ukrajnaban-glen-grant-brit-ezredes/" title="Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni">
# <img alt="Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566102/56610249_4185753_ca26c56dc70528826639b79b2478b300_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/haboru-oroszorszag-ukrajna-europai-csapatok-ukrajnaban-glen-grant-brit-ezredes/" title="Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni">
#        Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni
#       </a>
# </h2>
# <div class="ajanlo">
#       „Amit eddig tettek, az nem volt elég hatással Oroszországra” – mondta.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717253940">
#         48 perce
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/magyar-peter-partizan-gulyas-marton-tisza-program/" title="Nem kímélték Magyar Pétert, minden kikerült az asztalra">
# <img alt="Nem kímélték Magyar Pétert, minden kikerült az asztalra" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566101/56610107_4185741_d13245e341d14d4d2d4b900e83fd0ff8_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/magyar-peter-partizan-gulyas-marton-tisza-program/" title="Nem kímélték Magyar Pétert, minden kikerült az asztalra">
#        Nem kímélték Magyar Pétert, minden kikerült az asztalra
#       </a>
# </h2>
# <div class="ajanlo">
#       Gulyás Márton szerint hajlamos a nagyotmondásra a Tisza Párt alelnöke.
#      </div>
# </article>, <article class="rovatajanlo normal right">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717253700">
#         52 perce
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/kiraly-viktor-magyar-akcentus-parodia/" title="Király Viktor kiparodizálta a magyarok akcentusos angolját">
#        Király Viktor kiparodizálta a magyarok akcentusos angolját
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/sport/kezilabda/2024/06/01/esbjerg-gyori-eto/" title="Megvan a tizedik: drámai végjáték után Bajnokok Ligája-döntős a Győri ETO!">
# <img alt="Megvan a tizedik: drámai végjáték után Bajnokok Ligája-döntős a Győri ETO!" loading="lazy" src="https://kep.index.hu/1/0/5660/56609/566098/56609839_4185721_62809130bfa7435e27d3a093e93643b5_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/sport/kezilabda/2024/06/01/esbjerg-gyori-eto/" title="Megvan a tizedik: drámai végjáték után Bajnokok Ligája-döntős a Győri ETO!">
#         Megvan a tizedik: drámai végjáték után Bajnokok Ligája-döntős a Győri ETO!
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/toth_istvan">
# <img alt="Kocsmár-Tóth István" class="szerzo-kep" src="https://kep.index.hu/1/0/4397/43976/439766/43976670_3355564_d6ab0b5a8633a9cae175527b63b93122_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/toth_istvan" rel="author">
#             Kocsmár-Tóth István
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1408">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.01. 16:35
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-01 17:35:59
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Az utolsó másodpercben még volt egy labdája a hosszabbításért, de nem tudott élni vele az Esbjerg.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717252020">
#         1 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/ungar-peter-lmp-interju-ellenzek-fidesz-budapest-karacsony-gergely-vitezy-david-ep-valasztas-onkormanyzati-valasztas/" title="Ungár Péter: Ez egy BDSM-kapcsolat, a kormány a szadista, a főváros a mazochista">
# <img alt="Ungár Péter: Ez egy BDSM-kapcsolat, a kormány a szadista, a főváros a mazochista" loading="lazy" src="https://kep.index.hu/1/0/5660/56609/566097/56609747_4185715_0fa5cf043189249860dd148dd95d6319_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/ungar-peter-lmp-interju-ellenzek-fidesz-budapest-karacsony-gergely-vitezy-david-ep-valasztas-onkormanyzati-valasztas/" title="Ungár Péter: Ez egy BDSM-kapcsolat, a kormány a szadista, a főváros a mazochista">
#        Ungár Péter: Ez egy BDSM-kapcsolat, a kormány a szadista, a főváros a mazochista
#       </a>
# </h2>
# <div class="ajanlo">
#       Interjú az LMP társelnökével.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717251660">
#         1 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/vamos-miklos-krasznahorkai-laszlo-zsomle-odavan/" title="Nem várt helyről méltatták Krasznahorkai Lászlót">
# <img alt="Nem várt helyről méltatták Krasznahorkai Lászlót" loading="lazy" src="https://kep.index.hu/1/0/5661/56610/566100/56610069_4185739_ca98cf0ca21a1dfce60afe84c0e96108_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/vamos-miklos-krasznahorkai-laszlo-zsomle-odavan/" title="Nem várt helyről méltatták Krasznahorkai Lászlót">
#        Nem várt helyről méltatták Krasznahorkai Lászlót
#       </a>
# </h2>
# <div class="ajanlo">
#       Népszerű pályatársa szólalt meg.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717251060">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/techtud/2024/06/01/hold-por-raketa-robbanas-homokfuvas-technikai-karosodas-veszely-tortenelem-nemzetkozi-jog/" title="Nemzetközi jogi problémát jelent a holdra szállás közben felvert por">
# <img alt="Nemzetközi jogi problémát jelent a holdra szállás közben felvert por" loading="lazy" src="https://kep.index.hu/1/0/5656/56560/565609/56560909_4182107_1a424dd52af839458da62cf2b26997e2_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/techtud/2024/06/01/hold-por-raketa-robbanas-homokfuvas-technikai-karosodas-veszely-tortenelem-nemzetkozi-jog/" title="Nemzetközi jogi problémát jelent a holdra szállás közben felvert por">
#        Nemzetközi jogi problémát jelent a holdra szállás közben felvert por
#       </a>
# </h2>
# <div class="ajanlo">
#       A rakéták által szétfújt anyag komoly veszélyt jelent a közelben található technikára.
#      </div>
# </article>, <article class="rovatajanlo normal left">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717249800">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/vonatpotlo-busz-mav-medgyesegyhaza-mezohegyes-bekescsaba-keses/" title="Vonatpótló buszt pótló buszt indított a MÁV">
#        Vonatpótló buszt pótló buszt indított a MÁV
#       </a>
# </h2>
# <div class="ajanlo">
#       De mi történik, ha ez is lerobban?
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717249380">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/futball/2024/eb/2024/06/01/eb-2024-adidas-bajnokok-ligaja-nemet-magyar-valogatott/" title="Szeretetcunamival várták a német szurkolók Eb-házigazda csoportellenfelünket">
# <img alt="Szeretetcunamival várták a német szurkolók Eb-házigazda csoportellenfelünket" loading="lazy" src="https://kep.index.hu/1/0/5660/56609/566093/56609365_4185679_ce9f789ebbfda0b479dd7671c35c101b_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/futball/2024/eb/2024/06/01/eb-2024-adidas-bajnokok-ligaja-nemet-magyar-valogatott/" title="Szeretetcunamival várták a német szurkolók Eb-házigazda csoportellenfelünket">
#        Szeretetcunamival várták a német szurkolók Eb-házigazda csoportellenfelünket
#       </a>
# </h2>
# <div class="ajanlo">
#       Bázist váltottak a németek, öten még hiányoznak.
#      </div>
# </article>, <article class="rovatajanlo normal left">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717248612">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/sofia-vergara-exferje-joe-manganiello-tetovalas-ujrahasznositas/" title="Sofía Vergara nem eltávolíttatja, hanem újrahasznosítja exférjének szánt tetoválását, nem is akárhogyan">
#        Sofía Vergara nem eltávolíttatja, hanem újrahasznosítja exférjének szánt tetoválását, nem is akárhogyan
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717248240">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/gazdasag/2024/06/01/auto-verseny-ev-magyar-autoja-2025-autos-nagykoalicio/" title="Év Magyar Autója 2025: már lehet nevezni a versenyre">
# <img alt="Év Magyar Autója 2025: már lehet nevezni a versenyre" loading="lazy" src="https://kep.index.hu/1/0/5660/56608/566085/56608511_4185595_a2a652c88f535767991d632746f2e2f3_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/gazdasag/2024/06/01/auto-verseny-ev-magyar-autoja-2025-autos-nagykoalicio/" title="Év Magyar Autója 2025: már lehet nevezni a versenyre">
#        Év Magyar Autója 2025: már lehet nevezni a versenyre
#       </a>
# </h2>
# <div class="ajanlo">
#       Már megérkeztek az első fecskék.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717248120">
#         2 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/buddhista-szerzetes-szingapur-del-korea-betiltas-dj-fellepes/" title="Miért tiltották be a dél-koreai buddhista DJ fellépését Szingapúrban?">
# <img alt="Miért tiltották be a dél-koreai buddhista DJ fellépését Szingapúrban?" loading="lazy" src="https://kep.index.hu/1/0/5656/56561/565610/56561053_4182119_b33c2600d43930813a48e327a3e5362a_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/buddhista-szerzetes-szingapur-del-korea-betiltas-dj-fellepes/" title="Miért tiltották be a dél-koreai buddhista DJ fellépését Szingapúrban?">
#        Miért tiltották be a dél-koreai buddhista DJ fellépését Szingapúrban?
#       </a>
# </h2>
# <div class="ajanlo">
#       Maga a belügyminiszter akadályozta meg a DJ szettjét.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717246020">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/gazdasag/2024/06/01/rakay-philip-norton-consulting-arbevetel-profit-csokkenes-megafon/" title="Kiderült, hogy alakult Rákay Philip számára a tavalyi év">
# <img alt="Kiderült, hogy alakult Rákay Philip számára a tavalyi év" loading="lazy" src="https://kep.index.hu/1/0/4637/46374/463742/46374266_3536192_da91d8d165b076af0448402603e8b2f0_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/gazdasag/2024/06/01/rakay-philip-norton-consulting-arbevetel-profit-csokkenes-megafon/" title="Kiderült, hogy alakult Rákay Philip számára a tavalyi év">
#        Kiderült, hogy alakult Rákay Philip számára a tavalyi év
#       </a>
# </h2>
# <div class="ajanlo">
#       Megjelent a beszámoló.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717246020">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/vitray-tamas-musrovezeto-riporter-televiziozas-media-sertegetes/" title="Vitray Tamás: Ma már következmények nélkül lehet sértegetni">
# <img alt="Vitray Tamás: Ma már következmények nélkül lehet sértegetni" loading="lazy" src="https://kep.index.hu/1/0/5660/56605/566052/56605235_4185355_bb488e7b392791b9ffd84f856dd92ee9_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/vitray-tamas-musrovezeto-riporter-televiziozas-media-sertegetes/" title="Vitray Tamás: Ma már következmények nélkül lehet sértegetni">
#        Vitray Tamás: Ma már következmények nélkül lehet sértegetni
#       </a>
# </h2>
# <div class="ajanlo">
#       A legendás televíziós szerint nincs ez így rendjén.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717246020">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/ukrajna-nyugat-egyesult-allamok-orosz-ukran-haboru-feszultseg-tamogatas/" title="The Washington Post: Naponta jelennek meg új repedések Ukrajna és Amerika kapcsolatában">
# <img alt="The Washington Post: Naponta jelennek meg új repedések Ukrajna és Amerika kapcsolatában" loading="lazy" src="https://kep.index.hu/1/0/5658/56581/565817/56581795_4183607_aa8979954b4ab8e412df9b1be4788c6b_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/ukrajna-nyugat-egyesult-allamok-orosz-ukran-haboru-feszultseg-tamogatas/" title="The Washington Post: Naponta jelennek meg új repedések Ukrajna és Amerika kapcsolatában">
#        The Washington Post: Naponta jelennek meg új repedések Ukrajna és Amerika kapcsolatában
#       </a>
# </h2>
# <div class="ajanlo">
#       Amerika a korrupció elleni harcot kéri számon Ukrajnától.
#      </div>
# </article>, <article class="rovatajanlo normal left">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717245900">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/szlovenia-kajakozo-isonzo-folyo-vizbefulladt/" title="Kajakozó fulladt az Isonzóba Szlovéniában">
#        Kajakozó fulladt az Isonzóba Szlovéniában
#       </a>
# </h2>
# <div class="ajanlo">
#       A férfi öt társával szállt vízre.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717245900">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <span class="cimke cimke-mufaj">
#           Percről percre
#          </span>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/kezilabda/2024/06/01/noi-kezlabda-bajnokok-ligaja-2023-2024-gyor-esbjerg-elodonto-percrol-percre/" title="A Győri Audi ETO KC a 10. BL-döntőjét játszhatja vasárnap">
# <img alt="A Győri Audi ETO KC a 10. BL-döntőjét játszhatja vasárnap" loading="lazy" src="https://kep.index.hu/1/0/5660/56609/566091/56609141_4185657_21e26572aebb891fd0af23762d90574f_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/kezilabda/2024/06/01/noi-kezlabda-bajnokok-ligaja-2023-2024-gyor-esbjerg-elodonto-percrol-percre/" title="A Győri Audi ETO KC a 10. BL-döntőjét játszhatja vasárnap">
#        A Győri Audi ETO KC a 10. BL-döntőjét játszhatja vasárnap
#       </a>
# </h2>
# <div class="ajanlo">
#       A Győri Audi ETO KC a 10. BL-döntőjét játszhatja vasárnap
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717245660">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/kariko-katalin-professzori-kinevezes-szegedi-tudomanyegyetem/" title="Sosem találná ki, milyen kinevezésben részesült Karikó Katalin">
# <img alt="Sosem találná ki, milyen kinevezésben részesült Karikó Katalin" loading="lazy" src="https://kep.index.hu/1/0/5116/51165/511650/51165031_3900865_aa40f21c04e0b079701a1ef26b5eb512_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/kariko-katalin-professzori-kinevezes-szegedi-tudomanyegyetem/" title="Sosem találná ki, milyen kinevezésben részesült Karikó Katalin">
#        Sosem találná ki, milyen kinevezésben részesült Karikó Katalin
#       </a>
# </h2>
# <div class="ajanlo">
#       Újabb elismeréssel díjazták a munkásságát.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717244520">
#         3 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/der-andras-film-testamentum-biblia-omega-kobor-janos-enekes-zene-klip-muveszet-kultura-rock/" title="Kóbor János nem zenész volt, mégis bekerült a bandába">
# <img alt="Kóbor János nem zenész volt, mégis bekerült a bandába" loading="lazy" src="https://kep.index.hu/1/0/5659/56598/565980/56598021_4184797_b12271e159fb2963e7e6498c8ff2bf89_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/der-andras-film-testamentum-biblia-omega-kobor-janos-enekes-zene-klip-muveszet-kultura-rock/" title="Kóbor János nem zenész volt, mégis bekerült a bandába">
#        Kóbor János nem zenész volt, mégis bekerült a bandába
#       </a>
# </h2>
# <div class="ajanlo">
#       Ötödik kerék volt.
#      </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/sport/futball/2024/eb/2024/06/01/europa-bajnoksag-2024-fiatal-sztarok-elso-europa-bajnoksag-giorgio-scalvini-jude-bellingham-florian-wirtz-benjamin-sesko/" title="Derült égből villámcsapásként érkeznek a trónkövetelők, csak győzzék velük tartani a lépést">
# <img alt="Derült égből villámcsapásként érkeznek a trónkövetelők, csak győzzék velük tartani a lépést" loading="lazy" src="https://kep.index.hu/1/0/5646/56465/564655/56465563_4174989_a0872ade987b42ac8b556d3fc0014f6e_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/sport/futball/2024/eb/2024/06/01/europa-bajnoksag-2024-fiatal-sztarok-elso-europa-bajnoksag-giorgio-scalvini-jude-bellingham-florian-wirtz-benjamin-sesko/" title="Derült égből villámcsapásként érkeznek a trónkövetelők, csak győzzék velük tartani a lépést">
#         Derült égből villámcsapásként érkeznek a trónkövetelők, csak győzzék velük tartani a lépést
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/klicasz_szpirosz_szotirisz">
# <img alt="Klicasz Szpirosz Szotirisz" class="szerzo-kep" src="https://kep.index.hu/1/0/3892/38925/389250/38925043_2969215_9261553097fd848efe53593c5c8f73ed_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/klicasz_szpirosz_szotirisz" rel="author">
#             Klicasz Szpirosz Szotirisz
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1297">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.01. 14:12
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-01 17:09:33
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Szoboszlai karrierútját bejáró támadó? Vagy a tucatnevű portugál lesz a legnagyobb sztár?
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717243500">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/gazdasag/2024/06/01/egeszsegugy-varhato-elettartam-gyogyszer-gyogyszeripar-aipm-europa-egeszseg-gyogyszergyartok-innovativ-gyogyszergyartok/" title="Cselekedni kell a magyarok egészsége érdekében">
# <img alt="Cselekedni kell a magyarok egészsége érdekében" loading="lazy" src="https://kep.index.hu/1/0/5660/56607/566076/56607683_4185535_138b8f70e92ac947337be7fecac18850_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/gazdasag/2024/06/01/egeszsegugy-varhato-elettartam-gyogyszer-gyogyszeripar-aipm-europa-egeszseg-gyogyszergyartok-innovativ-gyogyszergyartok/" title="Cselekedni kell a magyarok egészsége érdekében">
#        Cselekedni kell a magyarok egészsége érdekében
#       </a>
# </h2>
# <div class="ajanlo">
#       Számos fontos egészségügyi mutató alapján Magyarország le van maradva az uniós átlagtól.
#      </div>
# </article>, <article class="rovatajanlo normal left">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717243212">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/kucsera-gabor-harom-ev-utan-vegre-boldog-vagyok-/" title="Kucsera Gábor: „Három év után végre boldog vagyok”">
#        Kucsera Gábor: „Három év után végre boldog vagyok”
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/belfold/2024/06/01/fidesz-bekemenet-erodemonstracio-orban-viktor-ep-valasztas/" title="Erőt demonstrál a Fidesz a választások előtt">
# <img alt="Erőt demonstrál a Fidesz a választások előtt" loading="lazy" src="https://kep.index.hu/1/0/5660/56607/566071/56607177_4185497_eca958e34aebfa67145a644508e78359_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/fidesz-bekemenet-erodemonstracio-orban-viktor-ep-valasztas/" title="Erőt demonstrál a Fidesz a választások előtt">
#         Erőt demonstrál a Fidesz a választások előtt
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo kep-nelkul">
# <div class="kovetes nem-kovetheto">
# <a class="email" href="mailto:indexugyelet@mail.index.NEMSPA_M.hu?subject=http://index.hu/belfold/2024/06/01/fidesz-bekemenet-erodemonstracio-orban-viktor-ep-valasztas/&amp;cc=cikkszerzonek@mail.index.NEMSPA_M.hu">
#             Index
#            </a>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.01. 13:59
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-01 16:29:18
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Élő, többórás műsorfolyamban számolunk be az eseményről.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717243020">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/fomo/2024/06/01/mike-tyson-jake-paul-boksz-halasztas-egeszsegugyi-problema-netflix/" title="Elhalasztják Mike Tyson és Jake Paul bokszmeccsét">
# <img alt="Elhalasztják Mike Tyson és Jake Paul bokszmeccsét" loading="lazy" src="https://kep.index.hu/1/0/5660/56608/566083/56608317_4185577_2dd8b75106ed131b82f4322f96d5967a_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/fomo/2024/06/01/mike-tyson-jake-paul-boksz-halasztas-egeszsegugyi-problema-netflix/" title="Elhalasztják Mike Tyson és Jake Paul bokszmeccsét">
#        Elhalasztják Mike Tyson és Jake Paul bokszmeccsét
#       </a>
# </h2>
# <div class="ajanlo">
#       Mindkét fél jobbnak látja így.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717241820">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/orszagos-vizugyi-foigazgatosag-arvizvedelem-dunai-arhullam/" title="Érdemes résen lenni, újabb dunai árhullámra figyelmeztettek">
# <img alt="Érdemes résen lenni, újabb dunai árhullámra figyelmeztettek" loading="lazy" src="https://kep.index.hu/1/0/5660/56607/566075/56607549_4185525_10a6d47b8c1208c7ca523199ff1f7191_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/orszagos-vizugyi-foigazgatosag-arvizvedelem-dunai-arhullam/" title="Érdemes résen lenni, újabb dunai árhullámra figyelmeztettek">
#        Érdemes résen lenni, újabb dunai árhullámra figyelmeztettek
#       </a>
# </h2>
# <div class="ajanlo">
#       Akár a harmadfokot megközelítően tetőzhet majd a folyó.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717241640">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/del-afrikai-koztarsasag-parlamenti-valasztasok-koalicios-kormanyzas-nelson-mandela-apartheid-2024/" title="Elvesztette többségét az apartheid rendszert megdöntő párt a Dél-afrikai Köztársaságban">
# <img alt="Elvesztette többségét az apartheid rendszert megdöntő párt a Dél-afrikai Köztársaságban" loading="lazy" src="https://kep.index.hu/1/0/5660/56608/566081/56608181_4185567_37cdff7cd9e82b3bf52cbbaf387288a1_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/del-afrikai-koztarsasag-parlamenti-valasztasok-koalicios-kormanyzas-nelson-mandela-apartheid-2024/" title="Elvesztette többségét az apartheid rendszert megdöntő párt a Dél-afrikai Köztársaságban">
#        Elvesztette többségét az apartheid rendszert megdöntő párt a Dél-afrikai Köztársaságban
#       </a>
# </h2>
# <div class="ajanlo">
#       Rosszul szerepelt az ANC.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717241460">
#         4 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/tech/godmode/2024/06/01/mad-max-videojatek-retrospektiv-george-miller-nyilatkozat-playstation-xbox-pc-film-mozi-adaptacio-ajanlo/" title="Igazi rejtett kincs ez a posztapokaliptikus játék">
# <img alt="Igazi rejtett kincs ez a posztapokaliptikus játék" loading="lazy" src="https://kep.index.hu/1/0/5660/56600/566000/56600089_4184951_e4d77b0d6991e0c614e71df5682177a3_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/tech/godmode/2024/06/01/mad-max-videojatek-retrospektiv-george-miller-nyilatkozat-playstation-xbox-pc-film-mozi-adaptacio-ajanlo/" title="Igazi rejtett kincs ez a posztapokaliptikus játék">
#        Igazi rejtett kincs ez a posztapokaliptikus játék
#       </a>
# </h2>
# <div class="ajanlo">
#       Őrült hajszákból és kemény verekedésekből sincs hiány benne.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717240260">
#         5 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/mcdonald-s-gyorsetterem-szoboszlai-dominik-menu/" title="Nincs több titok, megvan a McDonald’s Szoboszlai-menüje">
# <img alt="Nincs több titok, megvan a McDonald’s Szoboszlai-menüje" loading="lazy" src="https://kep.index.hu/1/0/5660/56607/566075/56607525_4185523_dabfad222eebb0b031413d3caf567afd_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/mcdonald-s-gyorsetterem-szoboszlai-dominik-menu/" title="Nincs több titok, megvan a McDonald’s Szoboszlai-menüje">
#        Nincs több titok, megvan a McDonald’s Szoboszlai-menüje
#       </a>
# </h2>
# <div class="ajanlo">
#       Június 4-től lesz kapható az étteremlánc magyarországi kínálatában.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717240080">
#         5 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/bencze-ilona-gorogorszag-szinesz-csalad/" title="Bencze Ilona beleszeretett Görögországba, de nem a tengerpart miatt">
# <img alt="Bencze Ilona beleszeretett Görögországba, de nem a tengerpart miatt" loading="lazy" src="https://kep.index.hu/1/0/5660/56607/566073/56607317_4185507_d10843e0111c52ea9fb350a3da02c4f0_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/bencze-ilona-gorogorszag-szinesz-csalad/" title="Bencze Ilona beleszeretett Görögországba, de nem a tengerpart miatt">
#        Bencze Ilona beleszeretett Görögországba, de nem a tengerpart miatt
#       </a>
# </h2>
# <div class="ajanlo">
#       Egy magazinműsor vendége volt a Jászai Mari-díjas színésznő.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717238640">
#         5 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/orban-viktor-urhajos-program-video-beszelgetes-kapu-tibor/" title="Orbán Viktor az új magyar űrhajósoknak beszélt gyerekkori álmáról">
# <img alt="Orbán Viktor az új magyar űrhajósoknak beszélt gyerekkori álmáról" loading="lazy" src="https://kep.index.hu/1/0/5660/56606/566066/56606653_4185461_09d170347f1adc0ca71062f145fddf35_wm.png"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/orban-viktor-urhajos-program-video-beszelgetes-kapu-tibor/" title="Orbán Viktor az új magyar űrhajósoknak beszélt gyerekkori álmáról">
#        Orbán Viktor az új magyar űrhajósoknak beszélt gyerekkori álmáról
#       </a>
# </h2>
# <div class="ajanlo">
#       Kapu Tiborral és társával találkozott a miniszterelnök.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717238460">
#         5 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/hajduszoboszlo-emberoles-gyilkossag-rendorseg/" title="Emberölés gyanúja miatt őrizetbe vettek egy hajdúszoboszlói férfit">
# <img alt="Emberölés gyanúja miatt őrizetbe vettek egy hajdúszoboszlói férfit" loading="lazy" src="https://kep.index.hu/1/0/5481/54810/548104/54810425_4050413_d7a502d7f380835dd614332dbed3c6bf_wm.png"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/hajduszoboszlo-emberoles-gyilkossag-rendorseg/" title="Emberölés gyanúja miatt őrizetbe vettek egy hajdúszoboszlói férfit">
#        Emberölés gyanúja miatt őrizetbe vettek egy hajdúszoboszlói férfit
#       </a>
# </h2>
# <div class="ajanlo">
#       Áldozata a helyszínen életét vesztette.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717237980">
#         5 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/techtud/2024/06/01/google-hirdetes-kereses-kiemelt-organikus-valtozas/" title="Aggasztó újítást vezetett be a Google">
# <img alt="Aggasztó újítást vezetett be a Google" loading="lazy" src="https://kep.index.hu/1/0/5660/56605/566055/56605541_4185381_73615079a1dbb5b47a3f5c929e35e044_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/techtud/2024/06/01/google-hirdetes-kereses-kiemelt-organikus-valtozas/" title="Aggasztó újítást vezetett be a Google">
#        Aggasztó újítást vezetett be a Google
#       </a>
# </h2>
# <div class="ajanlo">
#       Már keresni sem hagyják békésen az embert?
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717237680">
#         5 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/fedel-nelkul-ev-alkotasa-dijatado-muveszet/" title="Most mindenki az otthontalanság és a mélyszegénység problémájára figyelt">
# <img alt="Most mindenki az otthontalanság és a mélyszegénység problémájára figyelt" loading="lazy" src="https://kep.index.hu/1/0/5660/56602/566027/56602763_4185137_71a7c84c9c4788f5528142af7e8a5511_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/fedel-nelkul-ev-alkotasa-dijatado-muveszet/" title="Most mindenki az otthontalanság és a mélyszegénység problémájára figyelt">
#        Most mindenki az otthontalanság és a mélyszegénység problémájára figyelt
#       </a>
# </h2>
# <div class="ajanlo">
#       A művészet segítségével.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717237500">
#         5 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/idojaras-vihar-tuzoltok-katasztrofavedelem/" title="Viharos időjárás tombol az országban, több mint kétszáz helyszínen volt szükség a tűzoltókra">
# <img alt="Viharos időjárás tombol az országban, több mint kétszáz helyszínen volt szükség a tűzoltókra" loading="lazy" src="https://kep.index.hu/1/0/5481/54810/548102/54810223_4050395_c047b7cb34d85136f6854079d980714b_wm.png"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/idojaras-vihar-tuzoltok-katasztrofavedelem/" title="Viharos időjárás tombol az országban, több mint kétszáz helyszínen volt szükség a tűzoltókra">
#        Viharos időjárás tombol az országban, több mint kétszáz helyszínen volt szükség a tűzoltókra
#       </a>
# </h2>
# <div class="ajanlo">
#       Épületek tetőszerkezetét és kéményét is megrongálta a vihar.
#      </div>
# </article>, <article class="rovatajanlo normal right">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717236902">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/radics-gigi-elarulta-az-okat-annak-miert-nem-mutatja-meg-a-kislanyat/" title="Radics Gigi elárulta a valódi okát annak, miért nem mutatja meg a kislányát">
#        Radics Gigi elárulta a valódi okát annak, miért nem mutatja meg a kislányát
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717236000">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/01/vitezy-david-fopolgarmester-jelolt-budapest-langos-fogadalom-lmp/" title="Hatalmas vállalást tesz Vitézy Dávid a megválasztása esetén">
# ...
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717233960">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/zene/2024/06/01/stenk-zene-pop-hungaria-ifipark-rock-and-roll-fenyo-csak-egy-lepes/" title="Csak egy lépésre volt a Hungária a nagy áttöréstől">
# <img alt="Csak egy lépésre volt a Hungária a nagy áttöréstől" loading="lazy" src="https://kep.index.hu/1/0/5658/56582/565822/56582201_4183637_6e924ca2e58535e48ab36d3ad40ed2dd_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/zene/2024/06/01/stenk-zene-pop-hungaria-ifipark-rock-and-roll-fenyo-csak-egy-lepes/" title="Csak egy lépésre volt a Hungária a nagy áttöréstől">
#        Csak egy lépésre volt a Hungária a nagy áttöréstől
#       </a>
# </h2>
# <div class="ajanlo">
#       Egy elveszett dal zavarhatja fel a zenei állóvizet.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717233960">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/szikora-robert-r-go-haboru/" title="Szikora Róbert: A háború a Sátán akarata">
# <img alt="Szikora Róbert: A háború a Sátán akarata" loading="lazy" src="https://kep.index.hu/1/0/5063/50639/506398/50639875_3860705_13aa4468fc4386a26b01bdec8c93802f_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/szikora-robert-r-go-haboru/" title="Szikora Róbert: A háború a Sátán akarata">
#        Szikora Róbert: A háború a Sátán akarata
#       </a>
# </h2>
# <div class="ajanlo">
#       Az énekes elsőként azokat küldené a frontra, „akik kitalálják, hogy legyen háború”.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717233780">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/fomo/2024/06/01/asunta-basterra-netflix-dokumentum-sorozat-betores-spanyolorszag-szulok-gyerek-orokbefogadas/" title="Ismét megnyithatja kapuit a horrorház, ahol a szülők végeztek a saját lányukkal">
# <img alt="Ismét megnyithatja kapuit a horrorház, ahol a szülők végeztek a saját lányukkal" loading="lazy" src="https://kep.index.hu/1/0/5657/56579/565795/56579575_4183457_ace2866fc4328c2e92e14de300f0c50e_wm.png"/>
# </a>
# <a class="cim" href="https://index.hu/fomo/2024/06/01/asunta-basterra-netflix-dokumentum-sorozat-betores-spanyolorszag-szulok-gyerek-orokbefogadas/" title="Ismét megnyithatja kapuit a horrorház, ahol a szülők végeztek a saját lányukkal">
#        Ismét megnyithatja kapuit a horrorház, ahol a szülők végeztek a saját lányukkal
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717233600">
#         6 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/kozlekedes-baleset-m5-autopalya-lajosmizse-utkozes-karambol/" title="Két baleset is történt egymás után az M5-ös autópályán">
# <img alt="Két baleset is történt egymás után az M5-ös autópályán" loading="lazy" src="https://kep.index.hu/1/0/5481/54810/548102/54810223_4050395_c047b7cb34d85136f6854079d980714b_wm.png"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/06/01/kozlekedes-baleset-m5-autopalya-lajosmizse-utkozes-karambol/" title="Két baleset is történt egymás után az M5-ös autópályán">
#        Két baleset is történt egymás után az M5-ös autópályán
#       </a>
# </h2>
# <div class="ajanlo">
#       Több gépjármű ütközött.
#      </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/belfold/2024/06/01/egeszsegugyi-ellatas-europai-adatter-kutatas-magyar-eu-elnokseg/" title="Az egészségügyi adatok kulcsszerepet játszhatnak a magyar EU-elnökség során">
# <img alt="Az egészségügyi adatok kulcsszerepet játszhatnak a magyar EU-elnökség során" loading="lazy" src="https://kep.index.hu/1/0/5659/56599/565994/56599449_4184907_5d87b805a916c70028b4474f948eee59_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/egeszsegugyi-ellatas-europai-adatter-kutatas-magyar-eu-elnokseg/" title="Az egészségügyi adatok kulcsszerepet játszhatnak a magyar EU-elnökség során">
#         Az egészségügyi adatok kulcsszerepet játszhatnak a magyar EU-elnökség során
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/ernofy_nora">
# <img alt="- en -" class="szerzo-kep" src="https://kep.index.hu/1/0/4397/43975/439755/43975502_3355474_f52461df7d56524f6ef9c4dad7d10a31_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/ernofy_nora" rel="author">
#             - en -
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1398">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.01. 11:17
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-01 14:53:04
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Egyelőre még sok a bizonytalanság az uniós adattér-megvalósítást és felhasználást illetően.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717232940">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/sport/alapvonal/2024/06/01/sport-essca-olimpia-parizs-2024-konferencia/" title="A sport felgyorsítja a felső vezetők karrierívét">
# <img alt="A sport felgyorsítja a felső vezetők karrierívét" loading="lazy" src="https://kep.index.hu/1/0/5637/56377/563776/56377637_4168571_f2d163539cf199d989216c1d7f5272af_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/sport/alapvonal/2024/06/01/sport-essca-olimpia-parizs-2024-konferencia/" title="A sport felgyorsítja a felső vezetők karrierívét">
#        A sport felgyorsítja a felső vezetők karrierívét
#       </a>
# </h2>
# <div class="ajanlo">
#       Víziót, álmokat, bátorságot, vakmerőséget és stratégiai gondolkodásmódot ad.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717232880">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/tompos-katya-gyasz-halal-basti-juli-szinhaz/" title="Básti Juli Tompos Kátyáról: Igazi angyalka volt, akit mindenki szeretett">
# <img alt="Básti Juli Tompos Kátyáról: Igazi angyalka volt, akit mindenki szeretett" loading="lazy" src="https://kep.index.hu/1/0/5660/56604/566045/56604563_4185297_09fb053255ee5baf361b61434739616a_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/tompos-katya-gyasz-halal-basti-juli-szinhaz/" title="Básti Juli Tompos Kátyáról: Igazi angyalka volt, akit mindenki szeretett">
#        Básti Juli Tompos Kátyáról: Igazi angyalka volt, akit mindenki szeretett
#       </a>
# </h2>
# <div class="ajanlo">
#       Kollégája szerint elementáris ereje volt a nemrég meghalt színésznőnek.
#      </div>
# </article>, <article class="rovatajanlo normal right">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717232408">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/valovilag12-bekoltozo-show-villalako-/" title="ValóVilág 12: újabb három villalakó-jelölt mutatkozott be, akik felkavarnák az állóvizet Valenéknél">
#        ValóVilág 12: újabb három villalakó-jelölt mutatkozott be, akik felkavarnák az állóvizet Valenéknél
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717231020">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/2024/06/01/egyesult-kiralysag-mexiko-nagykovet-fegyver/" title="Elbocsátották a mexikói brit nagykövetet, miután fegyvert szegezett a követség alkalmazottjára">
# <img alt="Elbocsátották a mexikói brit nagykövetet, miután fegyvert szegezett a követség alkalmazottjára" loading="lazy" src="https://kep.index.hu/1/0/5660/56604/566048/56604891_4185321_75a94ff357ab17fc073ff7e7e742b655_wm.png"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/2024/06/01/egyesult-kiralysag-mexiko-nagykovet-fegyver/" title="Elbocsátották a mexikói brit nagykövetet, miután fegyvert szegezett a követség alkalmazottjára">
#        Elbocsátották a mexikói brit nagykövetet, miután fegyvert szegezett a követség alkalmazottjára
#       </a>
# </h2>
# <div class="ajanlo">
#       A fegyver feltehetően a diplomatát kísérő biztonságiaké volt.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717230000">
#         7 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kultur/2024/06/01/iland-videoklip-kek-gyemant-zene-videoklip/" title="Különleges gyémántra bukkantunk a Műcsarnok kiállításán">
# <img alt="Különleges gyémántra bukkantunk a Műcsarnok kiállításán" loading="lazy" src="https://kep.index.hu/1/0/5660/56604/566043/56604377_4185283_0eb44c1aaa80777d7e3d40c8532545b3_wm.png"/>
# </a>
# <a class="cim" href="https://index.hu/kultur/2024/06/01/iland-videoklip-kek-gyemant-zene-videoklip/" title="Különleges gyémántra bukkantunk a Műcsarnok kiállításán">
#        Különleges gyémántra bukkantunk a Műcsarnok kiállításán
#       </a>
# </h2>
# <div class="ajanlo">
#       Dalban mondták el.
#      </div>
# </article>, <article class="rovatajanlo normal left keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717228980">
#         8 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/01/nagy-attila-tibor-politikai-elemzo-karacsony-gergely-vitezy-david-szentkiralyi-alexandra-vita-velemeny/" title="Vitézy Dávid sziporkázott, Szentkirályi Alexandra jobban járt a távolmaradással">
# <img alt="Vitézy Dávid sziporkázott, Szentkirályi Alexandra jobban járt a távolmaradással" loading="lazy" src="https://kep.index.hu/1/0/5660/56603/566039/56603919_4185247_33c16e5b78fa41ee1914d4be70659fee_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/01/nagy-attila-tibor-politikai-elemzo-karacsony-gergely-vitezy-david-szentkiralyi-alexandra-vita-velemeny/" title="Vitézy Dávid sziporkázott, Szentkirályi Alexandra jobban járt a távolmaradással">
#        Vitézy Dávid sziporkázott, Szentkirályi Alexandra jobban járt a távolmaradással
#       </a>
# </h2>
# <div class="ajanlo">
#       Nagy Attila Tibor politikai elemző értékelte az Indexnek a péntek esti vitát.
#      </div>
# </article>, <article class="rovatajanlo normal right keppel">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717227600">
#         8 órája
#        </span>
# <span class="separator">
# </span>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a href="https://index.hu/kulfold/usa/feher_haz/2024/06/01/joe-biden-donald-trump-itelet-per/" title="Joe Biden Donald Trump elítéléséről: Senki nem áll törvények felett">
# <img alt="Joe Biden Donald Trump elítéléséről: Senki nem áll törvények felett" loading="lazy" src="https://kep.index.hu/1/0/5660/56603/566038/56603839_4185241_fad17a7cc6863714a85f5b954753a914_wm.jpg"/>
# </a>
# <a class="cim" href="https://index.hu/kulfold/usa/feher_haz/2024/06/01/joe-biden-donald-trump-itelet-per/" title="Joe Biden Donald Trump elítéléséről: Senki nem áll törvények felett">
#        Joe Biden Donald Trump elítéléséről: Senki nem áll törvények felett
#       </a>
# </h2>
# <div class="ajanlo">
#       Szerinte az esküdtek körültekintő döntést hoztak.
#      </div>
# </article>, <article class="rovatajanlo normal left">
# <header class="rovat-cikk-head">
# <h3>
# <span class="separator-box">
# </span>
# <span class="cikk-date-label" data-date="2024-06-01" data-datestamp="1717227000">
#         8 órája
#        </span>
# <span class="separator">
# </span>
# <ul class="cikk-cimkek">
# <li>
# <a class="cimke cimke-mufaj" href="http://index.hu/mindekozben">
#           Mindeközben
#          </a>
# </li>
# </ul>
# </h3>
# <div class="clearfix">
# </div>
# </header>
# <h2>
# <a class="cim" href="https://index.hu/mindekozben/poszt/2024/06/01/cooky-szecsi-debora-instagram-vs-valosag-video/" title="A fél internet Cooky Instagram vs. valóság videóján nevet, a párját, Szécsi Debórát figurázta ki">
#        A fél internet Cooky Instagram vs. valóság videóján nevet, a párját, Szécsi Debórát figurázta ki
#       </a>
# </h2>
# <div class="ajanlo">
# </div>
# </article>, <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/fomo/2024/06/01/daniel-stern-reszkessetek-betorok-konyv/" title="Kis híján meghalt a Reszkessetek, betörők! ikonikus színésze">
# <img alt="Kis híján meghalt a Reszkessetek, betörők! ikonikus színésze" loading="lazy" src="https://kep.index.hu/1/0/5659/56595/565954/56595451_4184599_b0b082b5877e22c1dd3c41eb3b9ff825_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/fomo/2024/06/01/daniel-stern-reszkessetek-betorok-konyv/" title="Kis híján meghalt a Reszkessetek, betörők! ikonikus színésze">
#         Kis híján meghalt a Reszkessetek, betörők! ikonikus színésze
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/harnisch_kitti">
# <img alt="Harnisch Kitti" class="szerzo-kep" src="https://kep.index.hu/1/0/4152/41525/415253/41525355_3169809_6bc9f849e6e4839cc9b4639882de03c1_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/harnisch_kitti" rel="author">
#             Harnisch Kitti
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1353">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.01. 09:27
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-01 14:14:17
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       Daniel Stern egy forgatás során került kalamajkába.
#      </div>
# </article>]

# %%
print(articles[0])
# Out:
# <article class="rovatajanlo vezeto keppel">
# <div class="article-container">
# <a href="https://index.hu/belfold/2024/06/01/orban-viktor-beszed-bekemenet-valasztasok-haboru/" title="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje">
# <img alt="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje" loading="lazy" src="https://kep.index.hu/1/0/5660/56609/566098/56609867_4185723_e6b8b4d0d0ff561d1f7cbd755727a428_wm.jpg"/>
# </a>
# <h2>
# <a href="https://index.hu/belfold/2024/06/01/orban-viktor-beszed-bekemenet-valasztasok-haboru/" title="Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje">
#         Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje
#        </a>
# </h2>
# </div>
# <div class="author-share-date-container">
# <div class="author-share-date">
# <div class="bal-hasab">
# <div class="szerzok_container">
# <div class="szerzo">
# <a href="https://index.hu/szerzo/peter_alvarez">
# <img alt="Péter Alvarez" class="szerzo-kep" src="https://kep.index.hu/1/0/4903/49034/490344/49034444_3737960_b998b0087613d5288b147749af5e46d1_wm.jpg"/>
# </a>
# <div class="kovetes">
# <a href="https://index.hu/szerzo/peter_alvarez" rel="author">
#             Péter Alvarez
#            </a>
# <span class="btn-pass" data-feed-id="feed://manis/cikkszerzo/1532">
# </span>
# </div>
# </div>
# </div>
# <div class="datum">
#          2024.06.01. 16:52
#          <span class="modositas-datuma-gomb" title="Módosítás dátuma">
#           Módosítva: 2024-06-01 17:11:13
#          </span>
# </div>
# </div>
# <div class="jobb-hasab">
# </div>
# </div>
# </div>
# <div class="ajanlo">
#       A miniszterelnök beszédével ért véget a Békemenet.
#      </div>
# <div class="iap iap--ado roadblock" data-id="adoceanindexhundcjqssfzl" id="adoceanindexhundcjqssfzl">
# <script class="iap-script">
#        window.iap_zones = window.iap_zones || [];
#                                                             window.iap_zones.push({"id":"adoceanindexhundcjqssfzl","empty":true,"lazy":false,"quality":false,"masterless":false,"area":"Index_Aloldal_RB_A","events":{"loaded":false,"visible":false,"viewed":false},"stat":{"site":"index","path":"24ora/","type":"rovat"}});
#       </script>
# </div>
# </article>

# %% [markdown]
# ## Egy darab cikk adatainak kinyerése

# %%
author = articles[0].find("div", class_="szerzo").text.strip()
date = articles[0].find("div", class_="datum")
published = date.contents[0].strip()
title = articles[0].find("a").get("title")
subtitle = articles[0].find("div", class_="ajanlo").text.strip()
url = articles[0].find("a").get("href")

print("Szerző: " + author)
print("Dátum: " + published)
print("Cím: " + title)
print("Alcím: " + subtitle)
print("url: " + url)
# Out:
# Szerző: Péter Alvarez
# Dátum: 2024.06.01. 16:52
# Cím: Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje
# Alcím: A miniszterelnök beszédével ért véget a Békemenet.
# url: https://index.hu/belfold/2024/06/01/orban-viktor-beszed-bekemenet-valasztasok-haboru/

# %% [markdown]
# ## Összes cikk kinyerése a főoldalról

# %%
content = []

for article in articles:
    url = article.find("a").get("href")
    if url == "http://index.hu/mindekozben":
        continue

    if article.find("div", class_="szerzo") == None:
        author = ""
    else:
        author = article.find("div", class_="szerzo").text.strip()

    if article.find("div", class_="datum") == None:
        published = ""
    else:
        date = article.find("div", class_="datum")
        published = date.contents[0].strip()

    if article.find("a").get("title") == None:
        title = ""
    else:
        title = article.find("a").get("title")

    subtitle = article.find("div", class_="ajanlo").text.strip()

    content.append((author, published, title, subtitle, url))

for item in content:
    print(item)
# Out:
# ('Péter Alvarez', '2024.06.01. 16:52', 'Orbán Viktor: A világháborúk mögött a gonosz áll, eljött az ördögűzés ideje', 'A miniszterelnök beszédével ért véget a Békemenet.', 'https://index.hu/belfold/2024/06/01/orban-viktor-beszed-bekemenet-valasztasok-haboru/')
# ('', '', 'Magyar Péter a Békemenet után tett bejelentést', '', 'https://index.hu/belfold/2024/06/01/magyar-peter-tisza-part-peticio-kampany-haboru-orban-viktor-deutsch-tamas-bekemenet/')
# ('', '', 'Havazott az olasz Alpokban a nyár előestéjén', 'A nem mindennapi időjárási jelenségről több videót is készítettek a helyiek.', 'https://index.hu/kulfold/2024/06/01/olaszorszag-havazas-alpok-nyar-livigno-sondrio-megye/')
# ('', '', 'Settenkedő járművek veszélyeztetik a gyalogosokat, de van megoldás', 'Rászokunk a fülelésre.', 'https://index.hu/tudomany/2024/06/01/elektromos-auto-hibrid-baleset-zaj-kornyezet-kimelo/')
# ('', '', 'Több százezer dolláros korrupcióval vádolják az amerikai haditengerészet egyik volt admirálisát', 'Átszámítva 180 millió forintos éves fizetéssel sikerült lekenyerezni.', 'https://index.hu/kulfold/2024/06/01/amerikai-egyesult-allamok-korrupcio-botrany-vesztegetes-robert-burke-haditengereszet-admiralis/')
# ('', '', 'Rozsdátlanításra készült az olimpiai bajnok, a világ idei legjobb eredménye lett belőle', 'Az amerikai világcsúcstartó legutóbb 2022 augusztusában állt rajthoz ebben a számban.', 'https://index.hu/sport/atletika/2024/06/01/atletika-olimpiai-bajnok-atlanta-gatfutas-sydney-mclaughlin-levrone-edwin-moses-classic/')
# ('', '', 'Ezekről az élményekről beszélt Tompos Kátya az utolsó interjújában', 'Több mint egy éve készült a műsor.', 'https://index.hu/kultur/2024/06/01/tompos-katya-szineszno-halala-utolso-interju/')
# ('', '', 'Brit szakértő: az európai csapatok kénytelenek lesznek Ukrajnába menni', '„Amit eddig tettek, az nem volt elég hatással Oroszországra” – mondta.', 'https://index.hu/kulfold/2024/06/01/haboru-oroszorszag-ukrajna-europai-csapatok-ukrajnaban-glen-grant-brit-ezredes/')
# ('', '', 'Nem kímélték Magyar Pétert, minden kikerült az asztalra', 'Gulyás Márton szerint hajlamos a nagyotmondásra a Tisza Párt alelnöke.', 'https://index.hu/belfold/2024/06/01/magyar-peter-partizan-gulyas-marton-tisza-program/')
# ('Kocsmár-Tóth István', '2024.06.01. 16:35', 'Megvan a tizedik: drámai végjáték után Bajnokok Ligája-döntős a Győri ETO!', 'Az utolsó másodpercben még volt egy labdája a hosszabbításért, de nem tudott élni vele az Esbjerg.', 'https://index.hu/sport/kezilabda/2024/06/01/esbjerg-gyori-eto/')
# ('', '', 'Ungár Péter: Ez egy BDSM-kapcsolat, a kormány a szadista, a főváros a mazochista', 'Interjú az LMP társelnökével.', 'https://index.hu/belfold/2024/06/01/ungar-peter-lmp-interju-ellenzek-fidesz-budapest-karacsony-gergely-vitezy-david-ep-valasztas-onkormanyzati-valasztas/')
# ('', '', 'Nem várt helyről méltatták Krasznahorkai Lászlót', 'Népszerű pályatársa szólalt meg.', 'https://index.hu/kultur/2024/06/01/vamos-miklos-krasznahorkai-laszlo-zsomle-odavan/')
# ('', '', 'Nemzetközi jogi problémát jelent a holdra szállás közben felvert por', 'A rakéták által szétfújt anyag komoly veszélyt jelent a közelben található technikára.', 'https://index.hu/techtud/2024/06/01/hold-por-raketa-robbanas-homokfuvas-technikai-karosodas-veszely-tortenelem-nemzetkozi-jog/')
# ('', '', 'Vonatpótló buszt pótló buszt indított a MÁV', 'De mi történik, ha ez is lerobban?', 'https://index.hu/belfold/2024/06/01/vonatpotlo-busz-mav-medgyesegyhaza-mezohegyes-bekescsaba-keses/')
# ('', '', 'Szeretetcunamival várták a német szurkolók Eb-házigazda csoportellenfelünket', 'Bázist váltottak a németek, öten még hiányoznak.', 'https://index.hu/sport/futball/2024/eb/2024/06/01/eb-2024-adidas-bajnokok-ligaja-nemet-magyar-valogatott/')
# ('', '', 'Év Magyar Autója 2025: már lehet nevezni a versenyre', 'Már megérkeztek az első fecskék.', 'https://index.hu/gazdasag/2024/06/01/auto-verseny-ev-magyar-autoja-2025-autos-nagykoalicio/')
# ('', '', 'Miért tiltották be a dél-koreai buddhista DJ fellépését Szingapúrban?', 'Maga a belügyminiszter akadályozta meg a DJ szettjét.', 'https://index.hu/kulfold/2024/06/01/buddhista-szerzetes-szingapur-del-korea-betiltas-dj-fellepes/')
# ('', '', 'Kiderült, hogy alakult Rákay Philip számára a tavalyi év', 'Megjelent a beszámoló.', 'https://index.hu/gazdasag/2024/06/01/rakay-philip-norton-consulting-arbevetel-profit-csokkenes-megafon/')
# ('', '', 'Vitray Tamás: Ma már következmények nélkül lehet sértegetni', 'A legendás televíziós szerint nincs ez így rendjén.', 'https://index.hu/kultur/2024/06/01/vitray-tamas-musrovezeto-riporter-televiziozas-media-sertegetes/')
# ('', '', 'The Washington Post: Naponta jelennek meg új repedések Ukrajna és Amerika kapcsolatában', 'Amerika a korrupció elleni harcot kéri számon Ukrajnától.', 'https://index.hu/kulfold/2024/06/01/ukrajna-nyugat-egyesult-allamok-orosz-ukran-haboru-feszultseg-tamogatas/')
# ('', '', 'Kajakozó fulladt az Isonzóba Szlovéniában', 'A férfi öt társával szállt vízre.', 'https://index.hu/kulfold/2024/06/01/szlovenia-kajakozo-isonzo-folyo-vizbefulladt/')
# ('', '', 'A Győri Audi ETO KC a 10. BL-döntőjét játszhatja vasárnap', 'A Győri Audi ETO KC a 10. BL-döntőjét játszhatja vasárnap', 'https://index.hu/sport/kezilabda/2024/06/01/noi-kezlabda-bajnokok-ligaja-2023-2024-gyor-esbjerg-elodonto-percrol-percre/')
# ('', '', 'Sosem találná ki, milyen kinevezésben részesült Karikó Katalin', 'Újabb elismeréssel díjazták a munkásságát.', 'https://index.hu/kultur/2024/06/01/kariko-katalin-professzori-kinevezes-szegedi-tudomanyegyetem/')
# ('', '', 'Kóbor János nem zenész volt, mégis bekerült a bandába', 'Ötödik kerék volt.', 'https://index.hu/kultur/2024/06/01/der-andras-film-testamentum-biblia-omega-kobor-janos-enekes-zene-klip-muveszet-kultura-rock/')
# ('Klicasz Szpirosz Szotirisz', '2024.06.01. 14:12', 'Derült égből villámcsapásként érkeznek a trónkövetelők, csak győzzék velük tartani a lépést', 'Szoboszlai karrierútját bejáró támadó? Vagy a tucatnevű portugál lesz a legnagyobb sztár?', 'https://index.hu/sport/futball/2024/eb/2024/06/01/europa-bajnoksag-2024-fiatal-sztarok-elso-europa-bajnoksag-giorgio-scalvini-jude-bellingham-florian-wirtz-benjamin-sesko/')
# ('', '', 'Cselekedni kell a magyarok egészsége érdekében', 'Számos fontos egészségügyi mutató alapján Magyarország le van maradva az uniós átlagtól.', 'https://index.hu/gazdasag/2024/06/01/egeszsegugy-varhato-elettartam-gyogyszer-gyogyszeripar-aipm-europa-egeszseg-gyogyszergyartok-innovativ-gyogyszergyartok/')
# ('Index', '2024.06.01. 13:59', 'Erőt demonstrál a Fidesz a választások előtt', 'Élő, többórás műsorfolyamban számolunk be az eseményről.', 'https://index.hu/belfold/2024/06/01/fidesz-bekemenet-erodemonstracio-orban-viktor-ep-valasztas/')
# ('', '', 'Elhalasztják Mike Tyson és Jake Paul bokszmeccsét', 'Mindkét fél jobbnak látja így.', 'https://index.hu/fomo/2024/06/01/mike-tyson-jake-paul-boksz-halasztas-egeszsegugyi-problema-netflix/')
# ('', '', 'Érdemes résen lenni, újabb dunai árhullámra figyelmeztettek', 'Akár a harmadfokot megközelítően tetőzhet majd a folyó.', 'https://index.hu/belfold/2024/06/01/orszagos-vizugyi-foigazgatosag-arvizvedelem-dunai-arhullam/')
# ('', '', 'Elvesztette többségét az apartheid rendszert megdöntő párt a Dél-afrikai Köztársaságban', 'Rosszul szerepelt az ANC.', 'https://index.hu/kulfold/2024/06/01/del-afrikai-koztarsasag-parlamenti-valasztasok-koalicios-kormanyzas-nelson-mandela-apartheid-2024/')
# ('', '', 'Igazi rejtett kincs ez a posztapokaliptikus játék', 'Őrült hajszákból és kemény verekedésekből sincs hiány benne.', 'https://index.hu/tech/godmode/2024/06/01/mad-max-videojatek-retrospektiv-george-miller-nyilatkozat-playstation-xbox-pc-film-mozi-adaptacio-ajanlo/')
# ('', '', 'Nincs több titok, megvan a McDonald’s Szoboszlai-menüje', 'Június 4-től lesz kapható az étteremlánc magyarországi kínálatában.', 'https://index.hu/belfold/2024/06/01/mcdonald-s-gyorsetterem-szoboszlai-dominik-menu/')
# ('', '', 'Bencze Ilona beleszeretett Görögországba, de nem a tengerpart miatt', 'Egy magazinműsor vendége volt a Jászai Mari-díjas színésznő.', 'https://index.hu/kultur/2024/06/01/bencze-ilona-gorogorszag-szinesz-csalad/')
# ('', '', 'Orbán Viktor az új magyar űrhajósoknak beszélt gyerekkori álmáról', 'Kapu Tiborral és társával találkozott a miniszterelnök.', 'https://index.hu/belfold/2024/06/01/orban-viktor-urhajos-program-video-beszelgetes-kapu-tibor/')
# ('', '', 'Emberölés gyanúja miatt őrizetbe vettek egy hajdúszoboszlói férfit', 'Áldozata a helyszínen életét vesztette.', 'https://index.hu/belfold/2024/06/01/hajduszoboszlo-emberoles-gyilkossag-rendorseg/')
# ('', '', 'Aggasztó újítást vezetett be a Google', 'Már keresni sem hagyják békésen az embert?', 'https://index.hu/techtud/2024/06/01/google-hirdetes-kereses-kiemelt-organikus-valtozas/')
# ('', '', 'Most mindenki az otthontalanság és a mélyszegénység problémájára figyelt', 'A művészet segítségével.', 'https://index.hu/kultur/2024/06/01/fedel-nelkul-ev-alkotasa-dijatado-muveszet/')
# ('', '', 'Viharos időjárás tombol az országban, több mint kétszáz helyszínen volt szükség a tűzoltókra', 'Épületek tetőszerkezetét és kéményét is megrongálta a vihar.', 'https://index.hu/belfold/2024/06/01/idojaras-vihar-tuzoltok-katasztrofavedelem/')
# ('', '', 'Hatalmas vállalást tesz Vitézy Dávid a megválasztása esetén', 'Mindez egy fotóból derült ki.', 'https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/01/vitezy-david-fopolgarmester-jelolt-budapest-langos-fogadalom-lmp/')
# ('', '', 'Orbán Viktor: Naponta jelentik be a pokolba vezető út újabb szakaszának átadását', 'A kormányfő beszédet mondott a Békemenet végállomásán.', 'https://index.hu/belfold/2024/06/01/bekemenet-fidesz-kormany-cof-rendezveny-orban-viktor/')
# ('', '', 'Milák Kristóf biztatóan mozgott, második idővel döntős Monacóban királyszámában', 'Délután bizonyíthat 200 pillangón.', 'https://index.hu/sport/uszas/2024/06/01/uszas-milak-kristof-mare-nostrum-monaco/')
# ('', '', 'Sosem zárt annyira veszteséges évet zárt a jegybank, mint tavaly', 'A pénzintézet zsinórban harmadik évben volt veszteséges.', 'https://index.hu/gazdasag/2024/06/01/mnb-veszteseg-jegybank-toke-2023/')
# ('', '', 'Csak egy lépésre volt a Hungária a nagy áttöréstől', 'Egy elveszett dal zavarhatja fel a zenei állóvizet.', 'https://index.hu/kultur/zene/2024/06/01/stenk-zene-pop-hungaria-ifipark-rock-and-roll-fenyo-csak-egy-lepes/')
# ('', '', 'Szikora Róbert: A háború a Sátán akarata', 'Az énekes elsőként azokat küldené a frontra, „akik kitalálják, hogy legyen háború”.', 'https://index.hu/belfold/2024/06/01/szikora-robert-r-go-haboru/')
# ('', '', 'Ismét megnyithatja kapuit a horrorház, ahol a szülők végeztek a saját lányukkal', '', 'https://index.hu/fomo/2024/06/01/asunta-basterra-netflix-dokumentum-sorozat-betores-spanyolorszag-szulok-gyerek-orokbefogadas/')
# ('', '', 'Két baleset is történt egymás után az M5-ös autópályán', 'Több gépjármű ütközött.', 'https://index.hu/belfold/2024/06/01/kozlekedes-baleset-m5-autopalya-lajosmizse-utkozes-karambol/')
# ('- en -', '2024.06.01. 11:17', 'Az egészségügyi adatok kulcsszerepet játszhatnak a magyar EU-elnökség során', 'Egyelőre még sok a bizonytalanság az uniós adattér-megvalósítást és felhasználást illetően.', 'https://index.hu/belfold/2024/06/01/egeszsegugyi-ellatas-europai-adatter-kutatas-magyar-eu-elnokseg/')
# ('', '', 'A sport felgyorsítja a felső vezetők karrierívét', 'Víziót, álmokat, bátorságot, vakmerőséget és stratégiai gondolkodásmódot ad.', 'https://index.hu/sport/alapvonal/2024/06/01/sport-essca-olimpia-parizs-2024-konferencia/')
# ('', '', 'Básti Juli Tompos Kátyáról: Igazi angyalka volt, akit mindenki szeretett', 'Kollégája szerint elementáris ereje volt a nemrég meghalt színésznőnek.', 'https://index.hu/kultur/2024/06/01/tompos-katya-gyasz-halal-basti-juli-szinhaz/')
# ('', '', 'Elbocsátották a mexikói brit nagykövetet, miután fegyvert szegezett a követség alkalmazottjára', 'A fegyver feltehetően a diplomatát kísérő biztonságiaké volt.', 'https://index.hu/kulfold/2024/06/01/egyesult-kiralysag-mexiko-nagykovet-fegyver/')
# ('', '', 'Különleges gyémántra bukkantunk a Műcsarnok kiállításán', 'Dalban mondták el.', 'https://index.hu/kultur/2024/06/01/iland-videoklip-kek-gyemant-zene-videoklip/')
# ('', '', 'Vitézy Dávid sziporkázott, Szentkirályi Alexandra jobban járt a távolmaradással', 'Nagy Attila Tibor politikai elemző értékelte az Indexnek a péntek esti vitát.', 'https://index.hu/belfold/2024/onkormanyzati_valasztas/2024/06/01/nagy-attila-tibor-politikai-elemzo-karacsony-gergely-vitezy-david-szentkiralyi-alexandra-vita-velemeny/')
# ('', '', 'Joe Biden Donald Trump elítéléséről: Senki nem áll törvények felett', 'Szerinte az esküdtek körültekintő döntést hoztak.', 'https://index.hu/kulfold/usa/feher_haz/2024/06/01/joe-biden-donald-trump-itelet-per/')
# ('Harnisch Kitti', '2024.06.01. 09:27', 'Kis híján meghalt a Reszkessetek, betörők! ikonikus színésze', 'Daniel Stern egy forgatás során került kalamajkába.', 'https://index.hu/fomo/2024/06/01/daniel-stern-reszkessetek-betorok-konyv/')

# %% [markdown]
# ## Fájlkezelés

# %%
if os.path.exists("output_index.csv"):
    os.remove("output_index.csv")

with open("output_index.csv", "a", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["author", "published", "title", "subtitle", "url"])
    writer.writerows(content)
    print("Fájl írása kész!")
# Out:
# Fájl írása kész!
